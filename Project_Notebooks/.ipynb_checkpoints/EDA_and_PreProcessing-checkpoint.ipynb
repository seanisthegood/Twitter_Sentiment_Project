# %%
# %%javascript
# /** Below because this notebook is pretty large */
# var rto = 500;
# console.log('NB: Increase require timeout to ' + rto + ' seconds');
# window.requirejs.config({waitSeconds: rto});

# %% [markdown]
# # Twitter Sentiment Analysis

# %% [markdown]
# This is a Natural Language Processing (NLP) Project to perform sentiment analysis on Tweets about various products to determine the if the sentiment was positive, negative, or neutral. A successful model would prove valueable.
#
# The challenge of Natural Language Processing is to handle how people actually write on Twitter - dealing with the many hurdles of abbreviation, misspellings, emojis, and other information in Tweets that can gum up a predictive model. A sentiment analyzer is able to

# %% [markdown]
# # Business Problem

# %% [markdown]
# "There is no such thing as bad press." The goal of this project is to work against that traditional idea. The dataset is Tweets from 2011 South by Southwest where the iPad 2 was launched by Apple. There are negative, positive, and neutral sentiment Tweets. To borrow a phrase, the goal is to find "The Haters," the critics and complainers. If in a given time those users can be reached, perhaps a savy PR team can quel a spark before it becomes a full on fire. An on the spot Sentiment Analyzer would be able to intake tweets and find which Tweets belong to the negative class.
#
# This could be employed in an ongoing fashion, or be deployed for specific events like conferences, festivals, and other events. A company launching a new product, a political candidate attempting a new messaging slogan, or a band dropping a new album could supplement the efforts of the social media manager to find negative sentiment before it spreads.

# %% [markdown]
# ## Project Metrics

# %% [markdown]
# The business problem for this project guides the metrics to that recall for negative tweets without abandoning precision of the negative tweets. For the purposes of this project positive and neutral sentiment will be grouped together, though during EDA I will examine positive and neutral sentiment to glean other insights about the language used.
#
# Trying to capture as many negative tweets as possible, without leading to false positive identification of negative tweets is important to maintaining a balanced metric so I may employ a F-Beta scorer during optimization. I will have to handle the imbalance of this dataset, happily for the stake holders a minority of the Tweets are negative, however for model training this can be a problem.

# %%
#Basic Imports
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
#sklearn imports
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn import feature_extraction, model_selection, naive_bayes, pipeline, manifold, preprocessing 
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
#Natural Language Toolkit Imports
from nltk.tokenize import regexp_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords, wordnet
from nltk import pos_tag
import nltk

# %%
#text imports
import json
import re
from bs4 import BeautifulSoup
import contractions
import num2words
import string

# %%
import sys

sys.path.insert(0, '/Users/seanyboy/Documents/Flatiron/Phase_4/Twitter_Sentiment_Project/Helper_Functions')
import functions as fn

# %% [markdown]
# ## Initial Data Exploration

# %% [markdown]
# ### Data Set`

# %%
#Problems with errors, using ignore parameter
with open('/Users/seanyboy/Documents/Flatiron/Phase_4/Twitter_Sentiment_Project/Data/judge-1377884607_tweet_product_company.csv', encoding='UTF8', errors='ignore') as f:
    data = pd.read_csv(f)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9093 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   tweet_text                                          9092 non-null   object
#  1   emotion_in_tweet_is_directed_at                     3291 non-null   object
#  2   is_there_an_emotion_directed_at_a_brand_or_product  9093 non-null   object
# dtypes: object(3)
# memory usage: 213.2+ KB

# %%
data[data['tweet_text'].isnull()]
# Out:
#   tweet_text emotion_in_tweet_is_directed_at  \
# 6  NaN        NaN
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 6  No emotion toward brand or product

# %%
#Dropping Null Tweet
data.drop(6,inplace=True)

# %%
data.sample(50)
# Out:
#                                                                                                                                                        tweet_text  \
# 2155  Standing at the top of the steps (right side coming out onto patio). Come and say, &quot;What's up, Android?&quot; #TeamAndroid #sxsw
# 1563  @mention @mention Apple is opening temp. 3rd-store at  #SXSW selling new iPad-2 to handle xtra sales  {link}
# 6152  RT @mention iPad 32 GB GIVEAWAY! Follow @mention and Retweet THIS message to be Entered. #sxswi #sxsw #samsungsxsw
# 2452  When bored during a keynote #sxsw, use your iPad to draw a picture - even if you are not a good artist!  {link} #sxswi
# 2931  *g* rt @mention  Love the Apple pop-up store at #SXSW. ... Now, one question. Will AT&amp;T bring trucks for signal again? Please say yes.
# 3897  #SXSW : Mistakes Made Building Netflix for iPhone (Plus, How to See Its Source Code!)\n\n {link}
# 1014  The Apple pop-up store line finally dwindled. Time to check out iPad2. #sxsw
# 6249  RT @mention Life Online Podcast w/ @mention @mention @mention on Android security, #SXSW, #DickBar, IE6, &amp; iPad 2 {link} #LolShow
# 3040  The dailies on iPad are going to evolve...they're still impossible to download (20 MB and up downloads) #sxsw
# 4035  #mint goal for iPhone app: top 3 finance app. #sxsw
# 5933  RT @mention Google's Marissa Mayer: &quot;The mobile phone is a cursor that connects the physical and digital worlds.&quot; #sxsw
# 1635  @mention @mention Thanks for the love! Show us your iPhone via twitpic and we'll share the love ;] #zazzlesxsw #sxsw
# 822   Google to launch social network &quot;Circles&quot; - denies launch at #sxsw though. {link} #google #circles
# 5907  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today at #sxsw rww.to/f6BCEt | O'goody more overload
# 487   Hey #sxsw exhibitors, why not capture your booth experience with a Retrollect disc? Most popular disc wins iPad 2! {link}
# 8808  Full #SXSW #touchingstories presentation:  {link}
# 586   #technews Google to launch new social network at SXSW? {link} #Tech_News #ACLU #SXSW #tech
# 5088  @mention on @mention apple iPad2 popup store @mention #sxsw is like red cross emergency tent for hipsters. Lol. &lt;3 #publicradio
# 1461  Congrats!!! RT @mention Yes! Gowalla wins best Andoid app at the Team Android Choice Awards. Thanks all! #sxsw
# 273   Surprise! Apple has opened a pop-up store in Austin so that the nerds in town for #SXSW can get their new iPads.... {link}
# 1089  @mention So @mention just spilled the beans: next platform for Flipboard is the iPhone. Team started working on it. #sxflip #SXSW #SXSWi۝ Gr8!
# 1348  And bring your laptop/iPad! RT @mention You should go to/ participate in this today; {link} #sxsw
# 5694  RT @mention Dudes! Dudes! Check it out: Tweet anything w/ 'iPad' in it &amp; naked lady response bots will tell you how they 'simply gaimed one free' #sxsw
# 6350  RT @mention New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by ... {link}
# 8604  Are you attending the #SXSW and want to explore #Austin ? Check out @mention for Austin {link} (via @mention
# 5611  RT @mention Check out the FREE @mention Sampler on iTunes! {link} #SXSW
# 1592  Score! RT@mention Google handing out free pi for pi day! #SXSW #win
# 5264  RT @mention #SXSW @mention talk - demo'ing Google Places w/ Hotpot! Integrated rating/recommendation system for Android/iPhone - cool stuff!!!
# 2099  Such a smart idea RT @mention w00t! @mention wrote about our #hollergram iPad app for #sxsw!  {link}
# 6425  RT @mention Our updated iPhone app has song info for select streams (incl. @mention 24/7) &amp; live video streaming in time for #SXSW {link}
# 8918  Jonathan with Zaggle showed us a cool free texting app for iPhone called ZMS @mention #SXSW
# 7259  Anyone know any android devs at #sxsw? let me know - there's a startup in need of help.
# 8207  If you got a view master last night, we can't wait to see your discs! Most popular wins an iPad 2! #sxsw
# 7659  Score a free imo tshirt outside the SXSW Apple store today at 2:15 PM &amp; check out imo's app for the iPad 2  {link} #sxsw #ipad2
# 6392  RT @mention Now there are 150 million mobile google maps users @mention #sxsw #science
# 5049  RT @mention .@mention imagines a future where Google asks you &quot;Why do you want to know that?&quot; when you search. #sxsw #smscifi
# 6744  RT @mention The iPad 2 is so thin, I could use it to cut lines of cocaine and then FaceTime with Mel Gibson. #Winning. #IPad2 #sxsw
# 3152  showing off an iPad 2 at #sxsw is pretty much like showing off a puppy anywhere else. gets the same fawning attention. and no, i dont ha ...
# 5870  RT @mention Google to Launch Major New Social Network Called Circles, {link} #sxsw - Brazil's orkut users have been waiting.
# 3465  @mention hello! Enjoy #Sxsw and ride anywhere in Austin for $10 . download the #GroundLink app, {link} booth 437
# 6650  RT @mention Send the waaaambulance RT @mention No, I didn't get an iPad 2 :( No, I'm not at #sxsw :( Yes, I am depressed :(
# 8722  my wife just tried to call my ATT iphone, only 2 have ATT say my number was not working. is #sxsw taking down all ATT networks nationwide?
# 3424  Hearing that google may launch a social network at an event tonight.  #sxsw
# 696   Spin Play iPad launch Party. Hanging with @mention and @mention #sxsw (@mention Cedar Street Courtyard) {link}
# 6168  RT @mention Is it bad that I just want to go home and read my Google Reader feed? #geek #sxsw
# 261   Found the app kyping my iPhone's geolocation &amp; not releasing when in background. Need a patch, @mention #batterykiller #SXSW
# 2435  I composed a tweet so acerbic and cynical about ipad users that my phone crashed and dumped all my apps. #twitterpower #sxsw #imthatgood
# 6551  RT @mention RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today @mention #SXSW {link} #privacy ?
# 5581  RT @mention Bounced over to catch Google's Marissa Mayer speak. Always admired her - intelligent, classy, successful. #sxsw
# 5835  RT @mention Google is smart positioning brand. They're not just a search engine. They're organizing world's info. Higher purpose. #savebrands #sxsw
#
#       emotion_in_tweet_is_directed_at  \
# 2155  NaN
# 1563  NaN
# 6152  NaN
# 2452  iPad
# 2931  Apple
# 3897  NaN
# 1014  iPad
# 6249  NaN
# 3040  NaN
# 4035  NaN
# 5933  NaN
# 1635  iPhone
# 822   NaN
# 5907  Google
# 487   iPad
# 8808  NaN
# 586   NaN
# 5088  NaN
# 1461  Android App
# 273   Apple
# 1089  NaN
# 1348  NaN
# 5694  NaN
# 6350  NaN
# 8604  NaN
# 5611  Other Apple product or service
# 1592  Google
# 5264  Other Google product or service
# 2099  iPad or iPhone App
# 6425  iPad or iPhone App
# 8918  iPad or iPhone App
# 7259  NaN
# 8207  NaN
# 7659  iPad or iPhone App
# 6392  Google
# 5049  NaN
# 6744  iPad
# 3152  iPad
# 5870  NaN
# 3465  NaN
# 6650  iPad
# 8722  iPhone
# 3424  NaN
# 696   NaN
# 6168  Other Google product or service
# 261   iPad or iPhone App
# 2435  iPad
# 6551  NaN
# 5581  NaN
# 5835  Google
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 2155  No emotion toward brand or product
# 1563  No emotion toward brand or product
# 6152  No emotion toward brand or product
# 2452  Positive emotion
# 2931  Positive emotion
# 3897  No emotion toward brand or product
# 1014  Positive emotion
# 6249  No emotion toward brand or product
# 3040  Negative emotion
# 4035  No emotion toward brand or product
# 5933  No emotion toward brand or product
# 1635  Positive emotion
# 822   No emotion toward brand or product
# 5907  Negative emotion
# 487   Positive emotion
# 8808  No emotion toward brand or product
# 586   No emotion toward brand or product
# 5088  No emotion toward brand or product
# 1461  Positive emotion
# 273   Positive emotion
# 1089  Positive emotion
# 1348  No emotion toward brand or product
# 5694  No emotion toward brand or product
# 6350  No emotion toward brand or product
# 8604  No emotion toward brand or product
# 5611  Positive emotion
# 1592  Positive emotion
# 5264  Positive emotion
# 2099  Positive emotion
# 6425  Positive emotion
# 8918  Positive emotion
# 7259  No emotion toward brand or product
# 8207  No emotion toward brand or product
# 7659  Positive emotion
# 6392  Positive emotion
# 5049  No emotion toward brand or product
# 6744  Positive emotion
# 3152  Positive emotion
# 5870  No emotion toward brand or product
# 3465  No emotion toward brand or product
# 6650  No emotion toward brand or product
# 8722  No emotion toward brand or product
# 3424  No emotion toward brand or product
# 696   No emotion toward brand or product
# 6168  Positive emotion
# 261   Negative emotion
# 2435  Negative emotion
# 6551  No emotion toward brand or product
# 5581  Positive emotion
# 5835  Positive emotion

# %%
data.head(50)
# Out:
#                                                                                                                                                      tweet_text  \
# 0   .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# 5   @teachntech00 New iPad Apps For #SpeechTherapy And Communication Are Showcased At The #SXSW Conference http://ht.ly/49n4M #iear #edchat #asd
# 7   #SXSW is just starting, #CTIA is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan
# 8   Beautifully smart and simple idea RT @madebymany @thenextweb wrote about our #hollergram iPad app for #sxsw! http://bit.ly/ieaVOB
# 9   Counting down the days to #sxsw plus strong Canadian dollar means stock up on Apple gear
# 10  Excited to meet the @samsungmobileus at #sxsw so I can show them my Sprint Galaxy S still running Android 2.1.   #fail
# 11  Find &amp; Start Impromptu Parties at #SXSW With @HurricaneParty http://bit.ly/gVLrIn I can't wait til the Android app comes out.
# 12  Foursquare ups the game, just in time for #SXSW http://j.mp/grN7pK) - Still prefer @Gowalla by far, best looking Android app to date.
# 13  Gotta love this #SXSW Google Calendar featuring top parties/ show cases to check out.  RT @hamsandwich via @ischafer =&gt;http://bit.ly/aXZwxB
# 14  Great #sxsw ipad app from @madebymany: http://tinyurl.com/4nqv92l
# 15  haha, awesomely rad iPad app by @madebymany http://bit.ly/hTdFim #hollergram #sxsw
# 16  Holler Gram for iPad on the iTunes App Store -  http://t.co/kfN3f5Q (via @marc_is_ken) #sxsw
# 17  I just noticed DST is coming this weekend. How many iPhone users will be an hour late at SXSW come Sunday morning? #SXSW #iPhone
# 18  Just added my #SXSW flights to @planely. Matching people on planes/airports. Also downloaded the @KLM iPhone app, nicely done.
# 19  Must have #SXSW app! RT @malbonster: Lovely review from Forbes for our SXSW iPad app Holler Gram - http://t.co/g4GZypV
# 20  Need to buy an iPad2 while I'm in Austin at #sxsw. Not sure if I'll need to Q up at an Austin Apple store?
# 21  Oh. My. God. The #SXSW app for iPad is pure, unadulterated awesome. It's easier to browse events on iPad than on the website!!!
# 22  Okay, this is really it: yay new @Foursquare for #Android app!!!!11 kthxbai. #sxsw
# 23  Photo: Just installed the #SXSW iPhone app, which is really nice! http://tumblr.com/x6t1pi6av7
# 24  Really enjoying the changes in Gowalla 3.0 for Android! Looking forward to seeing what else they &amp; Foursquare have up their sleeves at #SXSW
# 25  RT @LaurieShook: I'm looking forward to the #SMCDallas pre #SXSW party Wed., and hoping I'll win an #iPad resulting from my shameless promotion.  #ChevySMC
# 26  RT haha, awesomely rad iPad app by @madebymany http://bit.ly/hTdFim #hollergram #sxsw (via @michaelpiliero)
# 27  someone started an #austin @PartnerHub group in google groups, pre-#sxsw. great idea
# 28  The new #4sq3 looks like it is going to rock. Update for iPhone and Android should push tonight http://bit.ly/etsbZk #SXSW #KeepAustinWeird
# 29  They were right, the @gowalla 3 app on #android is sweeeeet! Nice job by the team there. #sxsw
# 30  Very smart from @madebymany #hollergram iPad app for #sxsw! http://t.co/A3xvWc6 (may leave my vuvuzela at home now)
# 31  You must have this app for your iPad if you are going to #SXSW http://itunes.apple.com/us/app/holler-gram/id420666439?mt=8 #hollergram
# 32  Attn: All  #SXSW frineds, @mention Register for #GDGTLive  and see Cobra iRadar for Android. {link}
# 33  Anyone at  #sxsw want to sell their old iPad?
# 34  Anyone at  #SXSW who bought the new iPad want to sell their older iPad to me?
# 35  At #sxsw.  Oooh. RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link}
# 36  The best!  RT @mention Ha! First in line for #ipad2 at #sxsw &quot;pop-up&quot; Apple store was an event planner #eventprofs #pcma #engage365
# 37  SPIN Play - a new concept in music discovery for your iPad from @mention &amp; spin.com {link} #iTunes #sxsw @mention
# 38  @mention  - False Alarm: Google Circles Not Coming Nowand Probably Not Ever? - {link} #Google #Circles #Social #SXSW
# 39  VatorNews - Google And Apple Force Print Media to Evolve? {link} #sxsw
# 40  @mention  - Great weather to greet you for #sxsw! Still need a sweater at night..Apple putting up &quot;flash store&quot; downtown to sell iPad2
# 41  HootSuite - HootSuite Mobile for #SXSW ~ Updates for iPhone, BlackBerry &amp; Android: Whether you۪re getting friend... {link}
# 42  Hey #SXSW - How long do you think it takes us to make an iPhone case? answer @mention using #zazzlesxsw and we۪ll make you one!
# 43  Mashable! - The iPad 2 Takes Over SXSW [VIDEO] #ipad #sxsw #gadgets {link}
# 44  For I-Pad ?RT @mention New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by ... {link}
# 45  #IPad2 's #SmartCover۪ Opens to Instant Access - I should have waited to get one! - {link} #apple #SXSW
# 46  Hand-Held Hobo۪: Drafthouse launches Hobo With a Shotgun۪ iPhone app #SXSW {link}
# 47  HOORAY RT @mention Apple Is Opening A Pop-Up Store In Austin For #SXSW | @mention {link}
# 48  Orly....? @mention Google set to launch new social network #Circles today at #sxsw۝
# 49  wooooo!!! @mention Apple store downtown Austin open til Midnight. #sxsw۝
# 50  Khoi Vinh (@mention says Conde Nast's headlong rush into iPad publishing was a &quot;fundamental misunderstanding&quot; of the platform #sxsw
#
#     emotion_in_tweet_is_directed_at  \
# 0   iPhone
# 1   iPad or iPhone App
# 2   iPad
# 3   iPad or iPhone App
# 4   Google
# 5   NaN
# 7   Android
# 8   iPad or iPhone App
# 9   Apple
# 10  Android
# 11  Android App
# 12  Android App
# 13  Other Google product or service
# 14  iPad or iPhone App
# 15  iPad or iPhone App
# 16  NaN
# 17  iPhone
# 18  iPad or iPhone App
# 19  iPad or iPhone App
# 20  iPad
# 21  iPad or iPhone App
# 22  Android App
# 23  iPad or iPhone App
# 24  Android App
# 25  iPad
# 26  iPad or iPhone App
# 27  Other Google product or service
# 28  iPad or iPhone App
# 29  Android App
# 30  iPad or iPhone App
# 31  iPad or iPhone App
# 32  NaN
# 33  NaN
# 34  NaN
# 35  NaN
# 36  iPad
# 37  NaN
# 38  Google
# 39  NaN
# 40  Apple
# 41  NaN
# 42  NaN
# 43  NaN
# 44  NaN
# 45  iPad or iPhone App
# 46  NaN
# 47  Apple
# 48  NaN
# 49  Apple
# 50  NaN
#
#    is_there_an_emotion_directed_at_a_brand_or_product
# 0   Negative emotion
# 1   Positive emotion
# 2   Positive emotion
# 3   Negative emotion
# 4   Positive emotion
# 5   No emotion toward brand or product
# 7   Positive emotion
# 8   Positive emotion
# 9   Positive emotion
# 10  Positive emotion
# 11  Positive emotion
# 12  Positive emotion
# 13  Positive emotion
# 14  Positive emotion
# 15  Positive emotion
# 16  No emotion toward brand or product
# 17  Negative emotion
# 18  Positive emotion
# 19  Positive emotion
# 20  Positive emotion
# 21  Positive emotion
# 22  Positive emotion
# 23  Positive emotion
# 24  Positive emotion
# 25  Positive emotion
# 26  Positive emotion
# 27  Positive emotion
# 28  Positive emotion
# 29  Positive emotion
# 30  Positive emotion
# 31  Positive emotion
# 32  No emotion toward brand or product
# 33  No emotion toward brand or product
# 34  No emotion toward brand or product
# 35  No emotion toward brand or product
# 36  Positive emotion
# 37  No emotion toward brand or product
# 38  Negative emotion
# 39  No emotion toward brand or product
# 40  Positive emotion
# 41  No emotion toward brand or product
# 42  No emotion toward brand or product
# 43  No emotion toward brand or product
# 44  No emotion toward brand or product
# 45  Positive emotion
# 46  Positive emotion
# 47  Positive emotion
# 48  No emotion toward brand or product
# 49  Positive emotion
# 50  No emotion toward brand or product

# %%
data.tail(50)
# Out:
#                                                                                                                                                   tweet_text  \
# 9043  Hey is anyone doing #sxsw signing up for the group texting app, groupme? got it on my iphone, but no one else is on it, so....kinda useless.
# 9044  Look everyone! Zomg @mention got an iPad 2 on the first day! #sxsw {link}
# 9045  @mention you are my favorite-- thanks for coming to @mention -- when you getting an iPhone again?? #SXSW
# 9046  you know you are on the plane to #SXSW when u become Facebook friends with your seatmate. He added me on his iPad, I added him on my laptop
# 9047  Those of you at #SXSW I need the details on Google Circle! What's it all about? @mention @mention
# 9048  @mention You bet man! Kindle and Apple for sure. You can pre-order on Amazon. You at #SXSW?
# 9049  @mention you can buy my used iPad and I'll pick one up tomorrow ;-) #sxsw
# 9050  @mention you can check out {link} for other #SXSW iPad apps too.
# 9051  @mention You can get an iPad 1 for under $350 now. And they'll be $99 before you know it. Look at iPhone. #newsapps #sxsw
# 9052  @mention You could buy a new iPad 2 tmrw at the Apple pop-up store at #sxsw: {link}
# 9053  @mention you could win a #sony Xperia play before you can buy it later today at #SXSW details here #android
# 9054  Guys, if you ever plan on attending #SXSW, you need 4 things, skinny jeans, flannel shirt, beard and an iPad #imanoutcast...
# 9055  @mention you give away that iPad yet.... ? #sxsw
# 9056  @mention you going to #Google announcement @mention #SXSW today? would love your realtime reaction to #Circles. {link}
# 9057  @mention You guys should do this &amp; give me the iPad you win :) &quot;@mention CBS, SCVNGR Launch Spy Game at SXSW - {link} #sxsw&quot;
# 9058  &quot;Do you know what Apple is really good at? Making you feel bad about your Xmas present!&quot; - Seth Meyers on iPad2 #sxsw #doyoureallyneedthat?
# 9059  @mention you know...they sell apple products at places other than #sxsw... just sayin.
# 9060  @mention you might also appreciate new iPhone app tweetcaster. Zip it feature let's you hide ANY keywords or hashtag, incl of course #sxsw :)
# 9061  @mention You realize I'm still padless? I just gave away a case at #bmm with @mention - need to win the next iPad first. #sxsw
# 9062  @mention you should find @mention or...you can go purchase the new ipad2 at the #sxsw apple kiosk
# 9063  @mention You should get the iPad 2  to save your back from lugging the laptop #SXSW #SXSWMyMistake
# 9064  @mention you should see the line here at #SXSW in front of the Apple store. Nothing like a tech geek gathering on launch day.
# 9065  Soooo do you think Apple will have a mobile store for iPad sales at #SXSW on Friday?!?! @mention @mention @mention @mention ;)
# 9066  How much you want to bet Apple is disproportionately stocking the #SXSW pop-up store with iPad 2? The influencer/hipsters thank you
# 9067  &quot;If you were able to afford to attend  #sxsw or buy an #iPad today, consider saving a few $$$ for #Japan #earthquake relief. #Justsayin&quot; #FF
# 9068  @mention you'll be at the google party tonight? Going to try and make it. too many events! #SXSWi #SXSW
# 9069  @mention You're not sure how many you ate? That IS a #drunkwalrus. Check out &quot;Gourdoughs&quot; when you're at #sxsw (Google 'em)
# 9070  You know you've made it to #sxsw when you see a bunch of grown men hooting over getting the iPad 2
# 9071  what are your essentials for #SxSW?  Mine? pocket camera, laptop, iPad, extra cords...
# 9072  @mention your iPhone 4 cases are Rad and Ready! Stop by tomorrow to get them! #Sxsw #zazzlesxsw #sxswi {link}
# 9073  At #SXSW your iphone charger is your best friend.
# 9074  At &quot;Your Mom Has an iPad: Designing for Boomers&quot; #sxsw @mention Austin Convention Center {link}
# 9075  At &quot;Your Mom Has an iPad&quot; session #yourmom #sxsw
# 9076  At &quot;Your Mom Has an iPad&quot; session at #SXSW (@mention ACC - Ballroom B w/ 23 others) {link}
# 9077  @mention your PR guy just convinced me to switch back to iPhone. Great #sxsw coverage. #princess
# 9078  Cue the hype RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 9079  &quot;papyrus...sort of like the ipad&quot; - nice! Lol! #SXSW Lavelle
# 9080  Diller says Google TV &quot;might be run over by the PlayStation and the Xbox, which are essentially ready today.&quot; #sxsw #diller
# 9081  Google says reports about launch of Circles social network at #sxsw are incorrect {link} No launch today at any rate.
# 9082  #Apple guys screaming and running by line to open the shop #austin #sxsw #ipad2 #crazyco {link}
# 9083  Google says the future is all around you! (ie, location and such): {link} #SXSW #CNN
# 9084  Google says the future is location, location, location: {link} #SXSW #CNN
# 9085  I've always used Camera+ for my iPhone b/c it has an image stabilizer mode. Suggestions for an iPad cam app w/ same feature? #SXSW #SXSWi
# 9086  Google says: want to give a lightning talk to a #H4ckers audience at #SXSW tonight? Email ben.mcgraw @mention gmail.com for a spot on stage.
# 9087  @mention Yup, but I don't have a third app yet. I'm on Android, any suggestions? #SXSW CC: @mention
# 9088  Ipad everywhere. #SXSW {link}
# 9089  Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 9090  Google's Zeiger, a physician never reported potential AE. Yet FDA relies on physicians. &quot;We're operating w/out data.&quot; #sxsw #health2dev
# 9091  Some Verizon iPhone customers complained their time fell back an hour this weekend.  Of course they were the New Yorkers who attended #SXSW.
# 9092  ϡ_ʋ΋ҋ⋁__RT @mention Google Tests Check-in Offers۝ At #SXSW {link}
#
#       emotion_in_tweet_is_directed_at  \
# 9043  NaN
# 9044  iPad
# 9045  iPhone
# 9046  NaN
# 9047  NaN
# 9048  Apple
# 9049  NaN
# 9050  NaN
# 9051  iPad
# 9052  NaN
# 9053  NaN
# 9054  NaN
# 9055  NaN
# 9056  NaN
# 9057  NaN
# 9058  NaN
# 9059  NaN
# 9060  iPad or iPhone App
# 9061  iPad
# 9062  NaN
# 9063  iPad
# 9064  Apple
# 9065  NaN
# 9066  Apple
# 9067  NaN
# 9068  NaN
# 9069  NaN
# 9070  iPad
# 9071  iPad
# 9072  iPhone
# 9073  NaN
# 9074  NaN
# 9075  NaN
# 9076  NaN
# 9077  iPhone
# 9078  NaN
# 9079  iPad
# 9080  Other Google product or service
# 9081  NaN
# 9082  NaN
# 9083  NaN
# 9084  NaN
# 9085  iPad or iPhone App
# 9086  NaN
# 9087  NaN
# 9088  iPad
# 9089  NaN
# 9090  NaN
# 9091  NaN
# 9092  NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 9043  Negative emotion
# 9044  Positive emotion
# 9045  Positive emotion
# 9046  No emotion toward brand or product
# 9047  No emotion toward brand or product
# 9048  Positive emotion
# 9049  Positive emotion
# 9050  No emotion toward brand or product
# 9051  No emotion toward brand or product
# 9052  Positive emotion
# 9053  No emotion toward brand or product
# 9054  Positive emotion
# 9055  No emotion toward brand or product
# 9056  No emotion toward brand or product
# 9057  No emotion toward brand or product
# 9058  I can't tell
# 9059  No emotion toward brand or product
# 9060  Positive emotion
# 9061  Positive emotion
# 9062  No emotion toward brand or product
# 9063  Positive emotion
# 9064  Positive emotion
# 9065  No emotion toward brand or product
# 9066  I can't tell
# 9067  No emotion toward brand or product
# 9068  No emotion toward brand or product
# 9069  No emotion toward brand or product
# 9070  Positive emotion
# 9071  Positive emotion
# 9072  Positive emotion
# 9073  No emotion toward brand or product
# 9074  No emotion toward brand or product
# 9075  No emotion toward brand or product
# 9076  No emotion toward brand or product
# 9077  Positive emotion
# 9078  No emotion toward brand or product
# 9079  Positive emotion
# 9080  Negative emotion
# 9081  No emotion toward brand or product
# 9082  No emotion toward brand or product
# 9083  No emotion toward brand or product
# 9084  No emotion toward brand or product
# 9085  Positive emotion
# 9086  No emotion toward brand or product
# 9087  No emotion toward brand or product
# 9088  Positive emotion
# 9089  No emotion toward brand or product
# 9090  No emotion toward brand or product
# 9091  No emotion toward brand or product
# 9092  No emotion toward brand or product

# %% [markdown]
# A manual look at the dataframe so the challenges that lay ahead, much of the key to modeling will be preprocessing in order to work through the model. There are some choices that will need to be made and also some general solutions.

# %% [markdown]
# ### Rename Columns

# %%
#Renaming Columns to shorter names
names = {'emotion_in_tweet_is_directed_at': 'Product',
        'is_there_an_emotion_directed_at_a_brand_or_product': 'Sentiment'}
data.rename(columns=names,
          inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9092 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  9092 non-null   object
#  1   Product     3291 non-null   object
#  2   Sentiment   9092 non-null   object
# dtypes: object(3)
# memory usage: 284.1+ KB

# %% [markdown]
# ### Target Breakdown

# %%
data['Sentiment'].value_counts(normalize=True)
# Out:
# No emotion toward brand or product    0.592609
# Positive emotion                      0.327541
# Negative emotion                      0.062692
# I can't tell                          0.017158
# Name: Sentiment, dtype: float64

# %% [markdown]
# As stated previously this is a massively imbalanced dataset, with neutral or no emotions dominating the dataset, negative tweets make up a scant 6 percent of all observations. I will adjust for this imbalance and also seek additional examples to help in the modeling process.

# %% [markdown]
# I will replace the labels with shorter strings.

# %%
data['Sentiment']=data['Sentiment'].str.replace('No emotion toward brand or product','Neutral')
data['Sentiment']=data['Sentiment'].str.replace('Positive emotion','Positive')
data['Sentiment']=data['Sentiment'].str.replace('Negative emotion','Negative')

# %%
plt.style.use('fivethirtyeight')
data['Sentiment'].value_counts(normalize=True).plot.bar()
plt.title('Tweet Sentiment Before Preprocessing')
plt.ylabel('Sentiment')
plt.xlabel('Sentiment Towards Brand')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Product Category Nulls

# %%
data[data['Product'].isna()]['Sentiment'].value_counts(normalize=True)
# Out:
# Neutral         0.913118
# Positive        0.052750
# I can't tell    0.025340
# Negative        0.008792
# Name: Sentiment, dtype: float64

# %%
np.sum(data['Product'].isna())
# Out:
# 5801

# %% [markdown]
# There are 5801 nulls in the product category, these are not neccesary for modeling but would help for overall insight, so I will attempt to label as many of the nulls as possible, but it will not affect modeling.

# %%
data[data['Sentiment']=="I can't tell"]['Product'].value_counts()
# Out:
# iPad                               4
# Apple                              2
# Google                             1
# Other Google product or service    1
# iPhone                             1
# Name: Product, dtype: int64

# %%
data[data['Sentiment']=="I can't tell"]
# Out:
#                                                                                                                                                  tweet_text  \
# 90    Thanks to @mention for publishing the news of @mention new medical Apps at the #sxswi conf. blog {link} #sxsw #sxswh
# 102   @mention &quot;Apple has opened a pop-up store in Austin so the nerds in town for #SXSW can get their new iPads. {link} #wow
# 237   Just what America needs. RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 341   The queue at the Apple Store in Austin is FOUR blocks long. Crazy stuff! #sxsw
# 368   Hope it's better than wave RT @mention Buzz is: Google's previewing a social networking platform at #SXSW: {link}
# ...                                                                                                                 ...
# 9020  It's funny watching a room full of people hold their iPad in the air to take a photo. Like a room full of tablets staring you down. #SXSW
# 9032  @mention yeah, we have @mention , Google has nothing on us :) #SXSW
# 9037  @mention Yes, the Google presentation was not exactly what I was expecting. #sxsw
# 9058  &quot;Do you know what Apple is really good at? Making you feel bad about your Xmas present!&quot; - Seth Meyers on iPad2 #sxsw #doyoureallyneedthat?
# 9066  How much you want to bet Apple is disproportionately stocking the #SXSW pop-up store with iPad 2? The influencer/hipsters thank you
#
#      Product     Sentiment
# 90    NaN     I can't tell
# 102   NaN     I can't tell
# 237   NaN     I can't tell
# 341   NaN     I can't tell
# 368   NaN     I can't tell
# ...   ...              ...
# 9020  NaN     I can't tell
# 9032  NaN     I can't tell
# 9037  NaN     I can't tell
# 9058  NaN     I can't tell
# 9066  Apple   I can't tell
#
# [156 rows x 3 columns]

# %%
len(data[data['Sentiment']=="I can't tell"])
# Out:
# 156

# %%
#Dropping Unclear Sentiment Examples
data = data[data['Sentiment']!="I can't tell"].copy()

# %%
data['Sentiment'].value_counts(normalize=True)
# Out:
# Neutral     0.602954
# Positive    0.333259
# Negative    0.063787
# Name: Sentiment, dtype: float64

# %% [markdown]
# This is still very imbalanced, but we can dig into the null values in the product category to help sort some of this out.

# %%
data[data['Product'].isna()]['Sentiment'].value_counts(normalize=True)
# Out:
# Neutral     0.936859
# Positive    0.054121
# Negative    0.009020
# Name: Sentiment, dtype: float64

# %%
plt.figure(figsize=(7,4))
data['Product'].value_counts(normalize=True).plot.barh()
plt.xticks(rotation = 83)
plt.title('Product Before Processing');
plt.xlabel('Percentage of Dataset')
plt.ylabel('Product')
# Out:
# Text(0, 0.5, 'Product')

# %% [markdown]
# Let's Dive into some tweet examples

# %% [markdown]
# ### Tweet Examples

# %%
poz_samples = data[data['Sentiment']=='Positive'].sample(n=5)

# %%
poz_samples
# Out:
#                                                                                                                                             tweet_text  \
# 7562  SXSW Interactive: Google۪s Mobile Future, &amp; Elusive Power of Here۪ - @mention @mention - #sxsw #google #mobile - {link}
# 3485  #sxsw fashion essential #2:  iPad plus 2 mobile phones for chronicling witty tweets, unlocking Mayor badges, taking photos of Hootsuite owl
# 5965  RT @mention Having fun w/ @mention new Check-In's feature on iPhone | See @mention latest article &quot;Roll your own 4square&quot; {link} #SXSW
# 8776  Bounced over to catch Google's Marissa Mayer speak. Always admired her - intelligent, classy, successful. #girlcrush #sxsw
# 1040  .@mention retiring from Wine Library TV, moving onto Daily Grape. Get the app on yr iPhone. #thankyouecon #SXSW
#
#                  Product Sentiment
# 7562  NaN                 Positive
# 3485  iPad                Positive
# 5965  NaN                 Positive
# 8776  Google              Positive
# 1040  iPad or iPhone App  Positive

# %% [markdown]
# It will be good to randomly show given examples of tweet sentiments to see if they are properly labeled.

# %%
def show_random(data,sentiment,num_tries=5,num_samps=5):
    for x in range(num_tries):
        print(f'Sampling {x} of {num_tries}')
        samples = data[data['Sentiment']==sentiment].sample(n=num_samps)
        index = list(samples.index)
        for x in index:
            print(x)
            print(samples['tweet_text'][x])
            print('-----')

# %%
show_random(data,'Positive')
# Out:
# Sampling 0 of 5
# 13
# Gotta love this #SXSW Google Calendar featuring top parties/ show cases to check out.  RT @hamsandwich via @ischafer =&gt;http://bit.ly/aXZwxB
# -----
# 24
# Really enjoying the changes in Gowalla 3.0 for Android! Looking forward to seeing what else they &amp; Foursquare have up their sleeves at #SXSW
# -----
# 8796
# Rescuing virtual robots in your daily life with your iPhone. Envisioning the day of the last tv broadcast. And that's just the morning #sxsw
# -----
# 3071
# Awesome Restaurant Week app for #iphone - {link} #austinites #sxsw
# -----
# 3250
# They are geniuses. RT @mention I may actually buy an iPad 2 tomorrow. Apple will have a temporary store in downtown Austin for #SXSW!
# -----
# Sampling 1 of 5
# 6191
# RT @mention It's our last day here at the #fastcompanygrille -- come by for the last day of iPhone makery! #zazzlesxsw #sxsw
# -----
# 597
# Check out GoogleTV to iPad Apps: The Connected TV Experience at SXSW.
# {link} #SXSW #ConnectedTV Fascinating!
# -----
# 3839
# awesome: iphones etc on at&amp;t and wifi frozen at #sxsw but  #tmobile teathering on my Android G2 works like a charm
# -----
# 5455
# RT @mention Apple Pop Up Store for #SXSW, Why not Pop Up Genius Bars - Everywhere?
# -----
# 5118
# RT @mention @mention Congrats on your iPhone app being featured at #SXSW!
# -----
# Sampling 2 of 5
# 2938
# Lol RT @mention at #sxsw: &quot;apple comes up with cool technology no one's ever heard of because they don't go to conferences&quot;
# -----
# 199
# More than 35 million miles per day are driving with Google Maps Navigation! #SXSW
# -----
# 6819
# RT @mention Trying the Steve Wozniak drink free thanks to Google #H4ckers #SXSW   @mention Speakeasy {link}
# -----
# 6676
# RT @mention Soundtrckr featured by @mention @mention as a Must-have for #SXSW {link}
# -----
# 3959
# @mention Just got my #SXSW Go iphone App! {link}
# -----
# Sampling 3 of 5
# 7638
# @mention re:new features of google maps,ex:ability to see inside amazing museums and be able to zoom to the brushstroke #SXSW #LoveHer
# -----
# 3315
# IPad design talk was great, but ran late, had to haul ass to get to Ballroom A Innovative Design through Biomimicry #sxsw
# -----
# 245
# Brilliant and enlightening game mechanics presentation by @mention from Google #SXSW
# -----
# 6632
# RT @mention RT: @mention With 150 million mobile users on Google maps, 40% of all Google Maps usage is from mobile devices. #maps #sxsw
# -----
# 1263
# I'm going to wait for the #iPad 4. you KNOW its going to be better than the iPad 2. #SXSW
# -----
# Sampling 4 of 5
# 3024
# Texas Observer Tomlinson says they would double revenue per issue with iPad subscriptions. #newsapps #sxsw
# -----
# 6131
# RT @mention In my next life I'm coming back as an iPad 2. Women can't keep their hands off this thing. #SXSW
# -----
# 5179
# RT @mention &quot;Google before you tweet&quot; is the new &quot;think before you speak.&quot; - Mark Belinsky, #911tweets panel at #SXSW.
# -----
# 1175
# Unveiling the pop-up Apple store in the Scarborough Building! #SXSW  {link}
# -----
# 3968
# Weinschenk at #bankinnovation: next battle for this is going to happen with apple, google, verizon, att. Great point. Totally agree. #sxsw
# -----

# %%
show_random(data,'Negative')
# Out:
# Sampling 0 of 5
# 4883
# There's no way that you an call the iPad count at #sxsw reasonable. I think there's one for every 2 people.
# -----
# 3623
# @mention if it makes you feel better google-wannabe fanbois were acting like giggling schoolgirls in front of Marissa Mayer y'day #SXSW
# -----
# 6265
# RT @mention Lonely Planet releases free Austin city guide iPhone app for #SXSW. Like there aren't enough apps cluttering up your handset.
# -----
# 7158
# Looking forward to delicious T-Mobile 4G here in Austin while iPhone users struggle to do anything.  #SXSW
# -----
# 6344
# RT @mention New #SXSW rule: no more ooing and ahing over your new iPad. We get it. Its not a big deal. Everybody has one now... :-)
# -----
# Sampling 1 of 5
# 354
# Trying to balance the power of power needs on iPhone vs iPad at #sxsw. This 3G iPad sucks it out quick. Might have go airplane mode.
# -----
# 1473
# SHITE APP. :( RT @mention New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponso_ (cont) {link}
# -----
# 2087
# @mention arg. It won't load on me iPhone. Not via the app store or the site. Just trying to #sxsw it and am feelin so out of touch.
# -----
# 3546
# Tomorrow I go back to the Apple store... *sigh* #sxsw
# -----
# 6023
# RT @mention Hmm... the sxsw.com/interactive/live stream isn't ipad/mobile compatible. Maybe next year. #sxsw
# -----
# Sampling 2 of 5
# 913
# Hm? Do we need another 1? RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# -----
# 2366
# It's official: people using the iPad 2 to take photos just look weird. #SXSW
# -----
# 357
# My iPhone battery can't keep up with my tweets! Thanks Apple.  #SXSW  #precommerce
# -----
# 2895
# Google seems to have sabotaged my YouTube account - WTF? Are they trying to OWN the entire online ecosystem?  VERY BAD FORM #SXSW
# -----
# 2303
# The walk by Lady Bird Lake was lovely, but Google Maps travel times are not to be trusted. #SXSW
# -----
# Sampling 3 of 5
# 3400
# #SXSW math: if my flight leaves at 6:45 AM and the clocks go ahead at 2 and my iphone alarm will not go off what time do i miss my flight?
# -----
# 4145
# Barry Diller's pragmatic and straight forward which is nice. Looks like he wants us to grab pitchforks vs. Apple #SXSW
# -----
# 3214
# Navigating a crowded party sucks. But its way worse when everyone walks around with their face in their iPhone. #sxsw #adpeopleproblems
# -----
# 939
# &quot;All of #SXSW is nothing but a teeming sea of iPhone addicts too busy Twittering to ever engage with one anoth_ (cont) {link}
# -----
# 1283
# Apple pop up store... line is ridic. #sxsw  {link}
# -----
# Sampling 4 of 5
# 5170
# RT @mention &quot;Apple: the most elegant fascist corporation in America today.&quot; -- Kara Swisher #sxsw #flipboard
# -----
# 7663
# Farmers prefer Balckberries over iPhones and Andriod devices. More durable? Anti-Apple feelings?  #mobilefarm #sxsw
# -----
# 5058
# RT @mention 'Google lost its way by caring too much for the business vs. the users' - @mention #psych #sxsw
# -----
# 4507
# Bereft wanderer. White cord, limp. Lifeless. There is no outlet for your iPhone here. #sxsw #poetry
# -----
# 2449
# Major iPad design flaw: the SXSW Go iPad app. It doesn't stay open when you switch apps! #ipaddesignheadaches #sxsw
# -----

# %% [markdown]
# I will say a glance looking at some of these tweets reveals some problem with the labeling of the sentiment. Some of the tweets that are labeled negative about a specific product are not actually targeting the product in question, but rather a situation or person.
#
# Maybe any press is bad press! So it's helpful to see the light that the products are being talked about even if it's not that product being targeted specifically.

# %%
show_random(data,'Neutral')
# Out:
# Sampling 0 of 5
# 496
# At a DSLR film discussion moderated by Guy Kawasaki, of Apple fame. Packed house! #SXSW
# -----
# 1856
# SXSW Quotables are giving away an iPad 2 today - all you need to do is sign up at {link} to be entered automatically. #sxsw
# -----
# 3494
# @mention Hmmm... thinking about borrowing an iPad from work for taking notes at #SXSW. Works well enough that I don't have to lug the MBP?
# -----
# 37
# SPIN Play - a new concept in music discovery for your iPad from @mention &amp; spin.com {link} #iTunes #sxsw @mention
# -----
# 4146
# Every outlet in this bar has an iPhone charger in it. #sxsw (@mention The Driskill Hotel Bar w/ 16 others) [pic]: {link}
# -----
# Sampling 1 of 5
# 3811
# Win free ipad 2 from webdoc.com #sxsw RT
# -----
# 5995
# RT @mention Hey #Austin, know a little about #iPhone or #Android, love music &amp; wanna make $20/hour during #SXSW?  Please let me know.
# -----
# 7690
# &quot;Clarity trumps density, tap quality trumps tap quantity_&quot; recap of @mention iPad #sxsw talk {link}
# -----
# 7704
# No. Confirmed RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# -----
# 6165
# RT @mention Is #Google launching a new social network today? #SXSW #socialmedia {link}
# -----
# Sampling 2 of 5
# 2645
# #sxsw five faces buried in iphone social apps while standing at a bar...yet having a great time.  I wouldn't believe it if I hadnt lived it.
# -----
# 1505
# like that's bad RT @mention Sitting at a bar listening to music w 3 ppl who r all nose down on iPhone. Waitress looks confused. #sxsw
# -----
# 3347
# &gt;&gt; Google Tests Check-in Offers۝ At SXSW: {link} #fb #in #SXSW
# -----
# 176
# Attending #SXSWi? Work in iPhone / iPad game development? Looking to hire an Austin-based iOS developer? I'm your man. Let's talk. #SXSW
# -----
# 7750
# @mention RT @mention Heading to  #SXSW? The @mention Austin guide for #iPhone is free for a limited time {link}
# -----
# Sampling 3 of 5
# 2823
# Just bumped into @mention here in Austin for SXSWi and Accelerater  {link}  #tech #SXSW
# -----
# 5346
# RT @mention 1 hour ago apple didn't have a store in downtown austin and now there is a store with hundreds of people there! #iPad2 #SXSW
# -----
# 5675
# RT @mention Digging John McRee's talk about designing for Boomers? Maybe you'll like this research: {link} #sxsw
# -----
# 5100
# RT @mention @mention @mention check this: {link} #SXSW #google
# -----
# 5688
# RT @mention Download 20+ free tracks from the @mention Music Sampler on @mention including @mention {link} #SXSW
# -----
# Sampling 4 of 5
# 1584
# Google's @mention envisions location-based future {link} #SXSW #location {link}
# -----
# 5618
# RT @mention Checkout the #TronLoungeSXSW to see Disney 2nd screen, FREE iPad app &amp; TronLegacy R3CONF1GUR3D Soundtrax #SXSW
# -----
# 6121
# RT @mention impulsive buy = all your friends at #SXSW -&gt; I now have one too. Selling my 1st gen 32gb 3g iPad now
# -----
# 2224
# Marissa Mayer: #Google Will Connect the Digital &amp; Physical Worlds Through Mobile {link} #SXSW #SXSWi
# -----
# 5294
# RT @mention #SXSW Google party: League of Extraordinary H4ackers promoting txt Redcross to 90999 to help Japan @mention Speakeasy {link} #photo
# -----

# %% [markdown]
# The sentiments appear to be labeled correctly, there did appear to be a neutral tweet that I would consider to be postive, it would be good to do a descriptive dive into the labeling to see what percentage of random samples are properly labeled and which are not.

# %% [markdown]
# ## Additional_Negative_Examples

# %% [markdown]
# I was able to find an additional examples from crowd flower for for additional negative examples of tweets. I will experiment with possibly using these examples as well to help with the problem of imbalanced data. This is a dataset pertaining to Apple stock price and the effect of tweets on predicting stock price movement.

# %%
new_data = pd.read_csv('/Users/seanyboy/Documents/Flatiron/Phase_4/Twitter_Sentiment_Project/Data/Apple-Twitter-Sentiment-DFE.csv',encoding='Latin1')

# %%
new_data.head(20)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0   623495513  True     golden      10                  NaN
# 1   623495514  True     golden      12                  NaN
# 2   623495515  True     golden      10                  NaN
# 3   623495516  True     golden      17                  NaN
# 4   623495517  False    finalized   3                   12/12/14 12:14
# 5   623495518  True     golden      13                  NaN
# 6   623495519  True     golden      13                  NaN
# 7   623495520  True     golden      9                   NaN
# 8   623495521  True     golden      15                  NaN
# 9   623495522  False    finalized   3                   12/12/14 0:52
# 10  623495523  True     golden      12                  NaN
# 11  623495524  True     golden      9                   NaN
# 12  623495525  True     golden      11                  NaN
# 13  623495526  False    finalized   3                   12/12/14 21:38
# 14  623495527  True     golden      17                  NaN
# 15  623495528  False    finalized   6                   12/12/14 15:50
# 16  623495529  True     golden      16                  NaN
# 17  623495530  False    finalized   3                   12/12/14 3:38
# 18  623495531  False    finalized   3                   12/12/14 4:59
# 19  623495532  False    finalized   3                   12/12/14 20:59
#
#        sentiment  sentiment:confidence                            date  \
# 0   3             0.6264                Mon Dec 01 19:30:03 +0000 2014
# 1   3             0.8129                Mon Dec 01 19:43:51 +0000 2014
# 2   3             1.0000                Mon Dec 01 19:50:28 +0000 2014
# 3   3             0.5848                Mon Dec 01 20:26:34 +0000 2014
# 4   3             0.6474                Mon Dec 01 20:29:33 +0000 2014
# 5   3             0.5975                Mon Dec 01 20:30:03 +0000 2014
# 6   5             0.8468                Mon Dec 01 20:32:45 +0000 2014
# 7   5             0.6736                Mon Dec 01 20:34:31 +0000 2014
# 8   3             0.7997                Mon Dec 01 20:36:47 +0000 2014
# 9   3             0.6360                Mon Dec 01 20:45:03 +0000 2014
# 10  1             1.0000                Mon Dec 01 20:46:01 +0000 2014
# 11  3             0.6658                Mon Dec 01 20:47:12 +0000 2014
# 12  3             0.8381                Mon Dec 01 21:00:15 +0000 2014
# 13  5             1.0000                Mon Dec 01 21:03:32 +0000 2014
# 14  1             1.0000                Mon Dec 01 21:09:50 +0000 2014
# 15  3             0.4798                Mon Dec 01 21:29:45 +0000 2014
# 16  1             0.9399                Mon Dec 01 21:35:14 +0000 2014
# 17  not_relevant  0.6904                Mon Dec 01 21:52:04 +0000 2014
# 18  3             0.6621                Mon Dec 01 21:53:12 +0000 2014
# 19  3             1.0000                Mon Dec 01 22:22:09 +0000 2014
#
#               id            query   sentiment_gold  \
# 0   5.400000e+17  #AAPL OR @Apple  3\nnot_relevant
# 1   5.400000e+17  #AAPL OR @Apple  3\n1
# 2   5.400000e+17  #AAPL OR @Apple  3
# 3   5.400000e+17  #AAPL OR @Apple  3\n1
# 4   5.400000e+17  #AAPL OR @Apple  NaN
# 5   5.400000e+17  #AAPL OR @Apple  5
# 6   5.400000e+17  #AAPL OR @Apple  5
# 7   5.400000e+17  #AAPL OR @Apple  5\n3
# 8   5.400000e+17  #AAPL OR @Apple  1
# 9   5.400000e+17  #AAPL OR @Apple  NaN
# 10  5.400000e+17  #AAPL OR @Apple  1
# 11  5.400000e+17  #AAPL OR @Apple  5
# 12  5.400000e+17  #AAPL OR @Apple  3
# 13  5.400000e+17  #AAPL OR @Apple  NaN
# 14  5.400000e+17  #AAPL OR @Apple  1
# 15  5.400000e+17  #AAPL OR @Apple  NaN
# 16  5.400000e+17  #AAPL OR @Apple  1
# 17  5.400000e+17  #AAPL OR @Apple  NaN
# 18  5.400000e+17  #AAPL OR @Apple  NaN
# 19  5.400000e+17  #AAPL OR @Apple  NaN
#
#                                                                                                                                         text
# 0   #AAPL:The 10 best Steve Jobs emails ever...http://t.co/82G1kL94tx
# 1   RT @JPDesloges: Why AAPL Stock Had a Mini-Flash Crash Today $AAPL #aapl\nhttp://t.co/hGFcjYa0E9
# 2   My cat only chews @apple cords. Such an #AppleSnob.
# 3   I agree with @jimcramer that the #IndividualInvestor should own not trade #Apple #AAPL, it's extended so today's pullback is good to see
# 4   Nobody expects the Spanish Inquisition #AAPL
# 5   #AAPL:5 Rocket Stocks to Buy for December Gains: Apple and More...http://t.co/eG5XhXdLLS
# 6   Top 3 all @Apple #tablets. Damn right! http://t.co/RJiGn2JUuB
# 7   CNBCTV: #Apple's margins better than expected? #aapl http://t.co/7geVrtOGLK
# 8   Apple Inc. Flash Crash: What You Need to Know http://t.co/YJIgtifdAj #AAPL
# 9   #AAPL:This Presentation Shows What Makes The World's Biggest Tech Companies ...http://t.co/qlH9PqSoSd
# 10  WTF MY BATTERY WAS 31% ONE SECOND AGO AND NOW IS 29% WTF IS THIS @apple
# 11  Apple Watch Tops Search Engine List of Best Wearable Tech http://t.co/LTEzJzqqF8 #AAPL #iWatch #AppleWatch
# 12  The Best-Designed #iPhone #Apps In the World, According to @apple: http://t.co/Razqvpxofg http://t.co/ev7uKWiEcz
# 13  RT @peterpham: Bought my @AugustSmartLock at the @apple store..pretty good logo match . can't wait to install it! http://t.co/z8VKMhbnR3
# 14  @apple Contact sync between Yosemite and iOS8 is seriously screwed up. It used to be much more stable in the past. #icloud #isync
# 15  #aapl @applenws Thanks to the non factual dumb Twitter followers stock drops 3 points in one minute. Thanks dummies. #rumors
# 16  WARNING IF YOU BUY AN IPHONE 5S UNLOCKED FROM @APPLE IPHONE YOU CANNOT USE IT ON VERIZON NETWORK
# 17  @Apple John Cantlie has been a prisoner of ISIS for 739 days, show you have not abandoned him. Sign https://t.co/WTn4fuiJ0P
# 18  @apple- thanks for xtra checkin at upper westside store- but why are appointments running almost 50 minutes late?
# 19  Why #AAPL Stock Had a Mini-Flash Crash Today: Money Morning: Nothing the analysts suggested would make a widel... http://t.co/jFGsSy2Ei3

# %%
#Renaming Columns to shorter names
names = {'query': 'Product',
        'sentiment': 'Sentiment','text':'tweet_text'}
new_data.rename(columns=names,
          inplace=True)

# %%
show_random(new_data,'1',5,5)
# Out:
# Sampling 0 of 5
# 1851
# This happened to me SEVERAL times!! Fuck you @Apple deleted rivals' music from iPods for years...http://t.co/QBvcBmZVOF @MailOnline
# -----
# 2469
# RT @AllisonSalz: When you request custom gift wrap from @apple ... Don't do it ... http://t.co/DoenA0e8nx
# -----
# 2760
# @Amy_Mc blame @apple and their rubbish memory on my phone
# -----
# 130
# So, on my iphone5, the @apple health kit is no longer gathering data.  Sigh.
# -----
# 2497
# Dear @apple , please find a solution to this, it happens with all of your cords: http://t.co/MsnP6PI2O9
# -----
# Sampling 1 of 5
# 2908
# Poor dudes out here gettin slandered because he wants to argue against @apple
# -----
# 1542
# RT @OneRepublic: Studio at 45,000 ft.  One outlet,  4 computers.  @Apple we need the batteries of the future NoW!!!! http://t.co/astp9x6KET
# -----
# 835
# @sethlouey @Apple iOS updates bricked Trish's phone too, seems like the Apple is getting a bit rotten
# -----
# 169
# RT @bella_bong_: @apple U need to get ur fucking shit together and let me txt while on YouTube
# -----
# 2847
# The most #innovative company (#Apple) doesn't have an official #Twitter acct. for the company http://t.co/kcf5liWWF4. @apple @AppIeOfflciaI
# -----
# Sampling 2 of 5
# 1252
# Hey @apple, fuck you for thinking I want text messages to pop up on my computer, iPad and phone.. #ThisIsWhyPeopleGetMurdered
# -----
# 1635
# RT @OneRepublic: Studio at 45,000 ft.  One outlet,  4 computers.  @Apple we need the batteries of the future NoW!!!! http://t.co/astp9x6KET
# -----
# 1068
# #iPhone6 users complain to @Apple [#Apple] about front. (#Wednesday, 3 #December) http://t.co/PiCjZ3u6us
# -----
# 14
# @apple Contact sync between Yosemite and iOS8 is seriously screwed up. It used to be much more stable in the past. #icloud #isync
# -----
# 148
# My phone is on acid right now @apple fix this
# -----
# Sampling 3 of 5
# 2851
# @apple I have been on hold for 30 minutes thank god I sold most of my stock is this comcast or apple?
# -----
# 835
# @sethlouey @Apple iOS updates bricked Trish's phone too, seems like the Apple is getting a bit rotten
# -----
# 318
# Hey @apple, how come I can't make Genius Bar appointments online anymore?
# -----
# 686
# @FaZeNikan @Apple I had the same thing. Bought an iPhone 5 when it came out and had to replace the battery after a month or two.
# -----
# 825
# @jakeflem @Apple That sucks, don't know what it cost in dollars but for us that was å£400 :(
# -----
# Sampling 4 of 5
# 717
# I've sent my computer out to @apple twice for repairs in the last month and each time it comes back with a new problem Something isn't right
# -----
# 2376
# Real tired of my charger breaking every month @Apple
# -----
# 3286
# Why can't we FaceTime more than one person at a time @apple ? I need answers dammit until then oovoo winning.
# -----
# 618
# You need to send me my IPhone before I cancel @tmobile @apple
# -----
# 3797
# Just been handed this @apple device to fix ..m.. owner doesn't fancy waiting .... #nowounder http://t.co/Op8YZAOJk0
# -----

# %%
show_random(new_data,'3',5,5)
# Out:
# Sampling 0 of 5
# 866
# RT @HamzeiAnalytics: BLOCK TRADE detected in #AAPL
# -----
# 1048
# New HA Blog Post &gt;&gt;&gt; Final #AAPL #PutCallRatios for Wednesday, December 3, 2014:  http://t.co/nHjKfKDd3s
# -----
# 744
# Apple's PT raised by JMP Securities to $150.00. outperform rating. http://t.co/omCdSCu85d $AAPL #AAPL
# -----
# 3761
# Confirmed: Bose speakers returning to #Apple Stores after removal earlier this year - http://t.co/yXPyde3TvQ #AAPL #BeatsElectronics
# -----
# 810
# APPLE - Fibonacci Technicals Levels - Intraday  Update - $AAPL #aapl
# http://t.co/Yv3QE2BGxD
# -----
# Sampling 1 of 5
# 3484
# RT @TeamCavuto: Protesters stage #DieIn protests in @Apple store in NYC... Is it me, or is this anger misplaced? RETWEET if you agree.
# -----
# 2610
# Looking down on the crazy George Street, #Sydney in the rain from the @Apple Genius Bar... http://t.co/TuBXTBvKy4
# -----
# 3777
# Jeff Daniels in Talks to Play Former Apple CEO John Sculley in Aaron Sorkin's Steve Jobs Movie [Mac Blog] http://t.co/qg1CP2ozaW #AAPL
# -----
# 219
# RT @elnuevoherald: Steve Jobs, clave en juicio contra @Apple
# http://t.co/IcEOFgkm1q http://t.co/eDiR5Mahxn
# -----
# 3115
# @scarlettsinatra @LunchGod @Naivana_ @apple simple solution http://t.co/TWSWCaXC3j
# -----
# Sampling 2 of 5
# 423
# Back from the Dead: Old iPods Drag Apple to Court http://t.co/8CqmzYqeGT #AAPL #SteveJobs
# -----
# 348
# CNBCTV:  #iPhone growth peaked? #aapl  http://t.co/iTlGPv7oaR
# -----
# 1747
# RT @OneRepublic: Studio at 45,000 ft.  One outlet,  4 computers.  @Apple we need the batteries of the future NoW!!!! http://t.co/astp9x6KET
# -----
# 904
# RT @thehill: .@Apple CEO @tim_cook visits @WhiteHouse http://t.co/O5dYvVi0I1 by @JMHattem
# -----
# 2081
# @Apple @DonorsChoose @BestBuy Help me reach my goal.
# -----
# Sampling 3 of 5
# 1287
# Steve #Wozniak on #Apple, the Computer Revolution, and Working With #SteveJobs - Businessweek #aapl http://t.co/DvUBLAZ9x4
# -----
# 3387
# RT @TeamCavuto: Protesters stage #DieIn protests in @Apple store in NYC... Is it me, or is this anger misplaced? RETWEET if you agree.
# -----
# 563
# @TheWeldingRoom @Apple @Monster @redbull You need to try the Ultra Red Monster!
# -----
# 2690
# #AAPL:Check Out The Collection Of A Guy Who Started Accumulating Classic App...http://t.co/FlMVxvl9Hw
# -----
# 766
# Is apple fairly valued at $115? #aapl #ios #AppleWatch #ApplePay #apple #iPhone6 #iPhone6Plus #stocks #finance #stocks #trading #samsung
# -----
# Sampling 4 of 5
# 45
# RT @thehill: Justice Department cites 18th century federal law to get @Apple to unlock iPhones: http://t.co/Eth0QpAIom
# -----
# 741
# RT @JPDesloges: GTAT Creditors Want to Question Apple's Jeff Williams $AAPL #aapl
# http://t.co/FlFWmJ5LkH
# -----
# 633
# #Russia is selling its banned #SteveJobs #tribute #statue | @CultofMac http://t.co/RPsHWCAr3s #Apple #AAPL #iPhone #memorial #bastards
# -----
# 3347
# RT @TeamCavuto: Protesters stage #DieIn protests in @Apple store in NYC... Is it me, or is this anger misplaced? RETWEET if you agree.
# -----
# 3059
# Apple CEO Tim Cook comes out as gay @Apple   http://t.co/euFQQpMjj6  Via @posh360_Net
# -----

# %%
show_random(new_data,'5',5,5)
# Out:
# Sampling 0 of 5
# 3607
# #apple earns more #profit in on quarter than #amazon has earned in its lifetime.
# Amazon
# @apple
# WoW Facts... http://t.co/9BPay5nh8G
# -----
# 1478
# @OneRepublic @Apple 40,000 feet keep flying :)
# -----
# 1855
# @Apple just changed the game #AppleLive
# -----
# 3525
# @SimplyYours_Joh @Tyniaaaa_ @JColeNC @Apple  yeah
# -----
# 1376
# Nice job @Apple. Would you like your kid to sit on this? http://t.co/xXrnHodYyG
# -----
# Sampling 1 of 5
# 518
# @Apple #ipad #innovation  let us maintain what we enjoyed when we were young http://t.co/Tpt3k2GBAS via @HuffPostTech http://t.co/Tpt3k2GBAS
# -----
# 2990
# Takes more than #marketing to convert shoppers to buyers. @Apple &amp; @VictoriasSecret create a total sense experience. http://t.co/5a4G6455JR
# -----
# 950
# @jakeflem @Apple good we got a new shiny macs too so we will keep this handy!
# -----
# 1297
# My new MBP is freaking awesome @apple #apple #macbookpro #lovingit
# -----
# 1092
# LUV @apple #iphone I've had pretty much all the iPhones. #3GS, #4 , #4s , #5c &amp;  #MobilePhone http://t.co/p1mlp2zlyK http://t.co/9MT4uQeXFT
# -----
# Sampling 2 of 5
# 3260
# Completely in love with my @apple #iphone6 right now. Playing with my #newphone &amp; digging into some @pappajohns. Day=Complete #pizza
# -----
# 2630
# RT @_emilymahon: @nosheenh2oo9 @Apple this is my most favorite tweet
# -----
# 1108
# @Apple runs the world..look around you
# -----
# 2567
# @zdarsky @apple Bad Eyesight is for PC and android users.
# -----
# 425
# 5 gorgeous #iPhone #apps with surprising designs and amazing visuals | BGR #aapl http://t.co/6UkoSYokMn
# -----
# Sampling 3 of 5
# 2095
# So cool! @Apple stores will host free 'Hour of Code' workshops on Dec. 11 to promote computer science: http://t.co/HrOHssVtK1 #tech
# -----
# 3428
# RT @TeamCavuto: Protesters stage #DieIn protests in @Apple store in NYC... Is it me, or is this anger misplaced? RETWEET if you agree.
# -----
# 2901
# Do not disturb setting so nice THX @apple
# -----
# 1280
# How an SVN connection led to safer conditions for @apple's workforce http://t.co/c36k5fVoHQ @GreenAmerica @GlobalLabor1
# -----
# 1571
# @OneRepublic @Apple I WANNA HUG THEM SO MUCH
# -----
# Sampling 4 of 5
# 3878
# RT @shannonmmiller: Love the @Apple is supporting #HourOfCode with workshops! :) http://t.co/WP8D0FNjNu
# -----
# 3483
# Congrats @Apple I mean he wasn't using @googlehangouts_, right? #Apple #Google http://t.co/A3kHN5Hzk8
# -----
# 3049
# It makes you smarter.  Elevate is @apple app of the year!  Congratulations @jessepickard and team.  http://t.co/r0cgmthoCC
# -----
# 1650
# @OneRepublic @Apple #AppleAddict ! The show in Paris was Amazing !!!! Thank you guys !!!! See you soon !
# -----
# 2435
# $aapl @Apple survive the 2014 Holiday? Investors Say Yes.  http://t.co/RanqKt2Q9n'#roc #NYC #California #SanFrancisco #tech #christmas2014
# -----

# %% [markdown]
# Similary this dataset is grouped with numeric sentiments. '1' labels are negative, '3' is neutral with some subjective disagreement, and '5' is positive. These tweets are from a dataset trying to find sentiment regarding Apple stock price, I will use the negative tweets to potentially augment the lack of negative examples in the dataset.

# %%
neg_df = new_data[new_data['Sentiment']=='1'].copy()

# %%
neg_df=neg_df[['Product','Sentiment','tweet_text']].copy()

# %%
neg_df.columns
# Out:
# Index(['Product', 'Sentiment', 'tweet_text'], dtype='object')

# %%
data.columns
# Out:
# Index(['tweet_text', 'Product', 'Sentiment'], dtype='object')

# %%
neg_df['Sentiment']=neg_df['Sentiment'].str.replace('1','Negative')

# %%
neg_df['Product']=neg_df['Product'].str.replace('#AAPL OR @Apple','Apple')

# %%
neg_df.head(5)
# Out:
#    Product Sentiment  \
# 10  Apple   Negative
# 14  Apple   Negative
# 16  Apple   Negative
# 23  Apple   Negative
# 24  Apple   Negative
#
#                                                                                                                                       tweet_text
# 10  WTF MY BATTERY WAS 31% ONE SECOND AGO AND NOW IS 29% WTF IS THIS @apple
# 14  @apple Contact sync between Yosemite and iOS8 is seriously screwed up. It used to be much more stable in the past. #icloud #isync
# 16  WARNING IF YOU BUY AN IPHONE 5S UNLOCKED FROM @APPLE IPHONE YOU CANNOT USE IT ON VERIZON NETWORK
# 23  @Apple, For the love of GAWD, CENTER the '1'on the damn calendar app. You fixed it once, its back, off center, AGAIN! http://t.co/dMyAHEm1Lc
# 24  i get the storage almost full notification literally every 5 minutes chill @apple

# %%
new_data = pd.concat([data,neg_df]).reset_index()

# %%
new_data.drop('index',axis=1,inplace=True)

# %%
new_data['Sentiment'].value_counts(normalize=True)
# Out:
# Neutral     0.530576
# Positive    0.293255
# Negative    0.176169
# Name: Sentiment, dtype: float64

# %%
new_data.to_csv('additional_negs',index=False)

# %% [markdown]
# I've created a new dataframe that adds substantially more negative examples, it is at the sacrifice of having data from the original data source, the benefits of a model that can better understand negative examples will be beneficial

# %% [markdown]
# We will be able to use the same transformers on this new dataset for modeling, it may potentially offer better scores.

# %% [markdown]
# ### Sentiment by Product

# %%
data.groupby('Product')['Sentiment'].value_counts(normalize=True, sort=False).unstack(1).sort_index(axis=1, ascending=True).plot.barh(stacked=True)
plt.title('Sentiment by Product')
# Out:
# Text(0.5, 1.0, 'Sentiment by Product')

# %% [markdown]
# A look at a groupby with normalized value counts for the sentiment anlysis of the dataset shows bit of a surprise (to me at least) that iPhone has the highest negative emotion and lowest positive emotion. It is important to remember there are many more examples of iPhones in the Dataset, so it may be valueable to run a statistical test for understanding the validity here, but it is still noteworthy.

# %%
#Remove this character in particular
data['tweet_text']=data['tweet_text'].str.replace('۝','')

# %%
data.groupby('Product').Sentiment.value_counts(normalize=True).unstack(1).plot.barh(figsize=(8,6))
plt.title('Sentiment by PRoduct')
# Out:
# Text(0.5, 1.0, 'Sentiment by PRoduct')

# %%
data['Product']
# Out:
# 0       iPhone
# 1       iPad or iPhone App
# 2       iPad
# 3       iPad or iPhone App
# 4       Google
#          ...
# 9088    iPad
# 9089    NaN
# 9090    NaN
# 9091    NaN
# 9092    NaN
# Name: Product, Length: 8936, dtype: object

# %%
data['Sentiment'].value_counts(normalize=True).plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Overwhelming the dataset's targets show a neutral sentiment towards the products they are talking about. It will be worth taking an eyeball look at what constitutes the sentiment, but it terms of model metrics we have a dataset that shows way more positive cases than negative cases - an unbalanced dataset which will have to be accounted for in the modeling process.

# %% [markdown]
# ## Product Column Work

# %% [markdown]
# ### Null Values in Product Column

# %%
np.sum(data.isna())
# Out:
# tweet_text    0
# Product       0
# Sentiment     0
# dtype: int64

# %% [markdown]
# The dataset unfortuneatly features many null values in the product column. This is unfortunate as it makes up over half the dataset.

# %%
data[data['Product'].isna()]['Sentiment'].value_counts(normalize=True)
# Out:
# Series([], Name: Sentiment, dtype: float64)

# %%
data['Sentiment'].value_counts(normalize=True)
# Out:
# Neutral     0.539593
# Positive    0.385500
# Negative    0.074906
# Name: Sentiment, dtype: float64

# %%
counts = data['Product'].value_counts(dropna=False)
product_words = data[data['Product'].map(counts)>35]['Product'].value_counts().index.tolist()

# %%
product_words
lower_product = [w.lower() for w in product_words]
product_words.extend(lower_product)

# %%
product_words
# Out:
# ['iPad',
#  'Google',
#  'Apple',
#  'iPhone',
#  'iPad or iPhone App',
#  'Android',
#  'Other Google product or service',
#  'google',
#  'apple',
#  'ipad',
#  'ipad',
#  'google',
#  'apple',
#  'iphone',
#  'ipad or iphone app',
#  'android',
#  'other google product or service',
#  'google',
#  'apple',
#  'ipad']

# %% [markdown]
# Looking at the sentiment of the Products that we have values for versus the column without values shows a very different picture. I could impute the products for the Product column and attempt to create a more observations for training.

# %% [markdown]
# ### Mask to See Null Values in Product Column

# %%
na_mask = data.loc[:,'Product'].isna().copy()

# %%
display(len(data),len(data[na_mask]))
# Out:
# 7476
# 0

# %% [markdown]
# There are 5654 observations in this data set where the Product column is null. Of those 1297 contain iPad, 1020 Apple, 0 contain Ipad or iPhone App, 1463 contain Google, and 784 contain iPhone. Android or Android app is contained in 294 and 13 observations respectively.

# %%
data
# Out:
#                                                                                                                                              tweet_text  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1     @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2     @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3     @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# ...                                                                                                                                   ...
# 7471  Ipad everywhere. #SXSW {link}
# 7472  Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7473  Google's Zeiger, a physician never reported potential AE. Yet FDA relies on physicians. &quot;We're operating w/out data.&quot; #sxsw #health2dev
# 7474  Some Verizon iPhone customers complained their time fell back an hour this weekend.  Of course they were the New Yorkers who attended #SXSW.
# 7475  ϡ_ʋ΋ҋ⋁__RT @mention Google Tests Check-in Offers At #SXSW {link}
#
#                  Product Sentiment
# 0     iPhone              Negative
# 1     iPad or iPhone App  Positive
# 2     iPad                Positive
# 3     iPad or iPhone App  Negative
# 4     Google              Positive
# ...      ...                   ...
# 7471  iPad                Positive
# 7472  google              Neutral
# 7473  Google              Neutral
# 7474  iPhone              Neutral
# 7475  Google              Neutral
#
# [7476 rows x 3 columns]

# %%
#Creating a copy of the null product values to alter
Null_df=data.loc[na_mask].copy()

# %%
#Null Dataframe
Null_df
# Out:
# Empty DataFrame
# Columns: [tweet_text, Product, Sentiment]
# Index: []

# %%
#
Null_df['new_col'] = (Null_df['tweet_text'].str.findall(f"({'|'.join(product_words)})").str.join(', ').replace('', np.nan))

# %%
Null_df['new_col'].value_counts()
# Out:
# Series([], Name: new_col, dtype: int64)

# %%
Null_df['Product']=Null_df['new_col']
Null_df.drop('new_col',axis=1,inplace=True)

# %%
data.loc[na_mask,'Product']=Null_df.loc[:,'Product'].copy()

# %%
np.sum(data['Product'].isna())
# Out:
# 0

# %%
np.sum(data.isna())
# Out:
# tweet_text    0
# Product       0
# Sentiment     0
# dtype: int64

# %%
np.sum(data.isna())/len(data)
# Out:
# tweet_text    0.0
# Product       0.0
# Sentiment     0.0
# dtype: float64

# %%
data.Sentiment.value_counts(normalize=True)
# Out:
# Neutral     0.539593
# Positive    0.385500
# Negative    0.074906
# Name: Sentiment, dtype: float64

# %%
np.sum(data.isna())
# Out:
# tweet_text    0
# Product       0
# Sentiment     0
# dtype: int64

# %% [markdown]
# We now have greatly decreased the number of null values in the product column, but we have also increased increased the number of different products.

# %%
data['Product'].value_counts()
# Out:
# iPad                               2054
# Google                             1759
# Apple                              1210
# iPhone                             888
# iPad or iPhone App                 470
# Android                            312
# Other Google product or service    292
# google                             259
# apple                              116
# ipad                               116
# Name: Product, dtype: int64

# %% [markdown]
# Some of these are rendundent products in the the row. I can reduce these my deleting the second product.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7476 entries, 0 to 7475
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  7476 non-null   object
#  1   Product     7476 non-null   object
#  2   Sentiment   7476 non-null   object
# dtypes: object(3)
# memory usage: 175.3+ KB

# %%
data['Product']
# Out:
# 0       iPhone
# 1       iPad or iPhone App
# 2       iPad
# 3       iPad or iPhone App
# 4       Google
#          ...
# 7471    iPad
# 7472    google
# 7473    Google
# 7474    iPhone
# 7475    Google
# Name: Product, Length: 7476, dtype: object

# %%
product_words
# Out:
# ['iPad',
#  'Google',
#  'Apple',
#  'iPhone',
#  'iPad or iPhone App',
#  'Android',
#  'Other Google product or service',
#  'google',
#  'apple',
#  'ipad',
#  'ipad',
#  'google',
#  'apple',
#  'iphone',
#  'ipad or iphone app',
#  'android',
#  'other google product or service',
#  'google',
#  'apple',
#  'ipad']

# %%
data
# Out:
#                                                                                                                                              tweet_text  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1     @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2     @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3     @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# ...                                                                                                                                   ...
# 7471  Ipad everywhere. #SXSW {link}
# 7472  Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7473  Google's Zeiger, a physician never reported potential AE. Yet FDA relies on physicians. &quot;We're operating w/out data.&quot; #sxsw #health2dev
# 7474  Some Verizon iPhone customers complained their time fell back an hour this weekend.  Of course they were the New Yorkers who attended #SXSW.
# 7475  ϡ_ʋ΋ҋ⋁__RT @mention Google Tests Check-in Offers At #SXSW {link}
#
#                  Product Sentiment
# 0     iPhone              Negative
# 1     iPad or iPhone App  Positive
# 2     iPad                Positive
# 3     iPad or iPhone App  Negative
# 4     Google              Positive
# ...      ...                   ...
# 7471  iPad                Positive
# 7472  google              Neutral
# 7473  Google              Neutral
# 7474  iPhone              Neutral
# 7475  Google              Neutral
#
# [7476 rows x 3 columns]

# %%
not_na_mask = data.loc[:,'Product'].notna().copy()

# %%
data.loc[not_na_mask,'Product']
# Out:
# 0       iPhone
# 1       iPad or iPhone App
# 2       iPad
# 3       iPad or iPhone App
# 4       Google
#          ...
# 7471    iPad
# 7472    google
# 7473    Google
# 7474    iPhone
# 7475    Google
# Name: Product, Length: 7476, dtype: object

# %%
reduced_series = data.loc[not_na_mask,'Product'].map(lambda x: set(x.split(', ')))

# %%
reduced_series[100:150]
# Out:
# 100    {iPad}
# 101    {iPad}
# 102    {iPad}
# 103    {Google}
# 104    {Google}
# 105    {Google}
# 106    {Apple}
# 107    {Apple}
# 108    {iPhone}
# 109    {Apple}
# 110    {Google}
# 111    {iPhone}
# 112    {Apple}
# 113    {iPad or iPhone App}
# 114    {Apple}
# 115    {Apple}
# 116    {iPad or iPhone App}
# 117    {iPad}
# 118    {Apple}
# 119    {Apple}
# 120    {iPad}
# 121    {iPad}
# 122    {iPad}
# 123    {google}
# 124    {iPhone}
# 125    {iPad}
# 126    {iPhone}
# 127    {google}
# 128    {Google}
# 129    {iPad}
# 130    {Other Google product or service}
# 131    {Google}
# 132    {iPad}
# 133    {iPad}
# 134    {Google}
# 135    {iPad or iPhone App}
# 136    {iPad or iPhone App}
# 137    {iPad}
# 138    {Apple}
# 139    {iPad}
# 140    {Android}
# 141    {Google}
# 142    {Google}
# 143    {iPad}
# 144    {Google}
# 145    {iPhone}
# 146    {iPad}
# 147    {Google}
# 148    {Apple}
# 149    {iPad}
# Name: Product, dtype: object

# %%
' '.join({'iPad', 'iPhone'})
# Out:
# 'iPad iPhone'

# %%
data.loc[not_na_mask,'Product']=reduced_series

# %%
joined_series = data.loc[not_na_mask,'Product'].map(lambda x: ' '.join(x))

# %%
joined_series
# Out:
# 0       iPhone
# 1       iPad or iPhone App
# 2       iPad
# 3       iPad or iPhone App
# 4       Google
#          ...
# 7471    iPad
# 7472    google
# 7473    Google
# 7474    iPhone
# 7475    Google
# Name: Product, Length: 7476, dtype: object

# %%
data.loc[not_na_mask,'Product']=joined_series

# %% [markdown]
# ### Reducing Product Value Counts

# %%
data
# Out:
#                                                                                                                                              tweet_text  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1     @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2     @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3     @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# ...                                                                                                                                   ...
# 7471  Ipad everywhere. #SXSW {link}
# 7472  Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7473  Google's Zeiger, a physician never reported potential AE. Yet FDA relies on physicians. &quot;We're operating w/out data.&quot; #sxsw #health2dev
# 7474  Some Verizon iPhone customers complained their time fell back an hour this weekend.  Of course they were the New Yorkers who attended #SXSW.
# 7475  ϡ_ʋ΋ҋ⋁__RT @mention Google Tests Check-in Offers At #SXSW {link}
#
#                  Product Sentiment
# 0     iPhone              Negative
# 1     iPad or iPhone App  Positive
# 2     iPad                Positive
# 3     iPad or iPhone App  Negative
# 4     Google              Positive
# ...      ...                   ...
# 7471  iPad                Positive
# 7472  google              Neutral
# 7473  Google              Neutral
# 7474  iPhone              Neutral
# 7475  Google              Neutral
#
# [7476 rows x 3 columns]

# %%
data['Product'].value_counts()
# Out:
# iPad                               2054
# Google                             1759
# Apple                              1210
# iPhone                             888
# iPad or iPhone App                 470
# Android                            312
# Other Google product or service    292
# google                             259
# apple                              116
# ipad                               116
# Name: Product, dtype: int64

# %%
data['Product'].value_counts(normalize=True)
# Out:
# iPad                               0.274746
# Google                             0.235286
# Apple                              0.161851
# iPhone                             0.118780
# iPad or iPhone App                 0.062868
# Android                            0.041734
# Other Google product or service    0.039058
# google                             0.034644
# apple                              0.015516
# ipad                               0.015516
# Name: Product, dtype: float64

# %% [markdown]
# This has reduced string repetition greatly, but there are still cases where there are multiple products or a company's product that is a problem in the dataset. I have put effort into salvaging observations in the dataset that could've been labeled with actual products into set of being set to Nan as they were before. Looking at the value counts I can set a threshold of 1% and save a lion share of data without having to spend more time on preprocessing.

# %% [markdown]
# First iPad has its own large percentage of observations, so the "iPad Apple" values can be encoded as "iPad"

# %%
#Using .loc to change 'iPad Apple' to 'iPad'
data.loc[data['Product']=='iPad Apple','Product']='iPad'

# %%
data['Product'].value_counts(normalize=True)
# Out:
# iPad                               0.274746
# Google                             0.235286
# Apple                              0.161851
# iPhone                             0.118780
# iPad or iPhone App                 0.062868
# Android                            0.041734
# Other Google product or service    0.039058
# google                             0.034644
# apple                              0.015516
# ipad                               0.015516
# Name: Product, dtype: float64

# %%
data.loc[data['Product']=='Android App','Product']='Android'

# %%
display(
data['Product'].value_counts(normalize=True),
data['Product'].value_counts())
# Out:
# iPad                               0.274746
# Google                             0.235286
# Apple                              0.161851
# iPhone                             0.118780
# iPad or iPhone App                 0.062868
# Android                            0.041734
# Other Google product or service    0.039058
# google                             0.034644
# apple                              0.015516
# ipad                               0.015516
# Name: Product, dtype: float64
# iPad                               2054
# Google                             1759
# Apple                              1210
# iPhone                             888
# iPad or iPhone App                 470
# Android                            312
# Other Google product or service    292
# google                             259
# apple                              116
# ipad                               116
# Name: Product, dtype: int64

# %%
counts
# Out:
# iPad                               2054
# Google                             1759
# Apple                              1210
# iPhone                             888
# iPad or iPhone App                 470
# Android                            312
# Other Google product or service    292
# google                             259
# apple                              116
# ipad                               116
# Name: Product, dtype: int64

# %%
counts = data['Product'].value_counts()
data = data[~data['Product'].isin(counts[counts < 85].index)]

# %%
data['Product'].value_counts()
# Out:
# iPad                               2054
# Google                             1759
# Apple                              1210
# iPhone                             888
# iPad or iPhone App                 470
# Android                            312
# Other Google product or service    292
# google                             259
# apple                              116
# ipad                               116
# Name: Product, dtype: int64

# %% [markdown]
# ### Reduced Data Set

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7476 entries, 0 to 7475
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_text  7476 non-null   object
#  1   Product     7476 non-null   object
#  2   Sentiment   7476 non-null   object
# dtypes: object(3)
# memory usage: 233.6+ KB

# %% [markdown]
# This reduced dataset is 8699, down from the initial 9093. There is still the issue of unlabeled emotions as many tweets do not have an emotion attatched, this is especially true for the salvaged product names.

# %%
data['Product'].value_counts(normalize=True)
# Out:
# iPad                               0.274746
# Google                             0.235286
# Apple                              0.161851
# iPhone                             0.118780
# iPad or iPhone App                 0.062868
# Android                            0.041734
# Other Google product or service    0.039058
# google                             0.034644
# apple                              0.015516
# ipad                               0.015516
# Name: Product, dtype: float64

# %%
data.groupby('Product')['Sentiment'].value_counts(normalize=True, sort=False)
# Out:
# Product                          Sentiment
# Android                          Negative     0.054487
#                                  Neutral      0.474359
#                                  Positive     0.471154
# Apple                            Negative     0.081818
#                                  Neutral      0.450413
#                                  Positive     0.467769
# Google                           Negative     0.047754
#                                  Neutral      0.711200
#                                  Positive     0.241046
# Other Google product or service  Negative     0.160959
#                                  Neutral      0.030822
#                                  Positive     0.808219
# apple                            Neutral      0.982759
#                                  Positive     0.017241
# google                           Negative     0.007722
#                                  Neutral      0.949807
#                                  Positive     0.042471
# iPad                             Negative     0.067186
#                                  Neutral      0.512171
#                                  Positive     0.420643
# iPad or iPhone App               Negative     0.134043
#                                  Neutral      0.021277
#                                  Positive     0.844681
# iPhone                           Negative     0.123874
#                                  Neutral      0.621622
#                                  Positive     0.254505
# ipad                             Neutral      0.922414
#                                  Positive     0.077586
# Name: Sentiment, dtype: float64

# %%
data.groupby('Product').Sentiment.value_counts(normalize=True).unstack(1).plot.barh(figsize=(8,6))
# Out:
# <AxesSubplot:ylabel='Product'>

# %%
data=data.copy()

# %%
data['Product'].fillna('Unknown',inplace=True)

# %%
data
# Out:
#                                                                                                                                              tweet_text  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1     @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2     @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3     @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# ...                                                                                                                                   ...
# 7471  Ipad everywhere. #SXSW {link}
# 7472  Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7473  Google's Zeiger, a physician never reported potential AE. Yet FDA relies on physicians. &quot;We're operating w/out data.&quot; #sxsw #health2dev
# 7474  Some Verizon iPhone customers complained their time fell back an hour this weekend.  Of course they were the New Yorkers who attended #SXSW.
# 7475  ϡ_ʋ΋ҋ⋁__RT @mention Google Tests Check-in Offers At #SXSW {link}
#
#                  Product Sentiment
# 0     iPhone              Negative
# 1     iPad or iPhone App  Positive
# 2     iPad                Positive
# 3     iPad or iPhone App  Negative
# 4     Google              Positive
# ...      ...                   ...
# 7471  iPad                Positive
# 7472  google              Neutral
# 7473  Google              Neutral
# 7474  iPhone              Neutral
# 7475  Google              Neutral
#
# [7476 rows x 3 columns]

# %%
data[data['Product']=='Unknown'].sample()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [313], in <cell line: 1>()
# ----> 1 data[data['Product']=='Unknown'].sample()
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py:4993, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis)
#    4988 if n < 0:
#    4989     raise ValueError(
#    4990         "A negative number of rows requested. Please provide positive value."
#    4991     )
# -> 4993 locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4994 return self.take(locs, axis=axis)
#
# File mtrand.pyx:909, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
data['Product'].value_counts()

# %%
data = data[data['Product']!='Unknown'].copy()

# %% [markdown]
# ### Duplicates

# %%
data[data.duplicated(subset='tweet_text',keep='first')]
# Out:
#                                                                                                                                             tweet_text  \
# 378   Before It Even Begins, Apple Wins #SXSW {link}
# 641   Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 651   Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 652   Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw @mention
# 1765  @mention at #sxsw: &quot;apple comes up with cool technology no one's ever heard of because they don't go to conferences&quot;
# 1856  Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 2121  Counting down the days to #sxsw plus strong Canadian dollar means stock up on Apple gear
# 3140  Win free ipad 2 from webdoc.com #sxsw RT
# 3141  Win free iPad 2 from webdoc.com #sxsw RT
# 3253  Really enjoying the changes in Gowalla 3.0 for Android! Looking forward to seeing what else they &amp; Foursquare have up their sleeves at #SXSW
# 3263  #SXSW is just starting, #CTIA is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan
# 4059  Oh. My. God. The #SXSW app for iPad is pure, unadulterated awesome. It's easier to browse events on iPad than on the website!!!
# 4836  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 4838  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 4839  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #SXSW
# 4840  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 4841  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #SXSW
# 4842  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 4853  RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 5184  RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 5185  RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #SXSW
# 5186  RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 5187  RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #SXSW
# 5188  RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 5189  RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #SXSW
# 5190  RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 5388  RT @mention RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 5390  RT @mention RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 5419  RT @mention RT @mention It's not a rumor: Apple is opening up a temporary store in downtown Austin for #SXSW and the iPad 2 launch {link}
# 6970  I just noticed DST is coming this weekend. How many iPhone users will be an hour late at SXSW come Sunday morning? #SXSW #iPhone
# 6975  Google Latina and see what you find? Porn...this is the first impression that people get about us? #latism #sxsw #sxswLatAm #LatinasInTech
# 7185  Need to buy an iPad2 while I'm in Austin at #sxsw. Not sure if I'll need to Q up at an Austin Apple store?
#
#                  Product Sentiment
# 378   Apple               Positive
# 641   Google              Neutral
# 651   Google              Neutral
# 652   Google              Neutral
# 1765  Apple               Positive
# 1856  Google              Neutral
# 2121  Apple               Positive
# 3140  iPad                Positive
# 3141  iPad                Positive
# 3253  Android             Positive
# 3263  Android             Positive
# 4059  iPad or iPhone App  Positive
# 4836  Google              Neutral
# 4838  Google              Neutral
# 4839  Google              Neutral
# 4840  Google              Neutral
# 4841  Google              Neutral
# 4842  Google              Neutral
# 4853  Google              Neutral
# 5184  Google              Neutral
# 5185  Google              Neutral
# 5186  Google              Positive
# 5187  Google              Neutral
# 5188  Google              Positive
# 5189  Google              Neutral
# 5190  Google              Neutral
# 5388  Google              Neutral
# 5390  Google              Neutral
# 5419  iPad                Neutral
# 6970  iPhone              Negative
# 6975  Google              Neutral
# 7185  iPad                Positive

# %% [markdown]
# ### Check Point - Product Column Processed

# %%
data.to_csv('/Users/seanyboy/Documents/Flatiron/Phase_4/Twitter_Sentiment_Project/Data/product_processed.csv',index=False)

# %%
# data = pd.read_csv('product_processed.csv')

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive

# %%
fn.Process_Tweet
# Out:
# <function functions.Process_Tweet(text, remove_HTML=False, replace_moji_bake=False, remove_mentions=False, remove_hashtags=False, contraction_fix=False, strip_links=False, no_leading=False, lower=False, remove_numerals=False)>

# %%
import sys, importlib

# %%
importlib.reload(fn)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/seanyboy/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# <module 'functions' from '/Users/seanyboy/Documents/Flatiron/Phase_4/Twitter_Sentiment_Project/Helper_Functions/functions.py'>

# %%
data.columns
# Out:
# Index(['tweet_text', 'Product', 'Sentiment'], dtype='object')

# %%
np.sum(data[data['Product']=='Unknown']['tweet_text'].str.contains('free'))
# Out:
# 0

# %%
for w in product_words:
    print(w,np.sum(data[data['Product']=='Unknown']['tweet_text'].str.contains(w)))
# Out:
# iPad 0
# Google 0
# Apple 0
# iPhone 0
# iPad or iPhone App 0
# Android 0
# Other Google product or service 0
# google 0
# apple 0
# ipad 0
# ipad 0
# google 0
# apple 0
# iphone 0
# ipad or iphone app 0
# android 0
# other google product or service 0
# google 0
# apple 0
# ipad 0

# %%
data['Sentiment'].value_counts(normalize=True)
# Out:
# Neutral     0.539593
# Positive    0.385500
# Negative    0.074906
# Name: Sentiment, dtype: float64

# %%
data[data['Product']!='Unknown']['Sentiment'].value_counts(normalize=True)
# Out:
# Neutral     0.539593
# Positive    0.385500
# Negative    0.074906
# Name: Sentiment, dtype: float64

# %%
data['Product'].value_counts(normalize=True)
# Out:
# iPad                               0.274746
# Google                             0.235286
# Apple                              0.161851
# iPhone                             0.118780
# iPad or iPhone App                 0.062868
# Android                            0.041734
# Other Google product or service    0.039058
# google                             0.034644
# apple                              0.015516
# ipad                               0.015516
# Name: Product, dtype: float64

# %% [markdown]
# I will be dropping the tweets from the dataset that are "Unknown" in the product column after the preprocessing work that I have done. These tweets are neutral in sentiment AND they are not related to any relevant products, they will merely be muddy. In a real world scenario, we would filter out these irelevent tweets in pursuit of the cases we actually care about.

# %%
plt.style.use('fivethirtyeight')
data['Sentiment'].value_counts(normalize=True).plot.bar()
plt.title('Tweet Sentiment After Processing')
plt.ylabel('Sentiment')
plt.xlabel('Sentiment Towards Brand')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## Text Processing

# %% [markdown]
# Processing the text for modeling will the be great challenge of this task as there are multiple decision points that will affect the modeling process. Some of these I will consider hard preprocessing - aboslutely neccesary as part of data cleaning and some steps are optional and will be chosen as to how they affect scoring of the model.

# %% [markdown]
# ### Removing HTML characters

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive

# %%
data['Remove_HTML']=fn.Process_Tweet(data['tweet_text'],remove_HTML=True,replace_moji_bake=True)
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)

# %% [markdown]
# Below is an example of this function in action. It removes the HTML that were poorly translated in the dataframe, especially text like '&amp' that appear throughout the dataset.

# %%
data.loc[6133,'tweet_text':'Remove_HTML']
# Out:
# tweet_text     The bad apple shows up late shoots down ideas and leaves early - meeting personality #2 #gamestorming #sxsw
# Product        apple
# Sentiment      Neutral
# Remove_HTML    The bad apple shows up late shoots down ideas and leaves early - meeting personality #2 #gamestorming #sxsw
# Name: 6133, dtype: object

# %%
np.sum(data['tweet_text'].str.contains('amp;'))
# Out:
# 570

# %%
np.sum(data['Remove_HTML'].str.contains('amp;'))
# Out:
# 0

# %%
np.sum(data['tweet_text'].str.contains('&quot;'))
# Out:
# 690

# %%
np.sum(data['Remove_HTML'].str.contains('&quot;'))
# Out:
# 0

# %%
np.sum(data['tweet_text'].str.contains('۝'))
# Out:
# 0

# %%
np.sum(data['Remove_HTML'].str.contains('۝'))
# Out:
# 0

# %% [markdown]
# Function successfully removed instances of HTML 'amp;' and '&quot;' from the dataset. That's progress for sure as these characters will not be helpful.

# %% [markdown]
# ### Stripping Mentions From Tweets

# %%
data['no_mentions']=fn.Process_Tweet(data['Remove_HTML'],remove_mentions=True)

# %%
data['mentions']=data['Remove_HTML'].str.findall(r'[@]\w+')

# %%
data['mentions'] = data['mentions'].map(lambda x: ' '.join(x))

# %%
data['mentions'].value_counts()
# Out:
#                                                                                    3501
# @mention                                                                           2684
# @mention @mention                                                                  970
# @mention @mention @mention                                                         236
# @mention @mention @mention @mention                                                38
# @madebymany                                                                        3
# @mention @mention @mention @mention @Schmittastic                                  3
# @mention @mention @mention @mention @garyvee                                       2
# @mention @mention @mention @mentionR                                               2
# @mention @mention @mention @mentionW                                               2
# @mention @mention @mention @mention @Dr_Black @jerranalley @tbalinas               1
# @marc_is_ken                                                                       1
# @madebymany @thenextweb                                                            1
# @mention @mention @mention @mention @CMmeetup                                      1
# @mention @mention @mention @mention @eightbit @garyvee                             1
# @mention @mention @mention @mentions                                               1
# @madebymany @michaelpiliero                                                        1
# @Gowalla                                                                           1
# @malbonster                                                                        1
# @jessedee @fludapp                                                                 1
# @planely @KLM                                                                      1
# @hamsandwich @ischafer                                                             1
# @mention @mention @mention @mention @lepanele                                      1
# @sxtxstate                                                                         1
# @mention @mention @mention @mention @mobileroadie                                  1
# @gowalla                                                                           1
# @mention @mention @mention @mention @jerranalley @tbalinas                         1
# @wesley83                                                                          1
# @mention @mention @mention @mention @sehugg @kshepherd @juntao @WuChangTX          1
# @PartnerHub                                                                        1
# @mention @mention @mention @mention @sheltongreen @EricSchu_Ras                    1
# @samsungmobileus                                                                   1
# @mention @mention @mention @mentionc                                               1
# @mention @mention @mention @mention @jeremie                                       1
# @mention @mention @mention @mention @anniemal @maura                               1
# @LaurieShook                                                                       1
# @teachntech00                                                                      1
# @Foursquare                                                                        1
# @mention @mention @mention @mentionm                                               1
# @HurricaneParty                                                                    1
# @swonderlin                                                                        1
# @mention @mention @mention @mention @PeterApokotos                                 1
# @sxsw                                                                              1
# @mention @mention @mention @mentionn                                               1
# @mention @mention @mention @mention @GapPacker @flavugm @MarcusRoss @JordanBell    1
# Name: mentions, dtype: int64

# %%
data[data['tweet_text'].str.contains('@mention')]
# Out:
#                                                                                                                                          tweet_text  \
# 31    Attn: All  #SXSW frineds, @mention Register for #GDGTLive  and see Cobra iRadar for Android. {link}
# 34    At #sxsw.  Oooh. RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link}
# 35    The best!  RT @mention Ha! First in line for #ipad2 at #sxsw &quot;pop-up&quot; Apple store was an event planner #eventprofs #pcma #engage365
# 36    SPIN Play - a new concept in music discovery for your iPad from @mention &amp; spin.com {link} #iTunes #sxsw @mention
# 37    @mention  - False Alarm: Google Circles Not Coming Nowand Probably Not Ever? - {link} #Google #Circles #Social #SXSW
# ...                                                                                                                    ...
# 7462  Cue the hype RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7469  Google says: want to give a lightning talk to a #H4ckers audience at #SXSW tonight? Email ben.mcgraw @mention gmail.com for a spot on stage.
# 7470  @mention Yup, but I don't have a third app yet. I'm on Android, any suggestions? #SXSW CC: @mention
# 7472  Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7475  ϡ_ʋ΋ҋ⋁__RT @mention Google Tests Check-in Offers At #SXSW {link}
#
#       Product Sentiment  \
# 31    Android  Neutral
# 34    Google   Neutral
# 35    iPad     Positive
# 36    iPad     Neutral
# 37    Google   Negative
# ...      ...        ...
# 7462  google   Neutral
# 7469  Google   Neutral
# 7470  Android  Neutral
# 7472  google   Neutral
# 7475  Google   Neutral
#
#                                                                                                                                        Remove_HTML  \
# 31    Attn: All  #SXSW frineds, @mention Register for #GDGTLive  and see Cobra iRadar for Android. {link}
# 34    At #sxsw.  Oooh. RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link}
# 35    The best!  RT @mention Ha! First in line for #ipad2 at #sxsw "pop-up" Apple store was an event planner #eventprofs #pcma #engage365
# 36    SPIN Play - a new concept in music discovery for your iPad from @mention & spin.com {link} #iTunes #sxsw @mention
# 37    @mention  - False Alarm: Google Circles Not Coming Nowand Probably Not Ever? - {link} #Google #Circles #Social #SXSW
# ...                                                                                                                    ...
# 7462  Cue the hype RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7469  Google says: want to give a lightning talk to a #H4ckers audience at #SXSW tonight? Email ben.mcgraw @mention gmail.com for a spot on stage.
# 7470  @mention Yup, but I don't have a third app yet. I'm on Android, any suggestions? #SXSW CC: @mention
# 7472  Wave, buzz... RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7475  ϡ_ʋ΋ҋ⋁__RT @mention Google Tests Check-in Offers At #SXSW {link}
#
#                                                                                                                                no_mentions  \
# 31    Attn: All  #SXSW frineds,  Register for #GDGTLive  and see Cobra iRadar for Android. {link}
# 34    At #sxsw.  Oooh. RT  Google to Launch Major New Social Network Called Circles, Possibly Today {link}
# 35    The best!  RT  Ha! First in line for #ipad2 at #sxsw "pop-up" Apple store was an event planner #eventprofs #pcma #engage365
# 36    SPIN Play - a new concept in music discovery for your iPad from  & spin.com {link} #iTunes #sxsw
# 37      - False Alarm: Google Circles Not Coming Nowand Probably Not Ever? - {link} #Google #Circles #Social #SXSW
# ...                                                                                                            ...
# 7462  Cue the hype RT  We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7469  Google says: want to give a lightning talk to a #H4ckers audience at #SXSW tonight? Email ben.mcgraw  gmail.com for a spot on stage.
# 7470   Yup, but I don't have a third app yet. I'm on Android, any suggestions? #SXSW CC:
# 7472  Wave, buzz... RT  We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# 7475  ϡ_ʋ΋ҋ⋁__RT  Google Tests Check-in Offers At #SXSW {link}
#
#                mentions
# 31    @mention
# 34    @mention
# 35    @mention
# 36    @mention @mention
# 37    @mention
# ...        ...
# 7462  @mention
# 7469  @mention
# 7470  @mention @mention
# 7472  @mention
# 7475  @mention
#
# [3953 rows x 6 columns]

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                   no_mentions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#              mentions
# 0  @wesley83
# 1  @jessedee @fludapp
# 2  @swonderlin
# 3  @sxsw
# 4  @sxtxstate

# %% [markdown]
# These mentions will not semantically improve the model, so I will safely proceed to removing them from the dataset.

# %% [markdown]
# ### Removing and Preserving Hashtags

# %% [markdown]
# Preserving the hashtags may be helpful to additional EDA.

# %%
data['hashtags'] = data['no_mentions'].str.findall(r'\B#\w*[a-zA-Z]+\w*')

# %%
data['hashtags'] = data['hashtags'].map(lambda x: ' '.join(x))

# %%
data['hashtags'].value_counts()
# Out:
# #sxsw                             2140
# #SXSW                             1970
# #SxSW                             71
# #Apple #SXSW                      47
# #sxsw #sxswi                      36
#                                   ..
# #jealous #sxsw #wssxsw            1
# #sxsw #tattoo #ipad_ #allshare    1
# #SXSW #iPad2 #SXSWi               1
# #UXdes #iPad #SXSW                1
# #apple #ipad2 #SXSW #TC           1
# Name: hashtags, Length: 1672, dtype: int64

# %%
data['no_hashtags'] = fn.Process_Tweet(data['no_mentions'],remove_hashtags=True)

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                   no_mentions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#              mentions            hashtags  \
# 0  @wesley83           #RISE_Austin #SXSW
# 1  @jessedee @fludapp  #SXSW
# 2  @swonderlin         #iPad #SXSW
# 3  @sxsw               #sxsw
# 4  @sxtxstate          #SXSW
#
#                                                                                                              no_hashtags
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival isn't as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)

# %% [markdown]
# ### Replacing Contractions

# %% [markdown]
# Contraction replacement is a helpful way to reduce computational cost and streamline the dataset.

# %%
data['no_contractions'] = fn.Process_Tweet(data['no_hashtags'],contraction_fix=True)

# %%
data.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                   no_mentions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#              mentions            hashtags  \
# 0  @wesley83           #RISE_Austin #SXSW
# 1  @jessedee @fludapp  #SXSW
# 2  @swonderlin         #iPad #SXSW
# 3  @sxsw               #sxsw
# 4  @sxtxstate          #SXSW
#
#                                                                                                              no_hashtags  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival isn't as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                             no_contractions
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)

# %% [markdown]
# ### Removing Texts from Links

# %% [markdown]
# Links appear as a result of the webscraping performed and should replaced.

# %%
np.sum(data['no_contractions'].str.contains('link'))
# Out:
# 3169

# %%
np.sum(data['no_contractions'].str.contains('http'))
# Out:
# 23

# %%
data['no_links']=fn.Process_Tweet(data['no_contractions'],strip_links=True)

# %%
np.sum(data['no_links'].str.contains('link'))
# Out:
# 26

# %%
np.sum(data['no_links'].str.contains('http'))
# Out:
# 0

# %%
data[data['no_links'].str.contains('link')]
# Out:
#                                                                                                                                               tweet_text  \
# 581   Disliking iPhone twitter auto shortening links for me. #sxsw
# 683   Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today @mention #sxsw!
# 887   #sxsw app schedule #fail try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 1247  At Google's scale, tiny changes (even in colors of blue) can be meaningful. There's an optimum shade of blue for links. #sxsw @mention
# 1258  @mention (CEO Gowalla) tells his journey of Blinksale to iconbuffet to Packrat. Then the #iPhone was born and the lightbulb turned on...#sxsw
# 1344  @mention @mention Thank you all for retweeting @mention @mention &amp; me about the link re #sxsw &amp; the popup Apple Store.
# 1415  Enjoying #SXSW Radio Station {link} If you have an iphone use link {link} &amp; plug it into your sound system.
# 1617  Google analytics can track offsite links as virtual page views using JavaScript. #moreknowledge #sxsw #mitharvard
# 1667  Google plans to bring &quot;The Power of Here&quot; to life in the future by linking the digital and the physical worlds. {link} #sxsw
# 1799  We're creatures of habit. Google found that CTRs for blue links far outpaced green. The darker the link, the more clicks it got. #sxsw
# 3001  See? So big my links smooshed. Here's Google Realtime for #SXSW {link}
# 3366  Any #Google fans in town for #SXSW? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 3439  @mention link to google story doesn't work. ??  thx! #SXSW
# 3440  @mention link? or I have to google it huh?  see u in austin for #SXSW? let me buy you a drink if you'll be there!
# 3818  Interesting RT @mention Google analytics can track offsite links as virtual pg views using Script. #moreknowledge #sxsw #mitharvard
# 4371  RT @mention #sxsw app schedule #fail try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 4443  RT @mention Any #Google fans in town for #SXSW? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 4763  RT @mention Google analytics can track offsite links as virtual page views using JavaScript. #moreknowledge #sxsw #mitharvard
# 4820  RT @mention Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter. #SXSW
# 4871  RT @mention Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today @mention #sxsw!
# 5484  RT @mention See? So big my links smooshed. Here's Google Realtime for #SXSW {link}
# 5591  RT @mention This @mention article about #SXSW is so good I'm linking to it on an iPhone on a train: {link}
# 6152  #sxsw #sxprotect  {link} is the Google Doc to get all the relevant links from this panel
# 6470  Many folks have asked about my iPhone battery case. Here's the link {link} #sxsw #fb #Li
# 6665  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter. #SXSW
# 7256  Free #SXSW streams/downloads via new free Winamp app in Android market, direct link to app download in market {link}
#
#                               Product Sentiment  \
# 581   iPad or iPhone App               Negative
# 683   Other Google product or service  Positive
# 887   google                           Neutral
# 1247  Google                           Positive
# 1258  iPhone                           Positive
# 1344  Apple                            Neutral
# 1415  iPhone                           Positive
# 1617  Other Google product or service  Positive
# 1667  Google                           Positive
# 1799  Google                           Neutral
# 3001  Google                           Neutral
# 3366  Google                           Neutral
# 3439  google                           Neutral
# 3440  google                           Neutral
# 3818  Google                           Positive
# 4371  google                           Neutral
# 4443  Google                           Neutral
# 4763  Google                           Neutral
# 4820  Google                           Positive
# 4871  Google                           Neutral
# 5484  Google                           Neutral
# 5591  iPhone                           Positive
# 6152  Other Google product or service  Positive
# 6470  iPhone                           Neutral
# 6665  Google                           Neutral
# 7256  Android                          Positive
#
#                                                                                                                                              Remove_HTML  \
# 581   Disliking iPhone twitter auto shortening links for me. #sxsw
# 683   Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today @mention #sxsw!
# 887   #sxsw app schedule #fail try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 1247  At Google's scale, tiny changes (even in colors of blue) can be meaningful. There's an optimum shade of blue for links. #sxsw @mention
# 1258  @mention (CEO Gowalla) tells his journey of Blinksale to iconbuffet to Packrat. Then the #iPhone was born and the lightbulb turned on...#sxsw
# 1344  @mention @mention Thank you all for retweeting @mention @mention & me about the link re #sxsw & the popup Apple Store.
# 1415  Enjoying #SXSW Radio Station {link} If you have an iphone use link {link} & plug it into your sound system.
# 1617  Google analytics can track offsite links as virtual page views using JavaScript. #moreknowledge #sxsw #mitharvard
# 1667  Google plans to bring "The Power of Here" to life in the future by linking the digital and the physical worlds. {link} #sxsw
# 1799  We're creatures of habit. Google found that CTRs for blue links far outpaced green. The darker the link, the more clicks it got. #sxsw
# 3001  See? So big my links smooshed. Here's Google Realtime for #SXSW {link}
# 3366  Any #Google fans in town for #SXSW? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 3439  @mention link to google story doesn't work. ??  thx! #SXSW
# 3440  @mention link? or I have to google it huh?  see u in austin for #SXSW? let me buy you a drink if you'll be there!
# 3818  Interesting RT @mention Google analytics can track offsite links as virtual pg views using Script. #moreknowledge #sxsw #mitharvard
# 4371  RT @mention #sxsw app schedule #fail try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 4443  RT @mention Any #Google fans in town for #SXSW? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 4763  RT @mention Google analytics can track offsite links as virtual page views using JavaScript. #moreknowledge #sxsw #mitharvard
# 4820  RT @mention Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter. #SXSW
# 4871  RT @mention Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today @mention #sxsw!
# 5484  RT @mention See? So big my links smooshed. Here's Google Realtime for #SXSW {link}
# 5591  RT @mention This @mention article about #SXSW is so good I'm linking to it on an iPhone on a train: {link}
# 6152  #sxsw #sxprotect  {link} is the Google Doc to get all the relevant links from this panel
# 6470  Many folks have asked about my iPhone battery case. Here's the link {link} #sxsw #fb #Li
# 6665  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter. #SXSW
# 7256  Free #SXSW streams/downloads via new free Winamp app in Android market, direct link to app download in market {link}
#
#                                                                                                                                      no_mentions  \
# 581   Disliking iPhone twitter auto shortening links for me. #sxsw
# 683   Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today  #sxsw!
# 887   #sxsw app schedule #fail try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 1247  At Google's scale, tiny changes (even in colors of blue) can be meaningful. There's an optimum shade of blue for links. #sxsw
# 1258   (CEO Gowalla) tells his journey of Blinksale to iconbuffet to Packrat. Then the #iPhone was born and the lightbulb turned on...#sxsw
# 1344    Thank you all for retweeting   & me about the link re #sxsw & the popup Apple Store.
# 1415  Enjoying #SXSW Radio Station {link} If you have an iphone use link {link} & plug it into your sound system.
# 1617  Google analytics can track offsite links as virtual page views using JavaScript. #moreknowledge #sxsw #mitharvard
# 1667  Google plans to bring "The Power of Here" to life in the future by linking the digital and the physical worlds. {link} #sxsw
# 1799  We're creatures of habit. Google found that CTRs for blue links far outpaced green. The darker the link, the more clicks it got. #sxsw
# 3001  See? So big my links smooshed. Here's Google Realtime for #SXSW {link}
# 3366  Any #Google fans in town for #SXSW? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 3439   link to google story doesn't work. ??  thx! #SXSW
# 3440   link? or I have to google it huh?  see u in austin for #SXSW? let me buy you a drink if you'll be there!
# 3818  Interesting RT  Google analytics can track offsite links as virtual pg views using Script. #moreknowledge #sxsw #mitharvard
# 4371  RT  #sxsw app schedule #fail try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 4443  RT  Any #Google fans in town for #SXSW? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 4763  RT  Google analytics can track offsite links as virtual page views using JavaScript. #moreknowledge #sxsw #mitharvard
# 4820  RT  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter. #SXSW
# 4871  RT  Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today  #sxsw!
# 5484  RT  See? So big my links smooshed. Here's Google Realtime for #SXSW {link}
# 5591  RT  This  article about #SXSW is so good I'm linking to it on an iPhone on a train: {link}
# 6152  #sxsw #sxprotect  {link} is the Google Doc to get all the relevant links from this panel
# 6470  Many folks have asked about my iPhone battery case. Here's the link {link} #sxsw #fb #Li
# 6665  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter. #SXSW
# 7256  Free #SXSW streams/downloads via new free Winamp app in Android market, direct link to app download in market {link}
#
#                                  mentions                          hashtags  \
# 581                                        #sxsw
# 683   @mention                             #sxsw
# 887                                        #sxsw #fail
# 1247  @mention                             #sxsw
# 1258  @mention                             #iPhone #sxsw
# 1344  @mention @mention @mention @mention  #sxsw
# 1415                                       #SXSW
# 1617                                       #moreknowledge #sxsw #mitharvard
# 1667                                       #sxsw
# 1799                                       #sxsw
# 3001                                       #SXSW
# 3366                                       #Google #SXSW
# 3439  @mention                             #SXSW
# 3440  @mention                             #SXSW
# 3818  @mention                             #moreknowledge #sxsw #mitharvard
# 4371  @mention                             #sxsw #fail
# 4443  @mention                             #Google #SXSW
# 4763  @mention                             #moreknowledge #sxsw #mitharvard
# 4820  @mention                             #SXSW
# 4871  @mention @mention                    #sxsw
# 5484  @mention                             #SXSW
# 5591  @mention @mention                    #SXSW
# 6152                                       #sxsw #sxprotect
# 6470                                       #sxsw #fb #Li
# 6665                                       #SXSW
# 7256                                       #SXSW
#
#                                                                                                                             no_hashtags  \
# 581   Disliking iPhone twitter auto shortening links for me.
# 683   Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today  !
# 887    app schedule  try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 1247  At Google's scale, tiny changes (even in colors of blue) can be meaningful. There's an optimum shade of blue for links.
# 1258   (CEO Gowalla) tells his journey of Blinksale to iconbuffet to Packrat. Then the  was born and the lightbulb turned on...
# 1344    Thank you all for retweeting   & me about the link re  & the popup Apple Store.
# 1415  Enjoying  Radio Station {link} If you have an iphone use link {link} & plug it into your sound system.
# 1617  Google analytics can track offsite links as virtual page views using JavaScript.
# 1667  Google plans to bring "The Power of Here" to life in the future by linking the digital and the physical worlds. {link}
# 1799  We're creatures of habit. Google found that CTRs for blue links far outpaced green. The darker the link, the more clicks it got.
# 3001  See? So big my links smooshed. Here's Google Realtime for  {link}
# 3366  Any  fans in town for ? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 3439   link to google story doesn't work. ??  thx!
# 3440   link? or I have to google it huh?  see u in austin for ? let me buy you a drink if you'll be there!
# 3818  Interesting RT  Google analytics can track offsite links as virtual pg views using Script.
# 4371  RT   app schedule  try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 4443  RT  Any  fans in town for ? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 4763  RT  Google analytics can track offsite links as virtual page views using JavaScript.
# 4820  RT  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter.
# 4871  RT  Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today  !
# 5484  RT  See? So big my links smooshed. Here's Google Realtime for  {link}
# 5591  RT  This  article about  is so good I'm linking to it on an iPhone on a train: {link}
# 6152     {link} is the Google Doc to get all the relevant links from this panel
# 6470  Many folks have asked about my iPhone battery case. Here's the link {link}
# 6665  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter.
# 7256  Free  streams/downloads via new free Winamp app in Android market, direct link to app download in market {link}
#
#                                                                                                                          no_contractions  \
# 581   Disliking iPhone twitter auto shortening links for me.
# 683   Google to launch new social network Circles, linking you more closely to peeps you connect w/most. possibly today  !
# 887    app schedule  try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 1247  At Google's scale, tiny changes (even in colors of blue) can be meaningful. There is an optimum shade of blue for links.
# 1258   (CEO Gowalla) tells his journey of Blinksale to iconbuffet to Packrat. Then the  was born and the lightbulb turned on...
# 1344    Thank you all for retweeting   & me about the link re  & the popup Apple Store.
# 1415  Enjoying  Radio Station {link} If you have an iphone use link {link} & plug it into your sound system.
# 1617  Google analytics can track offsite links as virtual page views using JavaScript.
# 1667  Google plans to bring "The Power of Here" to life in the future by linking the digital and the physical worlds. {link}
# 1799  We are creatures of habit. Google found that CTRs for blue links far outpaced green. The darker the link, the more clicks it got.
# 3001  See? So big my links smooshed. Here is Google Realtime for  {link}
# 3366  Any  fans in town for ? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 3439   link to google story does not work. ??  thanks!
# 3440   link? or I have to google it huh?  see you in austin for ? let me buy you a drink if you will be there!
# 3818  Interesting RT  Google analytics can track offsite links as virtual pg views using Script.
# 4371  RT   app schedule  try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 4443  RT  Any  fans in town for ? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link: {link}
# 4763  RT  Google analytics can track offsite links as virtual page views using JavaScript.
# 4820  RT  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter.
# 4871  RT  Google to launch new social network Circles, linking you more closely to peeps you connect w/most. possibly today  !
# 5484  RT  See? So big my links smooshed. Here is Google Realtime for  {link}
# 5591  RT  This  article about  is so good I am linking to it on an iPhone on a train: {link}
# 6152     {link} is the Google Doc to get all the relevant links from this panel
# 6470  Many folks have asked about my iPhone battery case. Here is the link {link}
# 6665  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter.
# 7256  Free  streams/downloads via new free Winamp app in Android market, direct link to app download in market {link}
#
#                                                                                                                                 no_links
# 581   Disliking iPhone twitter auto shortening links for me.
# 683   Google to launch new social network Circles, linking you more closely to peeps you connect w/most. possibly today  !
# 887    app schedule  try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 1247  At Google's scale, tiny changes (even in colors of blue) can be meaningful. There is an optimum shade of blue for links.
# 1258   (CEO Gowalla) tells his journey of Blinksale to iconbuffet to Packrat. Then the  was born and the lightbulb turned on...
# 1344    Thank you all for retweeting   & me about the link re  & the popup Apple Store.
# 1415  Enjoying  Radio Station  If you have an iphone use link  & plug it into your sound system.
# 1617  Google analytics can track offsite links as virtual page views using JavaScript.
# 1667  Google plans to bring "The Power of Here" to life in the future by linking the digital and the physical worlds.
# 1799  We are creatures of habit. Google found that CTRs for blue links far outpaced green. The darker the link, the more clicks it got.
# 3001  See? So big my links smooshed. Here is Google Realtime for
# 3366  Any  fans in town for ? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link:
# 3439   link to google story does not work. ??  thanks!
# 3440   link? or I have to google it huh?  see you in austin for ? let me buy you a drink if you will be there!
# 3818  Interesting RT  Google analytics can track offsite links as virtual pg views using Script.
# 4371  RT   app schedule  try sched.org - google: sched sxsw 2011 click first link. All the unofficial parties and room counts. Genius.
# 4443  RT  Any  fans in town for ? Stop by the Austin GTUG meeting Wednesday the 7th at 7:00pm. map link:
# 4763  RT  Google analytics can track offsite links as virtual page views using JavaScript.
# 4820  RT  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter.
# 4871  RT  Google to launch new social network Circles, linking you more closely to peeps you connect w/most. possibly today  !
# 5484  RT  See? So big my links smooshed. Here is Google Realtime for
# 5591  RT  This  article about  is so good I am linking to it on an iPhone on a train:
# 6152      is the Google Doc to get all the relevant links from this panel
# 6470  Many folks have asked about my iPhone battery case. Here is the link
# 6665  Google tested 41 shades of blue for link colors AND it made a difference. At scale the nuances really matter.
# 7256  Free  streams/downloads via new free Winamp app in Android market, direct link to app download in market

# %%
data[data['no_links'].str.contains('http')]
# Out:
# Empty DataFrame
# Columns: [tweet_text, Product, Sentiment, Remove_HTML, no_mentions, mentions, hashtags, no_hashtags, no_contractions, no_links]
# Index: []

# %% [markdown]
# ### Leading Punctuation

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                   no_mentions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#              mentions            hashtags  \
# 0  @wesley83           #RISE_Austin #SXSW
# 1  @jessedee @fludapp  #SXSW
# 2  @swonderlin         #iPad #SXSW
# 3  @sxsw               #sxsw
# 4  @sxtxstate          #SXSW
#
#                                                                                                              no_hashtags  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival isn't as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                             no_contractions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                    no_links
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)

# %%
#Some tweets have leading punctuation that must be removed
data['no_leading']=fn.Process_Tweet(data['no_links'],no_leading=True)

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                   no_mentions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#              mentions            hashtags  \
# 0  @wesley83           #RISE_Austin #SXSW
# 1  @jessedee @fludapp  #SXSW
# 2  @swonderlin         #iPad #SXSW
# 3  @sxsw               #sxsw
# 4  @sxtxstate          #SXSW
#
#                                                                                                              no_hashtags  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival isn't as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                             no_contractions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                    no_links  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                  no_leading
# 0   I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)

# %%
data.sample(5)
# Out:
#                                                                                                                             tweet_text  \
# 1589  5 Essential Business #Collaboration Apps for #iPad {link} #BPM #SXSW #SXSWi
# 447   I want to go to the Apple pop-up store, but I'm afraid I'll leave with a new iPad. #SXSW
# 3388  Popup Apple Store opens up for #SXSW. Love that this is going to be right in the middle of the action. {link} via @mention
# 1272  @mention @mention @mention &quot;@mention Google to Launch Major New Social Network: Circles, Possibly Today {link}  #sxsw&quot;
# 5073  RT @mention Is it bad that I just want to go home and read my Google Reader feed? #geek #sxsw
#
#                               Product Sentiment  \
# 1589  iPad                             Neutral
# 447   iPad                             Positive
# 3388  Apple                            Positive
# 1272  Other Google product or service  Positive
# 5073  Other Google product or service  Positive
#
#                                                                                                                      Remove_HTML  \
# 1589  5 Essential Business #Collaboration Apps for #iPad {link} #BPM #SXSW #SXSWi
# 447   I want to go to the Apple pop-up store, but I'm afraid I'll leave with a new iPad. #SXSW
# 3388  Popup Apple Store opens up for #SXSW. Love that this is going to be right in the middle of the action. {link} via @mention
# 1272  @mention @mention @mention "@mention Google to Launch Major New Social Network: Circles, Possibly Today {link}  #sxsw"
# 5073  RT @mention Is it bad that I just want to go home and read my Google Reader feed? #geek #sxsw
#
#                                                                                                              no_mentions  \
# 1589  5 Essential Business #Collaboration Apps for #iPad {link} #BPM #SXSW #SXSWi
# 447   I want to go to the Apple pop-up store, but I'm afraid I'll leave with a new iPad. #SXSW
# 3388  Popup Apple Store opens up for #SXSW. Love that this is going to be right in the middle of the action. {link} via
# 1272     " Google to Launch Major New Social Network: Circles, Possibly Today {link}  #sxsw"
# 5073  RT  Is it bad that I just want to go home and read my Google Reader feed? #geek #sxsw
#
#                                  mentions  \
# 1589
# 447
# 3388  @mention
# 1272  @mention @mention @mention @mention
# 5073  @mention
#
#                                     hashtags  \
# 1589  #Collaboration #iPad #BPM #SXSW #SXSWi
# 447   #SXSW
# 3388  #SXSW
# 1272  #sxsw
# 5073  #geek #sxsw
#
#                                                                                                         no_hashtags  \
# 1589  5 Essential Business  Apps for  {link}
# 447   I want to go to the Apple pop-up store, but I'm afraid I'll leave with a new iPad.
# 3388  Popup Apple Store opens up for . Love that this is going to be right in the middle of the action. {link} via
# 1272     " Google to Launch Major New Social Network: Circles, Possibly Today {link}  "
# 5073  RT  Is it bad that I just want to go home and read my Google Reader feed?
#
#                                                                                                     no_contractions  \
# 1589  5 Essential Business  Apps for  {link}
# 447   I want to go to the Apple pop-up store, but I am afraid I will leave with a new iPad.
# 3388  Popup Apple Store opens up for . Love that this is going to be right in the middle of the action. {link} via
# 1272     " Google to Launch Major New Social Network: Circles, Possibly Today {link}  "
# 5073  RT  Is it bad that I just want to go home and read my Google Reader feed?
#
#                                                                                                      no_links  \
# 1589  5 Essential Business  Apps for
# 447   I want to go to the Apple pop-up store, but I am afraid I will leave with a new iPad.
# 3388  Popup Apple Store opens up for . Love that this is going to be right in the middle of the action.  via
# 1272     " Google to Launch Major New Social Network: Circles, Possibly Today   "
# 5073  RT  Is it bad that I just want to go home and read my Google Reader feed?
#
#                                                                                                    no_leading
# 1589  5 Essential Business  Apps for
# 447   I want to go to the Apple pop-up store, but I am afraid I will leave with a new iPad.
# 3388  Popup Apple Store opens up for . Love that this is going to be right in the middle of the action.  via
# 1272     " Google to Launch Major New Social Network: Circles, Possibly Today   "
# 5073  RT  Is it bad that I just want to go home and read my Google Reader feed?

# %% [markdown]
# ### Converting Numerals to Words

# %%
data['no_numerals'] = fn.Process_Tweet(data['no_leading'],remove_numerals=True)

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                   no_mentions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#              mentions            hashtags  \
# 0  @wesley83           #RISE_Austin #SXSW
# 1  @jessedee @fludapp  #SXSW
# 2  @swonderlin         #iPad #SXSW
# 3  @sxsw               #sxsw
# 4  @sxtxstate          #SXSW
#
#                                                                                                              no_hashtags  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival isn't as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                             no_contractions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                    no_links  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                  no_leading  \
# 0   I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                 no_numerals
# 0   I have a  three G iPhone. After  three  hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for   two  also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)

# %%
data.sample(5)
# Out:
#                                                                                                                      tweet_text  \
# 2551  Quoi de neuf sur #Blogger ? | What۪s new with Blogger | Official #Google Blog {link} #SXSW
# 4504  RT @mention Apple set to open popup shop in core of SXSW action  - they're going to sell iPad2 at #SXSW! {link} // danger
# 2786  Homeless guy outside pop-up #SXSW Apple store holding sign: &quot;saving up for ipad 2&quot; (don't ask for a photo)
# 1239  The world's largest iPad. #sxsw {link}
# 4382  RT @mention #SXSW Interactive: Google۪s Mobile Future, and the Elusive Power of Here' | @mention {link}
#
#      Product Sentiment  \
# 2551  Google  Neutral
# 4504  iPad    Neutral
# 2786  iPad    Positive
# 1239  iPad    Positive
# 4382  Google  Neutral
#
#                                                                                                                     Remove_HTML  \
# 2551  Quoi de neuf sur #Blogger ? | What۪s new with Blogger | Official #Google Blog {link} #SXSW
# 4504  RT @mention Apple set to open popup shop in core of SXSW action  - they're going to sell iPad2 at #SXSW! {link} // danger
# 2786  Homeless guy outside pop-up #SXSW Apple store holding sign: "saving up for ipad 2" (don't ask for a photo)
# 1239  The world's largest iPad. #sxsw {link}
# 4382  RT @mention #SXSW Interactive: Google۪s Mobile Future, and the Elusive Power of Here' | @mention {link}
#
#                                                                                                             no_mentions  \
# 2551  Quoi de neuf sur #Blogger ? | What۪s new with Blogger | Official #Google Blog {link} #SXSW
# 4504  RT  Apple set to open popup shop in core of SXSW action  - they're going to sell iPad2 at #SXSW! {link} // danger
# 2786  Homeless guy outside pop-up #SXSW Apple store holding sign: "saving up for ipad 2" (don't ask for a photo)
# 1239  The world's largest iPad. #sxsw {link}
# 4382  RT  #SXSW Interactive: Google۪s Mobile Future, and the Elusive Power of Here' |  {link}
#
#                mentions                hashtags  \
# 2551                     #Blogger #Google #SXSW
# 4504  @mention           #SXSW
# 2786                     #SXSW
# 1239                     #sxsw
# 4382  @mention @mention  #SXSW
#
#                                                                                                        no_hashtags  \
# 2551  Quoi de neuf sur  ? | What۪s new with Blogger | Official  Blog {link}
# 4504  RT  Apple set to open popup shop in core of SXSW action  - they're going to sell iPad2 at ! {link} // danger
# 2786  Homeless guy outside pop-up  Apple store holding sign: "saving up for ipad 2" (don't ask for a photo)
# 1239  The world's largest iPad.  {link}
# 4382  RT   Interactive: Google۪s Mobile Future, and the Elusive Power of Here' |  {link}
#
#                                                                                                     no_contractions  \
# 2551  Quoi de neuf sur  ? | What۪s new with Blogger | Official  Blog {link}
# 4504  RT  Apple set to open popup shop in core of SXSW action  - they are going to sell iPad2 at ! {link} // danger
# 2786  Homeless guy outside pop-up  Apple store holding sign: "saving up for ipad 2" (do not ask for a photo)
# 1239  The world's largest iPad.  {link}
# 4382  RT   Interactive: Google۪s Mobile Future, and the Elusive Power of Here' |  {link}
#
#                                                                                                      no_links  \
# 2551  Quoi de neuf sur  ? | What۪s new with Blogger | Official  Blog
# 4504  RT  Apple set to open popup shop in core of SXSW action  - they are going to sell iPad2 at !  // danger
# 2786  Homeless guy outside pop-up  Apple store holding sign: "saving up for ipad 2" (do not ask for a photo)
# 1239  The world's largest iPad.
# 4382  RT   Interactive: Google۪s Mobile Future, and the Elusive Power of Here' |
#
#                                                                                                    no_leading  \
# 2551  Quoi de neuf sur  ? | What۪s new with Blogger | Official  Blog
# 4504  RT  Apple set to open popup shop in core of SXSW action  - they are going to sell iPad2 at !  // danger
# 2786  Homeless guy outside pop-up  Apple store holding sign: "saving up for ipad 2" (do not ask for a photo)
# 1239  The world's largest iPad.
# 4382  RT   Interactive: Google۪s Mobile Future, and the Elusive Power of Here' |
#
#                                                                                                       no_numerals
# 2551  Quoi de neuf sur  ? | What۪s new with Blogger | Official  Blog
# 4504  RT  Apple set to open popup shop in core of SXSW action  - they are going to sell iPad two  at !  // danger
# 2786  Homeless guy outside pop-up  Apple store holding sign: "saving up for ipad  two " (do not ask for a photo)
# 1239  The world's largest iPad.
# 4382  RT   Interactive: Google۪s Mobile Future, and the Elusive Power of Here' |

# %% [markdown]
# ### Lowercasing

# %%
data['lower_case'] = fn.Process_Tweet(data['no_numerals'],lower=True)

# %%
data.head(5)
# Out:
#                                                                                                                                     tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#               Product Sentiment  \
# 0  iPhone              Negative
# 1  iPad or iPhone App  Positive
# 2  iPad                Positive
# 3  iPad or iPhone App  Negative
# 4  Google              Positive
#
#                                                                                                                                    Remove_HTML  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2  @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3  @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                   no_mentions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2   Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3   I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4   great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#              mentions            hashtags  \
# 0  @wesley83           #RISE_Austin #SXSW
# 1  @jessedee @fludapp  #SXSW
# 2  @swonderlin         #iPad #SXSW
# 3  @sxsw               #sxsw
# 4  @sxtxstate          #SXSW
#
#                                                                                                              no_hashtags  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival isn't as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                             no_contractions  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                    no_links  \
# 0  . I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                  no_leading  \
# 0   I have a 3G iPhone. After 3 hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for  2 also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                 no_numerals  \
# 0   I have a  three G iPhone. After  three  hrs tweeting at , it was dead!  I need to upgrade. Plugin stations at .
# 1   Know about  ? Awesome iPad/iPhone app that you will likely appreciate for its design. Also, they are giving free Ts at
# 2   Can not wait for   two  also. They should sale them down at .
# 3   I hope this year's festival is not as crashy as this year's iPhone app.
# 4   great stuff on Fri : Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) & Matt Mullenweg (Wordpress)
#
#                                                                                                                  lower_case
# 0   i have a  three g iphone. after  three  hrs tweeting at , it was dead!  i need to upgrade. plugin stations at .
# 1   know about  ? awesome ipad/iphone app that you will likely appreciate for its design. also, they are giving free ts at
# 2   can not wait for   two  also. they should sale them down at .
# 3   i hope this year's festival is not as crashy as this year's iphone app.
# 4   great stuff on fri : marissa mayer (google), tim o'reilly (tech books/conferences) & matt mullenweg (wordpress)

# %% [markdown]
# The Processing has removed a lot of the characters that need to be removed for modeling, but some characters remain. Abbreviations are another sticky point, certain lingo and shortening of words was specific to this era of twitter where tweets were hard-capped at 140 characters.

# %% [markdown]
# ### Replacing Other Special Characers

# %% [markdown]
# Most if not all of the punctuation have been removed, some punctuation can be valuable for more advanced models. There are numerals that need to be converted into the words for numerals. There are many abbrevations and slang terms in the the text as well. At this point I will stop and just take a look at the top words in the processed text.

# %% [markdown]
# ## Word Clouds

# %% [markdown]
# ### Basic Word Cloud Cleaned Text

# %%
sample_text = ''.join(data['lower_case'])
wordcloud = WordCloud(width=1000, height=760, background_color="white",collocations=False).generate(sample_text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Negative Word Cloud

# %%
sample_text = ''.join(data[data['Sentiment']=='Negative']['lower_case'])
wordcloud = WordCloud(width=1000, height=760, background_color="red",collocations=False).generate(sample_text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Positive Word Cloud

# %%
sample_text = ''.join(data[data['Sentiment']=='Positive']['lower_case'])
wordcloud = WordCloud(width=1000, height=760, background_color="white",collocations=False).generate(sample_text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# A quick glance so some interesting words in the given sentiments. It looks like "fascist" and "headaches" pop up in the negative tweets.

# %% [markdown]
# ### Fun with Negative Words

# %%
np.sum(data[data['Sentiment']=='Negative']['lower_case'].str.contains('fascist'))
# Out:
# 14

# %%
np.sum(data[data['Sentiment']=='Negative']['lower_case'].str.contains('headache'))
# Out:
# 17

# %%
np.sum(data[data['Sentiment']=='Positive']['lower_case'].str.contains('party'))/np.sum(data['Sentiment']=='Positive')
# Out:
# 0.04198473282442748

# %%
np.sum(data[data['Sentiment']=='Negative']['lower_case'].str.contains('party'))
# Out:
# 6

# %%
np.sum(data[data['Sentiment']=='Neutral']['lower_case'].str.contains('party'))/np.sum(data['Sentiment']=='Neutral')
# Out:
# 0.03668815071888944

# %% [markdown]
# ### Word Percentages

# %%
def word_percentages(data,word):
    neg_occurances = np.sum(data[data['Sentiment']=='Negative']['lower_case'].str.contains(word))/np.sum(data['Sentiment']=='Negative')
    poz_occurances = np.sum(data[data['Sentiment']=='Positive']['lower_case'].str.contains(word))/np.sum(data['Sentiment']=='Positive')
    neutral_occurances = np.sum(data[data['Sentiment']=='Neutral']['lower_case'].str.contains(word))/np.sum(data['Sentiment']=='Neutral')
    return f'The word {word} appears {round(neg_occurances,4)}% of the negative portion of the dataset, {round(poz_occurances,4)} of the positive portion of the dataset, and {round(neutral_occurances,4)} of the neutral portion of the dataset.'

# %%
word_percentages(data,'fascist')
# Out:
# 'The word fascist appears 0.025% of the negative portion of the dataset, 0.0 of the positive portion of the dataset, and 0.0002 of the neutral portion of the dataset.'

# %%
word_percentages(data,'party')
# Out:
# 'The word party appears 0.0107% of the negative portion of the dataset, 0.042 of the positive portion of the dataset, and 0.0367 of the neutral portion of the dataset.'

# %%
word_percentages(data,'free')
# Out:
# 'The word free appears 0.0036% of the negative portion of the dataset, 0.0316 of the positive portion of the dataset, and 0.0243 of the neutral portion of the dataset.'

# %%
word_percentages(data,'headache')
# Out:
# 'The word headache appears 0.0304% of the negative portion of the dataset, 0.001 of the positive portion of the dataset, and 0.0032 of the neutral portion of the dataset.'

# %%
word_percentages(data,'app')
# Out:
# 'The word app appears 0.3304% of the negative portion of the dataset, 0.4046 of the positive portion of the dataset, and 0.3024 of the neutral portion of the dataset.'

# %%
word_percentages(data,'cool')
# Out:
# 'The word cool appears 0.0089% of the negative portion of the dataset, 0.0441 of the positive portion of the dataset, and 0.0047 of the neutral portion of the dataset.'

# %% [markdown]
# ## Lematization

# %%
#Grabbing Stopwords from NLTK
sw = stopwords.words('english')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/seanyboy/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Borrowed Function to attatch parts of speech for lemmonization
def get_wordnet_pos(treebank_tag):
    '''
    Translate nltk POS to wordnet tags
    '''
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def doc_preparer(doc, stop_words=sw):
    '''
    
    :param doc: a document from a corpus
    :return: a document string with words which have been 
            lemmatized, 
            parsed for stopwords, 
            made lowercase,
            and stripped of punctuation and numbers.
    '''
    
    regex_token = RegexpTokenizer(r"([a-zA-Z]+(?:’[a-z]+)?)")
    doc = regex_token.tokenize(doc)
    doc = [word.lower() for word in doc]
    doc = [word for word in doc if word not in sw]
    doc = pos_tag(doc)
    doc = [(word[0], get_wordnet_pos(word[1])) for word in doc]
    lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
    doc = [lemmatizer.lemmatize(word[0], word[1]) for word in doc]
    return (doc)

# %%
data['lemma_tokens']= [doc_preparer(doc, sw) for doc in data['lower_case']]

# %% [markdown]
# ### Top Lemmatized Words from Dataset

# %%
corpus = [' '.join(data.lemma_tokens.apply(lambda x: ', '.join([str(i) for i in x])))]
neg_corpus = [' '.join(data[data['Sentiment']=='Negative']['lemma_tokens'].apply(lambda x: ', '.join([str(i) for i in x])))]
poz_corpus = [' '.join(data[data['Sentiment']=='Positive']['lemma_tokens'].apply(lambda x: ', '.join([str(i) for i in x])))]
neutral_corpus = [' '.join(data[data['Sentiment']=='Neutral']['lemma_tokens'].apply(lambda x: ', '.join([str(i) for i in x])))]

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
get_top_n_words(neg_corpus,n=10)
# Out:
# [('ipad', 183),
#  ('iphone', 149),
#  ('google', 139),
#  ('rt', 137),
#  ('apple', 106),
#  ('two', 100),
#  ('app', 57),
#  ('store', 47),
#  ('new', 45),
#  ('one', 43)]

# %%
get_top_n_words(poz_corpus,n=10)
# Out:
# [('ipad', 1000),
#  ('rt', 912),
#  ('apple', 740),
#  ('two', 672),
#  ('google', 661),
#  ('store', 547),
#  ('iphone', 441),
#  ('app', 378),
#  ('new', 355),
#  ('get', 285)]

# %%
get_top_n_words(corpus=neutral_corpus,n=10)
# Out:
# [('rt', 1416),
#  ('google', 1391),
#  ('ipad', 1018),
#  ('apple', 873),
#  ('store', 776),
#  ('two', 706),
#  ('new', 586),
#  ('launch', 503),
#  ('iphone', 465),
#  ('austin', 458)]

# %% [markdown]
# It's more or less the same words as the top words in each of the dataets.

# %%
def get_top_tfidf_words(corpus, n=None):
    vec = TfidfVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
get_top_tfidf_words(poz_corpus,n=20)
# Out:
# [('ipad', 0.43973617798157927),
#  ('rt', 0.40103939431920027),
#  ('apple', 0.32540477170636867),
#  ('two', 0.2955027116036213),
#  ('google', 0.2906656136458239),
#  ('store', 0.24053568935592387),
#  ('iphone', 0.19392365448987645),
#  ('app', 0.16622027527703698),
#  ('new', 0.15610634318346064),
#  ('get', 0.1253248107247501),
#  ('austin', 0.1103737806733764),
#  ('one', 0.10949430831741323),
#  ('pop', 0.09454327826603955),
#  ('launch', 0.0848690823504448),
#  ('go', 0.08442934617246323),
#  ('open', 0.07519488643485006),
#  ('android', 0.06727963523118163),
#  ('party', 0.06727963523118163),
#  ('line', 0.06288227345136584),
#  ('come', 0.06244253727338426)]

# %%
get_top_tfidf_words(neg_corpus,n=20)
# Out:
# [('ipad', 0.4503620327693096),
#  ('iphone', 0.3666882124733723),
#  ('google', 0.34207826532750835),
#  ('rt', 0.3371562758983356),
#  ('apple', 0.26086543974615745),
#  ('two', 0.2460994714586391),
#  ('app', 0.1402766987314243),
#  ('store', 0.11566675158556038),
#  ('new', 0.1107447621563876),
#  ('one', 0.10582277272721481),
#  ('like', 0.10336177801262843),
#  ('get', 0.10090078329804203),
#  ('need', 0.08613481501052368),
#  ('people', 0.08613481501052368),
#  ('go', 0.0812128255813509),
#  ('circle', 0.07136884672300534),
#  ('launch', 0.07136884672300534),
#  ('design', 0.06890785200841895),
#  ('think', 0.06890785200841895),
#  ('social', 0.06890785200841895)]

# %%
get_top_tfidf_words(neutral_corpus,20)
# Out:
# [('rt', 0.4431161174049729),
#  ('google', 0.43529273962593035),
#  ('ipad', 0.3185679431626147),
#  ('apple', 0.27319235204416764),
#  ('store', 0.24283764626148235),
#  ('two', 0.22093218848016305),
#  ('new', 0.18337997514075857),
#  ('launch', 0.15740636091433713),
#  ('iphone', 0.1455148266901924),
#  ('austin', 0.14332428091206045),
#  ('social', 0.13550090313301785),
#  ('circle', 0.12799046046513696),
#  ('today', 0.11641186135215391),
#  ('pop', 0.10420739201684745),
#  ('network', 0.10358152179452404),
#  ('one', 0.09388053334851122),
#  ('open', 0.08981237690340907),
#  ('call', 0.08793476623643884),
#  ('get', 0.08762183112527713),
#  ('app', 0.08105019379088135)]

# %% [markdown]
# ### Added Stopwords

# %% [markdown]
# For the sake of experimentation I will remove the top words and put them in the stopwords list.

# %%
top_words = get_top_tfidf_words(corpus,10)

# %%
top_words = [w[0] for w in top_words]

# %%
sw.extend(top_words)

# %%
data['new_stop_words']= [doc_preparer(doc, sw) for doc in data['lower_case']]

# %%
corpus = [' '.join(data.lemma_tokens.apply(lambda x: ', '.join([str(i) for i in x])))]
neg_corpus = [' '.join(data[data['Sentiment']=='Negative']['new_stop_words'].apply(lambda x: ', '.join([str(i) for i in x])))]
poz_corpus = [' '.join(data[data['Sentiment']=='Positive']['new_stop_words'].apply(lambda x: ', '.join([str(i) for i in x])))]
neutral_corpus = [' '.join(data[data['Sentiment']=='Neutral']['new_stop_words'].apply(lambda x: ', '.join([str(i) for i in x])))]

# %%
get_top_tfidf_words(corpus,10)
# Out:
# [('rt', 0.42825796789345494),
#  ('ipad', 0.3823918001352918),
#  ('google', 0.3806544452959674),
#  ('apple', 0.2986512968798576),
#  ('two', 0.2567810452521405),
#  ('store', 0.23801761298743743),
#  ('iphone', 0.18329093554872006),
#  ('new', 0.17130318715738196),
#  ('austin', 0.12752184520640808),
#  ('launch', 0.12595822585101615)]

# %%
get_top_tfidf_words(neg_corpus,10)
# Out:
# [('app', 0.270537449515196),
#  ('one', 0.20408965489742853),
#  ('like', 0.1993433838533023),
#  ('get', 0.19459711280917605),
#  ('need', 0.16611948654441858),
#  ('people', 0.16611948654441858),
#  ('go', 0.1566269444561661),
#  ('circle', 0.1376418602796611),
#  ('design', 0.13289558923553485),
#  ('think', 0.13289558923553485)]

# %%
get_top_tfidf_words(poz_corpus,10)
# Out:
# [('app', 0.3478423690859145),
#  ('get', 0.26134188576825323),
#  ('one', 0.2291342590010389),
#  ('pop', 0.1969266322338246),
#  ('go', 0.1766818382658613),
#  ('open', 0.15459660848262866),
#  ('android', 0.14079333986810824),
#  ('party', 0.14079333986810824),
#  ('line', 0.1315911607917613),
#  ('sxsw', 0.13067094288412662)]

# %%
get_top_tfidf_words(neutral_corpus,10)
# Out:
# [('social', 0.28230889178647417),
#  ('circle', 0.26666128577521464),
#  ('today', 0.24253789317452285),
#  ('pop', 0.21711053340622607),
#  ('network', 0.21580656623862113),
#  ('one', 0.19559507514074423),
#  ('call', 0.1832073870484971),
#  ('get', 0.18125143629708965),
#  ('open', 0.17994746912948467),
#  ('app', 0.1688637482048425)]

# %% [markdown]
# ### TFIDF WordClouds

# %%
sample_text = ' '.join(data.lemma_tokens.apply(lambda x: ', '.join([str(i) for i in x])))
wordcloud = WordCloud(width=1000, height=760, background_color="white",collocations=False).generate(sample_text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
sample_text = ' '.join(data[data['Sentiment']=='Negative']['new_stop_words'].apply(lambda x: ', '.join([str(i) for i in x])))
wordcloud = WordCloud(width=1000, height=760, background_color="red",collocations=False).generate(sample_text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
sample_text = ' '.join(data[data['Sentiment']=='Positive']['new_stop_words'].apply(lambda x: ', '.join([str(i) for i in x])))
wordcloud = WordCloud(width=1000, height=760, background_color="#03f0fc",collocations=False).generate(sample_text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(20,10),facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Bigram Wordclouds

# %%
def get_top_tfidf_words(corpus, n=None):
    vec = TfidfVectorizer(ngram_range=(2,2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
get_top_tfidf_words(poz_corpus,10)
# Out:
# [('social network', 0.27653733830498894),
#  ('marissa mayer', 0.1929330267244109),
#  ('network call', 0.18328637538819037),
#  ('call circle', 0.18328637538819037),
#  ('major social', 0.1736397240519698),
#  ('open pop', 0.16720862316115612),
#  ('open temporary', 0.15434642137952873),
#  ('even begin', 0.13183756826168078),
#  ('possibly today', 0.13183756826168078),
#  ('circle possibly', 0.12862201781627394)]

# %%
neg_bigrams
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [409], in <cell line: 1>()
# ----> 1 neg_bigrams
#
# NameError: name 'neg_bigrams' is not defined

# %%
def get_top_tfidf_bigrams(corpus, n=None):
    vec = TfidfVectorizer(ngram_range=(2,2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = {word: sum_words[0, idx] for word, idx in     vec.vocabulary_.items()}
    words_freq = {k: v for k, v in sorted(words_freq.items(), key=lambda item: item[1], reverse = True)}
    
    return words_freq

# %%
neg_bigrams = get_top_tfidf_bigrams(neg_corpus,100000)
neg_bigrams

# %%
wordcloud = WordCloud(width=1000, height=760,min_word_length =3,
                      background_color='red')
wordcloud.generate_from_frequencies(frequencies=neg_bigrams)
plt.figure( figsize=(15,10),facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
poz_bigrams = get_top_tfidf_bigrams(poz_corpus,100000)
poz_bigrams

# %%
wordcloud = WordCloud(width=1000, height=760,min_word_length =4,
                      background_color='white')
wordcloud.generate_from_frequencies(frequencies=poz_bigrams)
plt.figure( figsize=(20,10),facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# It's interesting to look at the dataset and see how similar the top words using both frequency and tfidf are for the different sentiments. They are close, it will be challenging to get the models to recognize the differences in the sentiments.

# %%
def reduct_product_columns(col):
    col.replace('iPad','Apple')
    col.replace('iPhone','Apple')
    col.replace('iPad or iPhone App')
    col.replace('Android','Google')
    col.replace('Other Google product or service','Google')
    col.replace('google','Google')
    col.replace('ipad','Apple')
    col.replace('apple','Apple')

# %%
apple_dict = dict(zip(["iPad", "iPhone", "iPad or iPhone App",'ipad','apple'], ["Apple"]*5))
google_dict = dict(zip(['Android','Other Google product or service','google'],['Google']*3))

# %%
data['Parent_Company']=data['Parent_Company'].replace(apple_dict)
data['Parent_Company']=data['Parent_Company'].replace(google_dict)

# %%
data['Parent_Company'].value_counts()
# Out:
# Apple     4854
# Google    2622
# Name: Parent_Company, dtype: int64

# %%
data['Parent_Company']=data['Product']

# %%
data.groupby('Parent_Company').Sentiment.value_counts(normalize=True).unstack(1).plot.bar(figsize=(8,6))
plt.xticks(rotation=0)
plt.title('Sentiment Percentage by Parent Company')
plt.xlabel('Parent Company')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# ## EDA Assessments

# %% [markdown]
# The dataset presents processing challenges. I am allowing misspellings and abbreviations as the wordclouds revealed enough differences in the dataset for modeling. There is a lot of overlap in the wordclouds and frequencies, but there is also many differences. Removing observations will help the modeling process. There is a negative sentiment towards some apple products, but those may be balanced by positive feelings as well.
#
# The challenges to machine learning with NLP are certainly a preprocessing struggle as much as a struggle with any other portion of the work. It is fascinating to see the phrases that bubble up, particulary the negative phrases.
