# %%
#Basic Imports
import pandas as pd
import numpy as np

# %%
#sklearn imports
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn import feature_extraction, model_selection, naive_bayes, pipeline, manifold, preprocessing 
from sklearn.pipeline import Pipeline
from sklearn.dummy import DummyClassifier

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
from skopt import BayesSearchCV
from sklearn.model_selection import GridSearchCV
from skopt.space import Real, Categorical, Integer
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import ComplementNB
from sklearn.ensemble import RandomForestClassifier
import pickle

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
#Natural Language Toolkit Imports
from nltk.tokenize import regexp_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords, wordnet
from nltk import pos_tag
import nltk

# %%
from Helpers import functions as fn
import re
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/seanyboy/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
sns.set_theme('talk')
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Processing Text

# %% [markdown]
# This notebook will be used for various conventional model iterations. These models will be compared to deeper neural network models. I will select the best model and save them for later use.

# %%
df = pd.read_csv('product_processed.csv')

# %%
df['processed_text']=fn.Process_Tweet(df['tweet_text'],remove_HTML=True,remove_numerals=True,replace_moji_bake=True,remove_hashtags=True,contraction_fix=True,no_leading=True,lower=True,remove_mentions=True)
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
df['processed_text'].head(5)
# Out:
# 0     i have a  three g iphone. after  three  hrs t...
# 1     know about  ? awesome ipad/iphone app that yo...
# 2     can not wait for   two  also. they should sal...
# 3     i hope this year's festival is not as crashy ...
# 4     great stuff on fri : marissa mayer (google), ...
# Name: processed_text, dtype: object

# %% [markdown]
# ### Parts of Speech Tags

# %% [markdown]
# I will be attatching parts of speech tags for lemmitization processing.

# %%
#Grabbing Stopwords from NLTK
sw = stopwords.words('english')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/seanyboy/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### Changing Sentiment Target to Numeric

# %%
#Setting Target as numeric
df['Sentiment']=df['Sentiment'].replace({"Positive": 0, "Negative": 1, "Neutral": 3}).astype(np.uint8)
#combining neutral and positive sentiments
df['Sentiment']=df['Sentiment'].replace(3,0).copy()

# %%
# df=df[df['Sentiment']!=3]

# %%
y = df['Sentiment']

# %%
df['Sentiment'].value_counts(normalize=True)
# Out:
# 0    0.925094
# 1    0.074906
# Name: Sentiment, dtype: float64

# %% [markdown]
# Clearly still an imbalanced dataset, we are going to prioritize finding the minority class.

# %%
X = df['processed_text']
token_docs = [fn.doc_preparer(doc, sw) for doc in X]
# Out:
# ['three', 'g', 'iphone', 'three', 'hrs', 'tweeting', 'dead', 'need', 'upgrade', 'plugin', 'stations']
# ['know', 'awesome', 'ipad', 'iphone', 'app', 'likely', 'appreciate', 'design', 'also', 'giving', 'free', 'ts']
# ['wait', 'two', 'also', 'sale']
# ['hope', 'year', 'festival', 'crashy', 'year', 'iphone', 'app']
# ['great', 'stuff', 'fri', 'marissa', 'mayer', 'google', 'tim', 'reilly', 'tech', 'books', 'conferences', 'matt', 'mullenweg', 'wordpress']
# ['new', 'ipad', 'apps', 'communication', 'showcased', 'conference', 'http', 'ht', 'ly', 'forty', 'nine', 'n', 'four']
# ['starting', 'around', 'corner', 'hop', 'skip', 'jump', 'good', 'time', 'fan']
# ['beautifully', 'smart', 'simple', 'idea', 'rt', 'wrote', 'ipad', 'app', 'http', 'bit', 'ly', 'ieavob']
# ['counting', 'days', 'plus', 'strong', 'canadian', 'dollar', 'means', 'stock', 'apple', 'gear']
# ['excited', 'meet', 'show', 'sprint', 'galaxy', 'still', 'running', 'android', 'two', 'one']
# ['find', 'start', 'impromptu', 'parties', 'http', 'bit', 'ly', 'gvlrin', 'cannot', 'wait', 'til', 'android', 'app', 'comes']
# ['foursquare', 'ups', 'game', 'time', 'http', 'j', 'mp', 'grn', 'seven', 'pk', 'still', 'prefer', 'far', 'best', 'looking', 'android', 'app', 'date']
# ['got', 'love', 'google', 'calendar', 'featuring', 'top', 'parties', 'show', 'cases', 'check', 'rt', 'via', 'http', 'bit', 'ly', 'axzwxb']
# ['great', 'ipad', 'app', 'http', 'tinyurl', 'com', 'four', 'nqv', 'ninety', 'two', 'l']
# ['haha', 'awesomely', 'rad', 'ipad', 'app', 'http', 'bit', 'ly', 'htdfim']
# ['holler', 'gram', 'ipad', 'itunes', 'app', 'store', 'http', 'co', 'kfn', 'three', 'f', 'five', 'q', 'via']
# ['noticed', 'dst', 'coming', 'weekend', 'many', 'iphone', 'users', 'hour', 'late', 'sxsw', 'come', 'sunday', 'morning']
# ['added', 'flights', 'matching', 'people', 'planes', 'airports', 'also', 'downloaded', 'iphone', 'app', 'nicely', 'done']
# ['must', 'app', 'rt', 'lovely', 'review', 'forbes', 'sxsw', 'ipad', 'app', 'holler', 'gram', 'http', 'co', 'g', 'four', 'gzypv']
# ['need', 'buy', 'ipad', 'two', 'austin', 'sure', 'need', 'q', 'austin', 'apple', 'store']
# ['oh', 'god', 'app', 'ipad', 'pure', 'unadulterated', 'awesome', 'easier', 'browse', 'events', 'ipad', 'website']
# ['okay', 'really', 'yay', 'new', 'app', 'eleven', 'kthxbai']
# ['photo', 'installed', 'iphone', 'app', 'really', 'nice', 'http', 'tumblr', 'com', 'x', 'six', 'one', 'pi', 'six', 'av', 'seven']
# ['really', 'enjoying', 'changes', 'gowalla', 'three', 'zero', 'android', 'looking', 'forward', 'seeing', 'else', 'foursquare', 'sleeves']
# ['rt', 'looking', 'forward', 'pre', 'party', 'wed', 'hoping', 'win', 'resulting', 'shameless', 'promotion']
# ['rt', 'haha', 'awesomely', 'rad', 'ipad', 'app', 'http', 'bit', 'ly', 'htdfim', 'via']
# ['someone', 'started', 'group', 'google', 'groups', 'pre', 'great', 'idea']
# ['new', 'looks', 'like', 'going', 'rock', 'update', 'iphone', 'android', 'push', 'tonight', 'http', 'bit', 'ly', 'etsbzk']
# ['right', 'three', 'app', 'sweeeeet', 'nice', 'job', 'team']
# ['smart', 'ipad', 'app', 'http', 'co', 'three', 'xvwc', 'six', 'may', 'leave', 'vuvuzela', 'home']
# ['must', 'app', 'ipad', 'going', 'http', 'itunes', 'apple', 'com', 'us', 'app', 'holler', 'gram', 'id', 'four', 'hundred', 'twenty', 'million', 'six', 'hundred', 'sixty', 'six', 'thousand', 'four', 'hundred', 'thirty', 'nine', 'mt', 'eight']
# ['attn', 'frineds', 'register', 'see', 'cobra', 'iradar', 'android', 'link']
# ['anyone', 'want', 'sell', 'old', 'ipad']
# ['anyone', 'bought', 'new', 'ipad', 'want', 'sell', 'older', 'ipad']
# ['oooh', 'rt', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['best', 'rt', 'ha', 'first', 'line', 'pop', 'apple', 'store', 'event', 'planner']
# ['spin', 'play', 'new', 'concept', 'music', 'discovery', 'ipad', 'spin', 'com', 'link']
# ['false', 'alarm', 'google', 'circles', 'coming', 'nowand', 'probably', 'ever', 'link']
# ['great', 'weather', 'greet', 'still', 'need', 'sweater', 'night', 'apple', 'putting', 'flash', 'store', 'downtown', 'sell', 'ipad', 'two']
# ['hey', 'long', 'think', 'takes', 'us', 'make', 'iphone', 'case', 'answer', 'using', 'make', 'one']
# ['pad', 'rt', 'new', 'app', 'store', 'includes', 'uberguide', 'sponsored', 'link']
# ['opens', 'instant', 'access', 'waited', 'get', 'one', 'link']
# ['hand', 'held', 'hobo', 'drafthouse', 'launches', 'hobo', 'shotgun', 'iphone', 'app', 'link']
# ['hooray', 'rt', 'apple', 'opening', 'pop', 'store', 'austin', 'link']
# ['orly', 'google', 'set', 'launch', 'new', 'social', 'network', 'today']
# ['wooooo', 'apple', 'store', 'downtown', 'austin', 'open', 'til', 'midnight']
# ['khoi', 'vinh', 'says', 'conde', 'nast', 'headlong', 'rush', 'ipad', 'publishing', 'fundamental', 'misunderstanding', 'platform']
# ['connect', 'digital', 'physical', 'worlds', 'mobile', 'link']
# ['talking', 'link', 'google', 'effort', 'allow', 'users', 'open', 'systems']
# ['link', 'rt', 'google', 'tweet', 'new', 'think', 'speak', 'mark', 'belinsky', 'panel']
# ['link', 'rt', 'one', 'st', 'stop', 'hunt', 'austin', 'java', 'get', 'spy', 'game', 'four', 'chance', 'two', 'win', 'ipad']
# ['link', 'rt', 'check', 'holler', 'gram', 'ipad', 'app', 'link']
# ['fun', 'pic', 'link']
# ['via', 'link', 'guy', 'kawasaki', 'talks', 'enchanted', 'sxsw', 'knows', 'stuff']
# ['link', 'spec', 'recipes', 'web', 'google', 'search', 'link']
# ['rt', 'heard', 'apple', 'pop', 'store', 'downtown', 'austin', 'pics', 'already', 'gowalla', 'link']
# ['rt', 'think', 'apple', 'pop', 'store', 'austin', 'would', 'lot', 'interesting', 'actually', 'know', 'popped']
# ['rt', 'line', 'apple', 'store', 'insane']
# ['attending', 'ipad', 'design', 'headaches', 'link']
# ['check', 'line', 'ipad', 'two', 'austin', 'power', 'link']
# ['check', 'rt', 'giving', 'added', 'value', 'location', 'based', 'services', 'needs', 'battle', 'check', 'fatigue']
# ['rt', 'come', 'party', 'w', 'google', 'tonight', 'link', 'bands', 'food', 'art', 'ice', 'cream', 'nifty', 'interactive', 'maps']
# ['ha', 'ha', 'rt', 'news', 'yahoo', 'com', 'loosing', 'search', 'traffic', 'new', 'site', 'google', 'com', 'doubt', 'last', 'though', 'w', 'weird', 'name']
# ['holla', 'rt', 'google', 'party', 'best', 'ever', 'get', 'butt']
# ['love', 'iphone', 'case', 'cannot', 'get', 'phone']
# ['ipad', 'two', 'rt', 'droid', 'mac', 'rt', 'confession', 'using', 'laptop', 'ipad', 'blackberry', 'follow']
# ['new', 'post', 'iphone', 'app', 'makes', 'easy', 'connect', 'social', 'networks', 'people', 'meet', 'link']
# ['nice', 'iphone', 'app', 'behaving', 'today', 'crashes', 'yesterday', 'ridiculous']
# ['nice', 'rt', 'apple', 'opening', 'popup', 'store', 'ipad', 'launch', 'downtown', 'austin', 'link', 'via']
# ['nice', 'rt', 'hey', 'apple', 'fans', 'get', 'peek', 'space', 'slated', 'pop', 'apple', 'store', 'tomorrow', 'link']
# ['one', 'thing', 'great', 'get', 'great', 'earth', 'face', 'google', 'company', 'love']
# ['thanks', 'mention', 'new', 'ipad', 'apps', 'showcased', 'conf', 'link']
# ['provide', 'iphone', 'chargers', 'changed', 'mind', 'going', 'next', 'year']
# ['xmas', 'rt', 'shiny', 'new', 'apps', 'new', 'book', 'pop', 'ipad', 'two', 'stores', 'christmas', 'nerds']
# ['yai', 'rt', 'new', 'app', 'store', 'includes', 'uberguide', 'sponsored', 'cont', 'link']
# ['fast', 'fun', 'future', 'google', 'presenting', 'search', 'local', 'mobile']
# ['gsd', 'google', 'industry', 'party', 'tonight', 'see', 'link']
# ['new', 'buzz', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'rt']
# ['headline', 'two', 'must', 'gadget', 'hmm', 'could', 'seen', 'one', 'coming', 'link']
# ['know', 'dataviz', 'translates', 'satanic', 'iphone', 'sayin']
# ['google', 'launched', 'checkins', 'month', 'ago', 'check', 'ins', 'ok', 'check', 'outs', 'future']
# ['google', 'launched', 'checkins', 'month', 'ago', 'check', 'ins', 'ok', 'check', 'outs', 'future', 'via']
# ['google', 'tweet', 'new', 'think', 'speak', 'mark', 'belinsky', 'panel']
# ['attending', 'left', 'brain', 'search', 'google', 'right', 'brain', 'search', 'x', 'talking', 'future', 'search', 'engines']
# ['opens', 'mobile', 'park', 'content', 'incubator', 'link', 'constructs', 'pop', 'store', 'link']
# ['kawasaki', 'c', 'lewis', 'level', 'reasoning', 'apple', 'continued', 'existence', 'evidence', 'existence', 'god']
# ['kawasaki', 'pagemaker', 'saved', 'apple', 'oh', 'days']
# ['kawasaki', 'pagemaker', 'saved', 'apple', 'oh', 'days', 'via']
# ['unboxing', 'apple', 'store', 'sxsw', 'link']
# ['ipad', 'two', 'great', 'thoughts', 'w', 'japan', 'apac', 'regions', 'dealing', 'w', 'earthquake', 'tsunami', 'trauma']
# ['schools', 'experts', 'sxsw', 'cnet', 'blogs', 'link']
# ['schools', 'marketing', 'experts', 'link']
# ['schools', 'marketing', 'experts', 'link']
# ['temporary', 'store', 'def', 'tent', 'powerhouse', 'gym', 'link']
# ['temporary', 'store', 'six', 'th', 'congress', 'along', 'ten', 'zero', 'happy', 'hipsters']
# ['wins', 'link', 'opening', 'temporary', 'store', 'downtown', 'austin', 'support', 'launch', 'good']
# ['trending', 'today', 'fun', 'nerdy', 'nerds']
# ['funny', 'trending', 'matter', 'minutes', 'point', 'least', 'according', 'twitter', 'iphone']
# ['christian', 'devs', 'want', 'talk', 'maybe', 'wk', 'together', 'cool', 'app']
# ['remember', 'ultimately', 'aware', 'audience', 'app', 'targeted', 'towards', 'unexpected', 'experience', 'good']
# ['apple', 'taken', 'storm', 'link', 'excited', 'part']
# ['haz', 'ifrom', 'gr', 'eight', 'link']
# ['stacks', 'waiting', 'bought', 'got', 'mine', 'hassle', 'apple', 'handled', 'perfectly', 'link']
# ['future', 'elusive', 'power', 'link', 'via']
# ['need', 'reviews', 'play', 'google', 'places', 'got', 'app', 'link']
# ['need', 'reviews', 'play', 'google', 'places', 'got', 'app', 'link']
# ['follow', 'lead', 'link']
# ['follow', 'lead', 'link', 'via', 'rg']
# ['take', 'rt', 'major', 'south', 'korean', 'director', 'gets', 'one', 'hundred', 'thirty', 'zero', 'make', 'movie', 'entirely', 'iphone', 'link']
# ['beautiful', 'apple', 'store', 'sxsw', 'pic', 'link']
# ['q', 'one', 'prep', 'amazing', 'pre', 'push', 'locally', 'focus', 'location', 'based', 'google', 'owns', 'ten', 'regions', 'billboards']
# ['accounts', 'need', 'follow', 'apps', 'download', 'iphone']
# ['way', 'apple', 'store', 'sold', 'three', 'g', 'models', 'vzw']
# ['must', 'app', 'rt', 'lovely', 'review', 'forbes', 'sxsw', 'ipad', 'app', 'holler', 'gram', 'link']
# ['temporary', 'apple', 'store', 'apple', 'sneaky', 'usual', 'link']
# ['anyone', 'pop', 'apple', 'store', 'austin', 'got', 'hopping', 'place', 'today']
# ['beta', 'testing', 'interactive', 'book', 'ipad', 'app', 'moonbot', 'studios', 'louisiana', 'cool', 'app']
# ['apple', 'day', 'one', 'seeing', 'ton']
# ['giving', 'away', 'two', 'new', 'ipad', 'two', 'wifi', 'thirty', 'two', 'g', 'black', 'apple', 'cover', 'tweet', 'fo', 'info', 'tonight', 'bo', 'lt', 'house']
# ['anyone', 'chance', 'check', 'pop', 'apple', 'store', 'wondering', 'worth', 'trek', 'convention', 'center']
# ['ipad', 'store', 'sold', 'everything', 'except', 'sixty', 'four', 'gig', 'wifi', 'white', 'manage', 'get']
# ['ipad', 'store', 'sold', 'everything', 'except', 'sixty', 'four', 'gig', 'wifi', 'white', 'also', 'known', 'white', 'jeans', 'configuration']
# ['offered', 'ipad', 'promo', 'ninjafinder', 'users', 'fans', 'sucks']
# ['austin', 'conference', 'google', 'search', 'interactive', 'music', 'film']
# ['marc', 'ecko', 'launches', 'app', 'autodial', 'political', 'change', 'link']
# ['learning', 'life', 'changing', 'impact', 'ipad', 'real', 'people', 'actual', 'lives', 'bravo']
# ['lonelyplanet', 'austin', 'guide', 'free', 'limited', 'time', 'link']
# ['anyone', 'heading', 'aclu', 'event', 'seen', 'owt', 'google', 'circles']
# ['prompt', 'memory', 'go', 'google', 'map', 'describe', 'childhood', 'walk']
# ['apple', 'store', 'still', 'ipad', 'two', 'short', 'lines']
# ['left', 'tradeshow', 'demo', 'google', 'theatre', 'ok', 'get', 'see', 'presenters', 'using']
# ['following', 'tweets', 'google', 'realtime', 'four', 'platforms', 'tweet', 'deck', 'listening', 'panel', 'realizing', 'spoken', 'one', 'today']
# ['anyone', 'want', 'ipad', 'two', 'line', 'pick', 'one', 'someone', 'willing', 'pay', 'fifty', 'grab', 'one']
# ['anyone', 'want', 'make', 'quick', 'hundred', 'dollars', 'new', 'ad', 'hoc', 'apple', 'store', 'gets', 'hundred', 'plus', 'cost']
# ['monday', 'barry', 'diller', 'new', 'york', 'times', 'congress', 'lunch', 'w', 'hotel', 'party', 'google', 'party', 'six', 'dirty', 'martinis', 'mondays']
# ['seriously', 'testing', 'mobile', 'apps', 'constant', 'ipad', 'crashes', 'causing', 'lost', 'schedules', 'sync', 'wp', 'seven']
# ['ready', 'iphone', 'apps', 'two', 'make', 'blogging', 'easier', 'link']
# ['ipad', 'two', 'conflagration', 'doofusness', 'link']
# ['attention', 'ers', 'link', 'rumored', 'pop', 'temporary', 'apple', 'store', 'ipad', 'two', 'launch', 'needs']
# ['went', 'lousy', 'link']
# ['picture', 'link']
# ['gsd', 'google', 'seven', 'ten', 'rt', 'best', 'party', 'hit', 'tonight']
# ['gsd', 'google', 'industry', 'party', 'great', 'meet', 'link']
# ['spent', 'one', 'zero', 'come', 'sxsw', 'already', 'used', 'ipad', 'one', 'wait', 'couple', 'city', 'blocks', 'link']
# ['day', 'one', 'marissa', 'mayer', 'google', 'connect', 'digital', 'physical', 'worlds', 'mobile', 'link']
# ['behind', 'one', 'hundred', 'emails', 'give', 'one', 'line', 'iphone', 'composed', 'replies']
# ['like', 'ten', 'pm', 'night', 'line', 'around', 'block', 'popup', 'apple', 'stores', 'selling', 'ipad', 'two']
# ['one', 'hundred', 'fifty', 'million', 'mobile', 'users', 'google', 'maps', 'mobile']
# ['currently', 'one', 'hundred', 'fifty', 'people', 'line', 'pop', 'apple', 'store']
# ['ipad', 'two', 'available', 'sixty', 'four', 'gb', 'wifi', 'model', 'six', 'hundred', 'ninety', 'nine', 'plus', 'optional', 'leather', 'smart', 'cover', 'sixty', 'nine']
# ['less', 'two', 'hours', 'announce', 'details', 'ipad', 'two', 'giveaway']
# ['two', 'ipad', 'two', 'seen', 'wild', 'people', 'say', 'fast', 'still', 'pics', 'terrible']
# ['ipad', 'two', 'queue', 'course']
# ['two', 'takes', 'video', 'link']
# ['many', 'ipad', 'two', 'snapping', 'away', 'keynote', 'slides']
# ['apple', 'two', 'hundred', 'users', 'credit', 'cards', 'sync', 'itunes', 'one', 'click', 'purchase']
# ['two', 'nd', 'cocktail', 'texas', 'snowflake', 'google']
# ['new', 'post', 'three', 'iphone', 'apps', 'using', 'south', 'southwest', 'interactive', 'link']
# ['new', 'post', 'three', 'iphone', 'apps', 'using', 'south', 'southwest', 'interactive', 'link']
# ['sweet', 'new', 'three', 'google', 'maps', 'demo', 'going', 'ballroom']
# ['thirty', 'five', 'million', 'miles', 'per', 'day', 'driving', 'google', 'maps', 'navigation']
# ['rt', 'four', 'p', 'line', 'apple', 'store', 'longer', 'wider', 'two', 'hundred', 'fifty', 'people', 'one', 'hour']
# ['smart', 'four', 'packing', 'extra', 'rt', 'way', 'sunny', 'austin', 'extra', 'iphone', 'stow', 'case']
# ['wonder', 'four', 'sqwill', 'attempt', 'block', 'gowalla', 'cross', 'checkins', 'way', 'facebook', 'blocked', 'google', 'contacts', 'connections']
# ['day', 'five', 'store', 'still', 'line', 'growing', 'link']
# ['wandering', 'six', 'th', 'street', 'girls', 'stopped', 'ceviche', 'mojitos', 'apple', 'juice', 'ice', 'cream']
# ['band', 'want', 'share', 'track', 'audience', 'stage', 'use', 'frostwire', 'android', 'wi', 'fi', 'available']
# ['got', 'busy', 'week', 'ahead', 'new', 'book', 'apps', 'available', 'amazon', 'attending']
# ['believe', 'went', 'aussies', 'rt', 'ipad', 'two', 'sold', 'seventy', 'went', 'new', 'buyers', 'report', 'link']
# ['google', 'spreadsheet', 'two', 'hundred', 'seventy', 'parties', 'year', 'link', 'plan', 'going', 'party']
# ['guy', 'line', 'apple', 'pop', 'store', 'sixth', 'street', 'austin', 'guy', 'told']
# ['iphone', 'need', 'car', 'use', 'zimride', 'etc', 'share', 'rides']
# ['seen', 'lot', 'tablets', 'every', 'single', 'one', 'ipad']
# ['receiving', 'lot', 'messages', 'telling', 'sexy', 'response', 'post', 'looking', 'meet', 'fellow', 'christian', 'iphone', 'devs']
# ['picked', 'mophie', 'battery', 'case', 'four', 'iphone', 'prep', 'lugging', 'around', 'laptop', 'using', 'phone', 'huge', 'win', 'last', 'year']
# ['news', 'p', 'rt', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['rumor', 'monger', 'good', 'read', 'preview', 'link', 'via']
# ['hobo', 'shotgun', 'iphone', 'game', 'link']
# ['hobo', 'shotgun', 'video', 'game', 'coming', 'ipad', 'iphone', 'users', 'yes', 'please', 'link']
# ['build', 'store', 'less', 'twenty', 'four', 'hours', 'one', 'biggest', 'launches', 'company', 'history', 'got']
# ['took', 'survey', 'iphone', 'starbucks', 'line', 'got', 'free', 'starbucks', 'gift', 'card', 'instant', 'research', 'instant', 'gratification']
# ['read', 'sounds', 'like', 'incredible', 'app', 'available', 'android', 'phones', 'yet']
# ['wondering', 'circles', 'google', 'reveal', 'new', 'social', 'network', 'link']
# ['google', 'search', 'local', 'marissa', 'mayer']
# ['wondering', 'street', 'closures', 'sxsw', 'made', 'google', 'map', 'show', 'link']
# ['questions', 'inside', 'ipad', 'two', 'fire', 'way']
# ['apple', 'iie', 'ad', 'eighty', 'five', 'si', 'swimsuit', 'issue', 'garage', 'sale', 'link']
# ['flipboard', 'adds', 'instagram', 'photos', 'social', 'search', 'apps', 'link']
# ['iphone', 'alarms', 'botch', 'timechange', 'many', 'ers', 'freak', 'late', 'flights', 'missed', 'panels', 'behind', 'bloody', 'marys']
# ['shouts', 'ladies', 'holding', 'ipad', 'two', 'free', 'shows', 'take', 'photos', 'sipping', 'free', 'beer', 'cc']
# ['dj', 'hoodie', 'allen', 'due', 'respect', 'probably', 'make', 'way', 'back', 'google']
# ['meant', 'also', 'wish', 'stupid', 'iphone']
# ['audioboo', 'american', 'dream', 'bust', 'link']
# ['skifta', 'app', 'based', 'media', 'shifting', 'service', 'turns', 'android', 'phone', 'link']
# ['rumors', 'apple', 'store', 'opening', 'six', 'th', 'congress', 'signs', 'point', 'yes', 'link']
# ['apple', 'security', 'guy', 'locks', 'store', 'link']
# ['apple', 'security', 'guy', 'locks', 'store', 'realtime', 'sxsw', 'link', 'curated']
# ['got', 'ipad', 'two', 'link', 'cc']
# ['picked', 'ipad', 'two', 'pop', 'apple', 'store', 'fifteen', 'minute', 'wait']
# ['brilliant', 'enlightening', 'game', 'mechanics', 'presentation', 'google']
# ['gsd', 'google', 'sitting', 'tree', 'link']
# ['pic', 'winning', 'ipad', 'cc', 'link', 'cont', 'link']
# ['iphone', 'thirsty', 'chevy', 'volt', 'lounge', 'w', 'sixteen', 'others', 'link']
# ['iphone', 'thirsty', 'chevy', 'volt', 'lounge', 'w', 'sixteen', 'others', 'link', 'link']
# ['came', 'left', 'iphone', 'playing', 'song', 'chosen', 'random', 'skream', 'listening', 'records', 'wall', 'appropriate']
# ['marketing', 'sales', 'genius', 'link']
# ['reminder', 'android', 'chrome', 'tts', 'talk', 'one', 'pm', 'today', 'link']
# ['backupify', 'announces', 'cloudsight', 'search', 'first', 'searchable', 'archive', 'solution', 'social', 'media', 'google', 'apps', 'link']
# ['google', 'announcing', 'social', 'network', 'circles', 'via', 'tweets', 'interesting', 'myopia', 'cause', 'buzz', 'jokes', 'interesting']
# ['need', 'ipad', 'iphone', 'laptop', 'dictaphone', 'vid', 'camera', 'wow', 'love', 'meet', 'real', 'cerebellum', 'charged', 'people']
# ['see', 'anything', 'google', 'circles']
# ['app', 'iphone', 'ridiculous', 'personal', 'planner', 'next', 'five', 'days']
# ['found', 'app', 'kyping', 'iphone', 'geolocation', 'releasing', 'background', 'need', 'patch']
# ['app', 'iphone', 'live', 'rsvp', 'events', 'phone', 'check', 'sundayswagger', 'eventbrite', 'com', 'three', 'twenty']
# ['iphone', 'app', 'screen', 'missing', 'link']
# ['love', 'app', 'awesome', 'rt', 'must', 'see', 'app', 'bizzy', 'link']
# ['apple', 'pop', 'store', 'nuts', 'still', 'packed', 'eleven', 'thirty', 'link']
# ['say', 'apple', 'popup', 'store', 'austin', 'link']
# ['course', 'apple', 'built', 'temp', 'store', 'austin', 'texas', 'understand', 'concept', 'corralling', 'cattle']
# ['love', 'apple', 'let', 'something', 'like', 'retail', 'store', 'near', 'keep', 'away', 'opening', 'pop', 'store', 'link']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'get', 'new', 'link']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'get', 'new', 'ipads', 'link']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'get', 'new', 'ipads', 'http', 'link']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'get', 'new', 'ipads', 'link']
# ['apple', 'heads', 'sxsw', 'sets', 'temporary', 'store', 'austin', 'link']
# ['apple', 'great', 'example', 'retail', 'store', 'layed', 'future', 'registers', 'checkout', 'line']
# ['apple', 'opening', 'temporary', 'store', 'downtown', 'austin', 'ipad', 'two', 'launch', 'link']
# ['apple', 'opening', 'temporary', 'store', 'downtown', 'austin', 'ipad', 'two', 'launch', 'oh', 'yay', 'traffic']
# ['apple', 'opening', 'pop', 'store', 'austin', 'sxsw', 'link']
# ['apple', 'opening', 'pop', 'store', 'austin', 'sxsw', 'geekfest', 'apple', 'link']
# ['apple', 'popup', 'store', 'open', 'noon', 'fresh', 'shipment', 'ipad', 'two', 'pretty', 'sure', 'going', 'get', 'one', 'fingers', 'crossed']
# ['apple', 'saves', 'sxsw', 'set', 'open', 'pop', 'store', 'link']
# ['apple', 'schools', 'marketing', 'experts', 'link']
# ['apple', 'schools', 'marketing', 'experts', 'link']
# ['apple', 'schools', 'marketing', 'experts', 'link', 'via']
# ['apple', 'schools', 'marketing', 'experts', 'link', 'via', 'true', 'love', 'loathe', 'one', 'marketing', 'like']
# ['apple', 'schools', 'marketing', 'experts', 'cnet', 'link']
# ['apple', 'schools', 'marketing', 'experts', 'cnet', 'blogs', 'link']
# ['apple', 'store', 'downtown', 'austin', 'open', 'til', 'midnight', 'still', 'time']
# ['apple', 'store', 'congress', 'link']
# ['apple', 'store', 'mall', 'sunday', 'ten', 'x', 'crowded', 'line', 'fake', 'need', 'fucking', 'dongle', 'genius', 'let']
# ['two', 'wks', 'apple', 'store', 'six', 'th', 'austin', 'street', 'opened']
# ['makeshift', 'apple', 'store', 'six', 'th', 'congress', 'kidding', 'amazing']
# ['temporary', 'apple', 'store', 'huge', 'line', 'link']
# ['temporary', 'apple', 'store', 'sxsw', 'really', 'cool', 'ipad', 'two']
# ['temporary', 'apple', 'store', 'set', 'shit', 'temptation', 'going', 'control']
# ['temporary', 'apple', 'store', 'line', 'goes', 'around', 'block', 'link']
# ['temporary', 'apple', 'store', 'opens', 'five', 'pm', 'six', 'th', 'congress', 'line', 'already', 'growing', 'view', 'io', 'link', 'via']
# ['temporary', 'apple', 'store', 'block', 'office', 'cannot', 'wait', 'see', 'line', 'tomorrow', 'photos', 'come']
# ['apple', 'store', 'opens', 'noon', 'day', 'closes', 'run', 'ipad', 'two', 'buy', 'stock', 'ten', 'years', 'ago']
# ['base', 'camp', 'apple', 'link']
# ['ipad', 'news', 'apps', 'last', 'year', 'link']
# ['ten', 'iphone', 'apps', 'probably', 'need', 'use', 'link']
# ['one', 'hundred', 'fifty', 'million', 'mobile', 'google', 'maps', 'users']
# ['lines', 'already', 'forming', 'apple', 'pop', 'store', 'austin', 'people', 'see', 'festival', 'link']
# ['android', 'rt', 'ten', 'new', 'mobile', 'apps', 'using', 'sxsw', 'link']
# ['attending', 'sxsw', 'report', 'see', 'android', 'phone', 'get', 'bannka', 'app']
# ['ipad', 'apps', 'like', 'software', 'development', 'release', 'start', 'working', 'update']
# ['tweets', 'stalled', 'data', 'sluggish', 'come', 'verizon', 'embarrassing', 'iphone', 'customers', 'switched']
# ['tweeting', 'google', 'coming', 'circles', 'platform', 'today', 'outside', 'circle', 'keep']
# ['slate', 'see', 'much', 'traffic', 'mobile', 'safari', 'app', 'ipad']
# ['unloading', 'store', 'corner', 'six', 'th', 'congress', 'austin', 'temp', 'store', 'link']
# ['great', 'day', 'jaloux', 'new', 'ipad', 'look', 'school', 'bus', 'one', 'st', 'day', 'school', 'link']
# ['arrived', 'issue', 'resolved', 'dying', 'use', 'iphone', 'app', 'cannot', 'login', 'rt']
# ['screenburn', 'launch', 'clients', 'new', 'iphone', 'game', 'find', 'link']
# ['anyone', 'wants', 'see', 'demo', 'piccraft', 'ipad', 'two', 'find']
# ['want', 'ipad', 'two', 'apple', 'setting', 'temporary', 'store', 'check', 'link']
# ['overheard', 'ipad', 'relaxing', 'computer', 'agreed']
# ['overheard', 'interactive', 'arg', 'hate', 'iphone', 'want', 'blackberry', 'back']
# ['meet', 'author', 'host', 'android', 'devs', 'sat', 'twelve', 'thirty', 'pm', 'hilton', 'room', 'six', 'hundred', 'fifteen', 'ab']
# ['apple', 'comes', 'cool', 'technology', 'one', 'ever', 'heard', 'go', 'conferences']
# ['apple', 'sets', 'five', 'zero', 'square', 'foot', 'temporary', 'store', 'sxsw', 'sell', 'new', 'ipads', 'test', 'potential', 'traffic', 'link']
# ['overheard', 'google', 'launch', 'products', 'people', 'events']
# ['nerd', 'bait', 'apple', 'set', 'open', 'popup', 'shop', 'core', 'sxsw', 'action', 'link']
# ['long', 'line', 'else', 'apple', 'store', 'link']
# ['last', 'year', 'everbody', 'talking', 'ipad', 'year', 'social', 'media', 'driven', 'revolutions', 'year', 'better']
# ['long', 'line', 'apple', 'pop', 'store', 'ipad', 'two', 'great', 'marketing', 'apple']
# ['google', 'four', 'people', 'work', 'seven', 'people', 'rather', 'seven', 'people', 'work', 'four']
# ['knackered', 'home', 'playing', 'ipad', 'updating', 'iphone', 'timeline', 'smashed', 'partytweets', 'cannot', 'make', 'go', 'bed']
# ['overheard', 'mdw', 'second', 'halfway', 'iphone', 'battery', 'already', 'even', 'boarded', 'plane']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'link']
# ['first', 'day', 'sxsw', 'fun', 'final', 'presentation', 'google', 'doodles']
# ['huge', 'line', 'store', 'crowd', 'tripping', 'get', 'new', 'ipad']
# ['eighty', 'party']
# ['queue', 'apple', 'pop', 'store', 'link']
# ['woman', 'google', 'talk', 'sounded', 'like', 'chelsea', 'handler', 'lol']
# ['laughed', 'ipad', 'spent', 'week', 'hauling', 'macbook', 'everywhere', 'really', 'want', 'ipad', 'shoulder', 'rub']
# ['attendees', 'need', 'qr', 'code', 'reader', 'iphone', 'tweet', 'us', 'image', 'badge', 'first', 'five', 'get', 'optiscan', 'free']
# ['hey', 'attendees', 'hop', 'line', 'store', 'four', 'days', 'til', 'new', 'ipad', 'two', 'comes']
# ['anyone', 'attending', 'google', 'aclu', 'party', 'sxsw', 'could', 'plz', 'pictures', 'thanks']
# ['march', 'eleven', 'austin', 'tx', 'people', 'line', 'registration', 'apple', 'store']
# ['landed', 'austin', 'spotted', 'google', 'places', 'ads', 'airport', 'ultimate', 'austin', 'pocket', 'guide', 'like']
# ['took', 'away', 'lego', 'pit', 'replaced', 'recharging', 'station', 'might', 'check', 'prices', 'iphone', 'crap', 'samsung', 'android']
# ['awesome', 'meet', 'standing', 'apple', 'queue', 'yesterday', 'day', 'two', 'cute']
# ['bad', 'apple', 'shows', 'late', 'qs', 'process', 'poo', 'poos', 'ideas', 'leaves', 'early', 'even', 'creative', 'busy']
# ['bahrain', 'govt', 'turned', 'google', 'earth', 'result', 'people', 'learned', 'govt', 'turn', 'back']
# ['trying', 'balance', 'power', 'power', 'needs', 'iphone', 'vs', 'ipad', 'three', 'g', 'ipad', 'sucks', 'quick', 'might', 'go', 'airplane', 'mode']
# ['iphone', 'battery', 'one', 'hundred']
# ['iphone', 'battery', 'cannot', 'keep', 'tweets', 'thanks', 'apple']
# ['another', 'google', 'wave', 'rt', 'interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'w', 'big', 'news', 'link']
# ['fun', 'watch', 'rt', 'apple', 'opening', 'pop', 'store', 'austin', 'sxsw', 'link']
# ['control', 'set', 'open', 'popup', 'shop', 'core', 'action', 'link', 'via', 'cc']
# ['yeah', 'sure', 'rt', 'check', 'link']
# ['celebrate', 'beauty', 'web', 'msft', 'launch', 'play', 'new', 'game', 'win', 'ipad', 'two', 'link']
# ['texas', 'amazing', 'met', 'many', 'influential', 'people', 'work', 'twitter', 'foursquare', 'microsoft', 'even', 'apple']
# ['woke', 'iphone', 'finished', 'recharging', 'means', 'got', 'enough', 'sleep', 'last', 'night', 'right']
# ['quiet', 'storm', 'looking', 'forward', 'seeing', 'google', 'marissa', 'mayer']
# ['best', 'thing', 'heard', 'weekend', 'gave', 'ipad', 'two', 'money', 'relief', 'need', 'ipad', 'two']
# ['ipad', 'two', 'better', 'time', 'improve']
# ['cus', 'pacman', 'google', 'singularity', 'noobs', 'meetup']
# ['link', 'go', 'beyond', 'earth', 'hour', 'year', 'sharing', 'positive', 'actions', 'world', 'download', 'sixty', 'iphone', 'app']
# ['google', 'vs', 'bing', 'bing', 'shot', 'success', 'w', 'structured', 'search', 'potentially', 'higher', 'margin', 'cpa', 'model', 'vs']
# ['course', 'bing', 'results', 'good', 'google']
# ['black', 'white', 'ipad', 'question']
# ['anyone', 'bringing', 'ipad', 'vs', 'computer']
# ['impulsive', 'buy', 'friends', 'one', 'selling', 'one', 'st', 'gen', 'thirty', 'two', 'gb', 'three', 'g', 'ipad']
# ['buying', 'two', 'new', 'ipad']
# ['someone', 'buying', 'present', 'rt', 'apple', 'opening', 'pop', 'store', 'austin', 'link']
# ['nice', 'find', 'rsq', 'link']
# ['south', 'southwest', 'panels', 'illustrated', 'pics', 'sometimes', 'best', 'link']
# ['google', 'calendar', 'saturday', 'night', 'giant', 'overlap', 'parties']
# ['google', 'canadian', 'tuxedo', 'lose', 'hours']
# ['exciting', 'wait', 'rt', 'apple', 'opening', 'temporary', 'store', 'downtown', 'austin', 'ipad', 'two', 'launch', 'link']
# ['great', 'certain', 'meetings', 'rt', 'hello', 'holler', 'gram', 'new', 'ipad', 'app', 'link']
# ['miss', 'charles', 'chen', 'android', 'chromeos', 'access', 'sxsw', 'google', 'booth', 'exhibit', 'hall', 'three', 'one', 'pm']
# ['group', 'chat', 'apps', 'told', 'l', 'two', 'apps', 'yet', 'avail', 'android', 'point', 'need', 'phone', 'apps']
# ['daily', 'chord', 'tuesday', 'march', 'eight', 'hackers', 'discover', 'google', 'music', 'servicestory', 'rollin', 'link']
# ['daily', 'chord', 'tuesday', 'march', 'eight', 'hackers', 'discover', 'google', 'music', 'servicestory', 'rolling', 'stone', 'mo', 'link']
# ['google', 'circle', 'austin', 'link']
# ['google', 'circles', 'link', 'ht', 'maybe', 'reconsidering', 'shape']
# ['google', 'circles', 'rt', 'launching', 'products', 'plenty', 'else']
# ['ten', 'austin', 'classics', 'missed', 'four', 'blog', 'com', 'twitter', 'iphone', 'three', 'twelve', 'eleven', 'twelve', 'forty', 'pm']
# ['trying', 'collaborate', 'events', 'friends', 'google', 'calendar', 'plancast']
# ['come', 'hear', 'speak', 'forty', 'mins', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'ballrm', 'eleven', 'zero']
# ['ipad', 'two', 'coming', 'guess', 'apple', 'pretty', 'desperate', 'give', 'attention']
# ['coming', 'sure', 'download', 'sxsw', 'go', 'app', 'schedules', 'locations', 'events', 'link']
# ['seriously', 'considering', 'leaving', 'macbook', 'pro', 'home', 'flying', 'solo', 'ipad', 'week', 'think', 'make', 'work']
# ['among', 'cool', 'goofy', 'things', 'spied', 'today', 'ipad', 'case', 'made', 'look', 'like', 'etchnsketch', 'grown', 'game', 'tug', 'war']
# ['could', 'find', 'probably', 'fiting', 'ipad']
# ['crazy', 'look', 'around', 'sxsw', 'realize', 'last', 'year', 'one', 'ipad']
# ['crazy', 'big', 'crowds', 'apple', 'store', 'sxsw', 'link']
# ['read', 'article', 'google', 'say', 'rumor', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'link']
# ['l', 'four', 'iphone', 'come', 'uj', 'booth', 'acc', 'hall', 'two', 'snap', 'pics', 'send', 'us', 'link']
# ['shipments', 'daily', 'follow', 'four', 'updates', 'rt', 'pop', 'apple', 'store', 'seems', 'pop', 'ipad', 'two']
# ['day', 'three', 'tired', 'hold', 'ipad', 'week', 'death', 'happy', 'death']
# ['beautiful', 'day', 'come', 'grab', 'slice', 'two', 'check', 'get', 'deal']
# ['four', 'days']
# ['iphone', 'dead', 'find', 'secret', 'batphone']
# ['excellent', 'deck', 'rt', 'nth', 'time', 'lucky', 'google', 'new', 'social', 'network', 'launch', 'maybe', 'link']
# ['default', 'state', 'users', 'leisurely', 'contemplative']
# ['mobile', 'definitely', 'hot', 'topic', 'year', 'every', 'session', 'standing', 'room', 'next', 'lessons', 'learnt', 'building', 'netflix', 'iphone', 'app']
# ['apple', 'deliberately', 'chose', 'march', 'eleven', 'ipad', 'two', 'availability', 'knowing', 'large', 'chunk', 'customer', 'base']
# ['google', 'tv', 'demo', 'league', 'extraordinary', 'hackers', 'cool', 'stuff', 'like', 'web', 'apps', 'tv']
# ['best', 'ipad', 'design', 'big', 'chunky', 'elements', 'generous', 'space', 'clarity', 'trumps', 'density', 'tap', 'quality', 'trumps', 'tap', 'quantity']
# ['attending', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'w', 'great', 'stuff', 'far']
# ['attending', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'akqa', 'lynn', 'teo', 'ballroom', 'yes', 'hiring']
# ['check', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas']
# ['check', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'link']
# ['headed', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'link']
# ['taking', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'link']
# ['adobe', 'developed', 'engine', 'essentially', 'convert', 'swf', 'files', 'jquery', 'html', 'five', 'existing', 'flash', 'files', 'portable', 'ipad']
# ['behaviour', 'different', 'lots', 'phone', 'calls', 'using', 'ipad', 'laptop', 'notsomuch', 'mobiles', 'internets']
# ['barry', 'diller', 'thinks', 'ipad', 'content', 'nuts', 'link']
# ['really', 'need', 'another', 'big', 'social', 'network', 'right', 'thanks', 'link']
# ['q', 'two', 'think', 'google', 'check', 'offers', 'testing', 'link']
# ['japan', 'docomo', 'introduced', 'mobile', 'apps', 'six', 'years', 'apple', 'came', 'app', 'store']
# ['bad', 'button', 'rt', 'know', 'time', 'abnormal', 'amount', 'app', 'updates', 'iphone']
# ['web', 'devs', 'wait', 'line', 'ipad', 'two', 'signup', 'new', 'relic', 'using', 'promo', 'sxsw', 'two', 'thousand', 'eleven', 'eligible', 'win', 'one', 'link']
# ['guess', 'drew', 'bigger', 'crowd', 'chimp', 'could', 'work', 'sorry']
# ['jeez', 'guys', 'know', 'apple', 'pop', 'gold', 'gym', 'realize', 'un', 'jobs', 'aesthetic']
# ['even', 'begins', 'link', 'via']
# ['even', 'begins', 'wins', 'link']
# ['even', 'begins', 'wins', 'link']
# ['even', 'begins', 'wins', 'link', 'opening', 'temporary', 'store', 'downtown', 'austin', 'support', 'launch']
# ['even', 'begins', 'wins', 'past', 'week', 'major', 'dilemma', 'link']
# ['even', 'begins', 'apple', 'wins', 'techcrunch', 'link']
# ['even', 'begins', 'apple', 'wins', 'link']
# ['even', 'begins', 'apple', 'wins', 'link']
# ['even', 'begins', 'apple', 'wins', 'link']
# ['even', 'begins', 'apple', 'wins', 'link']
# ['even', 'begins', 'apple', 'wins', 'link', 'via']
# ['even', 'begins', 'apple', 'wins', 'link']
# ['even', 'begins', 'apple', 'wins', 'link', 'via']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'link', 'going', 'get', 'sum', 'via']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'techcrunch', 'link']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'link', 'win', 'big']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'link']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'link']
# ['even', 'begins', 'apple', 'winssxsw', 'link']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'link']
# ['even', 'begins', 'apple', 'winssxsw', 'link', 'via']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'link', 'via']
# ['badgeless', 'event', 'free', 'drinks', 'heading', 'free', 'google', 'sponsored', 'happy', 'hour', 'semantic', 'web', 'austin', 'fogo', 'de', 'cho']
# ['best', 'swag', 'ever', 'thanks', 'charging', 'iphone', 'thanks', 'link']
# ['thanks', 'everyone', 'came', 'today', 'good', 'luck', 'winning', 'ipad', 'stop', 'tomorrow', 'chances', 'win']
# ['timing', 'everything', 'ipad', 'two', 'brand', 'winner', 'sxsw', 'link']
# ['hey', 'exhibitors', 'capture', 'booth', 'experience', 'retrollect', 'disc', 'popular', 'disc', 'wins', 'ipad', 'two', 'link']
# ['sees', 'facebook', 'google', 'competition', 'via']
# ['fantastic', 'schedule', 'app', 'iphone', 'bummer', 'still', 'crackberry']
# ['photo', 'far', 'best', 'accessory', 'ipad', 'followed', 'closely', 'margarita', 'link']
# ['one', 'fav', 'photos', 'far', 'link']
# ['watch', 'fb', 'four', 'big', 'brother', 'rt', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['think', 'fell', 'bit', 'love', 'today', 'thanks', 'throwing', 'nerd', 'party', 'speakeasy']
# ['way', 'figure', 'ipad', 'two', 'good', 'replacement', 'making', 'year']
# ['dslr', 'film', 'discussion', 'moderated', 'guy', 'kawasaki', 'apple', 'fame', 'packed', 'house']
# ['need', 'find', 'better', 'stream', 'follow', 'inane', 'ipad', 'two', 'tweets', 'surely', 'southby']
# ['find', 'stupid', 'stupid', 'game', 'currently', 'special', 'sale', 'link']
# ['rt', 'find', 'hottest', 'spots', 'w', 'hot', 'spots', 'app', 'link', 'iphone', 'link']
# ['trying', 'find', 'apple', 'pop', 'store']
# ['first', 'person', 'queue', 'new', 'apple', 'store', 'austin', 'may', 'link']
# ['flipboard', 'adds', 'instagram', 'photos', 'social', 'search', 'apps', 'link']
# ['il', 'ceo', 'di', 'flipboard', 'annuncia', 'la', 'versione', 'iphone', 'next', 'platform', 'flipboard', 'iphone', 'team', 'started', 'working']
# ['google', 'focusing', 'bridging', 'digital', 'physical', 'divide', 'eg', 'maps', 'streetview', 'hotpot', 'autonomous', 'driving']
# ['hey', 'folks', 'please', 'keep', 'us', 'posted', 'google', 'hope', 'blast', 'link']
# ['follow', 'customers', 'forbes', 'link', 'alcoholics', 'call', 'enabling', 'rest', 'us', 'call', 'genius']
# ['please', 'rt', 'follow', 'next', 'big', 'social', 'network', 'chance', 'win', 'seven', 'zero', 'followers']
# ['preparing', 'talk', 'doodles', 'fun', 'friday', 'five', 'pm', 'link']
# ['good', 'news', 'austin', 'bound', 'apple', 'fanboys', 'link']
# ['saving', 'ipad', 'two', 'photo', 'apple', 'store', 'link']
# ['wish', 'list', 'tech', 'google', 'apps', 'helps', 'level', 'playing', 'field', 'kids', 'may', 'software', 'home']
# ['designing', 'ipad', 'catch', 'matt', 'carlson', 'matthew', 'davis', 'mon', 'nine', 'thirty', 'hilton', 'link']
# ['hitlantis', 'ipad', 'cool', 'song', 'explorer', 'app', 'hitlantis', 'com']
# ['searching', 'temporary', 'apple', 'store']
# ['queue', 'forming', 'austin', 'pop', 'apple', 'store', 'link', 'guy', 'front', 'since', 'five', 'apparently']
# ['frankenstein', 'amalgamation', 'fragmented', 'digital', 'identities', 'becoming', 'anti', 'schizophrenic', 'google', 'ai', 'sm', 'sci', 'fi']
# ['win', 'free', 'ipad', 'two', 'webdoc', 'com', 'rt']
# ['hey', 'friends', 'anyone', 'iphone', 'charger', 'borrow', 'tonight', 'lmk']
# ['friends', 'sxsw', 'willing', 'pick', 'ipad', 'pay', 'premium', 'dm', 'link']
# ['good', 'talk', 'akqas', 'ipad', 'interface', 'w', 'callback', 'design', 'principles', 'wish', 'go', 'beyond', 'media', 'marketing', 'examples']
# ['person', 'front', 'took', 'picture', 'new', 'ipad']
# ['future', 'local', 'contextual', 'discovery', 'google', 'marissa', 'mayer', 'argues', 'exceptionally', 'valuable', 'type', 'search']
# ['future', 'touch', 'user', 'interface', 'design', 'wondering', 'presentation', 'microsoft', 'employees', 'mention', 'ipad']
# ['sxsw', 'geek', 'games', 'compete', 'gain', 'vip', 'status', 'win', 'big', 'prizes', 'know', 'link']
# ['zazzle', 'gearing', 'hit', 'look', 'tweets', 'come', 'create', 'iphone', 'case']
# ['marketing', 'genius', 'apple', 'opens', 'pop', 'store', 'outside', 'link']
# ['get', 'look', 'rumored', 'pop', 'store', 'austin', 'link']
# ['trying', 'get', 'eighty', 'retro', 'party', 'maggie', 'mae', 'line', 'huge', 'hope', 'worth', 'wait']
# ['get', 'ready', 'word', 'circles', 'trending']
# ['get', 'soundcloud', 'iphone', 'app', 'link', 'start', 'recording', 'use', 'four', 'sq', 'geotagging', 'map', 'link']
# ['get', 'food', 'forget', 'snap', 'photo', 'win', 'macbook', 'air', 'ipad', 'two', 'apple', 'tv']
# ['austin', 'getting', 'full', 'underway', 'tell', 'iphone', 'intermittent', 'brick']
# ['google', 'give', 'social', 'networking', 'another', 'try', 'circles', 'via', 'link']
# ['zaarly', 'giving', 'away', 'ipad', 'two', 'person', 'beta', 'signup', 'referrals', 'link']
# ['google', 'giving', 'free', 'google', 'labs', 'laptops', 'open', 'source', 'coders', 'r', 'attending', 'meet', 'got', 'cupcake']
# ['go', 'app', 'available', 'blackberry', 'windows', 'seven', 'addition', 'iphone', 'ipad', 'android', 'link']
# ['need', 'go', 'seven', 'mo', 'old', 'sitter', 'know', 'score', 'apple', 'martin', 'like']
# ['go', 'sxsw', 'next', 'year', 'rt', 'apple', 'open', 'temporary', 'store', 'link']
# ['want', 'go', 'apple', 'pop', 'store', 'afraid', 'leave', 'new', 'ipad']
# ['bomb', 'goes', 'convention', 'center', 'apple', 'going', 'lose', 'devastating', 'share', 'customer', 'base']
# ['omg', 'going', 'macbook', 'pro', 'ipad', 'iphone', 'four', 'ipod', 'galaxy', 'tab']
# ['going', 'want', 'talk', 'html', 'css', 'catch', 'google', 'webmaster', 'team']
# ['golden', 'tickets', 'f', 'four', 'sq', 'party', 'day', 'real', 'party', 'felix', 'da', 'housecat', 'playing', 'ipad', 'link']
# ['queue', 'google', 'er', 'bing', 'talk', 'spam', 'ridiculous', 'busiest', 'seen']
# ['haha', 'google', 'party', 'like', 'one', 'thousand', 'nine', 'hundred', 'eighty', 'six', 'party', 'link']
# ['gsd', 'google', 'party', 'blowing', 'mind', 'much', 'amazing', 'food', 'drink', 'music', 'photo', 'booth', 'fun']
# ['google', 'authenticator', 'app', 'mobile', 'devices', 'step', 'ahead']
# ['google', 'circles', 'first', 'real', 'alternative', 'facebook']
# ['google', 'circles', 'launch', 'link', 'may', 'good', 'timing', 'given', 'twitter']
# ['google', 'place', 'value', 'domain', 'extension', 'equal']
# ['attending', 'google', 'keynote', 'seeing', 'google', 'maps', 'mobile', 'features']
# ['google', 'name', 'built', 'getting', 'things', 'trying', 'marissa', 'mayer', 'frm']
# ['google', 'let', 'us', 'block', 'sites', 'cannot', 'stand', 'link', 'blocking', 'looks', 'like', 'need']
# ['length', 'google', 'penalty', 'based', 'severity', 'breach', 'webmaster', 'guidelines', 'e', 'white', 'text', 'white', 'bgr', 'might', 'get', 'thirty', 'day', 'pen']
# ['google', 'set', 'launch', 'new', 'social', 'network', 'today']
# ['need', 'google', 'lonelyboy', 'fifteen', 'talks', 'time']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'updated', 'happen', 'link']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'something', 'keep', 'watch']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'never', 'beat', 'myspace']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'bigger', 'gaga']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'goog']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'dejavu']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'sta', 'nije', 'dosta', 'gbuzz']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'te', 'dije', 'wey']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'super', 'interesting']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link', 'rt']
# ['google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'sxsw', 'link']
# ['google', 'launch', 'new', 'social', 'network', 'called', 'circles', 'today', 'link', 'applause', 'new', 'privacy', 'model', 'attempt']
# ['google', 'launch', 'new', 'social', 'network', 'sxsw', 'link']
# ['breaking', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'today', 'link', 'via']
# ['diller', 'google', 'tv', 'first', 'product', 'good', 'consumer', 'product', 'basically']
# ['google', 'connect', 'digital', 'physical', 'worlds', 'mobile', 'link', 'rt']
# ['google', 'connect', 'digital', 'physical', 'worlds', 'mobile', 'link', 'rt']
# ['future', 'google', 'contextual', 'discovery', 'location', 'context', 'helps', 'us', 'go', 'deeper', 'ever', 'searches', 'without', 'search']
# ['google', 'cutts', 'says', 'reputation', 'topicality', 'two', 'keys', 'matter', 'site', 'rankings', 'saying', 'trust', 'lda']
# ['google', 'marissa', 'mayer', 'talk', 'three', 'thirty', 'worth', 'going']
# ['ironic', 'googled', 'directions', 'party', 'ended', 'walked', 'six', 'blocks', 'wrong', 'direction', 'time', 'bed', 'think']
# ['check', 'googletv', 'ipad', 'apps', 'connected', 'tv', 'experience', 'sxsw', 'link']
# ['check', 'googletv', 'ipad', 'apps', 'connected', 'tv', 'experience', 'sxsw', 'link', 'fascinating']
# ['cnnmoney', 'got', 'craving', 'minds', 'created', 'app', 'foodspotting', 'link']
# ['microsoft', 'got', 'drunk', 'changed', 'iphone', 'default', 'search', 'yahoo']
# ['msc', 'page', 'guy', 'gets', 'tattoo', 'sxsw', 'could', 'win', 'free', 'ipad', 'two', 'link', 'link']
# ['bring', 'guys', 'start', 'austin', 'designing', 'digital', 'magazines', 'ipad']
# ['less', 'half', 'hour', 'tell', 'win', 'ipad', 'two', 'rt']
# ['ipad', 'two', 'hand', 'awesome', 'dude', 'gave', 'cutsies', 'three', 'hour', 'line']
# ['going', 'hang', 'ipad', 'hacked', 'nook', 'around', 'neck', 'week', 'become', 'flava', 'flav', 'top', 'hipsters']
# ['something', 'called', 'google', 'places', 'hotpot', 'works', 'recommendation', 'engine']
# ['heard', 'google', 'plans', 'launch', 'socnet', 'may', 'circles', 'learned', 'lot', 'five', 'years', 'lots', 'changed', 'via']
# ['bb', 'discriminatory', 'p', 'rt', 'officially', 'come', 'fc', 'grill', 'make', 'iphone', 'case']
# ['may', 'invites', 'cool', 'parties', 'two', 'iphone', 'chargers', 'pocket', 'happy', 'see']
# ['would', 'thunk', 'rt', 'agencies', 'push', 'google', 'directions', 'never', 'would', 'gone', 'otherwise', 'says']
# ['yet', 'see', 'someone', 'pc', 'dell', 'otherwise', 'sxsw', 'apple', 'macbook', 'pro', 'ipads', 'b', 'soon']
# ['meetings', 'line', 'popup', 'apple', 'store', 'ipad', 'two', 'love', 'place']
# ['hawk', 'ipad', 'two', 'festival', 'popup', 'store', 'link']
# ['want', 'hear', 'tell', 'google', 'love', 'story']
# ['oh', 'lordy', 'go', 'rt', 'time', 'store', 'open', 'pulling', 'trigger']
# ['loved', 'honesty', 'google', 'marissa', 'mayer', 'keynote', 'many', 'products', 'need', 'step', 'customer', 'service', 'locations']
# ['google', 'host', 'developer', 'day', 'sxsw', 'link']
# ['minus', 'six', 'hours', 'social', 'media', 'mavens', 'start', 'performing', 'degrading', 'sex', 'acts', 'iphone', 'charge']
# ['hey', 'bout', 'donating', 'spending', 'new', 'japan', 'really', 'need', 'thing']
# ['wondering', 'much', 'revenue', 'austin', 'store', 'grossed', 'account', 'ipad', 'two', 'amid', 'strategic', 'release']
# ['win', 'sxsw', 'hint', 'answer', 'every', 'year', 'link']
# ['apple', 'hp', 'popups', 'gee', 'wonder', 'get', 'traffic', 'link']
# ['scavenger', 'hunt', 'game', 'businesses', 'released', 'app', 'iphone', 'link']
# ['wonder', 'fit', 'ipad', 'two', 'luggage', 'packing', 'austin', 'hmmm']
# ['holy', 'moly', 'cannot', 'believe', 'line', 'apple', 'store', 'sxsw', 'link']
# ['could', 'forget', 'cell', 'phone', 'today', 'fail', 'glad', 'ipad']
# ['three', 'g', 'iphone', 'three', 'hrs', 'tweeting', 'dead', 'need', 'upgrade', 'plugin', 'stations']
# ['feeling', 'worst', 'place', 'try', 'get', 'ipad', 'two', 'everyone', 'trying', 'get', 'one']
# ['love', 'macbook', 'ipad', 'iphone', 'year', 'one', 'runs', 'juice', 'jump', 'next']
# ['holy', 'cow', 'got', 'hooked', 'paolo', 'alex', 'backup', 'charger', 'iphone', 'facebook', 'com', 'powermat']
# ['holy', 'cow', 'got', 'hooked', 'paolo', 'alex', 'backup', 'charger', 'iphone', 'facebook', 'com', 'powermat']
# ['knew', 'plied', 'beer', 'stogies', 'last', 'night', 'would', 'weasel', 'way', 'team', 'android', 'party', 'tonight']
# ['ok', 'nerds', 'totally', 'bateman', 'want', 'sign', 'ipad', 'two']
# ['last', 'year', 'traveled', 'heavy', 'year', 'light', 'get', 'right', 'next', 'year', 'left', 'ipad', 'home']
# ['thought', 'would', 'use', 'ipad', 'lot', 'even', 'touched', 'hmmzies']
# ['austin', 'convention', 'center', 'today', 'w', 'fam', 'showing', 'new', 'iphone', 'game']
# ['cool', 'one', 'rt', 'friday', 'five', 'pm', 'doodle', 'google', 'session', 'link']
# ...
# ['tweeting', 'sessions', 'going', 'first', 'young', 'entrepreneurs', 'marissa', 'mayer', 'google', 'wordpress']
# ['well', 'ipad', 'commercial', 'want', 'minimize', 'wear', 'tear', 'laptop']
# ['well', 'hear', 'someone', 'going', 'setup', 'pop', 'apple', 'store', 'oh', 'wait', 'fruit']
# ['well', 'put', 'totally', 'agree']
# ['well', 'hope', 'make', 'easier', 'find', 'little', 'android', 'wants', 'say', 'hi']
# ['wish', 'wish', 'ipad', 'two', 'said']
# ['ummmm', 'awesome', 'party', 'rt', 'djroe', 'apple', 'store', 'downtown', 'austin', 'open', 'til', 'midnight']
# ['awesome', 'got', 'ipad', 'two', 'link', 'via']
# ['chances', 'booth', 'selling', 'new', 'ipad', 'two']
# ['think', 'google', 'presentation', 'nice', 'see', 'retail', 'peeps']
# ['optimal', 'way', 'access', 'lanyrd', 'account', 'iphone']
# ['size', 'get', 'got', 'apple', 'pop', 'store', 'opened']
# ['guy', 'kawasaki', 'former', 'apple', 'evangelist', 'wanw']
# ['going', 'today', 'share', 'photos', 'video', 'ireport', 'link', 'cnn', 'iphone', 'app']
# ['friends', 'going', 'today', 'share', 'photos', 'video', 'link', 'cnn', 'iphone', 'app']
# ['wait', 'time', 'lookin', 'like', 'apple', 'store', 'north', 'already', 'sold', 'word', 'inventory']
# ['temp', 'store']
# ['apple', 'set', 'anyone', 'get']
# ['say', 'ipad', 'going', 'ubiquitous', 'lot', 'faster', 'anyone', 'expected', 'year', 'even', 'six', 'mo', 'ago']
# ['debating', 'laptop', 'take', 'would', 'rather', 'taking', 'ipad', 'two']
# ['black', 'white', 'ipad']
# ['see', 'white', 'ipad', 'two', 'rt', 'know', 'apartment', 'looks', 'like', 'needs', 'wires', 'link']
# ['said', 'able', 'get', 'ipad', 'two', 'apple', 'opening', 'pop', 'store', 'austin', 'sxsw', 'link']
# ['curious', 'google', 'surprised', 'usage', 'delete', 'button', 'gmail', 'mobile', 'app']
# ['google', 'austin', 'texas', 'two', 'thousand', 'eleven']
# ['post', 'sxswi', 'two', 'thousand', 'eleven', 'day', 'one', 'link', 'surprised', 'run', 'two', 'bpm', 'folks', 'pop', 'apple', 'store']
# ['rt', 'google', 'says', 'future', 'location', 'location', 'location', 'link']
# ['livetapp', 'raffling', 'ipad', 'two', 'check', 'tweet', 'sxsw', 'show', 'entered', 'win']
# ['time', 'switch', 'iphone', 'zip', 'chatter']
# ['chilling', 'big', 'hair', 'station', 'google', 'party', 'maggie', 'mays', 'link']
# ['partying', 'lustre', 'pearl', 'link']
# ['thirsty', 'gadget', 'using', 'charge', 'anywhere', 'iphone', 'happy', 'share', 'juice']
# ['iphone', 'use', 'free', 'ispyart', 'app', 'send', 'photos', 'link']
# ['jonathan', 'zaggle', 'showed', 'us', 'cool', 'free', 'texting', 'app', 'iphone', 'called', 'zms']
# ['current', 'twitter', 'feed', 'devastation', 'japan', 'parties', 'panels', 'ipad', 'two', 'artifacts', 'recollections', 'five', 'years', 'ago']
# ['get', 'owle', 'bubo', 'iphone', 'twenty', 'coupon', 'use', 'code', 'sbsw', 'two', 'thousand', 'eleven']
# ['walkin', 'street', 'navigating', 'via', 'google', 'tweeting', 'random', 'guy', 'yelping', 'welcome']
# ['google', 'arwords', 'arsense', 'anyone']
# ['would', 'prob', 'say', 'designing', 'ipad', 'apps']
# ['wow', 'gold', 'gym', 'underneath', 'apple', 'store', 'kind', 'nutshell', 'right']
# ['wow', 'came', 'google', 'results', 'perma']
# ['popular', 'link', 'terrible', 'concept', 'anyway']
# ['video', 'shows', 'guy', 'hacking', 'times', 'sq', 'billboards', 'w', 'iphone', 'real', 'link']
# ['rt', 'facebook', 'breathe', 'sigh', 'relief', 'google', 'kills', 'plans', 'four', 'google', 'circles', 'link']
# ['apple', 'knows', 'game', 'bring', 'ipad', 'two', 'people', 'link']
# ['apple', 'knows', 'influencers', 'apple', 'set', 'open', 'popup', 'shop', 'core', 'sxsw', 'action', 'sell', 'ipad', 'two', 'link']
# ['browser', 'prefer', 'internet', 'explorer', 'nine', 'google', 'chrome', 'sway', 'link', 'via']
# ['join', 'lenewz', 'fo', 'free', 'donuts', 'massage', 'trade', 'show', 'booth', 'one', 'thousand', 'four', 'hundred', 'twenty', 'two', 'behind', 'google']
# ['leaving', 'excellent', 'panel', 'writing', 'compelling', 'content', 'android', 'dev', 'meetup']
# ['check', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'link']
# ['hmmm', 'taxi', 'magic', 'iphone', 'appear', 'magic', 'austin']
# ['great', 'three', 'xml', 'visualization', 'skiers', 'using', 'google', 'location', 'data']
# ['festivalexplorer', 'iphone', 'app', 'finally', 'solves', 'sxsw', 'link']
# ['preso', 'l', 'express', 'pass', 'per', 'city', 'dark', 'e', 'road', 'nowhere', 'visto', 'il', 'primo', 'ipad', 'two', 'wild', 'e', 'ora', 'panel', 'con', 'il', 'cast', 'di', 'source', 'code']
# ['pop', 'store', 'smart', 'marketing', 'link']
# ['meet', 'hilton']
# ['store', 'link']
# ['even', 'starts', 'apple', 'captured', 'attention', 'whole', 'show', 'win', 'must', 'taking', 'lessons', 'sheen']
# ['new', 'film', 'year', 'folks', 'sitting', 'line', 'reading', 'scripts']
# ['link', 'google', 'going', 'social']
# ['google', 'blogger', 'sketchup', 'party', 'unexpectedly', 'quiet', 'compared', 'last', 'night']
# ['austin', 'ipad', 'two', 'line', 'one', 'seventy', 'five', 'blocks', 'long', 'line', 'enjoying', 'spectacle', 'link']
# ['keep', 'personal', 'stuff', 'corp', 'ipad', 'way', 'people', 'take', 'care', 'asset']
# ['follow', 'taptu', 'apple', 'ipad', 'two', 'lines', 'sxsw', 'two', 'thousand', 'eleven', 'hd', 'video', 'link', 'shared', 'taptu']
# ['line', 'feel', 'like', 'disgrace', 'geeks', 'everywhere', 'home', 'working', 'instead']
# ['ipad', 'people', 'brilliant', 'spider', 'secret', 'bryce', 'manor', 'ninety', 'nine', 'cents', 'right', 'buy', 'link']
# ['ipad', 'two', 'pop', 'store', 'apple', 'store', 'sxsw', 'w', 'pic', 'link']
# ['put', 'collective', 'entrepreneurial', 'social', 'minds', 'ipad', 'two', 'together', 'something', 'japan']
# ['pdx', 'tomorrow', 'drop', 'note', 'apple', 'pop', 'retail', 'store', 'epicenter', 'madness']
# ['love', 'opened', 'app', 'ipad', 'party', 'settle', 'argument', 'parentheses', 'use']
# ['group', 'war', 'heats', 'fast', 'society', 'launches', 'new', 'android', 'app', 'updates', 'iphone', 'app', 'link']
# ['far', 'iphone', 'mifi', 'rock', 'solid', 'cc']
# ['lovely', 'iphone', 'app', 'get', 'thanks', 'awesome', 'integration', 'link']
# ['started', 'planning', 'last', 'night', 'official', 'ipad', 'app', 'solid', 'resource', 'still', 'comes', 'short', 'scheduling']
# ['tenets', 'ipad', 'design']
# ['day', 'one', 'expected', 'everyone', 'glued', 'iphone', 'ipad', 'included']
# ['best', 'newly', 'added', 'iphone', 'app', 'goes', 'awesome', 'two', 'thousand', 'eleven', 'come', 'one', 'day', 'one', 'amazing', 'day']
# ['biomimicry', 'basis', 'design', 'problem', 'solving', 'google', 'studying', 'flocking', 'swarming', 'behavior', 'understand', 'collab', 'brilliant']
# ['google', 'guy', 'talk', 'explaining', 'made', 'realistic', 'twitter', 'bots', 'experiment', 'gee', 'thanks']
# ['gg', 'new', 'try', 'social', 'rt', 'interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'big', 'news', 'link', 'via']
# ['booth', 'link']
# ['leaving', 'bag', 'home', 'today', 'traveling', 'light', 'ipad', 'hand', 'really', 'need', 'lug', 'around', 'impedimenta']
# ['google', 'may', 'launching', 'new', 'social', 'network', 'called', 'circles', 'today', 'link']
# ['absolutely', 'beautiful', 'day', 'austin', 'mall', 'guys', 'track', 'ipad', 'two']
# ['way', 'means', 'get', 'ipad', 'two']
# ['party', 'thrown', 'google', 'aclu', 'tell', 'dad', 'maggie', 'mae', 'w', 'seventy', 'eight', 'others', 'link']
# ['think', 'effing', 'hubby', 'line', 'two', 'someone', 'point', 'towards', 'line', 'wife', 'number', 'two']
# ['case', 'fairy', 'god', 'mother', 'reading', 'mail', 'g', 'wish', 'week', 'two', 'go', 'two', 'dev', 'meetup', 'hilton', 'sat', 'twelve', 'thirty', 'pm']
# ['motley', 'fool', 'google', 'prepares', 'fight', 'facebook', 'circles', 'may', 'appeared', 'way', 'link']
# ['friend', 'new', 'app', 'developed', 'ck', 'show', 'support', 'link']
# ['apparently', 'google', 'launch', 'major', 'new', 'social', 'network', 'link']
# ['actually', 'idea', 'could', 'google', 'fine', 'knowing']
# ['anybody', 'trouble', 'downloading', 'pak', 'app', 'iphone']
# ['crazy', 'temporary', 'store', 'post', 'coming', 'pics']
# ['crazy', 'much', 'culture', 'documented', 'google', 'doodles']
# ['ipad', 'day', 'geekest', 'place', 'world', 'right', 'yes', 'queue', 'apple', 'opens', 'hidden', 'store', 'link']
# ['bing', 'party', 'location', 'last', 'year', 'google', 'party', 'six', 'lounge', 'w', 'link']
# ['looks', 'interesting', 'rt', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'link']
# ['looks', 'interesting', 'good', 'luck', 'localmind', 'available', 'iphone', 'link']
# ['ok', 'got', 'ipad', 'cover', 'better', 'given', 'ipad', 'tool']
# ['officially', 'ipad', 'ed', 'apple', 'store', 'sxsw', 'w', 'sixteen', 'others', 'link']
# ['getting', 'ipad', 'two', 'apple', 'store', 'w', 'four', 'others', 'link']
# ['data', 'iphone', 'finally', 'sorted', 'next', 'stop']
# ['link', 'guy', 'kawasaki', 'talks', 'enchanted', 'sxsw', 'knows', 'stuff']
# ['brought', 'lunch', 'took', 'train', 'last', 'two', 'days', 'earned', 'ipad']
# ['dropped', 'macbook', 'pro', 'walking', 'ipad', 'two', 'sounding', 'pretty', 'appealing', 'right', 'somehow', 'adapt', 'overcome']
# ['apparently', 'mobile', 'go', 'app', 'compatible', 'w', 'iphone', 'suggestions', 'good', 'mobile', 'aps', 'sxsw', 'thanks']
# ['one', 'st', 'injury', 'bicycle', 'stupid', 'concrete', 'ouch', 'link', 'fortunately', 'still', 'able', 'type', 'iphone', 'schedule']
# ['austin', 'pal', 'lost', 'phone', 'please', 'help', 'rt', 'left', 'white', 'iphone', 'four', 'g', 'cab', 'austin', 'internet', 'please', 'help']
# ['new', 'lonely', 'planet', 'austin', 'city', 'guide', 'iphone', 'app', 'free', 'sxsw', 'march', 'fifteen', 'twelve', 'pm', 'pst', 'link']
# ['lonely', 'planet', 'iphone', 'app', 'guide', 'austin', 'free', 'week']
# ['creativity', 'prompt', 'use', 'google', 'maps', 'virtually', 'take', 'walk', 'used', 'take', 'kid', 'see', 'memories', 'come', 'courtesy']
# ['still', 'seen', 'two', 'non', 'ipad', 'tablets', 'thousands', 'ipads']
# ['pretty', 'sure', 'panelist', 'thinks', 'apple', 'drowning', 'success', 'fucking', 'insane']
# ['happy', 'discovr', 'named', 'one', 'top', 'ten', 'must', 'apps', 'ipad', 'two', 'fight', 'way', 'thru', 'queue']
# ['apparently', 'apple', 'store', 'line', 'fifteen', 'minutes', 'moment']
# ['apparently', 'line', 'get', 'ipad', 'store', 'grew', 'two', 'blocks', 'five', 'blocks', 'past', 'thirty', 'mins', 'wut']
# ['apparently', 'ipad', 'iphone', 'app', 'block', 'tweets']
# ['way', 'see', 'tonight', 'hopefully', 'new', 'ipad', 'san', 'francisco', 'international', 'airport', 'sfo', 'link']
# ['crazy', 'thinking', 'upgrading', 'iphone', 'right']
# ['display', 'tonite', 'link', 'industry', 'party', 'link']
# ['smoked', 'way', 'much', 'yesterday', 'hahaha', 'painting', 'android', 'party', 'tonight', 'link']
# ['stopped', 'tron', 'legacy', 'lounge', 'audio', 'sync', 'function', 'extras', 'ipad', 'pretty', 'cool']
# ['second', 'day', 'using', 'apple', 'ipad', 'two', 'really', 'impressed', 'magnetic', 'cover', 'pure', 'brilliance', 'using', 'laptop', 'old', 'school']
# ['come', 'party', 'w', 'google', 'tonight', 'link', 'bands', 'food', 'art', 'ice', 'cream', 'nifty', 'interactive', 'maps']
# ['apparently', 'apple', 'set', 'temporary', 'ipad', 'two', 'shop', 'austin']
# ['way', 'love', 'discuss', 'apple', 'breeds', 'midst', 'pre', 'madness']
# ['apparently', 'google', 'ad', 'preferences', 'see', 'google', 'thinks', 'like']
# ['absolutely', 'rt', 'timely', 'good', 'schtuff', 'google', 'people', 'finder', 'four', 'japan', 'quake', 'link']
# ['good', 'job', 'rt', 'yes', 'gowalla', 'wins', 'best', 'andoid', 'app', 'team', 'android', 'choice', 'awards', 'thanks']
# ['line', 'ipad', 'thing', 'link']
# ['top', 'story', 'apple', 'schools', 'marketing', 'experts', 'thousands', 'town', 'demonstrate', 'social', 'march', 'link']
# ['yay', 'thank']
# ['maybe', 'link']
# ['yep', 'cannot', 'believe', 'set', 'pop', 'store', 'oh', 'wait', 'yes']
# ['marisa', 'meyer', 'showing', 'yelp', 'aka', 'google', 'hotpot']
# ['yes', 'picked', 'ipad', 'two', 'one', 'st', 'one']
# ['yes', 'favorited', 'want', 'win', 'need', 'win', 'doo', 'dah', 'doo', 'dah']
# ['flying', 'wants', 'free', 'miles', 'dm', 'shoot', 'code', 'currently', 'iphone']
# ['google', 'trying', 'fill', 'void', 'local', 'information', 'hotpot', 'biz', 'claim', 'provide', 'photos', 'info']
# ['analytics', 'one', 'hundred', 'one', 'google', 'analytics', 'standard', 'use']
# ['dear', 'everyone', 'coming', 'friendly', 'reminder', 'ipad', 'two', 'comes', 'friday', 'birthday', 'saturday']
# ['look', 'everyone', 'zomg', 'got', 'ipad', 'two', 'first', 'day', 'link']
# ['favorite', 'thanks', 'coming', 'getting', 'iphone']
# ['know', 'plane', 'become', 'facebook', 'friends', 'seatmate', 'added', 'ipad', 'added', 'laptop']
# ['need', 'details', 'google', 'circle']
# ['bet', 'man', 'kindle', 'apple', 'sure', 'pre', 'order', 'amazon']
# ['buy', 'used', 'ipad', 'pick', 'one', 'tomorrow']
# ['check', 'link', 'ipad', 'apps']
# ['get', 'ipad', 'one', 'three', 'hundred', 'fifty', 'ninety', 'nine', 'know', 'look', 'iphone']
# ['could', 'buy', 'new', 'ipad', 'two', 'tomorrow', 'apple', 'pop', 'store', 'link']
# ['guys', 'ever', 'plan', 'attending', 'need', 'four', 'things', 'skinny', 'jeans', 'flannel', 'shirt', 'beard', 'ipad']
# ['give', 'away', 'ipad', 'yet']
# ['going', 'announcement', 'today', 'would', 'love', 'realtime', 'reaction', 'link']
# ['guys', 'give', 'ipad', 'win', 'cbs', 'scvngr', 'launch', 'spy', 'game', 'sxsw', 'link']
# ['know', 'sell', 'apple', 'products', 'places', 'sayin']
# ['might', 'also', 'appreciate', 'new', 'iphone', 'app', 'tweetcaster', 'zip', 'feature', 'let', 'us', 'hide', 'keywords', 'hashtag', 'incl', 'course']
# ['realize', 'still', 'padless', 'gave', 'away', 'case', 'need', 'win', 'next', 'ipad', 'first']
# ['get', 'ipad', 'two', 'save', 'back', 'lugging', 'laptop']
# ['see', 'line', 'front', 'apple', 'store', 'nothing', 'like', 'tech', 'geek', 'gathering', 'launch', 'day']
# ['soooo', 'think', 'apple', 'mobile', 'store', 'ipad', 'sales', 'friday']
# ['able', 'afford', 'attend', 'buy', 'today', 'consider', 'saving', 'relief']
# ['google', 'party', 'tonight', 'going', 'try', 'make', 'many', 'events']
# ['sure', 'many', 'ate', 'check', 'gourdoughs', 'google']
# ['know', 'made', 'see', 'bunch', 'grown', 'men', 'hooting', 'getting', 'ipad', 'two']
# ['essentials', 'mine', 'pocket', 'camera', 'laptop', 'ipad', 'extra', 'cords']
# ['iphone', 'four', 'cases', 'rad', 'ready', 'stop', 'tomorrow', 'get', 'link']
# ['mom', 'ipad', 'designing', 'boomers', 'austin', 'convention', 'center', 'link']
# ['mom', 'ipad', 'session']
# ['mom', 'ipad', 'session', 'acc', 'ballroom', 'b', 'w', 'twenty', 'three', 'others', 'link']
# ['pr', 'guy', 'convinced', 'switch', 'back', 'iphone', 'great', 'coverage']
# ['cue', 'hype', 'rt', 'interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'big', 'news', 'link']
# ['papyrus', 'sort', 'like', 'ipad', 'nice', 'lol', 'lavelle']
# ['diller', 'says', 'google', 'tv', 'might', 'run', 'playstation', 'xbox', 'essentially', 'ready', 'today']
# ['google', 'says', 'reports', 'launch', 'circles', 'social', 'network', 'incorrect', 'link', 'launch', 'today', 'rate']
# ['google', 'says', 'future', 'around', 'ie', 'location', 'link']
# ['google', 'says', 'future', 'location', 'location', 'location', 'link']
# ['always', 'used', 'camera', 'iphone', 'b', 'c', 'image', 'stabilizer', 'mode', 'suggestions', 'ipad', 'cam', 'app', 'w', 'feature']
# ['google', 'says', 'want', 'give', 'lightning', 'talk', 'audience', 'tonight', 'email', 'ben', 'mcgraw', 'gmail', 'com', 'spot', 'stage']
# ['yup', 'third', 'app', 'yet', 'android', 'suggestions', 'cc']
# ['ipad', 'everywhere', 'link']
# ['wave', 'buzz', 'rt', 'interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'big', 'news', 'link']
# ['google', 'zeiger', 'physician', 'never', 'reported', 'potential', 'ae', 'yet', 'fda', 'relies', 'physicians', 'operating', 'w', 'data']
# ['verizon', 'iphone', 'customers', 'complained', 'time', 'fell', 'back', 'hour', 'weekend', 'course', 'new', 'yorkers', 'attended']
# ['rt', 'google', 'tests', 'check', 'offers', 'link']

# %%
#Create Training Data into a Dataframe with an index that corresponds to the target
X= pd.DataFrame(token_docs,columns=['processed_text'])
X.set_index(y.index,inplace=True)
X = X['processed_text']

# %%
X
# Out:
# 0       three g iphone three hr tweet dead need upgrad...
# 1       know awesome ipad iphone app likely appreciate...
# 2                                      wait two also sale
# 3               hope year festival crashy year iphone app
# 4       great stuff fri marissa mayer google tim reill...
#                               ...
# 7471                                 ipad everywhere link
# 7472    wave buzz rt interrupt regularly schedule geek...
# 7473    google zeiger physician never report potential...
# 7474    verizon iphone customer complain time fell bac...
# 7475                      rt google test check offer link
# Name: processed_text, Length: 7476, dtype: object

# %% [markdown]
# ## Train/Test/Split

# %% [markdown]
# I am splitting into a traditional train test split and then I will be splitting that into a training, validation set. I will not be looking at the test set until after final model selection.

# %%
len(X)
# Out:
# 7476

# %%
X_train, X_rem, y_train, y_rem = train_test_split(X,
                                                    y,
                                                    random_state=20,
                                                    train_size=0.80,stratify=y)

# %%
X_val, X_test, y_val, y_test = train_test_split(X_rem, y_rem,
                                          test_size=0.50, random_state=20,stratify=y_rem)

# %%
X_val
# Out:
# 4570                         rt even begin apple win link
# 2694    glad get faulty iphone go well everyone batter...
# 1957    official present contest world best mobile app...
# 2795    save set open pop store despite two austin tex...
# 1754    google quash circle rumour rt launching produc...
#                               ...
# 2213    win free ipad two webdoc com rt awesome tech r...
# 2798    school marketing expert thousand town demonstr...
# 4751    rt good cnn article important social web innov...
# 1595    alive love great talk jonathan dahl google mar...
# 6174               peep want ipad two link brilliant real
# Name: processed_text, Length: 748, dtype: object

# %% [markdown]
# ## Model Scoring Object

# %%
two_scorer = make_scorer(fbeta_score, beta=2)

# %%
cross_val_df = fn.cross_val_scores()

# %%
import importlib
from Helpers import functions as fn
importlib.reload(fn)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/seanyboy/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# <module 'Helpers.functions' from '/Users/seanyboy/Documents/Flatiron/Phase_4/Twitter_Sentiment_Project/Helpers/functions.py'>

# %% [markdown]
# ## Modeling Iterations

# %% [markdown]
# ### Baseline Dummy

# %%
dummy_pipe = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2))),
        ('clf', DummyClassifier(strategy='stratified'))
    ]
)

# %%
dummy_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('clf', DummyClassifier(strategy='stratified'))])

# %% [markdown]
# #### Dummy Scores

# %%
cross_val_df.cross_val_report(dummy_pipe,'Baseline Dummy',X_train,y_train)
# Out:
# [0.8638795986622073, 0.06913857677902621, 0.08167628552854136]

# %%
cross_val_df.history
# Out:
#              Name  mean_accuracy  std_accuracy  mean_precision  std_precision  \
# 0  Baseline Dummy        0.86388      0.009635        0.081676       0.036418
#
#    mean_recall  std_recall   mean_f1    std_f1 notes
# 0     0.069139     0.02688  0.066957  0.012847

# %% [markdown]
# Due to the class imblance even a Dummy model achives an accuray score of 88%, it's imporant to look to precision and recall.

# %%
fn.reporting(dummy_pipe,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       692
#            1       0.15      0.16      0.16        56
#
#     accuracy                           0.87       748
#    macro avg       0.54      0.54      0.54       748
# weighted avg       0.87      0.87      0.87       748

# %% [markdown]
# This is a clearly acceptable model. It sets a baseline.

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Given the class imbalance I am initiating a class_weight of balanced for the Logistic Regression baseline.

# %% [markdown]
# ### Baseline - Bag of Words

# %%
Baseline_LG = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,1),use_idf=False)),
        ('clf', LogisticRegression(class_weight='balanced',max_iter=1000))
    ]
)

# %%
Baseline_LG.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(use_idf=False)),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
cross_val_df.cross_val_report(Baseline_LG,'Baseline Logistic',X_train,y_train,'Balanced Weights/Ngrams 1,1,BoW')
# Out:
# [0.8297658862876254, 0.6157802746566793, 0.24581552577729368]

# %%
cross_val_df.history
# Out:
#                 Name  mean_accuracy  std_accuracy  mean_precision  \
# 0     Baseline Dummy       0.863880      0.009635        0.081676
# 1  Baseline Logistic       0.829766      0.008388        0.245816
#
#    std_precision  mean_recall  std_recall   mean_f1    std_f1  \
# 0       0.036418     0.069139    0.026880  0.066957  0.012847
# 1       0.022980     0.615780    0.062758  0.351303  0.033441
#
#                              notes
# 0
# 1  Balanced Weights/Ngrams 1,1,BoW

# %%
fn.reporting(Baseline_LG,X_train,y_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93      5532
#            1       0.38      0.93      0.54       448
#
#     accuracy                           0.88      5980
#    macro avg       0.68      0.90      0.73      5980
# weighted avg       0.95      0.88      0.90      5980

# %% [markdown]
# The baseline Logistic is severely overfit, as there is an extreme difference in the training scores and the cross-validation scores.

# %%
validation_scores = fn.model_scores()

# %%
validation_scores.report(Baseline_LG,'baseline_logistic',X_val,y_val,'n_grams 1,1,BoW')
# Out:
# [0.8275401069518716, 0.6428571428571429, 0.2482758620689655]

# %%
validation_scores.history
# Out:
#                 Name  accuracy  precision    recall        f1            notes
# 0  baseline_logistic   0.82754   0.248276  0.642857  0.358209  n_grams 1,1,BoW

# %%
fn.reporting(Baseline_LG,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90       692
#            1       0.25      0.64      0.36        56
#
#     accuracy                           0.83       748
#    macro avg       0.61      0.74      0.63       748
# weighted avg       0.91      0.83      0.86       748

# %% [markdown]
# ### Bag of Words - (1,2 Ngrams)

# %%
LG_1_2_grams = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2),use_idf=False)),
        ('clf', LogisticRegression(class_weight='balanced',max_iter=1000))
    ]
)

# %%
LG_1_2_grams.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2), use_idf=False)),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
cross_val_df.cross_val_report(LG_1_2_grams,'Logistic_BOW',X_train,y_train,'N_Grams_1,2')
# Out:
# [0.8628762541806021, 0.5533083645443195, 0.28522944490951585]

# %%
validation_scores.report(LG_1_2_grams,'Logistic_BOW',X_val,y_val,'N_gram_1,2')
# Out:
# [0.8743315508021391, 0.6428571428571429, 0.32727272727272727]

# %% [markdown]
# ### TFIDF (1,1 Ngrams)

# %%
LG_1_1_tfidf = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,1),use_idf=True)),
        ('clf', LogisticRegression(class_weight='balanced',max_iter=1000))
    ]
)

# %%
LG_1_1_tfidf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
cross_val_df.cross_val_report(LG_1_1_tfidf,'Logistic_TFIDF',X_train,y_train,'N_grams1,1')
# Out:
# [0.867056856187291, 0.5845443196004994, 0.3001155354209293]

# %%
validation_scores.report(LG_1_1_tfidf,'Logistic_TFIDF',X_val,y_val,'N_gram_1,1')
# Out:
# [0.8716577540106952, 0.625, 0.3181818181818182]

# %%
cross_val_df.history
# Out:
#                 Name  mean_accuracy  std_accuracy  mean_precision  \
# 0     Baseline Dummy       0.863880      0.009635        0.081676
# 1       Logistic_BOW       0.862876      0.006099        0.285229
# 3     Logistic_TFIDF       0.867057      0.004164        0.300116
# 2  Baseline Logistic       0.829766      0.008388        0.245816
#
#    std_precision  mean_recall  std_recall   mean_f1    std_f1  \
# 0       0.036418     0.069139    0.026880  0.066957  0.012847
# 1       0.022435     0.553308    0.062936  0.376122  0.032752
# 3       0.021531     0.584544    0.057838  0.396524  0.032114
# 2       0.022980     0.615780    0.062758  0.351303  0.033441
#
#                              notes
# 0
# 1                      N_Grams_1,2
# 3                       N_grams1,1
# 2  Balanced Weights/Ngrams 1,1,BoW

# %% [markdown]
# ### TFIDF (1,2 Ngrams)

# %%
LG_1_2_tfidf = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2),use_idf=True)),
        ('clf', LogisticRegression(class_weight='balanced',max_iter=1000))
    ]
)

# %%
LG_1_2_tfidf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
cross_val_df.cross_val_report(LG_1_2_tfidf,'Logistic_TFIDF',X_train,y_train,'N_grams1,2')
# Out:
# [0.8986622073578596, 0.43745318352059925, 0.35762510650367724]

# %%
validation_scores.report(LG_1_2_tfidf,'Logistic_TFIDF',X_val,y_val,'N_gram_1,2')
# Out:
# [0.9010695187165776, 0.5714285714285714, 0.3902439024390244]

# %%
cross_val_df.history
# Out:
#                 Name  mean_accuracy  std_accuracy  mean_precision  \
# 0     Baseline Dummy       0.863880      0.009635        0.081676
# 4     Logistic_TFIDF       0.898662      0.006983        0.357625
# 1       Logistic_BOW       0.862876      0.006099        0.285229
# 2     Logistic_TFIDF       0.867057      0.004164        0.300116
# 3  Baseline Logistic       0.829766      0.008388        0.245816
#
#    std_precision  mean_recall  std_recall   mean_f1    std_f1  \
# 0       0.036418     0.069139    0.026880  0.066957  0.012847
# 4       0.031299     0.437453    0.025999  0.393250  0.028001
# 1       0.022435     0.553308    0.062936  0.376122  0.032752
# 2       0.021531     0.584544    0.057838  0.396524  0.032114
# 3       0.022980     0.615780    0.062758  0.351303  0.033441
#
#                              notes
# 0
# 4                       N_grams1,2
# 1                      N_Grams_1,2
# 2                       N_grams1,1
# 3  Balanced Weights/Ngrams 1,1,BoW

# %%
LG_2_2_tfidf = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(2,2),use_idf=True)),
        ('clf', LogisticRegression(class_weight='balanced',max_iter=1000))
    ]
)

# %%
LG_2_2_tfidf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(2, 2))),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
cross_val_df.cross_val_report(LG_2_2_tfidf,'Logistic_TFIDF',X_train,y_train,'N_grams2,2')
# Out:
# [0.9135451505016723, 0.2990012484394507, 0.39543628086127136]

# %% [markdown]
# ### Tuned Logistic Regression

# %%
from sklearn.experimental import enable_halving_search_cv # noqa
from sklearn.model_selection import HalvingGridSearchCV

# %%
param_space = {'clf__class_weight': ['none','balanced'],'clf__C':[.01,.1,1,5,10,100],'tfidf__use_idf':[True,False],
              'tfidf__smooth_idf':[True,False],'tfidf__sublinear_tf':[True,False],
                                  'tfidf__ngram_range': [(1, 1), (1,2),(1,3)]}

# %%
# %%time

LG_GS = GridSearchCV(estimator=Baseline_LG,param_grid=param_space,cv=5,scoring=two_scorer,refit=True,n_jobs=-1)
LG_GS.fit(X_train,y_train)
# Out:
# CPU times: user 9.72 s, sys: 916 ms, total: 10.6 s
# Wall time: 7min 20s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(use_idf=False)),
#                                        ('clf',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=1000))]),
#              n_jobs=-1,
#              param_grid={'clf__C': [0.01, 0.1, 1, 5, 10, 100],
#                          'clf__class_weight': ['none', 'balanced'],
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'tfidf__smooth_idf': [True, False],
#                          'tfidf__sublinear_tf': [True, False],
#                          'tfidf__use_idf': [True, False]},
#              scoring=make_scorer(fbeta_score, beta=2))

# %%
LG_GS.best_params_
# Out:
# {'clf__C': 1,
#  'clf__class_weight': 'balanced',
#  'tfidf__ngram_range': (1, 1),
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True}

# %%
cross_val_df.cross_val_report(LG_GS.best_estimator_,'Tuned Logistic Regression',X_train,y_train)
# Out:
# [0.867056856187291, 0.5845443196004994, 0.3001155354209293]

# %%
cross_val_df.history.sort_values('mean_recall')
# Out:
#                         Name  mean_accuracy  std_accuracy  mean_precision  \
# 0             Baseline Dummy       0.863880      0.009635        0.081676
# 1             Logistic_TFIDF       0.913545      0.009138        0.395436
# 2             Logistic_TFIDF       0.898662      0.006983        0.357625
# 3               Logistic_BOW       0.862876      0.006099        0.285229
# 4             Logistic_TFIDF       0.867057      0.004164        0.300116
# 6  Tuned Logistic Regression       0.867057      0.004164        0.300116
# 5          Baseline Logistic       0.829766      0.008388        0.245816
#
#    std_precision  mean_recall  std_recall   mean_f1    std_f1  \
# 0       0.036418     0.069139    0.026880  0.066957  0.012847
# 1       0.086763     0.299001    0.072966  0.339969  0.078817
# 2       0.031299     0.437453    0.025999  0.393250  0.028001
# 3       0.022435     0.553308    0.062936  0.376122  0.032752
# 4       0.021531     0.584544    0.057838  0.396524  0.032114
# 6       0.021531     0.584544    0.057838  0.396524  0.032114
# 5       0.022980     0.615780    0.062758  0.351303  0.033441
#
#                              notes
# 0
# 1                       N_grams2,2
# 2                       N_grams1,2
# 3                      N_Grams_1,2
# 4                       N_grams1,1
# 6
# 5  Balanced Weights/Ngrams 1,1,BoW

# %%
validation_scores.report(Baseline_LG,'Tuned Logistic',X_val,y_val)
# Out:
# [0.8275401069518716, 0.6428571428571429, 0.2482758620689655]

# %%
validation_scores.history
# Out:
#                 Name  accuracy  precision    recall        f1            notes
# 0     Logistic_TFIDF  0.901070   0.390244  0.571429  0.463768       N_gram_1,2
# 1     Logistic_TFIDF  0.871658   0.318182  0.625000  0.421687       N_gram_1,1
# 2  baseline_logistic  0.827540   0.248276  0.642857  0.358209  n_grams 1,1,BoW
# 3       Logistic_BOW  0.874332   0.327273  0.642857  0.433735       N_gram_1,2
# 4     Tuned Logistic  0.827540   0.248276  0.642857  0.358209

# %%
fn.reporting(LG_GS.best_estimator_,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       692
#            1       0.32      0.62      0.42        56
#
#     accuracy                           0.87       748
#    macro avg       0.64      0.76      0.67       748
# weighted avg       0.92      0.87      0.89       748

# %% [markdown]
# ### Baseline Support Vector Machine

# %%
from sklearn import svm

# %%
Baseline_svm = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,1),use_idf=False)),
        ('svm', svm.SVC())
    ]
)

# %%
Baseline_svm.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(use_idf=False)), ('svm', SVC())])

# %%
cross_val_df.cross_val_report(Baseline_svm,'Baseline_svm',X_train,y_train)
# Out:
# [0.9280936454849499, 0.05585518102372035, 0.8222222222222222]

# %% [markdown]
# ### Support Vectmor Machine Ngram 1,2

# %%
SVM_1_2 = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2),use_idf=False)),
        ('svm', svm.SVC())
    ]
)
SVM_1_2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2), use_idf=False)),
#                 ('svm', SVC())])

# %%
cross_val_df.cross_val_report(SVM_1_2,'SVM_BOW',X_train,y_train,'ngram 1,2')
# Out:
# [0.9280936454849499, 0.06029962546816479, 0.7966666666666666]

# %%
fn.reporting(SVM_1_2,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       692
#            1       0.75      0.05      0.10        56
#
#     accuracy                           0.93       748
#    macro avg       0.84      0.53      0.53       748
# weighted avg       0.92      0.93      0.90       748

# %% [markdown]
# ### Support Vector TFIDF

# %%
SVM_tfidf_1_1 = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,1),use_idf=True)),
        ('svm', svm.SVC())
    ]
)
SVM_tfidf_1_1.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('svm', SVC())])

# %%
cross_val_df.cross_val_report(SVM_tfidf_1_1,'SVM_TFIDF',X_train,y_train,'ngram_1,1')
# Out:
# [0.9285953177257525, 0.07143570536828964, 0.7904761904761906]

# %%
SVM_tfidf_1_2 = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2),use_idf=True)),
        ('svm', svm.SVC())
    ]
)
SVM_tfidf_1_2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))), ('svm', SVC())])

# %%
cross_val_df.cross_val_report(SVM_tfidf_1_2,'SVM_TFIDF',X_train,y_train,'ngram_1,2')
# Out:
# [0.9285953177257525, 0.06699126092384519, 0.8068831168831169]

# %%
param_grid = {'svm__C': [0.1,1, 10,15,20], 'svm__gamma': [1,0.1,0.01,0.001],'svm__kernel': ['rbf', 'poly', 'sigmoid'],
             'tfidf__use_idf':[True, False],'tfidf__ngram_range':[(1,1),(1,2)],'svm__class_weight':[None,'balanced']}

# %%
tuned_svm = GridSearchCV(estimator=Baseline_svm,param_grid=param_grid,cv=5,scoring=two_scorer,refit=True,n_jobs=-1)

# %%
SVM_tfidf_3 = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2),use_idf=True)),
        ('svm', svm.SVC(C=20,gamma=1,kernel='sigmoid',class_weight='balanced'))
    ]
)
SVM_tfidf_3.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('svm',
#                  SVC(C=20, class_weight='balanced', gamma=1,
#                      kernel='sigmoid'))])

# %%
tuned_svm.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(use_idf=False)),
#                                        ('svm', SVC())]),
#              n_jobs=-1,
#              param_grid={'svm__C': [0.1, 1, 10, 15, 20],
#                          'svm__class_weight': [None, 'balanced'],
#                          'svm__gamma': [1, 0.1, 0.01, 0.001],
#                          'svm__kernel': ['rbf', 'poly', 'sigmoid'],
#                          'tfidf__ngram_range': [(1, 1), (1, 2)],
#                          'tfidf__use_idf': [True, False]},
#              scoring=make_scorer(fbeta_score, beta=2))

# %%
cross_val_df.cross_val_report(tuned_svm.best_estimator_,'Tuned_SVM',X_train,y_train)
# Out:
# [0.8560200668896322, 0.6114107365792759, 0.28469932844932844]

# %% [markdown]
# ### Baseline Compliment Bayes

# %%
Baseline_CB = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2))),
        ('cnb', ComplementNB())
    ]
)

# %%
Baseline_CB.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('cnb', ComplementNB())])

# %%
cross_val_df.cross_val_report(Baseline_CB,'Baseline Bayes',X_train,y_train)
# Out:
# [0.9292642140468228, 0.14499375780274656, 0.6144991100940758]

# %%
cross_val_df.history
# Out:
#                          Name  mean_accuracy  std_accuracy  mean_precision  \
# 0                Baseline_svm       0.928094      0.001399        0.822222
# 1                     SVM_BOW       0.928094      0.000916        0.796667
# 2                   SVM_TFIDF       0.928595      0.000853        0.806883
# 3              Baseline Dummy       0.863880      0.009635        0.081676
# 4                   SVM_TFIDF       0.928595      0.000853        0.790476
# 12             Baseline Bayes       0.929264      0.002727        0.614499
# 5              Logistic_TFIDF       0.913545      0.009138        0.395436
# 6              Logistic_TFIDF       0.898662      0.006983        0.357625
# 7                Logistic_BOW       0.862876      0.006099        0.285229
# 8              Logistic_TFIDF       0.867057      0.004164        0.300116
# 9   Tuned Logistic Regression       0.867057      0.004164        0.300116
# 10                  Tuned_SVM       0.856020      0.003234        0.284699
# 11          Baseline Logistic       0.829766      0.008388        0.245816
#
#     std_precision  mean_recall  std_recall   mean_f1    std_f1  \
# 0        0.093953     0.055855    0.023476  0.102999  0.042225
# 1        0.112744     0.060300    0.020735  0.110521  0.036022
# 2        0.110288     0.066991    0.018701  0.122359  0.031673
# 3        0.036418     0.069139    0.026880  0.066957  0.012847
# 4        0.122706     0.071436    0.026914  0.128624  0.043989
# 12       0.087212     0.144994    0.028733  0.234251  0.043402
# 5        0.086763     0.299001    0.072966  0.339969  0.078817
# 6        0.031299     0.437453    0.025999  0.393250  0.028001
# 7        0.022435     0.553308    0.062936  0.376122  0.032752
# 8        0.021531     0.584544    0.057838  0.396524  0.032114
# 9        0.021531     0.584544    0.057838  0.396524  0.032114
# 10       0.009235     0.611411    0.053870  0.388186  0.018418
# 11       0.022980     0.615780    0.062758  0.351303  0.033441
#
#                               notes
# 0
# 1                         ngram 1,2
# 2                         ngram_1,2
# 3
# 4                         ngram_1,1
# 12
# 5                        N_grams2,2
# 6                        N_grams1,2
# 7                       N_Grams_1,2
# 8                        N_grams1,1
# 9
# 10
# 11  Balanced Weights/Ngrams 1,1,BoW

# %%
fn.reporting(Baseline_CB,X_train,y_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      5532
#            1       0.80      0.62      0.70       448
#
#     accuracy                           0.96      5980
#    macro avg       0.89      0.81      0.84      5980
# weighted avg       0.96      0.96      0.96      5980

# %%
validation_scores.report(Baseline_CB,'Baseline CB',X_val,y_val)
# Out:
# [0.9264705882352942, 0.125, 0.5384615384615384]

# %%
validation_scores.history
# Out:
#                 Name  accuracy  precision    recall        f1            notes
# 5        Baseline CB  0.926471   0.538462  0.125000  0.202899
# 0     Logistic_TFIDF  0.901070   0.390244  0.571429  0.463768       N_gram_1,2
# 1     Logistic_TFIDF  0.871658   0.318182  0.625000  0.421687       N_gram_1,1
# 2  baseline_logistic  0.827540   0.248276  0.642857  0.358209  n_grams 1,1,BoW
# 3       Logistic_BOW  0.874332   0.327273  0.642857  0.433735       N_gram_1,2
# 4     Tuned Logistic  0.827540   0.248276  0.642857  0.358209

# %%
fn.reporting(Baseline_CB,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       692
#            1       0.54      0.12      0.20        56
#
#     accuracy                           0.93       748
#    macro avg       0.74      0.56      0.58       748
# weighted avg       0.90      0.93      0.90       748

# %% [markdown]
# ### Tuned Compliment Bayes

# %%
param_grid = {'cnb__alpha': [0.01, 0.1, 0.5, 1.0, 10.0],
               'tfidf__ngram_range': [(1, 1), (1,2),(1,3)],
              'cnb__class_prior': [None, [.07, .93]],
                'cnb__fit_prior': [True, False],'tfidf__use_idf':[True,False],
              'tfidf__smooth_idf':[True,False],'tfidf__sublinear_tf':[True,False]
                                      }

# %%
import multiprocessing

multiprocessing.cpu_count()
# Out:
# 4

# %%
# %%time

CB_GS = GridSearchCV(estimator=Baseline_CB,param_grid=param_grid,cv=5,scoring=two_scorer,refit=True,n_jobs=-1)
CB_GS.fit(X_train,y_train)
# Out:
# CPU times: user 14.2 s, sys: 1.26 s, total: 15.5 s
# Wall time: 4min 40s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(ngram_range=(1, 2))),
#                                        ('cnb', ComplementNB())]),
#              n_jobs=-1,
#              param_grid={'cnb__alpha': [0.01, 0.1, 0.5, 1.0, 10.0],
#                          'cnb__class_prior': [None, [0.07, 0.93]],
#                          'cnb__fit_prior': [True, False],
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'tfidf__smooth_idf': [True, False],
#                          'tfidf__sublinear_tf': [True, False],
#                          'tfidf__use_idf': [True, False]},
#              scoring=make_scorer(fbeta_score, beta=2))

# %%
CB_GS.best_params_
# Out:
# {'cnb__alpha': 0.1,
#  'cnb__class_prior': None,
#  'cnb__fit_prior': True,
#  'tfidf__ngram_range': (1, 1),
#  'tfidf__smooth_idf': False,
#  'tfidf__sublinear_tf': True,
#  'tfidf__use_idf': True}

# %%
validation_scores.report(CB_GS.best_estimator_,'Tune Comp Bayes',X_val,y_val)
# Out:
# [0.8409090909090909, 0.6071428571428571, 0.2595419847328244]

# %%
fn.reporting(CB_GS,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91       692
#            1       0.26      0.61      0.36        56
#
#     accuracy                           0.84       748
#    macro avg       0.61      0.73      0.64       748
# weighted avg       0.91      0.84      0.87       748

# %%
df['Sentiment'].value_counts(normalize=True)
# Out:
# 0    0.925094
# 1    0.074906
# Name: Sentiment, dtype: float64

# %%
validation_scores.history
# Out:
#                 Name  accuracy  precision    recall        f1            notes
# 0        Baseline CB  0.926471   0.538462  0.125000  0.202899
# 1     Logistic_TFIDF  0.901070   0.390244  0.571429  0.463768       N_gram_1,2
# 6    Tune Comp Bayes  0.840909   0.259542  0.607143  0.363636
# 2     Logistic_TFIDF  0.871658   0.318182  0.625000  0.421687       N_gram_1,1
# 3  baseline_logistic  0.827540   0.248276  0.642857  0.358209  n_grams 1,1,BoW
# 4       Logistic_BOW  0.874332   0.327273  0.642857  0.433735       N_gram_1,2
# 5     Tuned Logistic  0.827540   0.248276  0.642857  0.358209

# %% [markdown]
# ### Baseline Random Forrest Classifier

# %%
Baseline_RF = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2))),
        ('RF', RandomForestClassifier())
    ]
)

# %%
# %%time

Baseline_RF.fit(X_train,y_train)
# Out:
# CPU times: user 3.62 s, sys: 41.9 ms, total: 3.67 s
# Wall time: 3.78 s
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('RF', RandomForestClassifier())])

# %%
cross_val_df.cross_val_report(Baseline_RF,'Baseline Random Forrest',X_train,y_train)
# Out:
# [0.9311036789297658, 0.16729088639201, 0.665597606055272]

# %%
fn.reporting(Baseline_RF,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       692
#            1       0.81      0.23      0.36        56
#
#     accuracy                           0.94       748
#    macro avg       0.88      0.61      0.66       748
# weighted avg       0.93      0.94      0.92       748

# %% [markdown]
# ### Tuned Random Forrest

# %%
from skopt.space import Real, Categorical, Integer
from skopt import BayesSearchCV

# %%
random_grid = {'RF__class_weight': ["balanced", "balanced_subsample"], 'tfidf__ngram_range': [(1, 1), (1,2),(1,3)],
                                    'RF__max_depth': [5, 10, 15, 20, 30, None],
                                    'RF__n_estimators': [50,100,150],'tfidf__use_idf':[True,False],
              'tfidf__smooth_idf':[True,False],'tfidf__sublinear_tf':[True,False]
                                  }

# %%
param_space = {
        'RF__class_weight': Categorical(["balanced", "balanced_subsample"]),
        "tfidf__ngram_range": Categorical([(1, 1), (1,2),(1,3)]),
        "RF__max_depth": Integer(4, 30),
        
        'tfidf__smooth_df':Categorical([True,False]),
        'tfidf__sublinear_tf':Categorical([True,False]),
        "RF__n_estimators": Integer(50, 300)
        }

# %%
# %%time

RF_GS = GridSearchCV(estimator=Baseline_RF,param_grid=random_grid,cv=5,scoring=two_scorer,refit=True,n_jobs=-1)
RF_GS.fit(X_train,y_train)

# %%
RF_GS.best_params_

# %%
#Saving the grid search best model into a pickle
filename = 'Random_Forrest_Grid_Search.sav'
pickle.dump(RF_GS.best_estimator_, open(filename, 'wb'))

# %%
RF_GS = pickle.load(open('Random_Forrest_Grid_Search.sav', 'rb'))

# %%
cross_val_df.cross_val_report(RF_GS,'Grid RF',X_train,y_train,'Grid Search Random Forrest')
# Out:
# [0.7224080267558529, 0.6427465667915107, 0.156377444623574]

# %%
validation_scores.report(RF_GS,'Grid Search Random Forrest',X_val,y_val)
# Out:
# [0.6550802139037433, 0.7142857142857143, 0.14184397163120568]

# %%
fn.reporting(RF_GS,X_train,y_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.68      0.80      5532
#            1       0.17      0.79      0.28       448
#
#     accuracy                           0.69      5980
#    macro avg       0.57      0.74      0.54      5980
# weighted avg       0.92      0.69      0.76      5980

# %%
fn.reporting(RF_GS,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.65      0.78       692
#            1       0.14      0.71      0.24        56
#
#     accuracy                           0.66       748
#    macro avg       0.55      0.68      0.51       748
# weighted avg       0.90      0.66      0.74       748

# %% [markdown]
# My attempt at tuning the Random Forrest did not yield very good results. The model is now guessing many more negatives, and still missing roughly half of the actual negative cases. Hopefully adding more negative cases will help the model improve.

# %%
validation_scores.history
# Out:
#                          Name  accuracy  precision    recall        f1  \
# 0                 Baseline CB  0.926471   0.538462  0.125000  0.202899
# 1              Logistic_TFIDF  0.901070   0.390244  0.571429  0.463768
# 2             Tune Comp Bayes  0.840909   0.259542  0.607143  0.363636
# 3              Logistic_TFIDF  0.871658   0.318182  0.625000  0.421687
# 4           baseline_logistic  0.827540   0.248276  0.642857  0.358209
# 5                Logistic_BOW  0.874332   0.327273  0.642857  0.433735
# 6              Tuned Logistic  0.827540   0.248276  0.642857  0.358209
# 7  Grid Search Random Forrest  0.655080   0.141844  0.714286  0.236686
#
#              notes
# 0
# 1       N_gram_1,2
# 2
# 3       N_gram_1,1
# 4  n_grams 1,1,BoW
# 5       N_gram_1,2
# 6
# 7

# %% [markdown]
# ## Additional Negative Examples

# %% [markdown]
# Given the scores I'm dealing with I will be using the additional negative tweets to supplement this model.

# %% [markdown]
# ### Text Processing

# %%
new_df = pd.read_csv('additional_negs')

# %%
new_df['processed_text'] = fn.Process_Tweet(new_df['tweet_text'],remove_HTML=True,replace_moji_bake=True,strip_links=True,no_leading=True,contraction_fix=True,remove_numerals=True,remove_hashtags=False,remove_mentions=True)
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
X = new_df['processed_text']
token_docs = [fn.doc_preparer(doc, sw) for doc in X]
# Out:
# ['three', 'g', 'iphone', 'three', 'hrs', 'tweeting', 'rise', 'austin', 'dead', 'need', 'upgrade', 'plugin', 'stations', 'sxsw']
# ['know', 'awesome', 'ipad', 'iphone', 'app', 'likely', 'appreciate', 'design', 'also', 'giving', 'free', 'ts', 'sxsw']
# ['wait', 'ipad', 'two', 'also', 'sale', 'sxsw']
# ['hope', 'year', 'festival', 'crashy', 'year', 'iphone', 'app', 'sxsw']
# ['great', 'stuff', 'fri', 'sxsw', 'marissa', 'mayer', 'google', 'tim', 'reilly', 'tech', 'books', 'conferences', 'matt', 'mullenweg', 'wordpress']
# ['new', 'ipad', 'apps', 'speechtherapy', 'communication', 'showcased', 'sxsw', 'conference', 'iear', 'edchat', 'asd']
# ['sxsw', 'starting', 'ctia', 'around', 'corner', 'googleio', 'hop', 'skip', 'jump', 'good', 'time', 'android', 'fan']
# ['beautifully', 'smart', 'simple', 'idea', 'rt', 'wrote', 'hollergram', 'ipad', 'app', 'sxsw']
# ['counting', 'days', 'sxsw', 'plus', 'strong', 'canadian', 'dollar', 'means', 'stock', 'apple', 'gear']
# ['excited', 'meet', 'sxsw', 'show', 'sprint', 'galaxy', 'still', 'running', 'android', 'two', 'one', 'fail']
# ['find', 'start', 'impromptu', 'parties', 'sxsw', 'cannot', 'wait', 'til', 'android', 'app', 'comes']
# ['foursquare', 'ups', 'game', 'time', 'sxsw', 'still', 'prefer', 'far', 'best', 'looking', 'android', 'app', 'date']
# ['got', 'love', 'sxsw', 'google', 'calendar', 'featuring', 'top', 'parties', 'show', 'cases', 'check', 'rt', 'via']
# ['great', 'sxsw', 'ipad', 'app']
# ['haha', 'awesomely', 'rad', 'ipad', 'app', 'hollergram', 'sxsw']
# ['holler', 'gram', 'ipad', 'itunes', 'app', 'store', 'via', 'sxsw']
# ['noticed', 'dst', 'coming', 'weekend', 'many', 'iphone', 'users', 'hour', 'late', 'sxsw', 'come', 'sunday', 'morning', 'sxsw', 'iphone']
# ['added', 'sxsw', 'flights', 'matching', 'people', 'planes', 'airports', 'also', 'downloaded', 'iphone', 'app', 'nicely', 'done']
# ['must', 'sxsw', 'app', 'rt', 'lovely', 'review', 'forbes', 'sxsw', 'ipad', 'app', 'holler', 'gram']
# ['need', 'buy', 'ipad', 'two', 'austin', 'sxsw', 'sure', 'need', 'q', 'austin', 'apple', 'store']
# ['oh', 'god', 'sxsw', 'app', 'ipad', 'pure', 'unadulterated', 'awesome', 'easier', 'browse', 'events', 'ipad', 'website']
# ['okay', 'really', 'yay', 'new', 'android', 'app', 'eleven', 'kthxbai', 'sxsw']
# ['photo', 'installed', 'sxsw', 'iphone', 'app', 'really', 'nice']
# ['really', 'enjoying', 'changes', 'gowalla', 'three', 'zero', 'android', 'looking', 'forward', 'seeing', 'else', 'foursquare', 'sleeves', 'sxsw']
# ['rt', 'looking', 'forward', 'smcdallas', 'pre', 'sxsw', 'party', 'wed', 'hoping', 'win', 'ipad', 'resulting', 'shameless', 'promotion', 'chevysmc']
# ['rt', 'haha', 'awesomely', 'rad', 'ipad', 'app', 'hollergram', 'sxsw', 'via']
# ['someone', 'started', 'austin', 'group', 'google', 'groups', 'pre', 'sxsw', 'great', 'idea']
# ['new', 'four', 'sq', 'three', 'looks', 'like', 'going', 'rock', 'update', 'iphone', 'android', 'push', 'tonight', 'sxsw', 'keepaustinweird']
# ['right', 'three', 'app', 'android', 'sweeeeet', 'nice', 'job', 'team', 'sxsw']
# ['smart', 'hollergram', 'ipad', 'app', 'sxsw', 'may', 'leave', 'vuvuzela', 'home']
# ['must', 'app', 'ipad', 'going', 'sxsw', 'hollergram']
# ['attn', 'sxsw', 'frineds', 'register', 'gdgtlive', 'see', 'cobra', 'iradar', 'android']
# ['anyone', 'sxsw', 'want', 'sell', 'old', 'ipad']
# ['anyone', 'sxsw', 'bought', 'new', 'ipad', 'want', 'sell', 'older', 'ipad']
# ['sxsw', 'oooh', 'rt', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today']
# ['best', 'rt', 'ha', 'first', 'line', 'ipad', 'two', 'sxsw', 'pop', 'apple', 'store', 'event', 'planner', 'eventprofs', 'pcma', 'engage', 'three', 'hundred', 'sixty', 'five']
# ['spin', 'play', 'new', 'concept', 'music', 'discovery', 'ipad', 'spin', 'com', 'itunes', 'sxsw']
# ['false', 'alarm', 'google', 'circles', 'coming', 'nowand', 'probably', 'ever', 'google', 'circles', 'social', 'sxsw']
# ['vatornews', 'google', 'apple', 'force', 'print', 'media', 'evolve', 'sxsw']
# ['great', 'weather', 'greet', 'sxsw', 'still', 'need', 'sweater', 'night', 'apple', 'putting', 'flash', 'store', 'downtown', 'sell', 'ipad', 'two']
# ['hootsuite', 'hootsuite', 'mobile', 'sxsw', 'updates', 'iphone', 'blackberry', 'android', 'whether', 'getting', 'friend']
# ['hey', 'sxsw', 'long', 'think', 'takes', 'us', 'make', 'iphone', 'case', 'answer', 'using', 'zazzlesxsw', 'make', 'one']
# ['mashable', 'ipad', 'two', 'takes', 'sxsw', 'video', 'ipad', 'sxsw', 'gadgets']
# ['pad', 'rt', 'new', 'ubersocial', 'iphone', 'app', 'store', 'includes', 'uberguide', 'sxsw', 'sponsored']
# ['ipad', 'two', 'smartcover', 'opens', 'instant', 'access', 'waited', 'get', 'one', 'apple', 'sxsw']
# ['hand', 'held', 'hobo', 'drafthouse', 'launches', 'hobo', 'shotgun', 'iphone', 'app', 'sxsw']
# ['hooray', 'rt', 'apple', 'opening', 'pop', 'store', 'austin', 'sxsw']
# ['orly', 'google', 'set', 'launch', 'new', 'social', 'network', 'circles', 'today', 'sxsw']
# ['wooooo', 'apple', 'store', 'downtown', 'austin', 'open', 'til', 'midnight', 'sxsw']
# ['khoi', 'vinh', 'says', 'conde', 'nast', 'headlong', 'rush', 'ipad', 'publishing', 'fundamental', 'misunderstanding', 'platform', 'sxsw']
# ['help', 'forward', 'doc', 'anonymous', 'accounts', 'techies', 'people', 'help', 'us', 'jam', 'libya', 'sxsw']
# ['edchat', 'musedchat', 'sxsw', 'sxswi', 'classical', 'newtwitter']
# ['location', 'based', 'fast', 'fun', 'future', 'via', 'sxsw']
# ['google', 'connect', 'digital', 'physical', 'worlds', 'mobile', 'sxsw']
# ['talking', 'google', 'effort', 'allow', 'users', 'open', 'systems', 'bettercloud', 'sxsw']
# ['rt', 'google', 'tweet', 'new', 'think', 'speak', 'mark', 'belinsky', 'nine', 'hundred', 'eleven', 'tweets', 'panel', 'sxsw']
# ['rt', 'one', 'st', 'stop', 'sxsw', 'chaos', 'hunt', 'austin', 'java', 'get', 'spy', 'game', 'four', 'chance', 'two', 'win', 'ipad']
# ['rt', 'sxsw', 'check', 'holler', 'gram', 'ipad', 'app']
# ['fun', 'google', 'pic', 'sxsw']
# ['via', 'guy', 'kawasaki', 'talks', 'enchanted', 'sxsw', 'knows', 'stuff', 'books', 'internet', 'apple', 'sxsw']
# ['futuremf', 'spec', 'recipes', 'web', 'google', 'search', 'sxsw']
# ['omfg', 'rt', 'heard', 'apple', 'pop', 'store', 'downtown', 'austin', 'pics', 'already', 'gowalla', 'sxsw', 'ipad', 'two']
# ['smile', 'rt', 'think', 'apple', 'pop', 'store', 'austin', 'would', 'lot', 'interesting', 'actually', 'know', 'popped', 'sxsw']
# ['rt', 'line', 'apple', 'store', 'insane', 'sxsw']
# ['agree', 'rt', 'wait', 'fiona', 'apple', 'town', 'somebody', 'kidnap', 'put', 'recording', 'studio', 'records', 'new', 'album', 'sxsw']
# ['sxsw', 'want', 'buy', 'drink', 'seven', 'pm', 'fado', 'four', 'th', 'join', 'us']
# ['attending', 'ipad', 'design', 'headaches', 'sxsw']
# ['boooo', 'rt', 'flipboard', 'developing', 'iphone', 'version', 'android', 'says', 'sxsw']
# ['check', 'line', 'ipad', 'two', 'austin', 'power', 'sxswi', 'sxsw']
# ['check', 'rt', 'giving', 'added', 'value', 'location', 'based', 'services', 'needs', 'battle', 'check', 'fatigue', 'google', 'pnid', 'sxsw']
# ['chilcott', 'sxsw', 'stand', 'talking', 'blogger', 'staff', 'late', 'win', 'competition', 'best', 'tweet', 'mentioning', 'shirt']
# ['rt', 'come', 'party', 'w', 'google', 'tonight', 'sxsw', 'bands', 'food', 'art', 'ice', 'cream', 'nifty', 'interactive', 'maps']
# ['gowalla', 'promises', 'launch', 'foursquare', 'check', 'groupon', 'rewards', 'type', 'service', 'sxsw', 'finger', 'crossed']
# ['ha', 'ha', 'rt', 'sxsw', 'news', 'yahoo', 'com', 'loosing', 'search', 'traffic', 'new', 'site', 'google', 'com', 'doubt', 'last', 'though', 'w', 'weird', 'name']
# ['holla', 'rt', 'google', 'party', 'best', 'ever', 'get', 'butt', 'sxsw']
# ['love', 'iphone', 'case', 'sxsw', 'cannot', 'get', 'phone', 'fail']
# ['worship', 'sxsw']
# ['ipad', 'two', 'rt', 'droid', 'mac', 'rt', 'agnerd', 'confession', 'using', 'laptop', 'ipad', 'blackberry', 'follow', 'sxsw']
# ['launching', 'sxsw', 'rt', 'denies', 'social', 'network', 'called', 'circles', 'debut', 'today', 'despite', 'report']
# ['new', 'post', 'iphone', 'app', 'makes', 'easy', 'connect', 'social', 'networks', 'people', 'meet', 'sxsw']
# ['nice', 'iphone', 'app', 'behaving', 'today', 'crashes', 'yesterday', 'ridiculous', 'sxsw']
# ['nice', 'rt', 'apple', 'opening', 'popup', 'store', 'ipad', 'launch', 'downtown', 'austin', 'sxsw', 'via']
# ['nice', 'rt', 'hey', 'apple', 'fans', 'get', 'peek', 'space', 'slated', 'pop', 'sxsw', 'apple', 'store', 'tomorrow']
# ['one', 'thing', 'great', 'get', 'great', 'earth', 'face', 'google', 'company', 'love', 'sxsw', 'sxwsi']
# ['stay', 'tune', 'showcase', 'h', 'four', 'ckers', 'sxsw']
# ['thank', 'touchingstories', 'preso', 'sxsw', 'deck']
# ['thank', 'awesome', 'sxsw', 'party']
# ['thanks', 'rt', 'trying', 'contact', 'friends', 'family', 'japan', 'created', 'person', 'finder', 'sxsw']
# ['thanks', 'mention', 'new', 'speech', 'ipad', 'apps', 'showcased', 'sxsw', 'conf', 'sxswh', 'sxsh']
# ['thanks', 'publishing', 'news', 'new', 'medical', 'apps', 'sxswi', 'conf', 'blog', 'sxsw', 'sxswh', 'mhealth']
# ['sxsw', 'provide', 'iphone', 'chargers', 'changed', 'mind', 'going', 'next', 'year']
# ['wonder', 'apple', 'flashmob', 'tcrn', 'ch', 'fcs', 'forty', 'five', 'j', 'sxsw', 'ipad', 'two']
# ['wonder', 'putting', 'tips', 'api', 'sxsw', 'suxsw']
# ['xmas', 'rt', 'shiny', 'new', 'apps', 'new', 'book', 'pop', 'ipad', 'two', 'stores', 'sxsw', 'christmas', 'nerds']
# ['yai', 'rt', 'new', 'ubersocial', 'iphone', 'app', 'store', 'includes', 'uberguide', 'sxsw', 'sponsored', 'cont']
# ['yes', 'rt', 'hey', 'got', 'another', 'gem', 'free', 'sxsw', 'sxsw']
# ['fast', 'fun', 'future', 'google', 'presenting', 'sxsw', 'search', 'local', 'mobile']
# ['gsd', 'google', 'industry', 'party', 'tonight', 'see', 'sxsw', 'austin', 'welivehere', 'gsdm']
# ['new', 'buzz', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'rt', 'sxsw']
# ['headline', 'ipad', 'two', 'must', 'gadget', 'sxsw', 'hmm', 'could', 'seen', 'one', 'coming', 'gadget']
# ['know', 'dataviz', 'translates', 'satanic', 'iphone', 'sayin', 'sxsw']
# ['google', 'launched', 'checkins', 'month', 'ago', 'check', 'ins', 'ok', 'check', 'outs', 'future', 'sxsw', 'bizzy']
# ['google', 'launched', 'checkins', 'month', 'ago', 'check', 'ins', 'ok', 'check', 'outs', 'future', 'sxsw', 'bizzy', 'via']
# ['google', 'tweet', 'new', 'think', 'speak', 'mark', 'belinsky', 'nine', 'hundred', 'eleven', 'tweets', 'panel', 'sxsw']
# ['attending', 'left', 'brain', 'search', 'google', 'right', 'brain', 'search', 'x', 'bettersearch', 'talking', 'future', 'search', 'engines', 'sxsw']
# ['hp', 'opens', 'mobile', 'park', 'content', 'incubator', 'sxsw', 'apple', 'constructs', 'pop', 'store']
# ['kawasaki', 'c', 'lewis', 'level', 'reasoning', 'apple', 'continued', 'existence', 'evidence', 'existence', 'god', 'bawling', 'sxsw']
# ['kawasaki', 'pagemaker', 'saved', 'apple', 'oh', 'days', 'sxsw', 'jwtatl', 'enchantment']
# ['kawasaki', 'pagemaker', 'saved', 'apple', 'oh', 'days', 'sxsw', 'jwtatl', 'enchantment', 'via']
# ['spark', 'android', 'teamandroid', 'award', 'sxsw', 'read']
# ['unboxing', 'apple', 'sxsw', 'apple', 'store', 'sxsw']
# ['sxsw', 'apple', 'ipad', 'two', 'great', 'thoughts', 'w', 'japan', 'apac', 'regions', 'dealing', 'w', 'earthquake', 'tsunami', 'trauma', 'sxswi']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'sxsw', 'cnet', 'blogs']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts']
# ['temporary', 'apple', 'store', 'def', 'tent', 'powerhouse', 'gym', 'sxsw']
# ['temporary', 'apple', 'store', 'six', 'th', 'congress', 'sxsw', 'along', 'ten', 'zero', 'happy', 'hipsters']
# ['apple', 'wins', 'sxsw', 'opening', 'temporary', 'store', 'downtown', 'austin', 'support', 'ipad', 'two', 'launch', 'good']
# ['ipad', 'austin', 'trending', 'today', 'fun', 'sxsw', 'nerdy', 'nerds']
# ['headed', 'austin', 'sxsw', 'check', 'map', 'newbies', 'enjoy']
# ['funny', 'austin', 'trending', 'sxsw', 'matter', 'minutes', 'point', 'least', 'according', 'twitter', 'iphone']
# ['christian', 'ipad', 'iphone', 'devs', 'want', 'talk', 'sxsw', 'maybe', 'wk', 'together', 'cool', 'app']
# ['sxsw', 'ux', 'ipad', 'uxdes', 'remember', 'ultimately', 'aware', 'audience', 'app', 'targeted', 'towards', 'unexpected', 'experience', 'good']
# ['apple', 'ipad', 'two', 'taken', 'sxsw', 'austin', 'storm', 'excited', 'part', 'mobile']
# ['haz', 'ipad', 'two', 'ifrom', 'sxsw', 'gr', 'eight']
# ['stacks', 'ipad', 'two', 'waiting', 'bought', 'sxsw', 'got', 'mine', 'hassle', 'apple', 'handled', 'perfectly']
# ['google', 'mobile', 'future', 'elusive', 'power', 'via', 'eurorscg', 'sxsw', 'sxswi']
# ['notatsxsw', 'sxsw', 'free', 'download', 'meet', 'nearby', 'peps']
# ['smallbiz', 'need', 'reviews', 'play', 'google', 'places', 'got', 'app', 'seo', 'sxsw']
# ['smallbiz', 'need', 'reviews', 'play', 'google', 'places', 'got', 'app', 'seo', 'sxsw']
# ['samsung', 'sony', 'follow', 'apple', 'hp', 'lead', 'austin', 'atx', 'sxsw']
# ['samsung', 'sony', 'follow', 'apple', 'hp', 'lead', 'austin', 'atx', 'sxsw', 'via', 'rg']
# ['take', 'sxsw', 'rt', 'major', 'south', 'korean', 'director', 'gets', 'one', 'hundred', 'thirty', 'zero', 'make', 'movie', 'entirely', 'iphone']
# ['beautiful', 'sxsw', 'apple', 'store', 'sxsw', 'pic']
# ['q', 'one', 'sxsw', 'sxswi', 'prep', 'amazing', 'pre', 'push', 'locally', 'focus', 'location', 'based', 'google', 'owns', 'ten', 'regions', 'billboards', 'pr', 'twenty', 'chat']
# ['sxsw', 'accounts', 'need', 'follow', 'apps', 'download', 'iphone']
# ['headed', 'sxsw', 'want', 'share', 'gather', 'contact', 'info', 'turn', 'iphone', 'business', 'card', 'broadcaster']
# ['headed', 'sxsw', 'want', 'share', 'gather', 'contact', 'info', 'turn', 'iphone']
# ['way', 'sxsw', 'apple', 'store', 'sold', 'three', 'g', 'models', 'vzw']
# ['must', 'sxsw', 'app', 'rt', 'lovely', 'review', 'forbes', 'sxsw', 'ipad', 'app', 'holler', 'gram']
# ['temporary', 'sxsw', 'apple', 'store', 'apple', 'sneaky', 'usual']
# ['anyone', 'sxsw', 'pop', 'apple', 'store', 'austin', 'got', 'hopping', 'place', 'today']
# ['sxsw', 'beta', 'testing', 'interactive', 'book', 'ipad', 'app', 'moonbot', 'studios', 'louisiana', 'cool', 'app']
# ['apple', 'sxsw', 'day', 'one', 'seeing', 'ton', 'ipad', 'two']
# ['fastball', 'sxsw', 'giving', 'away', 'two', 'new', 'ipad', 'two', 'wifi', 'thirty', 'two', 'g', 'black', 'apple', 'cover', 'tweet', 'fo', 'info', 'sxswi', 'attsxsw', 'tonight', 'bo', 'lt', 'house']
# ['anyone', 'sxsw', 'chance', 'check', 'pop', 'apple', 'store', 'wondering', 'worth', 'trek', 'convention', 'center']
# ['sxsw', 'ipad', 'store', 'sold', 'everything', 'except', 'sixty', 'four', 'gig', 'wifi', 'white', 'manage', 'get']
# ['sxsw', 'ipad', 'store', 'sold', 'everything', 'except', 'sixty', 'four', 'gig', 'wifi', 'white', 'also', 'known', 'white', 'jeans', 'configuration']
# ['offered', 'sxsw', 'ipad', 'promo', 'ninjafinder', 'users', 'fans', 'sxsw', 'sucks', 'sxsw']
# ['sxsw', 'austin', 'conference', 'google', 'search', 'interactive', 'music', 'film']
# ['anyone', 'sxsw', 'know', 'apple', 'selling', 'ipad', 'two']
# ['anyone', 'sxsw', 'know', 'apple', 'store', 'new', 'shipment', 'ipads', 'yet']
# ['marc', 'ecko', 'sxsw', 'launches', 'iphone', 'app', 'autodial', 'political', 'change', 'edreform', 'edtech', 'eduvc', 'fightthepaddle']
# ['poursite', 'sxsw', 'learning', 'life', 'changing', 'impact', 'ipad', 'real', 'people', 'actual', 'lives', 'bravo']
# ['sxsw', 'lonelyplanet', 'austin', 'guide', 'iphone', 'free', 'limited', 'time', 'lp', 'travel']
# ['free', 'sxsw', 'mp', 'three', 'downloads', 'time', 'itunes']
# ['anyone', 'sxsw', 'heading', 'aclu', 'event', 'seen', 'owt', 'google', 'circles']
# ['sxsw', 'prompt', 'memory', 'go', 'google', 'map', 'describe', 'childhood', 'walk']
# ['apple', 'sxsw', 'store', 'still', 'ipad', 'two', 'short', 'lines']
# ['essential', 'sxsw', 'tools']
# ['left', 'sxsw', 'tradeshow', 'demo', 'google', 'theatre', 'ok', 'get', 'see', 'presenters', 'using']
# ['following', 'sxsw', 'tweets', 'google', 'realtime', 'four', 'platforms', 'tweet', 'deck', 'listening', 'panel', 'realizing', 'spoken', 'one', 'today']
# ['anyone', 'sxsw', 'want', 'ipad', 'two', 'line', 'pick', 'one', 'someone', 'willing', 'pay', 'fifty', 'grab', 'one']
# ['anyone', 'sxsw', 'want', 'make', 'quick', 'hundred', 'dollars', 'new', 'ipad', 'two', 'ad', 'hoc', 'apple', 'store', 'gets', 'hundred', 'plus', 'cost']
# ['solving', 'sxsw', 'induced', 'iphone', 'toilet', 'crisis', 'apple', 'store', 'crisis']
# ['monday', 'sxsw', 'barry', 'diller', 'new', 'york', 'times', 'congress', 'lunch', 'w', 'hotel', 'party', 'google', 'party', 'six', 'dirty', 'martinis', 'mondays']
# ['attending', 'sxsw', 'austin', 'guide', 'free', 'download', 'itunes', 'lp']
# ['seriously', 'sxsw', 'testing', 'mobile', 'apps', 'constant', 'ipad', 'crashes', 'causing', 'lost', 'schedules', 'sync', 'wp', 'seven']
# ['ready', 'sxsw', 'iphone', 'apps', 'two', 'make', 'blogging', 'easier', 'sxsw', 'sxswi']
# ['ipad', 'two', 'sxsw', 'conflagration', 'doofusness']
# ['attention', 'sxsw', 'ers', 'rumored', 'pop', 'temporary', 'apple', 'store', 'sxsw', 'ipad', 'two', 'launch', 'needs']
# ['went', 'sxswi', 'lousy', 'ipad', 'sxsw']
# ['hey', 'sxsw', 'sxswi', 'folks', 'want', 'learn', 'security', 'come', 'bsidesaustin']
# ['attending', 'sxswi', 'work', 'iphone', 'ipad', 'game', 'development', 'looking', 'hire', 'austin', 'based', 'ios', 'developer', 'man', 'let', 'us', 'talk', 'sxsw']
# ['winning', 'picture', 'android', 'google', 'sxsw']
# ['gsd', 'google', 'seven', 'ten', 'rt', 'best', 'party', 'hit', 'tonight', 'sxsw']
# ['gsd', 'google', 'industry', 'party', 'sxsw', 'great', 'meet']
# ['spent', 'one', 'zero', 'come', 'sxsw', 'already', 'used', 'ipad', 'one', 'wait', 'couple', 'city', 'blocks', 'ipad', 'two', 'sxsw']
# ['sxsw', 'day', 'one', 'marissa', 'mayer', 'google', 'connect', 'digital', 'physical', 'worlds', 'mobile']
# ['behind', 'one', 'hundred', 'emails', 'give', 'one', 'line', 'iphone', 'composed', 'replies', 'sxsw', 'protip']
# ['like', 'ten', 'pm', 'night', 'line', 'around', 'block', 'popup', 'apple', 'stores', 'selling', 'ipad', 'two', 'sxsw']
# ['one', 'thousand', 'one', 'hundred', 'fifty', 'four', 'free', 'songs', 'sxsw', 'year', 'alone']
# ['one', 'hundred', 'fifty', 'million', 'mobile', 'users', 'google', 'maps', 'mobile', 'sxsw']
# ['currently', 'one', 'hundred', 'fifty', 'people', 'line', 'pop', 'apple', 'store', 'sxsw']
# ['ipad', 'two', 'available', 'sxsw', 'sixty', 'four', 'gb', 'wifi', 'model', 'six', 'hundred', 'ninety', 'nine', 'plus', 'optional', 'leather', 'smart', 'cover', 'sixty', 'nine']
# ['love', 'two', 'entertain', 'please', 'grateful', 'edchat', 'musedchat', 'sxsw', 'sxswi', 'classical', 'newtwitter']
# ['less', 'two', 'hours', 'announce', 'details', 'ipad', 'two', 'giveaway', 'sxsw', 'sxswi']
# ['two', 'ipad', 'two', 'seen', 'wild', 'people', 'say', 'fast', 'still', 'pics', 'terrible', 'sxsw']
# ['ipad', 'two', 'queue', 'sxsw', 'course']
# ['ipad', 'two', 'takes', 'sxsw', 'video']
# ['many', 'ipad', 'two', 'snapping', 'away', 'keynote', 'slides', 'sxsw']
# ['apple', 'two', 'hundred', 'users', 'credit', 'cards', 'sync', 'itunes', 'one', 'click', 'purchase', 'winning', 'sxsw']
# ['two', 'nd', 'cocktail', 'texas', 'snowflake', 'google', 'cnngrill', 'sxsw']
# ['new', 'post', 'three', 'iphone', 'apps', 'using', 'south', 'southwest', 'interactive', 'sxsw', 'sxswi']
# ['new', 'post', 'three', 'iphone', 'apps', 'using', 'south', 'southwest', 'interactive', 'sxsw', 'sxswi']
# ['sweet', 'new', 'three', 'google', 'maps', 'demo', 'going', 'ballroom', 'sxsw']
# ['thirty', 'five', 'million', 'miles', 'per', 'day', 'driving', 'google', 'maps', 'navigation', 'sxsw']
# ['rt', 'four', 'p', 'ipad', 'two', 'line', 'apple', 'store', 'longer', 'wider', 'two', 'hundred', 'fifty', 'people', 'one', 'hour', 'sxsw']
# ['smart', 'four', 'packing', 'extra', 'rt', 'way', 'sunny', 'austin', 'sxsw', 'extra', 'iphone', 'stow', 'case']
# ['wonder', 'four', 'sqwill', 'attempt', 'block', 'gowalla', 'cross', 'checkins', 'way', 'facebook', 'blocked', 'google', 'contacts', 'connections', 'sxsw', 'lbswars']
# ['sxsw', 'day', 'five', 'apple', 'store', 'still', 'line', 'growing']
# ['check', 'five', 'steps', 'bulletproof', 'ux', 'strategy', 'sxsw', 'sxsw', 'rhjr', 'ux', 'five']
# ['wandering', 'six', 'th', 'street', 'girls', 'stopped', 'ceviche', 'mojitos', 'apple', 'juice', 'ice', 'cream', 'sxsw']
# ['band', 'sxsw', 'want', 'share', 'track', 'audience', 'stage', 'use', 'frostwire', 'android', 'wi', 'fi', 'available']
# ['got', 'busy', 'week', 'ahead', 'new', 'book', 'google', 'apps', 'available', 'amazon', 'attending', 'sxsw']
# ['believe', 'went', 'aussies', 'sxsw', 'rt', 'ipad', 'two', 'sold', 'seventy', 'went', 'new', 'buyers', 'report']
# ['google', 'spreadsheet', 'two', 'hundred', 'seventy', 'parties', 'sxsw', 'year', 'plan', 'going', 'sxsw', 'party']
# ['guy', 'line', 'apple', 'pop', 'store', 'sixth', 'street', 'austin', 'guy', 'told', 'sxsw']
# ['iphone', 'need', 'car', 'use', 'zimride', 'etc', 'share', 'rides', 'sxsw', 'shareable']
# ['seen', 'lot', 'tablets', 'every', 'single', 'one', 'ipad', 'sxsw']
# ['receiving', 'lot', 'messages', 'telling', 'sexy', 'response', 'post', 'looking', 'meet', 'fellow', 'christian', 'iphone', 'devs', 'sxsw']
# ['picked', 'mophie', 'battery', 'case', 'four', 'iphone', 'prep', 'sxsw', 'lugging', 'around', 'laptop', 'using', 'phone', 'huge', 'win', 'last', 'year']
# ['news', 'p', 'rt', 'google', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'possibly', 'today', 'sxsw']
# ['took', 'piss', 'trade', 'show', 'ipad', 'one', 'hand', 'iphone', 'pissing', 'kiiiiiilling', 'right', 'sxsw']
# ['rumor', 'monger', 'good', 'read', 'google', 'circles', 'preview', 'sxsw', 'via', 'socbiz', 'fb']
# ['hobo', 'shotgun', 'iphone', 'game', 'sxsw']
# ['hobo', 'shotgun', 'video', 'game', 'coming', 'ipad', 'iphone', 'users', 'yes', 'please', 'sxsw']
# ['build', 'store', 'less', 'twenty', 'four', 'hours', 'one', 'biggest', 'launches', 'company', 'history', 'got', 'apple', 'sxsw', 'ipad', 'two']
# ['took', 'survey', 'iphone', 'starbucks', 'line', 'got', 'free', 'starbucks', 'gift', 'card', 'instant', 'research', 'instant', 'gratification', 'sxsw', 'gsdm']
# ['apple', 'temporary', 'retail', 'store', 'austin', 'ipad', 'two', 'release', 'today', 'opens', 'five', 'pm', 'sxsw', 'sxswi', 'ipad', 'two']
# ['read', 'groupme', 'sxsw', 'sounds', 'like', 'incredible', 'app', 'available', 'android', 'phones', 'yet']
# ['wondering', 'circles', 'google', 'reveal', 'new', 'social', 'network', 'sxsw']
# ['google', 'search', 'local', 'marissa', 'mayer', 'sxsw']
# ['wondering', 'street', 'closures', 'sxsw', 'made', 'google', 'map', 'show', 'sxsw', 'austin']
# ['google', 'another', 'go', 'social', 'google', 'circles', 'sxsw', 'google']
# ['questions', 'inside', 'ipad', 'two', 'fire', 'way', 'sxsw']
# ['paraormal', 'activity', 'sanctuary', 'iphone', 'game', 'sketching', 'ar', 'experience', 'interactivity', 'magic', 'lense', 'eduar', 'sxsw']
# ['apple', 'iie', 'ad', 'eighty', 'five', 'si', 'swimsuit', 'issue', 'garage', 'sale', 'sxsw']
# ['flipboard', 'adds', 'instagram', 'photos', 'social', 'search', 'apps', 'apple', 'socialsearch', 'sxsw']
# ['spent', 'aftrnoon', 'frozen', 'lake', 'photographing', 'brother', 'scott', 'team', 'catch', 'sxsw', 'ths', 'weeknd']
# ['iphone', 'alarms', 'botch', 'timechange', 'many', 'sxsw', 'ers', 'freak', 'late', 'flights', 'missed', 'panels', 'behind', 'bloody', 'marys']
# ['shouts', 'ladies', 'holding', 'ipad', 'two', 'free', 'sxsw', 'shows', 'take', 'photos', 'sipping', 'free', 'beer', 'cc']
# ['dj', 'hoodie', 'allen', 'due', 'respect', 'probably', 'make', 'way', 'back', 'google', 'sxsw']
# ['meant', 'also', 'wish', 'sxsw', 'dyac', 'stupid', 'iphone']
# ['audioboo', 'american', 'dream', 'bust', 'ipad', 'sxsw', 'bum', 'begger', 'us', 'socialart', 'documentally']
# ['skifta', 'app', 'based', 'media', 'shifting', 'service', 'turns', 'android', 'phone', 'sxsw', 'mashable', 'sxswi']
# ['rumors', 'apple', 'store', 'opening', 'sxsw', 'six', 'th', 'congress', 'signs', 'point', 'yes']
# ['apple', 'security', 'guy', 'locks', 'store', 'sxsw']
# ['apple', 'security', 'guy', 'locks', 'store', 'sxsw', 'realtime', 'sxsw', 'curated']
# ['got', 'ipad', 'two', 'sxsw', 'cc']
# ['picked', 'ipad', 'two', 'sxsw', 'pop', 'apple', 'store', 'fifteen', 'minute', 'wait']
# ['brilliant', 'enlightening', 'game', 'mechanics', 'presentation', 'google', 'sxsw']
# ['gsd', 'google', 'sitting', 'tree', 'sxsw', 'gsdm']
# ['pic', 'winning', 'ipad', 'unsix', 'sxsw', 'cc', 'cont']
# ['iphone', 'thirsty', 'sxsw', 'chevy', 'volt', 'lounge', 'w', 'sixteen', 'others']
# ['iphone', 'thirsty', 'sxsw', 'chevy', 'volt', 'lounge', 'w', 'sixteen', 'others']
# ['came', 'left', 'sxsw', 'iphone', 'playing', 'song', 'chosen', 'random', 'skream', 'listening', 'records', 'wall', 'appropriate']
# ['marketing', 'sales', 'genius', 'apple', 'sxsw']
# ['arduino', 'android', 'flaming', 'skulls', 'refrigerator', 'speaks', 'salon', 'k', 'three', 'thirty', 'pm', 'sxsw', 'smartthings']
# ['reminder', 'android', 'chrome', 'tts', 'talk', 'one', 'pm', 'today', 'sxsw']
# ['ipad', 'two', 'vs', 'android', 'vs', 'world', 'panel', 'sxsw', 'today', 'three', 'thirty', 'pm']
# ['backupify', 'announces', 'cloudsight', 'search', 'first', 'searchable', 'archive', 'solution', 'social', 'media', 'google', 'apps', 'sxsw', 'sxswi']
# ['google', 'announcing', 'social', 'network', 'circles', 'via', 'sxsw', 'tweets', 'interesting', 'myopia', 'cause', 'buzz', 'jokes', 'interesting']
# ['need', 'sxsw', 'ipad', 'iphone', 'laptop', 'dictaphone', 'vid', 'camera', 'wow', 'love', 'meet', 'real', 'cerebellum', 'charged', 'people']
# ['see', 'anything', 'google', 'circles', 'sxsw']
# ['sxsw', 'app', 'iphone', 'ridiculous', 'personal', 'planner', 'next', 'five', 'days']
# ['sxsw', 'app', 'android', 'huge', 'props', 'get']
# ['found', 'app', 'kyping', 'iphone', 'geolocation', 'releasing', 'background', 'need', 'patch', 'batterykiller', 'sxsw']
# ['sxsw', 'app', 'iphone', 'live', 'rsvp', 'events', 'phone', 'check', 'sundayswagger', 'eventbrite', 'com', 'three', 'twenty', 'scoremore']
# ['iphone', 'app', 'screen', 'sxsw', 'missing']
# ['love', 'app', 'awesome', 'rt', 'must', 'see', 'android', 'app', 'sxsw', 'bizzy']
# ['sxsw', 'apple', 'pop', 'store', 'nuts', 'still', 'packed', 'eleven', 'thirty']
# ['say', 'apple', 'sxsw', 'popup', 'store', 'austin']
# ['breaking', 'apple', 'announces', 'partnership', 'w', 'porn', 'industry', 'new', 'ipad', 'two', 'video', 'chat', 'app', 'called', 'facetime', 'sxsw']
# ['course', 'apple', 'built', 'temp', 'store', 'austin', 'texas', 'understand', 'concept', 'corralling', 'cattle', 'sxsw', 'pickmeupanipad', 'two']
# ['love', 'apple', 'let', 'something', 'like', 'retail', 'store', 'near', 'sxsw', 'keep', 'away', 'opening', 'pop', 'store']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'sxsw', 'get', 'new', 'cnet']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'sxsw', 'get', 'new', 'ipads', 'cnet']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'sxsw', 'get', 'new', 'ipads']
# ['surprise', 'apple', 'opened', 'pop', 'store', 'austin', 'nerds', 'town', 'sxsw', 'get', 'new', 'ipads']
# ['technews', 'apple', 'heads', 'sxsw', 'sets', 'temporary', 'store', 'austin', 'tech', 'news', 'apple', 'ipad', 'two', 'rance', 'wilemon', 'sxsw', 'tech']
# ['apple', 'great', 'example', 'retail', 'store', 'layed', 'future', 'registers', 'checkout', 'line', 'sxsw']
# ['apple', 'opening', 'temporary', 'store', 'downtown', 'austin', 'sxsw', 'ipad', 'two', 'launch', 'gswsxsw']
# ['apple', 'opening', 'temporary', 'store', 'downtown', 'austin', 'sxsw', 'ipad', 'two', 'launch', 'oh', 'yay', 'traffic']
# ['technews', 'apple', 'opening', 'pop', 'store', 'austin', 'sxsw', 'tech', 'news', 'american', 'statesman', 'apple', 'apple', 'apple', 'sxsw', 'tech']
# ['technews', 'apple', 'opening', 'pop', 'store', 'austin', 'sxsw', 'geekfest', 'apple', 'tech', 'news', 'apple', 'brian', 'lam', 'ipad', 'two', 'sxsw', 'tech']
# ['sxsw', 'apple', 'popup', 'store', 'open', 'noon', 'fresh', 'shipment', 'ipad', 'two', 'pretty', 'sure', 'going', 'get', 'one', 'fingers', 'crossed']
# ['technews', 'apple', 'saves', 'sxsw', 'set', 'open', 'pop', 'store', 'tech', 'news', 'apple', 'sxsw', 'tech']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'via']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'via', 'true', 'love', 'loathe', 'one', 'marketing', 'like']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'cnet']
# ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'cnet', 'blogs', 'austin', 'atx', 'retail']
# ['apple', 'store', 'downtown', 'austin', 'open', 'til', 'midnight', 'sxsw', 'still', 'time']
# ['apple', 'store', 'downtown', 'austin', 'open', 'til', 'midnight', 'sxsw', 'ipad', 'two', 'left', 'stock']
# ['apple', 'store', 'congress', 'sxsw', 'austin']
# ['apple', 'store', 'mall', 'sunday', 'ten', 'x', 'crowded', 'line', 'fake', 'need', 'fucking', 'dongle', 'genius', 'let', 'sxsw']
# ['two', 'wks', 'apple', 'store', 'six', 'th', 'austin', 'street', 'opened', 'sxsw']
# ['special', 'apple', 'store', 'opening', 'six', 'th', 'congress', 'sxsw', 'ipad', 'two', 'launch', 'www', 'apple', 'com', 'retail', 'thedomain', 'apple', 'ipad', 'two', 'sxsw', 'fb']
# ['makeshift', 'apple', 'store', 'six', 'th', 'congress', 'kidding', 'amazing', 'sxsw', 'apple']
# ['temporary', 'apple', 'store', 'sxsw', 'huge', 'line']
# ['temporary', 'apple', 'store', 'sxsw', 'really', 'cool', 'ipad', 'two', 'apple', 'sxsw', 'fanboy']
# ['temporary', 'apple', 'store', 'set', 'sxsw', 'shit', 'temptation', 'going', 'control']
# ['temporary', 'apple', 'store', 'sxsw', 'line', 'goes', 'around', 'block']
# ['temporary', 'apple', 'store', 'opens', 'six', 'th', 'congress', 'tomorrow', 'ipad', 'two', 'sxsw']
# ['temporary', 'apple', 'store', 'opens', 'five', 'pm', 'six', 'th', 'congress', 'line', 'already', 'growing', 'ipad', 'view', 'io', 'via', 'sxsw']
# ['temporary', 'apple', 'store', 'block', 'office', 'cannot', 'wait', 'see', 'line', 'tomorrow', 'photos', 'come', 'sxsw', 'ipad', 'two']
# ['sxsw', 'apple', 'store', 'opens', 'noon', 'day', 'closes', 'run', 'ipad', 'two', 'buy', 'stock', 'ten', 'years', 'ago']
# ['base', 'camp', 'apple', 'sxsw']
# ['ipad', 'news', 'apps', 'last', 'year', 'sxsw']
# ['ten', 'iphone', 'apps', 'probably', 'need', 'use', 'sxsw']
# ['one', 'hundred', 'fifty', 'million', 'mobile', 'google', 'maps', 'users', 'sxsw']
# ['lines', 'already', 'forming', 'apple', 'pop', 'store', 'austin', 'people', 'see', 'festival', 'sxsw']
# ['android', 'rt', 'ten', 'new', 'mobile', 'apps', 'using', 'sxsw']
# ['sxsw', 'attending', 'sxsw', 'report', 'see', 'android', 'phone', 'get', 'bannka', 'app']
# ['ipad', 'apps', 'like', 'software', 'development', 'release', 'start', 'working', 'update', 'sxsw']
# ['tweets', 'stalled', 'data', 'sluggish', 'come', 'verizon', 'embarrassing', 'iphone', 'customers', 'switched', 'sxsw', 'iphone']
# ['tweeting', 'google', 'coming', 'circles', 'platform', 'today', 'outside', 'circle', 'keep', 'itsnot', 'sxsw']
# ['stupid', 'find', 'sxsw', 'mac', 'special', 'price', 'games', 'mac']
# ['slate', 'see', 'much', 'traffic', 'mobile', 'safari', 'app', 'ipad', 'sxsw', 'electricnews']
# ['unloading', 'apple', 'store', 'corner', 'six', 'th', 'congress', 'austin', 'temp', 'store', 'sxsw']
# ['great', 'day', 'sxsw', 'jaloux', 'new', 'ipad', 'look', 'school', 'bus', 'one', 'st', 'day', 'school']
# ['arrived', 'sxsw', 'issue', 'resolved', 'dying', 'use', 'iphone', 'app', 'cannot', 'login', 'rt']
# ['sxsw', 'screenburn', 'launch', 'clients', 'new', 'iphone', 'game', 'travellerarlaunch', 'find']
# ['anyone', 'sxsw', 'wants', 'see', 'demo', 'piccraft', 'ipad', 'two', 'find']
# ['sxsw', 'could', 'spend', 'teaching', 'theater', 'alone', 'look', 'schedule']
# ['sxsw', 'meet', 'us', 'fado', 'give', 'wristbands', 'magically', 'lead', 'beer', 'come', 'say', 'hi']
# ['sxsw', 'want', 'ipad', 'two', 'apple', 'setting', 'temporary', 'store', 'check']
# ['overheard', 'sxsw', 'ipad', 'relaxing', 'computer', 'agreed', 'ipad', 'apple']
# ['overheard', 'sxsw', 'interactive', 'arg', 'hate', 'iphone', 'want', 'blackberry', 'back', 'shocked']
# ['sxsw', 'meet', 'author', 'host', 'android', 'devs', 'sat', 'twelve', 'thirty', 'pm', 'hilton', 'room', 'six', 'hundred', 'fifteen', 'ab']
# ['sxsw', 'apple', 'comes', 'cool', 'technology', 'one', 'ever', 'heard', 'go', 'conferences']
# ['sxsw', 'apple', 'sets', 'five', 'zero', 'square', 'foot', 'temporary', 'store', 'sxsw', 'sell', 'new', 'ipads', 'test', 'potential', 'traffic']
# ['overheard', 'sxsw', 'google', 'launch', 'products', 'people', 'events']
# ['nerd', 'bait', 'sxsw', 'apple', 'set', 'open', 'popup', 'shop', 'core', 'sxsw', 'action']
# ['long', 'line', 'sxsw', 'else', 'apple', 'store']
# ['last', 'year', 'sxswi', 'everbody', 'talking', 'ipad', 'year', 'social', 'media', 'driven', 'revolutions', 'year', 'better', 'sxsw']
# ['long', 'line', 'apple', 'pop', 'store', 'ipad', 'two', 'great', 'marketing', 'apple', 'sxsw']
# ['google', 'four', 'people', 'work', 'seven', 'people', 'rather', 'seven', 'people', 'work', 'four', 'agileagency', 'sxsw']
# ['knackered', 'home', 'playing', 'ipad', 'updating', 'iphone', 'timeline', 'smashed', 'partytweets', 'cannot', 'make', 'go', 'bed', 'sxsw']
# ['overheard', 'mdw', 'second', 'halfway', 'iphone', 'battery', 'already', 'even', 'boarded', 'plane', 'sxsw', 'amateurhour']
# ['technews', 'sxsw', 'apple', 'schools', 'marketing', 'experts', 'tech', 'news', 'apple', 'jobs', 'co', 'sxsw', 'tech']
# ['first', 'day', 'sxsw', 'fun', 'final', 'presentation', 'google', 'doodles', 'googledoodle', 'sxsw']
# ['huge', 'line', 'apple', 'store', 'austin', 'sxsw', 'crowd', 'tripping', 'get', 'new', 'ipad']
# ['google', 'aclu', 'eighty', 'party', 'sxsw']
# ['queue', 'apple', 'pop', 'store', 'sxsw']
# ['posted', 'dmi', 'house', 'intimate', 'stranger', 'stage', 'got', 'restaurant', 'crowd', 'sitting', 'deal', 'wif', 'sxsw']
# ['woman', 'google', 'talk', 'sounded', 'like', 'chelsea', 'handler', 'lol', 'sxsw']
# ['laughed', 'ipad', 'spent', 'week', 'hauling', 'macbook', 'everywhere', 'really', 'want', 'ipad', 'shoulder', 'rub', 'sxsw']
# ['sxsw', 'attendees', 'need', 'qr', 'code', 'reader', 'iphone', 'tweet', 'us', 'image', 'badge', 'first', 'five', 'get', 'optiscan', 'free']
# ['hey', 'sxsw', 'attendees', 'hop', 'line', 'apple', 'store', 'four', 'days', 'til', 'new', 'ipad', 'two', 'comes']
# ['anyone', 'attending', 'google', 'aclu', 'party', 'sxsw', 'could', 'plz', 'pictures', 'thanks', 'sxsw']
# ['march', 'eleven', 'austin', 'tx', 'people', 'line', 'sxsw', 'registration', 'apple', 'store']
# ['landed', 'austin', 'spotted', 'google', 'places', 'ads', 'sxsw', 'airport', 'ultimate', 'austin', 'pocket', 'guide', 'like', 'yelp', 'itouru']
# ['took', 'away', 'lego', 'pit', 'replaced', 'recharging', 'station', 'sxsw', 'might', 'check', 'prices', 'iphone', 'crap', 'samsung', 'android']
# ['awesome', 'meet', 'standing', 'apple', 'queue', 'sxsw', 'yesterday', 'day', 'two', 'cute']
# ['bad', 'apple', 'shows', 'late', 'qs', 'process', 'poo', 'poos', 'ideas', 'leaves', 'early', 'even', 'creative', 'busy', 'gamestorming', 'sxsw']
# ['bahrain', 'govt', 'turned', 'google', 'earth', 'result', 'people', 'learned', 'govt', 'turn', 'back', 'sxsw']
# ['trying', 'balance', 'power', 'power', 'needs', 'iphone', 'vs', 'ipad', 'sxsw', 'three', 'g', 'ipad', 'sucks', 'quick', 'might', 'go', 'airplane', 'mode']
# ['racing', 'ballroom', 'see', 'marissa', 'mayer', 'sxsw', 'sxswi']
# ['iphone', 'battery', 'one', 'hundred', 'winning', 'sxsw']
# ['iphone', 'battery', 'cannot', 'keep', 'tweets', 'thanks', 'apple', 'sxsw', 'precommerce']
# ['another', 'google', 'wave', 'rt', 'interrupt', 'regularly', 'scheduled', 'sxsw', 'geek', 'programming', 'w', 'big', 'google', 'news']
# ['fun', 'watch', 'ipadmadness', 'rt', 'apple', 'opening', 'pop', 'store', 'austin', 'sxsw', 'sxsw']
# ['control', 'apple', 'set', 'open', 'popup', 'shop', 'core', 'sxsw', 'action', 'via', 'cc']
# ['yeah', 'sure', 'rt', 'check', 'sxsw', 'google']
# ['celebrate', 'beauty', 'web', 'msft', 'ie', 'nine', 'launch', 'play', 'new', 'html', 'five', 'game', 'win', 'ipad', 'two', 'sxsw']
# ['texas', 'amazing', 'met', 'many', 'influential', 'people', 'work', 'twitter', 'foursquare', 'microsoft', 'even', 'apple', 'sxsw', 'winning']
# ['woke', 'iphone', 'finished', 'recharging', 'means', 'got', 'enough', 'sleep', 'last', 'night', 'right', 'sxsw']
# ['quiet', 'storm', 'sxsw', 'looking', 'forward', 'seeing', 'google', 'marissa', 'mayer']
# ['companies', 'believing', 'nfc', 'google', 'nexus', 'nokia', 'also', 'carriers', 'verifone', 'even', 'apple', 'seems', 'sxsw', 'sxswnfc']
# ['best', 'thing', 'heard', 'weekend', 'sxsw', 'gave', 'ipad', 'two', 'money', 'japan', 'relief', 'need', 'ipad', 'two']
# ['ipad', 'two', 'better', 'time', 'improve', 'sxsw']
# ['cus', 'pacman', 'google', 'singularity', 'sxsw', 'noobs', 'meetup']
# ['go', 'beyond', 'earth', 'hour', 'year', 'sharing', 'positive', 'actions', 'world', 'download', 'earthhour', 'sixty', 'iphone', 'app', 'sxsw']
# ['far', 'biggest', 'sxsw', 'mistake', 'bringing', 'iphone', 'ipad', 'charger']
# ['google', 'vs', 'bing', 'bettersearch', 'bing', 'shot', 'success', 'w', 'structured', 'search', 'potentially', 'higher', 'margin', 'cpa', 'model', 'vs', 'google', 'sxsw']
# ['course', 'bing', 'results', 'good', 'google', 'seo', 'sxsw', 'qagb']
# ['black', 'white', 'ipad', 'sxsw', 'ipad', 'two', 'question']
# ['hootsuite', 'blog', 'social', 'media', 'dashboard', 'hootsuite', 'mobile', 'sxsw', 'updates', 'iphone', 'blackberry', 'android']
# ['hootsuite', 'blog', 'social', 'media', 'dashboard', 'hootsuite', 'mobile', 'sxsw', 'updates', 'iphone', 'blackberry', 'android']
# ['hoot', 'new', 'blog', 'post', 'hootsuite', 'mobile', 'sxsw', 'updates', 'iphone', 'blackberry', 'android']
# ['anyone', 'bringing', 'ipad', 'vs', 'computer', 'sxsw']
# ['impulsive', 'buy', 'friends', 'sxsw', 'one', 'selling', 'one', 'st', 'gen', 'thirty', 'two', 'gb', 'three', 'g', 'ipad']
# ['buying', 'two', 'new', 'ipad', 'geekdate', 'apple', 'sxsw', 'ipad', 'two']
# ['someone', 'buying', 'present', 'rt', 'apple', 'opening', 'pop', 'store', 'austin', 'sxsw']
# ['nice', 'find', 'rsq', 'sxsw', 'ipad', 'app']
# ['south', 'southwest', 'panels', 'illustrated', 'pics', 'sometimes', 'best', 'news', 'ogilvy', 'sxsw', 'trending', 'cyber', 'iphone']
# ['google', 'calendar', 'saturday', 'night', 'giant', 'overlap', 'sxsw', 'parties']
# ['google', 'canadian', 'tuxedo', 'lose', 'hours', 'sxsw']
# ['anyone', 'make', 'cooler', 'rt', 'launch', 'groupon', 'living', 'social', 'type', 'rewards', 'sxsw']
# ['exciting', 'wait', 'rt', 'apple', 'opening', 'temporary', 'store', 'downtown', 'austin', 'sxsw', 'ipad', 'two', 'launch']
# ['great', 'certain', 'meetings', 'rt', 'hello', 'holler', 'gram', 'new', 'ipad', 'app', 'hollergram', 'sxsw']
# ['miss', 'charles', 'chen', 'android', 'chromeos', 'access', 'sxsw', 'google', 'booth', 'exhibit', 'hall', 'three', 'one', 'pm', 'sxsw']
# ['reminder', 'charles', 'chen', 'talking', 'android', 'chromeos', 'access', 'today', 'one', 'pm', 'google', 'booth', 'exhibit', 'hall', 'three', 'sxsw']
# ['tomorrow', 'charles', 'chen', 'speaking', 'android', 'chromeos', 'access', 'google', 'booth', 'exhibit', 'hall', 'three', 'one', 'pm', 'sxsw']
# ['group', 'chat', 'apps', 'sxsw', 'told', 'l', 'two', 'apps', 'yet', 'avail', 'android', 'point', 'need', 'phone', 'apps']
# ['remember', 'chime', 'tweets', 'nasatweetup', 'experience', 'two', 'fifteen', 'pm', 'three', 'pm', 'central', 'time', 'sxsw', 'session']
# ['daily', 'chord', 'tuesday', 'march', 'eight', 'hackers', 'discover', 'google', 'music', 'servicestory', 'rollin', 'sxsw', 'music', 'news']
# ['daily', 'chord', 'tuesday', 'march', 'eight', 'hackers', 'discover', 'google', 'music', 'servicestory', 'rolling', 'stone', 'mo', 'sxsw']
# ['google', 'circle', 'austin', 'sxsw']
# ['google', 'circles', 'sxsw', 'ht', 'maybe', 'reconsidering', 'shape']
# ['google', 'circles', 'buzz', 'corners', 'rounded', 'might', 'find', 'today', 'sxsw', 'google']
# ['google', 'circles', 'rt', 'launching', 'products', 'sxsw', 'plenty', 'else']
# ['ten', 'austin', 'classics', 'missed', 'sxsw', 'four', 'blog', 'com', 'twitter', 'iphone', 'three', 'twelve', 'eleven', 'twelve', 'forty', 'pm']
# ['tools', 'collaboration', 'across', 'boundaries', 'google', 'webex', 'dropbox', 'whiteboarding', 'basecamp', 'join', 'ipad', 'sxsw', 'evolvingworkplace']
# ['trying', 'collaborate', 'sxsw', 'events', 'friends', 'google', 'calendar', 'plancast']
# ['sxsw', 'come', 'hear', 'speak', 'forty', 'mins', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'ballrm', 'eleven', 'zero', 'uxdes']
# ['ipad', 'two', 'coming', 'sxsw', 'guess', 'apple', 'pretty', 'desperate', 'give', 'attention']
# ['coming', 'sxsw', 'sure', 'download', 'sxsw', 'go', 'app', 'schedules', 'locations', 'events']
# ['seriously', 'considering', 'leaving', 'macbook', 'pro', 'home', 'flying', 'solo', 'ipad', 'week', 'think', 'make', 'work', 'sxsw']
# ['among', 'cool', 'goofy', 'things', 'spied', 'sxsw', 'today', 'ipad', 'case', 'made', 'look', 'like', 'etchnsketch', 'grown', 'game', 'tug', 'war']
# ['wishes', 'could', 'party', 'sxsw', 'instead', 'homework', 'tomorrow']
# ['could', 'find', 'sxsw', 'probably', 'fiting', 'ipad']
# ['check', 'coyne', 'pr', 'updates', 'sxsw', 'via']
# ['crazy', 'look', 'around', 'sxsw', 'realize', 'last', 'year', 'one', 'ipad', 'sxsw']
# ['crazy', 'big', 'crowds', 'sxsw', 'apple', 'store', 'sxsw']
# ['read', 'article', 'google', 'say', 'rumor', 'launch', 'major', 'new', 'social', 'network', 'called', 'circles', 'sxsw']
# ['sxsw', 'l', 'four', 'iphone', 'come', 'uj', 'booth', 'acc', 'hall', 'two', 'snap', 'pics', 'send', 'us', 'fightthepaddle']
# ['shipments', 'daily', 'follow', 'appleatxdt', 'four', 'updates', 'rt', 'pop', 'apple', 'store', 'seems', 'pop', 'ipad', 'two', 'sxsw']
# ['day', 'three', 'tired', 'hold', 'ipad', 'week', 'death', 'happy', 'death', 'sxsw']
# ['beautiful', 'day', 'austin', 'come', 'grab', 'slice', 'two', 'check', 'google', 'get', 'deal', 'sxswi', 'sxsw']
# ['four', 'days', 'ipad', 'sxsw', 'weekend', 'battlela']
# ['iphone', 'dead', 'find', 'secret', 'batphone', 'sxsw']
# ['google', 'debut', 'new', 'selective', 'social', 'network', 'today', 'sxsw', 'google', 'circles']
# ['trying', 'decide', 'session', 'attend', 'sxsw', 'marissa', 'meyer', 'later', 'today', 'given']
# ['excellent', 'deck', 'rt', 'nth', 'time', 'lucky', 'google', 'new', 'social', 'network', 'launch', 'maybe', 'sxsw']
# ['default', 'state', 'users', 'leisurely', 'contemplative', 'ipad', 'sxsw']
# ['mobile', 'definitely', 'hot', 'topic', 'year', 'every', 'session', 'standing', 'room', 'next', 'lessons', 'learnt', 'building', 'netflix', 'iphone', 'app', 'sxsw']
# ['apple', 'deliberately', 'chose', 'march', 'eleven', 'ipad', 'two', 'availability', 'knowing', 'large', 'chunk', 'customer', 'base', 'sxsw']
# ['google', 'tv', 'demo', 'league', 'extraordinary', 'hackers', 'cool', 'stuff', 'like', 'web', 'apps', 'tv', 'google', 'sxsw', 'lxh']
# ['best', 'ipad', 'design', 'big', 'chunky', 'elements', 'generous', 'space', 'clarity', 'trumps', 'density', 'tap', 'quality', 'trumps', 'tap', 'quantity', 'tapworthy', 'sxsw']
# ['attending', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'w', 'great', 'stuff', 'far', 'sxsw']
# ['attending', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'akqa', 'lynn', 'teo', 'ballroom', 'yes', 'hiring', 'sxsw']
# ['check', 'designing', 'android', 'sxsw', 'sxsw', 'uxamandroid']
# ['check', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'uxdes']
# ['check', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'sxsw', 'uxdes']
# ['headed', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'sxsw', 'uxdes']
# ['taking', 'designing', 'ipad', 'interfaces', 'new', 'navigation', 'schemas', 'sxsw', 'sxsw', 'uxdes']
# ['adobe', 'developed', 'engine', 'essentially', 'convert', 'swf', 'files', 'jquery', 'html', 'five', 'existing', 'flash', 'files', 'portable', 'ipad', 'sxsw']
# ['developer', 'awesome', 'name', 'event', 'rt', 'join', 'league', 'extraordinary', 'h', 'four', 'ckers', 'sxsw']
# ['behaviour', 'different', 'lots', 'phone', 'calls', 'using', 'ipad', 'laptop', 'notsomuch', 'mobiles', 'internets', 'sxsw']
# ['lovin', 'digital', 'band', 'sings', 'iphone', 'plays', 'guitar', 'app', 'fans', 'record', 'vids', 'ipad', 'two', 'cnn', 'digital', 'cnngrill', 'sxsw', 'sxswi']
# ['barry', 'diller', 'thinks', 'ipad', 'content', 'nuts', 'sxsw']
# ['really', 'need', 'another', 'big', 'social', 'network', 'right', 'thanks', 'sxsw', 'google']
# ['q', 'two', 'think', 'google', 'check', 'offers', 'testing', 'sxsw', 'smccolumbus']
# ['japan', 'docomo', 'introduced', 'mobile', 'apps', 'six', 'years', 'apple', 'came', 'app', 'store', 'jpmobilesummit', 'sxsw']
# ['time', 'apple', 'store', 'sxsw', 'open', 'pulling', 'ipad', 'two', 'trigger']
# ['sxsw', 'forget', 'come', 'privacybootcamp', 'startups']
# ['sxsw', 'forget', 'come', 'privacybootcamp', 'startups', 'acc', 'nine', 'abc', 'three', 'thirty', 'cst']
# ['bad', 'button', 'rt', 'know', 'sxsw', 'time', 'abnormal', 'amount', 'app', 'updates', 'iphone']
# ['web', 'devs', 'wait', 'line', 'ipad', 'two', 'sxsw', 'signup', 'new', 'relic', 'using', 'promo', 'sxsw', 'two', 'thousand', 'eleven', 'eligible', 'win', 'one']
# ['download', 'twenty', 'free', 'tracks', 'sxsw', 'music', 'sampler', 'available', 'store', 'today']
# ['download', 'twenty', 'free', 'tracks', 'sxsw', 'music', 'sampler', 'available', 'store', 'today']
# ['download', 'twenty', 'free', 'tracks', 'sxsw', 'music', 'sampler', 'available', 'store', 'today', 'fb']
# ['downloadfree', 'tracks', 'sxsw', 'music', 'sampler', 'available', 'green', 'lady', 'killers']
# ['guess', 'drew', 'bigger', 'crowd', 'sxsw', 'chimp', 'could', 'work', 'iphone', 'sorry']
# ['jeez', 'guys', 'know', 'apple', 'pop', 'gold', 'gym', 'realize', 'un', 'jobs', 'aesthetic', 'sxsw', 'apple']
# ['anyone', 'else', 'using', 'hashable', 'network', 'sxsw', 'week', 'trying', 'android', 'version']
# ['enjoy', 'sxsw', 'ride', 'anywhere', 'austin', 'ten', 'download', 'groundlink', 'app', 'booth', 'four', 'hundred', 'thirty', 'seven']
# ['enjoy', 'sxsw', 'ride', 'anywhere', 'austin', 'ten', 'dwnld', 'groundlink', 'app', 'booth', 'four', 'hundred', 'thirty', 'seven']
# ['even', 'begins', 'apple', 'winning', 'sxsw', 'via']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'tc', 'apple']
# ['even', 'begins', 'apple', 'wins', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'opening', 'temporary', 'store', 'downtown', 'austin', 'support', 'ipad', 'two', 'launch', 'genius']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'past', 'week', 'major', 'dilemma']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'techcrunch', 'ipad']
# ['even', 'begins', 'apple', 'wins', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'via']
# ['even', 'begins', 'apple', 'wins', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'via']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'going', 'get', 'sum', 'via']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'techcrunch', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'win', 'big', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'apple', 'ipad', 'two', 'pm', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'apple', 'ipad', 'two', 'sxsw', 'tc']
# ['even', 'begins', 'apple', 'winssxsw', 'apple', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'tc', 'apple', 'ipad', 'two', 'sxsw']
# ['even', 'begins', 'apple', 'winssxsw', 'via', 'apple', 'sxsw']
# ['even', 'begins', 'apple', 'wins', 'sxsw', 'via', 'apple', 'sxsw']
# ['badgeless', 'event', 'free', 'drinks', 'heading', 'free', 'google', 'sponsored', 'happy', 'hour', 'semantic', 'web', 'austin', 'fogo', 'de', 'cho', 'sxsw']
# ['best', 'swag', 'ever', 'thanks', 'charging', 'iphone', 'thanks', 'sxsw']
# ['thanks', 'everyone', 'making', 'great', 'day', 'shop', 'today', 'austin', 'come', 'see', 'us', 'tomorrow', 'sxsw']
# ['thanks', 'everyone', 'came', 'today', 'good', 'luck', 'winning', 'ipad', 'stop', 'tomorrow', 'chances', 'win', 'sxsw']
# ['timing', 'everything', 'ipad', 'two', 'brand', 'winner', 'sxsw', 'pnid', 'sxsw']
# ['hey', 'sxsw', 'exhibitors', 'capture', 'booth', 'experience', 'retrollect', 'disc', 'popular', 'disc', 'wins', 'ipad', 'two']
# ...
# ['condoseniors', 'said', 'needs', 'supply', 'condo', 'dedicated', 'tech', 'many', 'issues', 'iphone', 'imac', 'ipads', 'warrants', 'tech', 'eat', 'well']
# ['glad', 'getting', 'non', 'computer', 'four', 'macs', 'row']
# ['fucking', 'memer', 'faggots']
# ['bruh', 'means', 'type', 'lot', 'fuckin', 'punk', 'bitch']
# ['dear', 'please', 'create', 'middle', 'finger', 'emoji', 'soon', 'possible', 'sincerely', 'iphone', 'users']
# ['rt', 'dear', 'please', 'create', 'middle', 'finger', 'emoji', 'soon', 'possible', 'sincerely', 'iphone', 'users']
# ['got', 'kidding']
# ['rt', 'got', 'kidding']
# ['apple', 'product', 'chargers', 'look', 'like', 'rt', 'rt', 'got', 'kidding']
# ['struggle', 'rt', 'rt', 'got', 'kidding']
# ['rt', 'higher', 'price', 'targets', 'helping', 'apple', 'shares', 'aapl', 'aapl']
# ['many', 'iphone', 'chargers', 'need', 'go', 'make', 'charger', 'durability', 'point', 'new', 'iphone']
# ['caller', 'id', 'must', 'able', 'blocked', 'products', 'apple', 'iphone', 'six', 'iphone', 'six', 'plus']
# ['yo', 'make', 'hard', 'grip', 'six']
# ['apple', 'patented', 'idea', 'stevejobs', 'would', 'hated', 'aapl']
# ['pay', 'taxes', 'country']
# ['aapl', 'apple', 'returns', 'cash', 'shareholders', 'ideas']
# ['applecare', 'cares', 'beware', 'false', 'prophetsi', 'mean', 'profits']
# ['beware', 'anything', 'includes', 'word', 'care']
# ['talking', 'support', 'almost', 'two', 'hours', 'absolutely', 'help']
# ['fuck', 'recently', 'deleted', 'photo', 'album']
# ['come', 'aapl', 'get', 'shit', 'together']
# ['rt', 'fuck', 'recently', 'deleted', 'photo', 'album']
# ['oh', 'horrible', 'packaging', 'shipping', 'shame']
# ['inconsistency', 'overall', 'weirdness', 'controls', 'appstore', 'archive', 'previous', 'versions', 'easy', 'downgrade']
# ['tryng', 'get', 'back', 'snapchat', 'app', 'store', 'cooperating']
# ['removing', 'photo', 'upload', 'covering', 'refund', 'purchased', 'based', 'features']
# ['rt', 'rt', 'fuck', 'recently', 'deleted', 'photo', 'album']
# ['ios', 'eight', 'notification', 'center', 'pain', 'ass', 'way', 'sort', 'way', 'dismiss', 'notifications', 'hitting', 'x', 'app']
# ['iphone', 'six', 'fell', 'two', 'ft', 'screen', 'shattered', 'like', 'blown', 'wants', 'additional', 'one', 'hundred', 'nine', 'fix', 'maybe', 'make', 'product', 'lasts']
# ['f', 'geniuses', 'suck', 'ass']
# ['hate', 'phone', 'cannot', 'use', 'gone', 'completely', 'silent', 'call', 'would', 'get', 'even', 'less', 'help', 'get']
# ['apple', 'tv', 'sales', 'topped', 'chromecast', 'aapl', 'pushed', 'apple', 'inc', 'aapl', 'never', 'made', 'much', 'fuss', 'ab']
# ['thank', 'little', 'troll', 'putting', 'option', 'close', 'right', 'save', 'tab', 'legends']
# ['especially', 'telling', 'randomly', 'selected', 'grant', 'broke', 'ass', 'govt', 'get', 'free', 'govt']
# ['happy', 'monday', 'camera', 'fancy', 'iphone', 'six', 'plus', 'suddenly', 'stopped', 'working', 'weekend', 'instead', 'meme']
# ['hey', 'fuck', 'phone', 'speaker', 'longer', 'works', 'b', 'c']
# ['hey', 'nevermind', 'restart', 'phone', 'make', 'work']
# ['apple', 'inc', 'catching', 'iphone', 'six', 'supply', 'still', 'lagging', 'demand', 'aapl']
# ['imac', 'caught', 'fire', 'use', 'sitting', 'desk', 'luckily', 'nearby', 'able', 'sort']
# ['know', 'trying', 'phone', 'updates', 'turned', 'thanks', 'letting', 'aware', 'error']
# ['phone', 'awful', 'green', 'line', 'need', 'new', 'one', 'sort', 'af']
# ['could', 'learn', 'take', 'pictures', 'internet', 'better']
# ['rt', 'could', 'learn', 'take', 'pictures', 'internet', 'better']
# ['good', 'grief', 'could', 'sucky', 'hold', 'music', 'queue', 'playlist', 'offense', 'ewwwwww', 'johnny', 'cash', 'rap', 'song', 'gross']
# ['great', 'johnny', 'cash', 'damn', 'jarring']
# ['reason', 'iphone', 'imessage', 'bruh', 'make', 'better', 'battery']
# ['aapl', 'apple', 'stock', 'price', 'plummeting', 'time', 'sell', 'bit']
# ['bring', 'back', 'classicipod', 'cantbelieveitsgone']
# ['day', 'twelve', 'without', 'access', 'passwd', 'apple', 'working', 'new', 'apps', 'calendar', 'ecosystem', 'achilles', 'move']
# ['oh', 'wish', 'guys', 'would', 'port', 'hebrew', 'android', 'version', 'already', 'swapping', 'abck', 'forth']
# ['much', 'completely', 'broken', 'shit', 'world', 'fucks', 'sake', 'fuck', 'bullshit', 'autocorrects']
# ['bad', 'third', 'party', 'keyboards', 'ios', 'buggy', 'hell', 'therefore', 'completely', 'unusable', 'undeserved']
# ['former', 'exec', 'sentenced', 'one', 'year', 'prison', 'selling', 'company', 'secrets', 'uasm']
# ['rt', 'much', 'completely', 'broken', 'shit', 'world', 'fucks', 'sake', 'fuck', 'bullshit', 'autocorrects']
# ['aapl', 'apple', 'patented', 'idea', 'steve', 'jobs', 'would', 'hated']
# ['whitepower', 'hatemusic', 'hatespeech', 'icantbreathe', 'good', 'look']
# ['use', 'congrats', 'gave', 'government', 'permission', 'spy', 'apple']
# ['hah', 'defending', 'understand', 'internet']
# ['still', 'suicide', 'note', 'template', 'recent', 'pages', 'update', 'much', 'longer', 'wait']
# ['thanks', 'making', 'life', 'complicated']
# ['offensive', 'thing', 'lack', 'trashcan', 'emoji', 'stop', 'discrimination']
# ['rt', 'offensive', 'thing', 'lack', 'trashcan', 'emoji', 'stop', 'discrimination']
# ['macbook', 'pro', 'annoying', 'asus', 'windows', 'eight', 'computer', 'freezing', 'laggy', 'etc', 'much', 'excellence']
# ['cannot', 'facetime', 'one', 'person', 'time', 'need', 'answers', 'dammit', 'oovoo', 'winning']
# ['old', 'iphone', 'exploded', 'good', 'reason', 'heck']
# ['computer', 'sucks', 'fix']
# ['videos', 'tonight', 'turns', 'ipads', 'still', 'need', 'electricity', 'function', 'figure', 'ps', 'lol', 'key', 'studies', 'one', 'hundred', 'forty', 'four']
# ['past', 'week', 'phone', 'stay', 'freezing', 'closing', 'apps', 'wtf']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['apple', 'sucks', 'protesters', 'stage', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['alienating', 'people', 'blocking', 'federal', 'interstates', 'need', 'stopped', 'endangering', 'lives']
# ['also', 'steve', 'jobs', 'overrated']
# ['wtf', 'siri', 'step', 'game']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['point', 'anger', 'simply', 'manifestation', 'stupid']
# ['hopefully', 'endangering', 'lives']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['got', 'charger', 'like', 'two', 'weeks', 'ago', 'frick']
# ['rt', 'point', 'anger', 'simply', 'manifestation', 'stupid']
# ['actions', 'helping', 'democratswarontruth']
# ['mobile', 'iphone', 'nightmare', 'iphone', 'six']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['fuck', 'n', 'weak', 'ass', 'iphone']
# ['cocky', 'ass', 'apple', 'talking', 'bout', 'da', 'fruit', 'fuck']
# ['lmfao', 'rt', 'cocky', 'ass', 'apple', 'talking', 'bout', 'da', 'fruit', 'fuck']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['fuck']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['oh', 'live', 'streaming', 'tv', 'blows']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['battery', 'die', 'quick']
# ['airplay', 'sucks', 'yosemite']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['thanks', 'four', 'almost', 'burning', 'house']
# ['seriously', 'f', 'ing', 'hate', 'new', 'version', 'itunes', 'spend', 'hours', 'trying', 'figure', 'synch', 'w', 'deleting', 'everything']
# ['heck', 'phone', 'screen', 'looks', 'like', 'lost', 'battle', 'windstorm']
# ['democrat', 'funded', 'ows', 'paid', 'protesters', 'distraction', 'democrat', 'failures', 'aca', 'amnesty', 'taxes', 'debt', 'economy']
# ['phone', 'suck', 'much']
# ['rt', 'phone', 'suck', 'much']
# ['rt', 'phone', 'suck', 'much']
# ['fix', 'addis', 'phone', 'text', 'pls', 'thanks']
# ['please', 'make', 'charger', 'actually', 'last']
# ['come', 'et', 'al', 'get', 'stb', 'together', 'bypass', 'cable', 'satellite', 'companies']
# ['ayyy', 'fourth', 'phone', 'charger', 'week', 'broke', 'today', 'fuck']
# ['deal', 'taking', 'phone', 'beating', 'shit', 'fuck', 'whatever', 'damn', 'twitter', 'fuck']
# ['iphones', 'mad', 'sensitive', 'bro', 'cold', 'dies', 'even', 'lot', 'battery', 'left', 'hot', 'shuts', 'well', 'smfh']
# ['xcode', 'aapl', 'source', 'kit', 'crash', 'swift', 'getting', 'annoying']
# ['fuck']
# ['worst', 'thing', 'ever', 'update', 'software', 'computer', 'update', 'trash']
# ['ios', 'eight', 'delete', 'contact', 'actually', 'deleted', 'fml', 'fuck']
# ['rt', 'ios', 'eight', 'delete', 'contact', 'actually', 'deleted', 'fml', 'fuck']
# ['rt', 'protesters', 'stage', 'diein', 'protests', 'store', 'nyc', 'anger', 'misplaced', 'retweet', 'agree']
# ['phone', 'died', 'five', 'feel', 'betrayed']
# ['dear', 'worst', 'idea', 'ever', 'fix']
# ['rt', 'need', 'new', 'emojis', 'preferably', 'brown', 'people', 'shxt', 'like']
# ['hey', 'hell', 'hahaha']
# ['spellcheck', 'makes', 'want', 'stab', 'somebody', 'fuckin', 'word', 'wanted', 'use']
# ['yh', 'news', 'china', 'reminds', 'apple', 'need', 'support', 'privacy', 'security', 'products', 'apple', 'access']
# ['look', 'like', 'fucking', 'twelve', 'days']
# ['quality', 'bad', 'webcam', 'pics', 'excuse']
# ['thanks', 'making', 'shittiest', 'chargers']
# ['hell', 'mean', 'one', 'day', 'skype', 'let', 'login', 'cannot', 'even', 'open', 'app']
# ['damn', 'commercials', 'getting', 'worse', 'worse']
# ['remind', 'tomorrow', 'f', 'ing', 'tell', 'updates', 'want', 'install', 'actually']
# ['congrats', 'making', 'iphone', 'recording', 'drm', 'protected', 'cannot', 'play', 'anywhere', 'want', 'fail']
# ['danger', 'ok', 'want', 'fuck']
# ['iphone', 'six', 'plus', 'impossible', 'hold', 'without', 'cover', 'slides', 'hand', 'apple', 'iphone']
# ['ios', 'eight', 'lack', 'true', 'keyboard', 'integration', 'killing', 'half', 'assed', 'implementations', 'solutions']
# ['rt', 'need', 'new', 'emojis', 'preferably', 'brown', 'people', 'shxt', 'like']
# ['best', 'apps', 'two', 'thousand', 'fourteen', 'seems', 'wrong']
# ['go', 'wit', 'waiting', 'items', 'copy', 'shit', 'itunes', 'pissing']
# ['battery', 'already', 'eighty', 'three', 'within', 'fifteen', 'minutes', 'usage', 'fix']
# ['explain']
# ['ipad', 'irig', 'price', 'connect', 'guitar', 'could', 'buy', 'real', 'amp', 'loud', 'enough', 'perform', 'ripoff']
# ['yes', 'love', 'none', 'stuff', 'works', 'thank']
# ['real', 'quick', 'shout', 'technology', 'never', 'working']
# ['attention', 'free', 'ipads', 'would', 'go', 'faster', 'emails', 'go', 'straight', 'junk', 'folders', 'sortitout']
# ['dear', 'sometimes', 'write', 'gave', 'means', 'want', 'word', 'gave', 'word', 'typo']
# ['hey', 'keyboard', 'phone', 'sorts', 'drunk', 'morning', 'send', 'help', 'pls', 'thanks']
# ['official', 'williamsburg', 'longer', 'hip', 'anymore']
# ['moment', 'typing', 'tweet', 'official', 'client', 'ipad', 'one', 'crashes']
# ['apple', 'inc', 'doomed', 'aapl', 'dropped', 'one', 'eleven', 'currently', 'priced', 'one', 'hundred', 'eleven', 'one', 'hundred', 'fifty', 'five', 'aapl']
# ['face']
# ['one', 'iphone', 'five', 'speakers', 'stopped', 'working', 'cool', 'send', 'iphone', 'six', 'forgive']
# ['four', 'inch', 'iphone', 'six', 'five', 'reasons', 'apple', 'make', 'forbes', 'aapl']
# ['suck']
# ['rt', 'suck']
# ['apple', 'hoarding', 'iphone', 'six', 'supply', 'stores', 'aapl', 'aapl']
# ['happy', 'monday', 'camera', 'fancy', 'iphone', 'six', 'plus', 'suddenly', 'stopped', 'working', 'weekend', 'instead', 'meme']
# ['aapl', 'shares', 'fall', 'despite', 'price', 'target', 'increases', 'bmo', 'capital', 'citigroup', 'apple', 'aapl', 'wallstreet', 'nasdaq']
# ['tv', 'update', 'yet']
# ['iphone', 'fucked', 'thanks', 'great', 'help', 'get', 'new', 'iphone']
# ['refuse', 'make', 'full', 'federal', 'workforce', 'diversity', 'data', 'public', 'diversity', 'tech', 'technology', 'jobs']
# ['pop', 'message', 'box', 'iphones', 'terrible']
# ['apple', 'microsoft', 'worried', 'google', 'chromebooks', 'aapl', 'aapl']
# ['aapl', 'apple', 'aapl', 'stock', 'falling', 'today', 'amid', 'ipod', 'pricing', 'lawsuit']
# ['really', 'makes', 'hard', 'spend', 'money', 'apps', 'functionality', 'might', 'soon', 'disappear', 'today', 'menu', 'please', 'stop']
# ['tried', 'turning', 'problem']
# ['rt', 'tried', 'turning', 'problem']
# ['rt', 'tried', 'turning', 'problem']
# ['whatever', 'takes', 'bring', 'stock', 'nothing', 'dumb', 'aapl']
# ['ipod', 'lawsuit', 'loses', 'last', 'plaintiff', 'judge', 'discusses', 'halt', 'amid', 'search', 'replacements', 'aapl']
# ['made', 'mistake', 'time', 'replace', 'fix', 'two', 'thousand', 'eleven', 'macbook', 'pro', 'graphics', 'failure', 'mbp', 'two', 'thousand', 'eleven']
# ['literally', 'trying', 'get', 'id', 'enabled', 'since', 'november', 'actual', 'fuck', 'difficult']
# ['aapl', 'apple', 'products', 'may', 'bah', 'humbug', 'holiday', 'survey']
# ['rt', 'tried', 'turning', 'problem']
# ['please', 'make', 'green', 'button', 'used', 'full', 'screen', 'exception', 'rule', 'whomovedmycheese']
# ['another', 'fucking', 'software', 'update', 'really']
# ['twenty', 'eight', 'mb', 'need', 'wifi', 'install']
# ['handed', 'device', 'fix', 'owner', 'fancy', 'waiting', 'nowounder']
# ['dear', 'santa', 'want', 'christmas', 'send', 'iphone', 'ordered', 'nine', 'twenty', 'nine']
# ['yes', 'rt', 'remind', 'tomorrow', 'f', 'ing', 'tell', 'updates', 'want', 'install', 'actually']
# ['please', 'go', 'way', 'gone', 'ios', 'release', 'notes', 'deserve', 'know', 'happening', 'gear']
# ['gave', 'three', 'k', 'computer', 'weeks', 'ago', 'still', 'nothing', 'awesome']
# ['happy', 'monday', 'camera', 'fancy', 'iphone', 'six', 'plus', 'suddenly', 'stopped', 'working', 'weekend', 'instead', 'meme']
# ['block', 'trade', 'detected', 'aapl']
# ['hope', 'use', 'glass', 'new', 'store', 'williamsburg', 'afraid', 'sikrikim', 'tzimerman', 'break']
# ['make', 'difficult', 'get', 'help', 'products', 'wasted', 'forty', 'five', 'minutes', 'life', 'online', 'still', 'nowhere']
# ['phone', 'went', 'seventy', 'eight', 'twenty', 'one', 'please', 'tell', 'mathematically', 'possible']
# ['average', 'mac', 'user', 'faced', 'nine', 'malware', 'threats', 'last', 'year', 'os', 'x', 'remains', 'minor', 'target', 'mac', 'blog', 'aapl']
# ['rt', 'phone', 'went', 'seventy', 'eight', 'twenty', 'one', 'please', 'tell', 'mathematically', 'possible']
# ['fuck', 'third', 'charger', 'broke', 'like', 'two', 'months', 'suck', 'know']
# ['thirteen', 'left', 'even', 'shit']
# ['rt', 'tried', 'turning', 'problem']
# ['c', 'mon', 'ready', 'buy', 'watch', 'hurry', 'applewatch']
# ['android', 'chargers', 'years', 'still', 'top', 'tier', 'please', 'keep']
# ['please', 'ban', 'school', 'yik', 'yak', 'apps', 'itunes', 'app', 'store', 'apps', 'used', 'anonymous', 'bullying', 'threats']
# ['rt', 'tried', 'turning', 'problem']
# ['thinking', 'upgrading', 'yosemite', 'think', 'twice', 'everyone', 'rt', 'asmsg']
# ['proof', 'use', 'products', 'freaking', 'mail', 'shows', 'search', 'file', 'finder', 'nut', 'kicks']
# ['really', 'search', 'tool', 'useless', 'nut', 'kicks']
# ['minute', 'ten', 'minutes']
# ['gave', 'huge', 'middle', 'finger', 'face']
# ['rt', 'thinking', 'upgrading', 'yosemite', 'think', 'twice', 'everyone', 'rt', 'asmsg']
# ['rt', 'thinking', 'upgrading', 'yosemite', 'think', 'twice', 'everyone', 'rt', 'asmsg']
# ['group', 'facetime', 'thing', 'wtf']
# ['held', 'hostage', 'replacing', 'whole', 'phone', 'last', 'backup', 'six', 'hundred', 'thirty', 'morning', 'anything', 'since', 'byebyebye']
# ['hey', 'normal', 'laptop', 'charger', 'soldering', 'skin', 'thanks', 'j']
# ['iphone', 'five', 'photos', 'longer', 'downloading', 'automatically', 'laptop', 'sync', 'support', 'unhelpful', 'ideas']

# %%
new_df['Sentiment']=new_df['Sentiment'].replace({"Positive": 0, "Negative": 1, "Neutral": 3}).astype(np.uint8)
new_df['Sentiment']=new_df['Sentiment'].replace(3,0).copy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 new_df['Sentiment']=new_df['Sentiment'].replace({"Positive": 0, "Negative": 1, "Neutral": 3}).astype(np.uint8)
#       2 new_df['Sentiment']=new_df['Sentiment'].replace(3,0).copy()
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py:4563, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    4553 @doc(NDFrame.replace, klass=_shared_doc_kwargs["klass"])
#    4554 def replace(
#    4555     self,
#    (...)
#    4561     method="pad",
#    4562 ):
# -> 4563     return super().replace(
#    4564         to_replace=to_replace,
#    4565         value=value,
#    4566         inplace=inplace,
#    4567         limit=limit,
#    4568         regex=regex,
#    4569         method=method,
#    4570     )
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py:6500, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    6497     else:
#    6498         to_replace, value = keys, values
# -> 6500     return self.replace(
#    6501         to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6502     )
#    6503 else:
#    6504
#    6505     # need a non-zero len on all axes
#    6506     if not self.size:
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py:4563, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    4553 @doc(NDFrame.replace, klass=_shared_doc_kwargs["klass"])
#    4554 def replace(
#    4555     self,
#    (...)
#    4561     method="pad",
#    4562 ):
# -> 4563     return super().replace(
#    4564         to_replace=to_replace,
#    4565         value=value,
#    4566         inplace=inplace,
#    4567         limit=limit,
#    4568         regex=regex,
#    4569         method=method,
#    4570     )
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py:6543, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    6538         raise ValueError(
#    6539             f"Replacement lists must match in length. "
#    6540             f"Expecting {len(to_replace)} got {len(value)} "
#    6541         )
#    6542     self._consolidate_inplace()
# -> 6543     new_data = self._mgr.replace_list(
#    6544         src_list=to_replace,
#    6545         dest_list=value,
#    6546         inplace=inplace,
#    6547         regex=regex,
#    6548     )
#    6550 else:  # [NA, ''] -> 0
#    6551     new_data = self._mgr.replace(
#    6552         to_replace=to_replace, value=value, inplace=inplace, regex=regex
#    6553     )
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py:642, in BlockManager.replace_list(self, src_list, dest_list, inplace, regex)
#     638 # Calculate the mask once, prior to the call of comp
#     639 # in order to avoid repeating the same computations
#     640 mask = ~isna(values)
# --> 642 masks = [comp(s, mask, regex) for s in src_list]
#     644 result_blocks = []
#     645 src_len = len(src_list) - 1
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py:642, in <listcomp>(.0)
#     638 # Calculate the mask once, prior to the call of comp
#     639 # in order to avoid repeating the same computations
#     640 mask = ~isna(values)
# --> 642 masks = [comp(s, mask, regex) for s in src_list]
#     644 result_blocks = []
#     645 src_len = len(src_list) - 1
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py:636, in BlockManager.replace_list.<locals>.comp(s, mask, regex)
#     633     return ~mask
#     635 s = com.maybe_box_datetimelike(s)
# --> 636 return _compare_or_regex_search(values, s, regex, mask)
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py:1992, in _compare_or_regex_search(a, b, regex, mask)
#    1988     a = a[mask]
#    1990 if is_datetimelike_v_numeric(a, b) or is_numeric_v_string_like(a, b):
#    1991     # GH#29553 avoid deprecation warnings from numpy
# -> 1992     _check_comparison_types(False, a, b)
#    1993     return False
#    1995 result = op(a)
#
# File /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py:1971, in _compare_or_regex_search.<locals>._check_comparison_types(result, a, b)
#    1968 if isinstance(a, np.ndarray):
#    1969     type_names[0] = f"ndarray(dtype={a.dtype})"
# -> 1971 raise TypeError(
#    1972     f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1973 )
#
# TypeError: Cannot compare types 'ndarray(dtype=uint8)' and 'str'

# %%
y = new_df['Sentiment']

# %%
new_df['Sentiment'].value_counts(normalize=True)
# Out:
# 0    0.823831
# 1    0.176169
# Name: Sentiment, dtype: float64

# %%
fig, ax = plt.subplots()

labels=['Positive/Neutral','Negative']
plt.style.use('fivethirtyeight')
df['Sentiment'].value_counts(normalize=True).plot.bar()
plt.title('Tweet Sentiment Before Additional Negative Tweets')
plt.ylabel('Sentiment')
plt.xlabel('Sentient Towards Brand')
plt.xticks(rotation=0)
ax.set_xticklabels(labels=labels)
plt.show()

# %%
fig, ax = plt.subplots()

labels=['Positive/Neutral','Negative']


plt.style.use('fivethirtyeight')
new_df['Sentiment'].value_counts(normalize=True).plot.bar()
plt.title('Tweet Sentiment After Additional Negative Tweets')
plt.ylabel('Sentiment')
plt.xlabel('Sentient Towards Brand')
plt.xticks(rotation=0)
ax.set_xticklabels(labels=labels)
plt.show()

# %%
X= pd.DataFrame(token_docs,columns=['processed_text'])
X.set_index(y.index,inplace=True)
X = X['processed_text']

# %% [markdown]
# ### Train/Test/Split

# %%
X = new_df['processed_text']
y = new_df['Sentiment']

# %%
corpus = ''.join(X_train)
corpus = [corpus]

# %%
tokenizer = lambda docs: [vectorizer.build_tokenizer()(doc) for doc in X_train]

# %%
tokenizer(corpus)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 tokenizer(corpus)
#
# Input In [72], in <lambda>(docs)
# ----> 1 tokenizer = lambda docs: [vectorizer.build_tokenizer()(doc) for doc in X_train]
#
# Input In [72], in <listcomp>(.0)
# ----> 1 tokenizer = lambda docs: [vectorizer.build_tokenizer()(doc) for doc in X_train]
#
# NameError: name 'vectorizer' is not defined

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit_transform(corpus)
# Out:
# <1x8832 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8832 stored elements in Compressed Sparse Row format>

# %%
len(X)
# Out:
# 10155

# %%
X_train, X_rem, y_train, y_rem = train_test_split(X,
                                                    y,
                                                    random_state=42,
                                                    train_size=0.80,stratify=y)

# %%
X_val, X_test, y_val, y_test = train_test_split(X_rem, y_rem,
                                          test_size=0.50, random_state=42,stratify=y_rem)

# %%
len(X_test)
# Out:
# 1016

# %%
X_val
# Out:
# 1402    Startups: Free Premium Service on your  one st...
# 4801    Umm. Hello!! What about Android?! RT  Awesome ...
# 2356     Congrats on your iPhone app being featured at...
# 1484    like that is bad RT  Sitting at a bar listenin...
# 2427    UBER BRAND SMART: Going To move a ton of iPad ...
#                               ...
# 9176        lol iPhone,weak. Get on that Lumia level bruh
# 1499    Hmm...cannot get Twitter searches to update in...
# 3291    Abba has gotten dissed at  two  #sxsw panels i...
# 9119    L.A. School District Officially Ends $ one . t...
# 2211    In #SXSW Ballroom D for  from  \none seat rese...
# Name: processed_text, Length: 1015, dtype: object

# %% [markdown]
# ### Logistic Regression Additional Tweets

# %%
Baseline_LG = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2),)),
        ('clf', LogisticRegression(class_weight='balanced',max_iter=1000))
    ]
)

# %%
Baseline_LG.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
cross_val_df.cross_val_report(Baseline_LG,'Base Log Additional Tweets',X_train,y_train)
# Out:
# [0.9262679802955665, 0.7973294997685241, 0.7871827620939905]

# %%
fn.reporting(Baseline_LG,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       836
#            1       0.79      0.77      0.78       179
#
#     accuracy                           0.92      1015
#    macro avg       0.87      0.86      0.87      1015
# weighted avg       0.92      0.92      0.92      1015

# %% [markdown]
# This is a much improved scoring, the model was able to to tremendously gain recall, but did mistake some cases.

# %% [markdown]
# ### Tuned Logistic Regression

# %%
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingGridSearchCV

# %%
LG_param_space = {'clf__class_weight': [None,'balanced'],'clf__C':[.01,.1,1,5,10,100],
                                  'tfidf__ngram_range': [(1,1), (1,2),(1,3)],
                 'tfidf__max_df':[.90,1],'tfidf__use_idf': [True,False]}

# %%
# %%time

LG_GS_Neg = GridSearchCV(estimator=Baseline_LG,param_grid=LG_param_space,cv=5,scoring=two_scorer,refit=True,error_score='raise')
                                
LG_GS_Neg.fit(X_train,y_train)
# Out:
# CPU times: user 23min 8s, sys: 5min 7s, total: 28min 16s
# Wall time: 11min 59s
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(ngram_range=(1, 2))),
#                                        ('clf',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=1000))]),
#              param_grid={'clf__C': [0.01, 0.1, 1, 5, 10, 100],
#                          'clf__class_weight': [None, 'balanced'],
#                          'tfidf__max_df': [0.9, 1],
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'tfidf__use_idf': [True, False]},
#              scoring=make_scorer(fbeta_score, beta=2))

# %%
LG_GS_Neg.best_params_
# Out:
# {'clf__C': 10,
#  'clf__class_weight': 'balanced',
#  'tfidf__max_df': 0.9,
#  'tfidf__ngram_range': (1, 1),
#  'tfidf__use_idf': False}

# %%
cross_val_df.cross_val_report(LG_GS_Neg.best_estimator_,'Grid Logistic Additional Tweets',X_train,y_train)
# Out:
# [0.9293452823039031, 0.8099022928291222, 0.79372326005874]

# %%
validation_scores.report(LG_GS_Neg.best_estimator_,'Grid Logistic Addtiional Tweets',X_val,y_val)
# Out:
# [0.9221674876847291, 0.776536312849162, 0.7808988764044944]

# %%
X_val
# Out:
# 1402    Startups: Free Premium Service on your  one st...
# 4801    Umm. Hello!! What about Android?! RT  Awesome ...
# 2356     Congrats on your iPhone app being featured at...
# 1484    like that is bad RT  Sitting at a bar listenin...
# 2427    UBER BRAND SMART: Going To move a ton of iPad ...
#                               ...
# 9176        lol iPhone,weak. Get on that Lumia level bruh
# 1499    Hmm...cannot get Twitter searches to update in...
# 3291    Abba has gotten dissed at  two  #sxsw panels i...
# 9119    L.A. School District Officially Ends $ one . t...
# 2211    In #SXSW Ballroom D for  from  \none seat rese...
# Name: processed_text, Length: 1015, dtype: object

# %%
LG_GS_Neg = pickle.load(open('final_logistic.sav', 'rb'))

# %%
tfidf = TfidfVectorizer(ngram_range=(1,1))

# %%
tfidf.fit_transform(X_val)
# Out:
# <1015x3010 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15515 stored elements in Compressed Sparse Row format>

# %%
X_val
# Out:
# 1402    Startups: Free Premium Service on your  one st...
# 4801    Umm. Hello!! What about Android?! RT  Awesome ...
# 2356     Congrats on your iPhone app being featured at...
# 1484    like that is bad RT  Sitting at a bar listenin...
# 2427    UBER BRAND SMART: Going To move a ton of iPad ...
#                               ...
# 9176        lol iPhone,weak. Get on that Lumia level bruh
# 1499    Hmm...cannot get Twitter searches to update in...
# 3291    Abba has gotten dissed at  two  #sxsw panels i...
# 9119    L.A. School District Officially Ends $ one . t...
# 2211    In #SXSW Ballroom D for  from  \none seat rese...
# Name: processed_text, Length: 1015, dtype: object

# %%
tfidf.fit_transform(X_val)
# Out:
# <1015x3010 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15515 stored elements in Compressed Sparse Row format>

# %%
tfidf.vocabulary_
# Out:
# {'startups': 2462,
#  'free': 989,
#  'premium': 1982,
#  'service': 2284,
#  'on': 1791,
#  'your': 2990,
#  'one': 1792,
#  'st': 2453,
#  'job': 1365,
#  'post': 1965,
#  'if': 1254,
#  'you': 2989,
#  'answer': 106,
#  'our': 1819,
#  'two': 2763,
#  'min': 1642,
#  'survey': 2535,
#  'sxsw': 2545,
#  'sxswi': 2548,
#  'startup': 2460,
#  'launch': 1439,
#  'umm': 2778,
#  'hello': 1177,
#  'what': 2896,
#  'about': 8,
#  'android': 95,
#  'rt': 2196,
#  'awesome': 198,
#  'new': 1725,
#  'version': 2830,
#  'of': 1775,
#  'for': 969,
#  'iphone': 1338,
#  'and': 93,
#  'web': 2877,
#  'site': 2343,
#  'coming': 489,
#  'after': 46,
#  'congrats': 516,
#  'app': 123,
#  'being': 246,
#  'featured': 906,
#  'at': 164,
#  'like': 1471,
#  'that': 2632,
#  'is': 1343,
#  'bad': 205,
#  'sitting': 2345,
#  'bar': 219,
#  'listening': 1486,
#  'to': 2684,
#  'music': 1697,
#  'three': 2664,
#  'people': 1881,
#  'who': 2903,
#  'all': 72,
#  'nose': 1752,
#  'down': 731,
#  'waitress': 2856,
#  'looks': 1520,
#  'confused': 515,
#  'uber': 2770,
#  'brand': 306,
#  'smart': 2364,
#  'going': 1081,
#  'move': 1680,
#  'ton': 2692,
#  'ipad': 1335,
#  'apple': 131,
#  'opening': 1799,
#  'popup': 1954,
#  'shop': 2314,
#  'in': 1273,
#  'austin': 185,
#  'via': 2836,
#  'google': 1087,
#  'will': 2914,
#  'eat': 773,
#  'itself': 1352,
#  'rhizome': 2173,
#  'sxswk': 2549,
#  'hilton': 1189,
#  'great': 1108,
#  'longform': 1515,
#  'panel': 1846,
#  'much': 1691,
#  'content': 531,
#  'geared': 1047,
#  'toward': 2707,
#  'workplace': 2944,
#  'reading': 2089,
#  'kindle': 1408,
#  'changed': 401,
#  'bout': 297,
#  'time': 2674,
#  'ubersocial': 2772,
#  'now': 1764,
#  'the': 2633,
#  'store': 2485,
#  'includes': 1277,
#  'uberguide': 2771,
#  'sponsored': 2442,
#  'cont': 529,
#  'waiting': 2855,
#  'session': 2286,
#  'start': 2456,
#  'touching': 2704,
#  'stories': 2487,
#  'designing': 650,
#  'digital': 680,
#  'magazines': 1554,
#  'from': 1000,
#  'audience': 181,
#  'asks': 158,
#  'her': 1180,
#  'favorite': 899,
#  'non': 1750,
#  'product': 2005,
#  'why': 2906,
#  'she': 2305,
#  'says': 2233,
#  'really': 2094,
#  'love': 1533,
#  'my': 1700,
#  'swiss': 2542,
#  'omega': 1788,
#  'watch': 2868,
#  'it': 1349,
#  'amazes': 83,
#  'me': 1598,
#  'how': 1229,
#  'many': 1567,
#  'do': 709,
#  'not': 1753,
#  'tuck': 2741,
#  'flap': 949,
#  'their': 2637,
#  'case': 380,
#  'cnn': 469,
#  'tv': 2751,
#  'everywhere': 839,
#  'mobile': 1658,
#  'computers': 507,
#  'contest': 532,
#  'full': 1015,
#  'swing': 2541,
#  'seeing': 2263,
#  'so': 2386,
#  'actsofsharing': 29,
#  'com': 485,
#  'still': 2475,
#  'plenty': 1937,
#  'join': 1369,
#  'fun': 1017,
#  'are': 142,
#  'racing': 2063,
#  'around': 147,
#  'best': 251,
#  'be': 233,
#  'fueling': 1014,
#  'up': 2795,
#  'with': 2926,
#  'local': 1497,
#  'fare': 891,
#  'eatshopaustinapp': 774,
#  'an': 89,
#  'interview': 1322,
#  'artists': 153,
#  'behind': 245,
#  'ogilvynotes': 1783,
#  'ogilvy': 1782,
#  'sydney': 2556,
#  'podcast': 1944,
#  'ep': 811,
#  'four': 982,
#  'ausxsw': 188,
#  'read': 2087,
#  'eight': 778,
#  'er': 814,
#  'marissa': 1575,
#  'mayer': 1594,
#  'connect': 518,
#  'physical': 1902,
#  'worlds': 2948,
#  'through': 2666,
#  'get': 1059,
#  'shit': 2311,
#  'together': 2687,
#  'or': 1808,
#  'guy': 1129,
#  'samsung': 2216,
#  'galaxy': 1032,
#  'five': 944,
#  'surprising': 2534,
#  'most': 1679,
#  'popular': 1953,
#  'accessory': 16,
#  'seems': 2265,
#  'closely': 461,
#  'followed': 962,
#  'by': 348,
#  'bbq': 231,
#  'pork': 1956,
#  'waffle': 2852,
#  'cone': 511,
#  'checking': 419,
#  'out': 1820,
#  'design': 647,
#  'headaches': 1167,
#  'author': 189,
#  'josh': 1372,
#  'clark': 447,
#  'tapworthy': 2584,
#  'video': 2838,
#  'cast': 385,
#  'characters': 404,
#  'standing': 2454,
#  'line': 1475,
#  'during': 757,
#  'buying': 346,
#  'official': 1780,
#  'ios': 1333,
#  'meetup': 1611,
#  'almost': 75,
#  'employers': 795,
#  'looking': 1519,
#  'developers': 661,
#  'traveling': 2726,
#  'ten': 2615,
#  'thousand': 2662,
#  'eleven': 783,
#  'good': 1084,
#  'morning': 1676,
#  'am': 82,
#  'corner': 550,
#  'starbucks': 2455,
#  'smearing': 2372,
#  'banana': 213,
#  'over': 1823,
#  'retarded': 2163,
#  'ape': 120,
#  'was': 2865,
#  'evening': 828,
#  'rumor': 2200,
#  'monger': 1668,
#  'but': 341,
#  'this': 2655,
#  'circles': 437,
#  'preview': 1989,
#  'socbiz': 2388,
#  'fb': 901,
#  'hate': 1159,
#  'aapl': 3,
#  'we': 2873,
#  'have': 1162,
#  'problems_time': 2002,
#  'stop': 2480,
#  'edchat': 776,
#  'musedchat': 1695,
#  'classical': 448,
#  'newtwitter': 1730,
#  'example': 843,
#  'microformat': 1630,
#  'recipe': 2106,
#  'finder': 936,
#  'some': 2401,
#  'weeks': 2887,
#  'ago': 53,
#  'adapting': 33,
#  'microformats': 1631,
#  'open': 1797,
#  'source': 2418,
#  'geo': 1055,
#  'hashing': 1158,
#  'soon': 2411,
#  'used': 2809,
#  'called': 357,
#  'finally': 934,
#  'forced': 971,
#  'cannot': 368,
#  'tweet': 2753,
#  'better': 253,
#  'contextclues': 534,
#  'jeopardy': 1364,
#  'everyone': 837,
#  'here': 1181,
#  'map': 1568,
#  'places': 1920,
#  'ha': 1132,
#  'feel': 910,
#  'only': 1794,
#  'person': 1890,
#  'mac': 1546,
#  'ipod': 1340,
#  'replaced': 2140,
#  'never': 1724,
#  'set': 2288,
#  'foot': 967,
#  'again': 47,
#  'world': 2947,
#  'place': 1919,
#  'enjoying': 807,
#  'changes': 402,
#  'gowalla': 1101,
#  'zero': 3004,
#  'forward': 980,
#  'else': 784,
#  'they': 2645,
#  'foursquare': 983,
#  'sleeves': 2356,
#  'anybody': 113,
#  'know': 1416,
#  'whether': 2899,
#  'can': 365,
#  'nab': 1701,
#  'white': 2902,
#  'sixty': 2347,
#  'gb': 1042,
#  'popupstore': 1955,
#  'mistakes': 1653,
#  'made': 1551,
#  'building': 330,
#  'netflix': 1719,
#  'netflixiphone': 1720,
#  'harry': 1156,
#  'potter': 1969,
#  'emojis': 792,
#  'please': 1936,
#  'work': 2940,
#  'major': 1557,
#  'social': 2389,
#  'network': 1721,
#  'possibly': 1964,
#  'today': 2686,
#  'bing': 266,
#  'pagerank': 1842,
#  'hope': 1215,
#  'there': 2643,
#  'smack': 2360,
#  'salon': 2213,
#  'forty': 979,
#  'others': 1817,
#  'novelty': 1762,
#  'news': 1727,
#  'apps': 138,
#  'fades': 876,
#  'fast': 894,
#  'among': 87,
#  'delegates': 629,
#  'schools': 2239,
#  'marketing': 1579,
#  'experts': 863,
#  'temp': 2611,
#  'cc': 391,
#  'speech': 2435,
#  'therapy': 2642,
#  'communication': 495,
#  'showcased': 2321,
#  'hacker': 1135,
#  'party': 1857,
#  'times': 2675,
#  'cle': 450,
#  'startupbus': 2461,
#  'wjchat': 2928,
#  'seven': 2291,
#  'bought': 296,
#  'zagg': 2997,
#  'keyboard': 1396,
#  'high': 1186,
#  'hopes': 1217,
#  'plan': 1922,
#  'geek': 1049,
#  'influence': 1288,
#  'hit': 1198,
#  'highs': 1188,
#  'yesterday': 2983,
#  'when': 2897,
#  'opened': 1798,
#  'pop': 1950,
#  'sale': 2211,
#  'register': 2122,
#  'exclusive': 851,
#  'passes': 1859,
#  'events': 831,
#  'parties': 1856,
#  'give': 1067,
#  'liberty': 1465,
#  'sxswpass': 2553,
#  'south': 2419,
#  'southwest': 2420,
#  'selling': 2271,
#  'california': 355,
#  'cult': 584,
#  'followings': 963,
#  'dataviz': 613,
#  'translates': 2722,
#  'satanic': 2222,
#  'just': 1385,
#  'sayin': 2231,
#  'essdub': 819,
#  'bored': 292,
#  'keynote': 1397,
#  'use': 2808,
#  'draw': 738,
#  'picture': 1909,
#  'even': 827,
#  'artist': 152,
#  'totally': 2702,
#  'overshadowing': 1828,
#  'wins': 2920,
#  'arrives': 148,
#  'tomorrow': 2691,
#  'smd': 2371,
#  'us': 2803,
#  'weak': 2874,
#  'as': 154,
#  'phone': 1897,
#  'wow': 2953,
#  'downtown': 737,
#  'projecting': 2013,
#  'million': 1641,
#  'profits': 2009,
#  'weekend': 2886,
#  'alone': 76,
#  'may': 1592,
#  'stay': 2467,
#  'past': 1860,
#  'photo': 1900,
#  'spending': 2437,
#  'sat': 2221,
#  'night': 1741,
#  'chatting': 415,
#  'husband': 1240,
#  'skype': 2353,
#  'coffee': 479,
#  'has': 1157,
#  'taken': 2573,
#  'storm': 2488,
#  'excited': 849,
#  'part': 1854,
#  'no': 1748,
#  'imminent': 1262,
#  'apparently': 125,
#  'probably': 2000,
#  'want': 2860,
#  'micro': 1629,
#  'usb': 2807,
#  'charger': 407,
#  'starting': 2458,
#  'pay': 1867,
#  'days': 617,
#  'snapgoods': 2383,
#  'should': 2317,
#  'save': 2225,
#  'back': 202,
#  'lugging': 1541,
#  'laptop': 1429,
#  'sxswmymistake': 2550,
#  'interrupt': 1321,
#  'regularly': 2124,
#  'scheduled': 2236,
#  'programming': 2010,
#  'big': 260,
#  'hey': 1182,
#  'ask': 156,
#  'dennis': 642,
#  'checkins': 420,
#  'year': 2977,
#  'attendance': 172,
#  'exceeds': 846,
#  'last': 1431,
#  'thirteen': 2653,
#  'flooded': 951,
#  'emanon': 788,
#  'records': 2112,
#  'average': 192,
#  'price': 1990,
#  'resurgence': 2161,
#  'convention': 538,
#  'center': 393,
#  'fam': 882,
#  'showing': 2326,
#  'game': 1033,
#  'more': 1675,
#  'than': 2629,
#  'few': 918,
#  'pats': 1864,
#  'talking': 2580,
#  'julia': 1381,
#  'sweeney': 2538,
#  'learn': 1449,
#  'lining': 1478,
#  'long': 1512,
#  'cloud': 463,
#  'keep': 1390,
#  'personal': 1891,
#  'stuff': 2506,
#  'corp': 551,
#  'way': 2871,
#  'take': 2571,
#  'care': 374,
#  'asset': 161,
#  'radio': 2065,
#  'bands': 215,
#  'show': 2319,
#  'listen': 1484,
#  'nowplaying': 1767,
#  'newmusic': 1726,
#  'pls': 1938,
#  'own': 1831,
#  'buttons': 343,
#  'hack': 1133,
#  'direct': 682,
#  'interaction': 1313,
#  'medium': 1606,
#  'privacy': 1995,
#  'sales': 2212,
#  'genius': 1054,
#  'route': 2192,
#  'traffic': 2717,
#  'saving': 2228,
#  'maps': 1572,
#  'users': 2813,
#  'years': 2978,
#  'everyday': 836,
#  'things': 2648,
#  'crazy': 568,
#  'bit': 267,
#  'future': 1022,
#  'mapped': 1569,
#  'kia': 1398,
#  'recalls': 2099,
#  'seventy': 2292,
#  'optimas': 1805,
#  'top': 2698,
#  'advertising': 41,
#  'updated': 2797,
#  'hbs': 1164,
#  'startuptribe': 2463,
#  'meets': 1610,
#  'twelve': 2758,
#  'pm': 1942,
#  'info': 1289,
#  'drinks': 741,
#  'students': 2503,
#  'check': 417,
#  'merge': 1623,
#  'multiple': 1693,
#  'id': 1248,
#  'fail': 878,
#  'cool': 544,
#  'coolest': 546,
#  'ever': 833,
#  'etch': 824,
#  'sketch': 2348,
#  'attn': 177,
#  'temporary': 2613,
#  'fear': 904,
#  'ers': 817,
#  'confirmed': 514,
#  'week': 2885,
#  'wut': 2964,
#  'money': 1667,
#  'kthx': 1420,
#  'goers': 1079,
#  'droppin': 748,
#  'survival': 2536,
#  'tips': 2677,
#  'help': 1178,
#  'rock': 2189,
#  'hangover': 1147,
#  'cure': 588,
#  'tamale': 2582,
#  'house': 1228,
#  'would': 2952,
#  'think': 2650,
#  'watching': 2869,
#  'event': 829,
#  'without': 2927,
#  'twitter': 2762,
#  'anymore': 114,
#  'futurecast': 1023,
#  'longest': 1514,
#  'course': 560,
#  'improve': 1269,
#  'website': 2880,
#  'rankings': 2078,
#  'advice': 42,
#  'interesting': 1317,
#  'talk': 2578,
#  'fonts': 965,
#  'huge': 1234,
#  'location': 1500,
#  'dominance': 719,
#  'pumped': 2032,
#  'hear': 1171,
#  'dudes': 754,
#  'logos': 1508,
#  'make': 1559,
#  'gsdm': 1117,
#  'black': 273,
#  'tech': 2597,
#  'technology': 2604,
#  'aos': 119,
#  'giveaway': 1068,
#  'picking': 1906,
#  'steam': 2470,
#  'mashable': 1582,
#  'mashbash': 1583,
#  'steve': 2474,
#  'jobs': 1366,
#  'does': 713,
#  'position': 1960,
#  'device': 664,
#  'china': 426,
#  'where': 2898,
#  'suicide': 2518,
#  'rates': 2082,
#  'he': 1165,
#  'sells': 2272,
#  'dreams': 739,
#  'kawasaki': 1389,
#  'thisisdare': 2656,
#  'blogger': 280,
#  'blogging': 281,
#  'wish': 2923,
#  'meeting': 1609,
#  'teamandroid': 2594,
#  'rest': 2156,
#  'community': 496,
#  'next': 1731,
#  'siri': 2342,
#  'bull': 333,
#  'telling': 2609,
#  'rain': 2070,
#  'da': 599,
#  'fuck': 1009,
#  'went': 2892,
#  'twenty': 2759,
#  'tell': 2608,
#  'mathematically': 1587,
#  'possible': 1963,
#  'got': 1096,
#  'courtesy': 561,
#  'random': 2074,
#  'stranger': 2491,
#  'street': 2496,
#  'investor': 1332,
#  'thank': 2630,
#  'utter': 2818,
#  'name': 1704,
#  'built': 332,
#  'getting': 1062,
#  'trying': 2737,
#  'them': 2638,
#  'frm': 999,
#  'finding': 937,
#  'car': 371,
#  'cunning': 585,
#  'keeping': 1391,
#  'late': 1433,
#  'impulsive': 1271,
#  'lat_': 1432,
#  'come': 486,
#  'tonight': 2693,
#  'food': 966,
#  'art': 150,
#  'ice': 1246,
#  'cream': 569,
#  'nifty': 1738,
#  'interactive': 1315,
#  'lego': 1458,
#  'teamed': 2595,
#  'showdown': 2324,
#  'fourteen': 984,
#  'teams': 2596,
#  'making': 1561,
#  'bots': 295,
#  'mindstorm': 1644,
#  'nite': 1747,
#  'fight': 923,
#  'true': 2734,
#  'tablet': 2564,
#  'evidence': 840,
#  'might': 1635,
#  'well': 2891,
#  'call': 356,
#  'country': 558,
#  'united': 2786,
#  'states': 2465,
#  'sxswsa': 2554,
#  'saves': 2227,
#  'despite': 653,
#  'having': 1163,
#  'other': 1816,
#  'texas': 2624,
#  'locations': 1501,
#  'austinwins': 187,
#  'doing': 714,
#  'both': 294,
#  'least': 1452,
#  'pity': 1918,
#  'busy': 340,
#  'suppose': 2527,
#  'portal': 1958,
#  'update': 2796,
#  'hootsuite': 1213,
#  'updates': 2798,
#  'blackberry': 274,
#  'win': 2916,
#  'traded': 2714,
#  'xoom': 2969,
#  'won': 2933,
#  'js': 1377,
#  'winwin': 2922,
#  'winning': 2919,
#  'tigerblood': 2670,
#  'fill': 928,
#  'void': 2848,
#  'information': 1290,
#  'hotpot': 1224,
#  'biz': 270,
#  'claim': 444,
#  'provide': 2025,
#  'photos': 1901,
#  'feature': 905,
#  'gives': 1069,
#  'alternate': 80,
#  'routes': 2193,
#  'avoid': 193,
#  'collectively': 484,
#  'drivers': 746,
#  'yrs': 2994,
#  'day': 616,
#  'speechtherapy': 2436,
#  'conference': 512,
#  'iear': 1253,
#  'asd': 155,
#  'per': 1886,
#  'its': 1351,
#  'strategy': 2492,
#  'eighty': 780,
#  'themed': 2639,
#  'costume': 554,
#  'yep': 2981,
#  'uh': 2775,
#  'oh': 1784,
#  'left': 1455,
#  'cab': 350,
#  'internet': 1320,
#  'while': 2901,
#  'maybe': 1593,
#  'little': 1488,
#  'too': 2694,
#  'bear': 234,
#  'creatures': 572,
#  'vs': 2851,
#  'evo': 842,
#  'priorities': 1993,
#  'pubcamp': 2030,
#  'kirkus': 1410,
#  'download': 732,
#  'qrank': 2046,
#  'before': 243,
#  'prizes': 1998,
#  'actually': 30,
#  'hipster': 1192,
#  're': 2085,
#  'co': 472,
#  'online': 1793,
#  'picked': 1905,
#  'fifteen': 921,
#  'minute': 1647,
#  'wait': 2853,
#  'lounge': 1531,
#  'daily': 601,
#  'recharge': 2104,
#  'refresh': 2117,
#  'details': 656,
#  'hookers': 1212,
#  'accept': 12,
#  'products': 2007,
#  'coochie': 543,
#  'caused': 389,
#  'pain': 1844,
#  'said': 2210,
#  'peeps': 1876,
#  'taking': 2575,
#  'pictures': 1910,
#  'ridculous': 2175,
#  'counting': 557,
#  'plus': 1941,
#  'strong': 2500,
#  'canadian': 367,
#  'dollar': 716,
#  'means': 1601,
#  'stock': 2477,
#  'gear': 1046,
#  'smileyparty': 2375,
#  'sn': 2378,
#  'heat': 1174,
#  'sq': 2449,
#  'ins': 1300,
#  'see': 2262,
#  'hot': 1223,
#  'spots': 2445,
#  'wp': 2955,
#  'wedig': 2884,
#  'were': 2893,
#  'able': 7,
#  'afford': 45,
#  'attend': 171,
#  'buy': 344,
#  'consider': 522,
#  'japan': 1357,
#  'earthquake': 767,
#  'relief': 2131,
#  'chance': 398,
#  'thinking': 2651,
#  'upgrading': 2799,
#  'yosemite': 2988,
#  'twice': 2760,
#  'asmsg': 159,
#  'nick': 1736,
#  'eventseekr': 832,
#  'packing': 1838,
#  'literally': 1487,
#  'tshirts': 2739,
#  'sun': 2521,
#  'conversing': 541,
#  'dorks': 724,
#  'aol': 118,
#  'play': 1929,
#  'quadroid': 2048,
#  'qualcomm': 2050,
#  'platform': 1927,
#  'decade': 623,
#  'wintel': 2921,
#  'missed': 1651,
#  'touchingstories': 2705,
#  'catch': 388,
#  'song': 2407,
#  'sampler': 2215,
#  'available': 191,
#  'itunes': 1353,
#  'playing': 1932,
#  'core': 549,
#  'action': 26,
#  'geeks': 1051,
#  'need': 1716,
#  'phones': 1899,
#  'earth': 765,
#  'empowering': 796,
#  'against': 48,
#  'middle': 1633,
#  'east': 770,
#  'dictators': 670,
#  'bummed': 335,
#  'miss': 1650,
#  'quarantined': 2054,
#  'same': 2214,
#  'kiddie': 1400,
#  'cold': 480,
#  'garageband': 1036,
#  'comfort': 488,
#  'navigation': 1710,
#  'view': 2841,
#  'buildings': 331,
#  'marissagoogle': 1576,
#  'agree': 54,
#  'robust': 2188,
#  'chocolate': 429,
#  'fire': 940,
#  'guard': 1119,
#  'anyone': 115,
#  'any': 112,
#  'idea': 1249,
#  'till': 2672,
#  'suck': 2512,
#  'loading': 1496,
#  'prep': 1984,
#  'curious': 590,
#  'rises': 2182,
#  'shut': 2327,
#  'hell': 1176,
#  'message': 1624,
#  'missing': 1652,
#  'face': 870,
#  'leave': 1453,
#  'voicemail': 2847,
#  'extra': 868,
#  'special': 2431,
#  'revamped': 2167,
#  'fully': 1016,
#  'automated': 190,
#  'merchant': 1622,
#  'denniscrowley': 643,
#  'offered': 1777,
#  'promo': 2014,
#  'ninjafinder': 1746,
#  'fans': 887,
#  'sucks': 2514,
#  'could': 556,
#  'fine': 938,
#  'knowing': 1417,
#  'friends': 998,
#  'gen': 1052,
#  'thirty': 2654,
#  'th': 2628,
#  'downloading': 735,
#  'torrent': 2701,
#  'legal': 1457,
#  'usage': 2805,
#  'exceeded': 845,
#  'desktop': 651,
#  'xmas': 2968,
#  'first': 942,
#  'technews': 2602,
#  'headline': 1169,
#  'tech_news': 2598,
#  'aclu': 23,
#  'google_circles': 1088,
#  'social_network': 2390,
#  'focus': 956,
#  'based': 223,
#  'services': 2285,
#  'demoed': 639,
#  'vector': 2825,
#  'augmented': 183,
#  'reality': 2092,
#  'webvisions': 2882,
#  'packed': 1837,
#  'devices': 665,
#  'alarm': 66,
#  'ya': 2971,
#  'll': 1494,
#  'psyched': 2029,
#  'meet': 1608,
#  'guys': 1130,
#  'chilling': 425,
#  'hair': 1140,
#  'station': 2466,
#  'maggie': 1555,
#  'mays': 1595,
#  'melissa': 1615,
#  'uosxsw': 2794,
#  'chances': 399,
#  'unless': 2787,
#  'already': 77,
#  'possibility': 1962,
#  'goog': 1086,
#  'thanks': 2631,
#  'sprout': 2448,
#  'cashmere': 383,
#  'thinks': 2652,
#  'step': 2471,
#  'pr': 1972,
#  'team': 2593,
#  'parachute': 1850,
#  'into': 1327,
#  'mad': 1550,
#  'dying': 760,
#  'reason': 2096,
#  'technical': 2603,
#  'comments': 492,
#  'de': 618,
#  'gadgets': 1030,
#  'chunky': 435,
#  'elements': 782,
#  'generous': 1053,
#  'space': 2421,
#  'clarity': 446,
#  'trumps': 2735,
#  'density': 644,
#  'tap': 2583,
#  'quality': 2051,
#  'quantity': 2052,
#  'funny': 1020,
#  'moment': 1664,
#  'crowley': 579,
#  'gets': 1061,
#  'owners': 1833,
#  'hold': 1205,
#  'looked': 1518,
#  'lighters': 1469,
#  'concert': 509,
#  'lousy': 1532,
#  'solutions': 2399,
#  'which': 2900,
#  'because': 238,
#  'human': 1236,
#  'solution': 2398,
#  'heads': 1170,
#  'sets': 2289,
#  'codes': 478,
#  'valid': 2821,
#  'fifty': 922,
#  'nine': 1743,
#  'infektd': 1287,
#  'zlf': 3005,
#  ...}

# %%
X_val
# Out:
# 1402    Startups: Free Premium Service on your  one st...
# 4801    Umm. Hello!! What about Android?! RT  Awesome ...
# 2356     Congrats on your iPhone app being featured at...
# 1484    like that is bad RT  Sitting at a bar listenin...
# 2427    UBER BRAND SMART: Going To move a ton of iPad ...
#                               ...
# 9176        lol iPhone,weak. Get on that Lumia level bruh
# 1499    Hmm...cannot get Twitter searches to update in...
# 3291    Abba has gotten dissed at  two  #sxsw panels i...
# 9119    L.A. School District Officially Ends $ one . t...
# 2211    In #SXSW Ballroom D for  from  \none seat rese...
# Name: processed_text, Length: 1015, dtype: object

# %%
LG_GS_Neg.best_params_
# Out:
# {'clf__C': 10,
#  'clf__class_weight': 'balanced',
#  'tfidf__max_df': 0.9,
#  'tfidf__ngram_range': (1, 1),
#  'tfidf__use_idf': False}

# %%
y_val
# Out:
# 1402    0
# 4801    0
# 2356    0
# 1484    0
# 2427    0
#        ..
# 9176    1
# 1499    1
# 3291    0
# 9119    1
# 2211    0
# Name: Sentiment, Length: 1015, dtype: uint8

# %%
corpus = X_val

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2),lowercase=True)

# %%
TfidfVectorizer.fit_transform(X_val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 TfidfVectorizer.fit_transform(X_val)
#
# TypeError: fit_transform() missing 1 required positional argument: 'raw_documents'

# %%
tokenizer = lambda docs: [vectorizer.build_tokenizer()(doc) for doc in docs]

tokenizer(corpus)
# Out:
# [['rt',
#   'rt',
#   'wonder',
#   'street',
#   'closure',
#   'sxsw',
#   'make',
#   'google',
#   'map',
#   'show',
#   'linkone',
#   'panel',
#   'moderator',
#   'europe',
#   'say',
#   'spent',
#   'three',
#   'thousand',
#   'roam',
#   'charge',
#   'iphone',
#   'sxsw',
#   'two',
#   'thousand',
#   'tenbet',
#   'long',
#   'ipad',
#   'line',
#   'go',
#   'austinready',
#   'iphone',
#   'apps',
#   'two',
#   'make',
#   'blogging',
#   'easy',
#   'linkreally',
#   'google',
#   'circle',
#   'rt',
#   'launch',
#   'product',
#   'plenty',
#   'elsert',
#   'pop',
#   'store',
#   'selling',
#   'link',
#   'viaapple',
#   'open',
#   'pop',
#   'shop',
#   'austin',
#   'ipad',
#   'two',
#   'release',
#   'linkfun',
#   'watch',
#   'rt',
#   'apple',
#   'open',
#   'pop',
#   'store',
#   'austin',
#   'sxsw',
#   'linkgo',
#   'apple',
#   'pop',
#   'shop',
#   'congress',
#   'avenue',
#   'fridaygoogle',
#   'hand',
#   'free',
#   'pi',
#   'pi',
#   'dayget',
#   'ipad',
#   'two',
#   'give',
#   'red',
#   'cross',
#   'japan',
#   'first',
#   'dayseventy',
#   'mobile',
#   'hit',
#   'texas',
#   'tribune',
#   'come',
#   'apple',
#   'device',
#   'cor',
#   'via',
#   'niran',
#   'babalolalove',
#   'morphie',
#   'juicepack',
#   'today',
#   'recharge',
#   'iphone',
#   'worthdaily',
#   'chord',
#   'tuesday',
#   'march',
#   'eight',
#   'hacker',
#   'discover',
#   'google',
#   'music',
#   'servicestory',
#   'rollin',
#   'linkapple',
#   'sell',
#   'new',
#   'terp',
#   'two',
#   'album',
#   'rt',
#   'two',
#   'hundred',
#   'line',
#   'apple',
#   'pop',
#   'storert',
#   'march',
#   'eleven',
#   'austin',
#   'tx',
#   'people',
#   'line',
#   'registration',
#   'apple',
#   'storetrend',
#   'today',
#   'fun',
#   'nerdy',
#   'nerdeven',
#   'begin',
#   'win',
#   'past',
#   'week',
#   'major',
#   'dilemma',
#   'linkrt',
#   'much',
#   'fun',
#   'hand',
#   'chance',
#   'win',
#   'two',
#   'audi',
#   'car',
#   'apple',
#   'store',
#   'sxsw',
#   'linkindustry',
#   'party',
#   'grand',
#   'affairiphone',
#   'clearly',
#   'positively',
#   'happilyfalse',
#   'alarm',
#   'could',
#   'google',
#   'blush',
#   'rt',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'call',
#   'circle',
#   'linkrt',
#   'tweet',
#   'register',
#   'exclusive',
#   'pass',
#   'event',
#   'party',
#   'ipad',
#   'two',
#   'give',
#   'liberty',
#   'free',
#   'please',
#   'rtpick',
#   'carry',
#   'soho',
#   'trip',
#   'tomorrow',
#   'huge',
#   'lineapple',
#   'open',
#   'pop',
#   'store',
#   'downtown',
#   'austin',
#   'ipad',
#   'two',
#   'launch',
#   'linksocial',
#   'marketing',
#   'expert',
#   'everyone',
#   'face',
#   'facts',
#   'admit',
#   'apple',
#   'show',
#   'everyone',
#   'marketing',
#   'docheck',
#   'design',
#   'ipad',
#   'interface',
#   'new',
#   'navigation',
#   'schema',
#   'sxsw',
#   'linklove',
#   'app',
#   'update',
#   'iphone',
#   'sure',
#   'download',
#   'familiarize',
#   'wevidence',
#   'nfc',
#   'iphone',
#   'five',
#   'via',
#   'link',
#   'ccscore',
#   'free',
#   'go',
#   'tshirt',
#   'outside',
#   'sxsw',
#   'apple',
#   'store',
#   'today',
#   'two',
#   'fifteen',
#   'pm',
#   'check',
#   'go',
#   'app',
#   'ipad',
#   'two',
#   'linkbeta',
#   'test',
#   'interactive',
#   'book',
#   'ipad',
#   'app',
#   'moonbot',
#   'studio',
#   'louisiana',
#   'cool',
#   'appbuy',
#   'two',
#   'new',
#   'ipadrt',
#   'surprise',
#   'customer',
#   'wait',
#   'line',
#   'apple',
#   'store',
#   'austin',
#   'two',
#   'awesomert',
#   'talk',
#   'demo',
#   'ing',
#   'google',
#   'place',
#   'hotpot',
#   'integrate',
#   'rating',
#   'recommendation',
#   'system',
#   'android',
#   'iphone',
#   'cool',
#   'stuffhmm',
#   'nine',
#   'right',
#   'brain',
#   'leave',
#   'brain',
#   'rt',
#   'nine',
#   'ten',
#   'attendee',
#   'mac',
#   'ipadrumor',
#   'mill',
#   'ipad',
#   'three',
#   'six',
#   'fifteen',
#   'camera',
#   'slightly',
#   'thinner',
#   'rare',
#   'earths',
#   'case',
#   'different',
#   'still',
#   'smudgy',
#   'screentechnologist',
#   'think',
#   'search',
#   'history',
#   'see',
#   'one',
#   'hundred',
#   'twenty',
#   'five',
#   'person',
#   'line',
#   'get',
#   'google',
#   'bing',
#   'speak',
#   'rankcircle',
#   'circus',
#   'rt',
#   'google',
#   'circletweet',
#   'android',
#   'user',
#   'attendong',
#   'sxsw',
#   'please',
#   'report',
#   'scene',
#   'bannka',
#   'app',
#   'linkiphone',
#   'use',
#   'free',
#   'ispyart',
#   'app',
#   'send',
#   'photo',
#   'linkventurebeat',
#   'rt',
#   'second',
#   'day',
#   'business',
#   'apple',
#   'pop',
#   'store',
#   'appear',
#   'trend',
#   'linkpop',
#   'store',
#   'pure',
#   'genius',
#   'international',
#   'crowd',
#   'stock',
#   'go',
#   'homepat',
#   'know',
#   'talk',
#   'please',
#   'google',
#   'julia',
#   'sweeney',
#   'learnipad',
#   'find',
#   'friend',
#   'jeff',
#   'thanks',
#   'everyone',
#   'help',
#   'especiallythird',
#   'era',
#   'google',
#   'logo',
#   'interactive',
#   'play',
#   'space',
#   'get',
#   'readytried',
#   'initiate',
#   'carpooling',
#   'ridonkulous',
#   'taxi',
#   'line',
#   'geek',
#   'silent',
#   'bet',
#   'everyone',
#   'would',
#   'iphone',
#   'applustre',
#   'pearl',
#   'get',
#   'ready',
#   'presentation',
#   'team',
#   'android',
#   'awardb',
#   'social',
#   'rt',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'call',
#   'circle',
#   'possibly',
#   'today',
#   'linkwant',
#   'undivided',
#   'attention',
#   'please',
#   'take',
#   'mobile',
#   'phone',
#   'ipad',
#   'twort',
#   'hi',
#   'accidentally',
#   'take',
#   'ipad',
#   'set',
#   'would',
#   'please',
#   'return',
#   'linkrt',
#   'apple',
#   'align',
#   'big',
#   'tech',
#   'event',
#   'day',
#   'first',
#   'ce',
#   'gdc',
#   'popup',
#   'shop',
#   'ipad',
#   'two',
#   'linkpick',
#   'white',
#   'ipad',
#   'two',
#   'pop',
#   'apple',
#   'storert',
#   'hotpot',
#   'nextdesign',
#   'decision',
#   'make',
#   'base',
#   'google',
#   'analytics',
#   'cricket',
#   'go',
#   'use',
#   'metric',
#   'actionableapple',
#   'hp',
#   'popups',
#   'gee',
#   'wonder',
#   'get',
#   'traffic',
#   'linkgoogle',
#   'arwords',
#   'arsense',
#   'anyonehaha',
#   'yeah',
#   'call',
#   'google',
#   'circle',
#   'learn',
#   'tonightapple',
#   'set',
#   'open',
#   'popup',
#   'shop',
#   'core',
#   'action',
#   'link',
#   'geek',
#   'need',
#   'lovelove',
#   'get',
#   'one',
#   'pop',
#   'apple',
#   'store',
#   'attendeesee',
#   'indie',
#   'game',
#   'development',
#   'iphone',
#   'go',
#   'cceven',
#   'begin',
#   'apple',
#   'win',
#   'linkthink',
#   'may',
#   'go',
#   'ipad',
#   'laptop',
#   'today',
#   'veteran',
#   'reasoneven',
#   'begin',
#   'apple',
#   'win',
#   'linkrt',
#   'informal',
#   'unscientific',
#   'observation',
#   'far',
#   'computer',
#   'choice',
#   'hand',
#   'linkrt',
#   'confession',
#   'use',
#   'laptop',
#   'ipad',
#   'blackberry',
#   'follow',
#   'afar',
#   'see',
#   'rockrt',
#   'give',
#   'add',
#   'value',
#   'location',
#   'base',
#   'service',
#   'needs',
#   'battle',
#   'check',
#   'fatigueever',
#   'doubt',
#   'influence',
#   'apple',
#   'innovation',
#   'community',
#   'look',
#   'ipads',
#   'iphone',
#   'four',
#   'everywheresxsw',
#   'lady',
#   'ipad',
#   'bot',
#   'twitter',
#   'creator',
#   'persistent',
#   'guy',
#   'chase',
#   'last',
#   'nightattend',
#   'sxsw',
#   'report',
#   'see',
#   'android',
#   'phone',
#   'get',
#   'bannka',
#   'appexcite',
#   'tell',
#   'wonder',
#   'android',
#   'today',
#   'see',
#   'soonguy',
#   'kawasaki',
#   'former',
#   'apple',
#   'evangelist',
#   'wanwinteresting',
#   'fact',
#   'take',
#   'consideration',
#   'preso',
#   'paul',
#   'adam',
#   'rt',
#   'google',
#   'circleipad',
#   'two',
#   'launch',
#   'buzz',
#   'two',
#   'thousand',
#   'eleven',
#   'link',
#   'viart',
#   'want',
#   'win',
#   'ipad',
#   'get',
#   'casert',
#   'many',
#   'ask',
#   'last',
#   'night',
#   'free',
#   'android',
#   'phone',
#   'sign',
#   'urthots',
#   'com',
#   'visit',
#   'urthots',
#   'com',
#   'promoipad',
#   'two',
#   'acquire',
#   'thanks',
#   'perserverance',
#   'one',
#   'vote',
#   'husband',
#   'year',
#   'checkrt',
#   'alive',
#   'loving',
#   'great',
#   'talk',
#   'jonathan',
#   'dahl',
#   'google',
#   'marissa',
#   'mayerbarry',
#   'diller',
#   'ipad',
#   'newspaper',
#   'app',
#   'ipad',
#   'supersedesteve',
#   'job',
#   'position',
#   'iphone',
#   'device',
#   'make',
#   'china',
#   'suicide',
#   'rate',
#   'high',
#   'sell',
#   'dreamrt',
#   'bring',
#   'great',
#   'toys',
#   'demos',
#   'thanks',
#   'include',
#   'look',
#   'booth',
#   'right',
#   'next',
#   'googlegd',
#   'idea',
#   'rt',
#   'google',
#   'tweet',
#   'new',
#   'think',
#   'speak',
#   'mark',
#   'belinsky',
#   'panelgoogle',
#   'party',
#   'best',
#   'ever',
#   'get',
#   'buttgoogle',
#   'test',
#   'check',
#   'thing',
#   'jig',
#   'austinrt',
#   'explanation',
#   'continue',
#   'success',
#   'apple',
#   'existence',
#   'godnext',
#   'presentation',
#   'google',
#   'marissa',
#   'mayer',
#   'great',
#   'austin',
#   'convention',
#   'center',
#   'linkwould',
#   'love',
#   'google',
#   'say',
#   'want',
#   'knowapple',
#   'set',
#   'open',
#   'popup',
#   'shop',
#   'austin',
#   'six',
#   'th',
#   'con',
#   'sxsw',
#   'link',
#   'viaipad',
#   'two',
#   'go',
#   'sale',
#   'three',
#   'pm',
#   'look',
#   'thirty',
#   'two',
#   'gig',
#   'color',
#   'preferencenews',
#   'lot',
#   'ipad',
#   'bash',
#   'everyone',
#   'want',
#   'one',
#   'even',
#   'consistent',
#   'themetech',
#   'use',
#   'ipad',
#   'find',
#   'appointment',
#   'direction',
#   'nearby',
#   'customerlook',
#   'best',
#   'disc',
#   'create',
#   'winner',
#   'get',
#   'ipad',
#   'twort',
#   'line',
#   'wrap',
#   'around',
#   'block',
#   'ipad',
#   'two',
#   'second',
#   'day',
#   'linkanyone',
#   'read',
#   'heard',
#   'anything',
#   'google',
#   'circlegoogle',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'call',
#   'circle',
#   'link',
#   'brazil',
#   'orkut',
#   'user',
#   'waitmany',
#   'use',
#   'apple',
#   'one',
#   'use',
#   'window',
#   'voluntarilybrilliant',
#   'set',
#   'pop',
#   'store',
#   'downtown',
#   'austin',
#   'sell',
#   'ton',
#   'ipad',
#   'two',
#   'attendee',
#   'course',
#   'linkrt',
#   'zazzle',
#   'gear',
#   'hit',
#   'look',
#   'tweet',
#   'come',
#   'create',
#   'iphone',
#   'caselast',
#   'day',
#   'come',
#   'last',
#   'day',
#   'iphone',
#   'makeryhope',
#   'year',
#   'festival',
#   'crashy',
#   'year',
#   'iphone',
#   'appfolk',
#   'lonely',
#   'planet',
#   'iphone',
#   'guide',
#   'austin',
#   'free',
#   'week',
#   'linknew',
#   'iphone',
#   'autocorrect',
#   'already',
#   'tried',
#   'change',
#   'coworkers',
#   'visigoth',
#   'go',
#   'long',
#   'five',
#   'daygoogle',
#   'launching',
#   'product',
#   'linkrt',
#   'sxsw',
#   'attendees',
#   'come',
#   'see',
#   'booth',
#   'one',
#   'thousand',
#   'four',
#   'hundred',
#   'fifteen',
#   'trade',
#   'show',
#   'might',
#   'win',
#   'ipad',
#   'twochris',
#   'messina',
#   'google',
#   'drop',
#   'knowledge',
#   'web',
#   'identity',
#   'come',
#   'hyatt',
#   'right',
#   'moveipad',
#   'two',
#   'available',
#   'online',
#   'order',
#   'go',
#   'get',
#   'urlisten',
#   'marissa',
#   'meyer',
#   'head',
#   'google',
#   'social',
#   'get',
#   'grill',
#   'jc',
#   'penney',
#   'lolrt',
#   'apple',
#   'school',
#   'marketing',
#   'expert',
#   'linkapple',
#   'school',
#   'marketing',
#   'expert',
#   'cnet',
#   'blog',
#   'linkipad',
#   'store',
#   'sell',
#   'everything',
#   'except',
#   'sixty',
#   'four',
#   'gig',
#   'wifi',
#   'whitevolunteer',
#   'lot',
#   'bore',
#   'expect',
#   'thumb',
#   'already',
#   'get',
#   'tire',
#   'extreme',
#   'usagewifi',
#   'android',
#   'geek',
#   'nearby',
#   'please',
#   'try',
#   'share',
#   'frostwire',
#   'link',
#   'issue',
#   'updatemovie',
#   'star',
#   'moody',
#   'director',
#   'well',
#   'fine',
#   'guy',
#   'really',
#   'attract',
#   'crowd',
#   'one',
#   'show',
#   'ipad',
#   'twogoogle',
#   'doodle',
#   'always',
#   'strive',
#   'respect',
#   'complement',
#   'original',
#   'artworkhire',
#   'marketer',
#   'designer',
#   'creatives',
#   'social',
#   'medium',
#   'pro',
#   'come',
#   'see',
#   'booth',
#   'one',
#   'thousand',
#   'four',
#   'hundred',
#   'fifteen',
#   'trade',
#   'show',
#   'might',
#   'win',
#   'ipad',
#   'twosurprise',
#   'line',
#   'google',
#   'bing',
#   'wrap',
#   'austin',
#   'hilton',
#   'would',
#   'askballroom',
#   'talk',
#   'cool',
#   'project',
#   'obv',
#   'love',
#   'google',
#   'art',
#   'projectone',
#   'producer',
#   'go',
#   'hopefully',
#   'free',
#   'iphone',
#   'apps',
#   'dlcurious',
#   'know',
#   'devs',
#   'think',
#   'ref',
#   'iphone',
#   'android',
#   'development',
#   'buzz',
#   'still',
#   ...]]

# %%
vectorizer.fit_transform(X_val)
# Out:
# <1015x3010 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15515 stored elements in Compressed Sparse Row format>

# %%
X_val
# Out:
# 1402    Startups: Free Premium Service on your  one st...
# 4801    Umm. Hello!! What about Android?! RT  Awesome ...
# 2356     Congrats on your iPhone app being featured at...
# 1484    like that is bad RT  Sitting at a bar listenin...
# 2427    UBER BRAND SMART: Going To move a ton of iPad ...
#                               ...
# 9176        lol iPhone,weak. Get on that Lumia level bruh
# 1499    Hmm...cannot get Twitter searches to update in...
# 3291    Abba has gotten dissed at  two  #sxsw panels i...
# 9119    L.A. School District Officially Ends $ one . t...
# 2211    In #SXSW Ballroom D for  from  \none seat rese...
# Name: processed_text, Length: 1015, dtype: object

# %%
X_val
# Out:
# 1402    Startups: Free Premium Service on your  one st...
# 4801    Umm. Hello!! What about Android?! RT  Awesome ...
# 2356     Congrats on your iPhone app being featured at...
# 1484    like that is bad RT  Sitting at a bar listenin...
# 2427    UBER BRAND SMART: Going To move a ton of iPad ...
#                               ...
# 9176        lol iPhone,weak. Get on that Lumia level bruh
# 1499    Hmm...cannot get Twitter searches to update in...
# 3291    Abba has gotten dissed at  two  #sxsw panels i...
# 9119    L.A. School District Officially Ends $ one . t...
# 2211    In #SXSW Ballroom D for  from  \none seat rese...
# Name: processed_text, Length: 1015, dtype: object

# %%
fn.reporting(LG_GS_Neg.best_estimator_,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       836
#            1       0.78      0.78      0.78       179
#
#     accuracy                           0.92      1015
#    macro avg       0.87      0.86      0.87      1015
# weighted avg       0.92      0.92      0.92      1015

# %%
cross_val_df.history
# Out:
#                                Name  mean_accuracy  std_accuracy  \
# 0                      Baseline_svm       0.928094      0.001399
# 1                           SVM_BOW       0.928094      0.000916
# 2                         SVM_TFIDF       0.928595      0.000853
# 3                    Baseline Dummy       0.863880      0.009635
# 4                         SVM_TFIDF       0.928595      0.000853
# 5                    Baseline Bayes       0.929264      0.002727
# 6           Baseline Random Forrest       0.931104      0.002925
# 7                    Logistic_TFIDF       0.913545      0.009138
# 8                    Logistic_TFIDF       0.898662      0.006983
# 9                      Logistic_BOW       0.862876      0.006099
# 10                   Logistic_TFIDF       0.867057      0.004164
# 11        Tuned Logistic Regression       0.867057      0.004164
# 12                        Tuned_SVM       0.856020      0.003234
# 13                Baseline Logistic       0.829766      0.008388
# 14                          Grid RF       0.722408      0.026052
# 15       Base Log Additional Tweets       0.926268      0.003799
# 16  Grid Logistic Additional Tweets       0.929345      0.004527
#
#     mean_precision  std_precision  mean_recall  std_recall   mean_f1  \
# 0         0.822222       0.093953     0.055855    0.023476  0.102999
# 1         0.796667       0.112744     0.060300    0.020735  0.110521
# 2         0.806883       0.110288     0.066991    0.018701  0.122359
# 3         0.081676       0.036418     0.069139    0.026880  0.066957
# 4         0.790476       0.122706     0.071436    0.026914  0.128624
# 5         0.614499       0.087212     0.144994    0.028733  0.234251
# 6         0.665598       0.120304     0.167291    0.037383  0.274529
# 7         0.395436       0.086763     0.299001    0.072966  0.339969
# 8         0.357625       0.031299     0.437453    0.025999  0.393250
# 9         0.285229       0.022435     0.553308    0.062936  0.376122
# 10        0.300116       0.021531     0.584544    0.057838  0.396524
# 11        0.300116       0.021531     0.584544    0.057838  0.396524
# 12        0.284699       0.009235     0.611411    0.053870  0.388186
# 13        0.245816       0.022980     0.615780    0.062758  0.351303
# 14        0.156377       0.006583     0.642747    0.046535  0.249126
# 15        0.787183       0.014182     0.797329    0.020037  0.792012
# 16        0.793723       0.017728     0.809902    0.019774  0.801488
#
#       std_f1                            notes
# 0   0.042225
# 1   0.036022                        ngram 1,2
# 2   0.031673                        ngram_1,2
# 3   0.012847
# 4   0.043989                        ngram_1,1
# 5   0.043402
# 6   0.049378
# 7   0.078817                       N_grams2,2
# 8   0.028001                       N_grams1,2
# 9   0.032752                      N_Grams_1,2
# 10  0.032114                       N_grams1,1
# 11  0.032114
# 12  0.018418
# 13  0.033441  Balanced Weights/Ngrams 1,1,BoW
# 14  0.015882       Grid Search Random Forrest
# 15  0.011487
# 16  0.012629

# %% [markdown]
# ### Baseline Compliment Bayes

# %%
Comp_Bayes_Added_Neg = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2))),
        ('cnb', ComplementNB())
    ]
)

# %%
Comp_Bayes_Added_Neg.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('cnb', ComplementNB())])

# %%
cross_val_df.cross_val_report(Comp_Bayes_Added_Neg,'Comp Bayes Added Negs',X_train,y_train)
# Out:
# [0.8877394467601365, 0.3717404546672839, 0.9759869568300521]

# %%
fn.reporting(Comp_Bayes_Added_Neg,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       836
#            1       0.96      0.42      0.58       179
#
#     accuracy                           0.89      1015
#    macro avg       0.93      0.71      0.76      1015
# weighted avg       0.90      0.89      0.88      1015

# %% [markdown]
# ### Tuned Bayes

# %%
param_grid = {'cnb__alpha': [0.01, 0.1, 0.5, 1.0, 10.0],
               'tfidf__ngram_range': [(1, 1), (1,2),(1,3)],'tfidf__use_idf':[True,False],
              'cnb__class_prior': [None, [.17, .83]],
                'cnb__fit_prior': [True, False]
                                      }

# %%
# %%time

CB_GS_Added_Neg = GridSearchCV(estimator=Baseline_CB,param_grid=param_grid,cv=5,scoring=two_scorer,refit=True)
CB_GS_Added_Neg.fit(X_train,y_train)
# Out:
# CPU times: user 4min 31s, sys: 4.72 s, total: 4min 36s
# Wall time: 4min 36s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(ngram_range=(1, 2))),
#                                        ('cnb', ComplementNB())]),
#              param_grid={'cnb__alpha': [0.01, 0.1, 0.5, 1.0, 10.0],
#                          'cnb__class_prior': [None, [0.17, 0.83]],
#                          'cnb__fit_prior': [True, False],
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'tfidf__use_idf': [True, False]},
#              scoring=make_scorer(fbeta_score, beta=2))

# %%
cross_val_df.cross_val_report(CB_GS_Added_Neg.best_estimator_,'Comp Bayes Added Negs',X_train,y_train)
# Out:
# [0.9080502463054186, 0.7973148802417095, 0.7143107999349358]

# %%
validation_scores.report(CB_GS_Added_Neg.best_estimator_,'Tuned Comp Bayes Added Neg',X_val,y_val)
# Out:
# [0.9152709359605912, 0.7988826815642458, 0.7409326424870466]

# %%
CB_GS_Added_Neg.best_params_
# Out:
# {'cnb__alpha': 0.1,
#  'cnb__class_prior': None,
#  'cnb__fit_prior': True,
#  'tfidf__ngram_range': (1, 1),
#  'tfidf__use_idf': False}

# %%
fn.reporting(CB_GS_Added_Neg.best_estimator_,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       836
#            1       0.74      0.80      0.77       179
#
#     accuracy                           0.92      1015
#    macro avg       0.85      0.87      0.86      1015
# weighted avg       0.92      0.92      0.92      1015

# %%
validation_scores.history
# Out:
#                               Name  accuracy  precision    recall        f1  \
# 0                      Baseline CB  0.926471   0.538462  0.125000  0.202899
# 1                   Logistic_TFIDF  0.901070   0.390244  0.571429  0.463768
# 2                  Tune Comp Bayes  0.840909   0.259542  0.607143  0.363636
# 3                   Logistic_TFIDF  0.871658   0.318182  0.625000  0.421687
# 4                baseline_logistic  0.827540   0.248276  0.642857  0.358209
# 5                     Logistic_BOW  0.874332   0.327273  0.642857  0.433735
# 6                   Tuned Logistic  0.827540   0.248276  0.642857  0.358209
# 7       Grid Search Random Forrest  0.655080   0.141844  0.714286  0.236686
# 8  Grid Logistic Addtiional Tweets  0.922167   0.780899  0.776536  0.778711
# 9       Tuned Comp Bayes Added Neg  0.915271   0.740933  0.798883  0.768817
#
#              notes
# 0
# 1       N_gram_1,2
# 2
# 3       N_gram_1,1
# 4  n_grams 1,1,BoW
# 5       N_gram_1,2
# 6
# 7
# 8
# 9

# %% [markdown]
# ### Random Forrest

# %%
Baseline_RF_Add_Neg = Pipeline(
    [
        ('tfidf',TfidfVectorizer(ngram_range=(1,2))),
        ('RF', RandomForestClassifier())
    ]
)

# %%
Baseline_RF_Add_Neg.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('RF', RandomForestClassifier())])

# %%
cross_val_df.cross_val_report(Baseline_RF_Add_Neg,'Baseline Random Forrest_Add_Examples',X_train,y_train)
# Out:
# [0.947070253884047, 0.7225481835237934, 0.9626208426521625]

# %%
cross_val_df.history
# Out:
#                                     Name  mean_accuracy  std_accuracy  \
# 0                           Baseline_svm       0.928094      0.001399
# 1                                SVM_BOW       0.928094      0.000916
# 2                              SVM_TFIDF       0.928595      0.000853
# 3                         Baseline Dummy       0.863880      0.009635
# 4                              SVM_TFIDF       0.928595      0.000853
# 5                         Baseline Bayes       0.929264      0.002727
# 6                Baseline Random Forrest       0.931104      0.002925
# 7                         Logistic_TFIDF       0.913545      0.009138
# 8                  Comp Bayes Added Negs       0.887739      0.004822
# 9                         Logistic_TFIDF       0.898662      0.006983
# 10                          Logistic_BOW       0.862876      0.006099
# 11                        Logistic_TFIDF       0.867057      0.004164
# 12             Tuned Logistic Regression       0.867057      0.004164
# 13                             Tuned_SVM       0.856020      0.003234
# 14                     Baseline Logistic       0.829766      0.008388
# 15                               Grid RF       0.722408      0.026052
# 19  Baseline Random Forrest_Add_Examples       0.947070      0.005791
# 16                 Comp Bayes Added Negs       0.908050      0.008261
# 17            Base Log Additional Tweets       0.926268      0.003799
# 18       Grid Logistic Additional Tweets       0.929345      0.004527
#
#     mean_precision  std_precision  mean_recall  std_recall   mean_f1  \
# 0         0.822222       0.093953     0.055855    0.023476  0.102999
# 1         0.796667       0.112744     0.060300    0.020735  0.110521
# 2         0.806883       0.110288     0.066991    0.018701  0.122359
# 3         0.081676       0.036418     0.069139    0.026880  0.066957
# 4         0.790476       0.122706     0.071436    0.026914  0.128624
# 5         0.614499       0.087212     0.144994    0.028733  0.234251
# 6         0.665598       0.120304     0.167291    0.037383  0.274529
# 7         0.395436       0.086763     0.299001    0.072966  0.339969
# 8         0.975987       0.014207     0.371740    0.025968  0.537941
# 9         0.357625       0.031299     0.437453    0.025999  0.393250
# 10        0.285229       0.022435     0.553308    0.062936  0.376122
# 11        0.300116       0.021531     0.584544    0.057838  0.396524
# 12        0.300116       0.021531     0.584544    0.057838  0.396524
# 13        0.284699       0.009235     0.611411    0.053870  0.388186
# 14        0.245816       0.022980     0.615780    0.062758  0.351303
# 15        0.156377       0.006583     0.642747    0.046535  0.249126
# 19        0.962621       0.009011     0.722548    0.025791  0.823759
# 16        0.714311       0.023215     0.797315    0.026714  0.753355
# 17        0.787183       0.014182     0.797329    0.020037  0.792012
# 18        0.793723       0.017728     0.809902    0.019774  0.801488
#
#       std_f1                            notes
# 0   0.042225
# 1   0.036022                        ngram 1,2
# 2   0.031673                        ngram_1,2
# 3   0.012847
# 4   0.043989                        ngram_1,1
# 5   0.043402
# 6   0.049378
# 7   0.078817                       N_grams2,2
# 8   0.028075
# 9   0.028001                       N_grams1,2
# 10  0.032752                      N_Grams_1,2
# 11  0.032114                       N_grams1,1
# 12  0.032114
# 13  0.018418
# 14  0.033441  Balanced Weights/Ngrams 1,1,BoW
# 15  0.015882       Grid Search Random Forrest
# 19  0.013715
# 16  0.022040
# 17  0.011487
# 18  0.012629

# %%
X_train
# Out:
# 3827    SXSW : Mistakes Made Building Netflix for iPho...
# 8496    Great visualisation of the ghost movement logi...
# 4606     No iPhone? No worries. Drop into one of our v...
# 3483     i heard the downtown location sold $ one m in...
# 3222    Google before you tweet" is the new "think bef...
#                               ...
# 72      Gowalla's  promises to launch Foursquare check...
# 2820    As the geeks leave Austin and the music people...
# 7318    Clearly Apple has another daylight savings tim...
# 957     Apple to open pop up store at #SXSW in time fo...
# 1310    I sort of wish the pop-up Apple Store only sol...
# Name: processed_text, Length: 8124, dtype: object

# %%
random_grid = {'RF__class_weight': ["balanced", "balanced_subsample"], 'tfidf__ngram_range': [(1, 1), (1,2),(1,3)],'tfidf__use_idf':[True,False],
                                    'RF__max_depth': [3,4,5,6,7,8,9,10, 15, 20, 30, None],'RF__min_samples_split': [2,4,6,8]}

# %%
# %%time
import warnings
import sklearn.exceptions
warnings.filterwarnings("ignore", category=sklearn.exceptions.UndefinedMetricWarning)
halving_cv = HalvingGridSearchCV(Baseline_RF,param_grid=random_grid,scoring=two_scorer, n_jobs=-1, min_resources="exhaust", factor=3, cv=5)
halving_cv.fit(X_train,y_train)
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ...
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# CPU times: user 33.9 s, sys: 3.92 s, total: 37.8 s
# Wall time: 9min 1s
# HalvingGridSearchCV(estimator=Pipeline(steps=[('tfidf',
#                                                TfidfVectorizer(ngram_range=(1,
#                                                                             2))),
#                                               ('RF',
#                                                RandomForestClassifier())]),
#                     n_jobs=-1,
#                     param_grid={'RF__class_weight': ['balanced',
#                                                      'balanced_subsample'],
#                                 'RF__max_depth': [3, 4, 5, 6, 7, 8, 9, 10, 15,
#                                                   20, 30, None],
#                                 'RF__min_samples_split': [2, 4, 6, 8],
#                                 'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                                 'tfidf__use_idf': [True, False]},
#                     scoring=make_scorer(fbeta_score, beta=2))

# %%
halving_cv.best_params_
# Out:
# {'RF__class_weight': 'balanced',
#  'RF__max_depth': 20,
#  'RF__min_samples_split': 8,
#  'tfidf__ngram_range': (1, 1),
#  'tfidf__use_idf': False}

# %%
RF_GS_Added_Neg.best_params_

# %%
cross_val_df.cross_val_report(halving_cv.best_estimator_,'Random Forrest Added Negs Halving Search',X_train,y_train)
# Out:
# [0.9356219780219781, 0.7260276309056797, 0.9125037864906203]

# %%
# %%time
cross_val_df.cross_val_report(RF_GS_Added_Neg.best_estimator_,'Random Forrest Added Negs Grid Search',X_train,y_train)

# %%
validation_scores.report(halving_cv.best_estimator_,'Random Forrest Added Negs Halving Grid Search',X_val,y_val)
# Out:
# [0.9280788177339901, 0.6983240223463687, 0.8680555555555556]

# %%
fn.reporting(halving_cv.best_estimator_,X_val,y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       836
#            1       0.87      0.70      0.77       179
#
#     accuracy                           0.93      1015
#    macro avg       0.90      0.84      0.87      1015
# weighted avg       0.93      0.93      0.92      1015

# %%
validation_scores.history
# Out:
#                                              Name  accuracy  precision  \
# 0                                     Baseline CB  0.926471   0.538462
# 1                                  Logistic_TFIDF  0.901070   0.390244
# 2                                 Tune Comp Bayes  0.840909   0.259542
# 3                                  Logistic_TFIDF  0.871658   0.318182
# 4                               baseline_logistic  0.827540   0.248276
# 5                                    Logistic_BOW  0.874332   0.327273
# 6                                  Tuned Logistic  0.827540   0.248276
# 10  Random Forrest Added Negs Halving Grid Search  0.928079   0.868056
# 7                      Grid Search Random Forrest  0.655080   0.141844
# 8                 Grid Logistic Addtiional Tweets  0.922167   0.780899
# 9                      Tuned Comp Bayes Added Neg  0.915271   0.740933
#
#       recall        f1            notes
# 0   0.125000  0.202899
# 1   0.571429  0.463768       N_gram_1,2
# 2   0.607143  0.363636
# 3   0.625000  0.421687       N_gram_1,1
# 4   0.642857  0.358209  n_grams 1,1,BoW
# 5   0.642857  0.433735       N_gram_1,2
# 6   0.642857  0.358209
# 10  0.698324  0.773994
# 7   0.714286  0.236686
# 8   0.776536  0.778711
# 9   0.798883  0.768817

# %%
cross_val_df.history
# Out:
#                                         Name  mean_accuracy  std_accuracy  \
# 0                               Baseline_svm       0.928094      0.001399
# 1                                    SVM_BOW       0.928094      0.000916
# 2                                  SVM_TFIDF       0.928595      0.000853
# 3                             Baseline Dummy       0.863880      0.009635
# 4                                  SVM_TFIDF       0.928595      0.000853
# 5                             Baseline Bayes       0.929264      0.002727
# 6                    Baseline Random Forrest       0.931104      0.002925
# 7                             Logistic_TFIDF       0.913545      0.009138
# 8                      Comp Bayes Added Negs       0.887739      0.004822
# 9                             Logistic_TFIDF       0.898662      0.006983
# 10                              Logistic_BOW       0.862876      0.006099
# 11                            Logistic_TFIDF       0.867057      0.004164
# 12                 Tuned Logistic Regression       0.867057      0.004164
# 13                                 Tuned_SVM       0.856020      0.003234
# 14                         Baseline Logistic       0.829766      0.008388
# 15                                   Grid RF       0.722408      0.026052
# 16      Baseline Random Forrest_Add_Examples       0.947070      0.005791
# 20  Random Forrest Added Negs Halving Search       0.935622      0.004925
# 17                     Comp Bayes Added Negs       0.908050      0.008261
# 18                Base Log Additional Tweets       0.926268      0.003799
# 19           Grid Logistic Additional Tweets       0.929345      0.004527
#
#     mean_precision  std_precision  mean_recall  std_recall   mean_f1  \
# 0         0.822222       0.093953     0.055855    0.023476  0.102999
# 1         0.796667       0.112744     0.060300    0.020735  0.110521
# 2         0.806883       0.110288     0.066991    0.018701  0.122359
# 3         0.081676       0.036418     0.069139    0.026880  0.066957
# 4         0.790476       0.122706     0.071436    0.026914  0.128624
# 5         0.614499       0.087212     0.144994    0.028733  0.234251
# 6         0.665598       0.120304     0.167291    0.037383  0.274529
# 7         0.395436       0.086763     0.299001    0.072966  0.339969
# 8         0.975987       0.014207     0.371740    0.025968  0.537941
# 9         0.357625       0.031299     0.437453    0.025999  0.393250
# 10        0.285229       0.022435     0.553308    0.062936  0.376122
# 11        0.300116       0.021531     0.584544    0.057838  0.396524
# 12        0.300116       0.021531     0.584544    0.057838  0.396524
# 13        0.284699       0.009235     0.611411    0.053870  0.388186
# 14        0.245816       0.022980     0.615780    0.062758  0.351303
# 15        0.156377       0.006583     0.642747    0.046535  0.249126
# 16        0.962621       0.009011     0.722548    0.025791  0.823759
# 20        0.912504       0.015382     0.726028    0.021412  0.798776
# 17        0.714311       0.023215     0.797315    0.026714  0.753355
# 18        0.787183       0.014182     0.797329    0.020037  0.792012
# 19        0.793723       0.017728     0.809902    0.019774  0.801488
#
#       std_f1                            notes
# 0   0.042225
# 1   0.036022                        ngram 1,2
# 2   0.031673                        ngram_1,2
# 3   0.012847
# 4   0.043989                        ngram_1,1
# 5   0.043402
# 6   0.049378
# 7   0.078817                       N_grams2,2
# 8   0.028075
# 9   0.028001                       N_grams1,2
# 10  0.032752                      N_Grams_1,2
# 11  0.032114                       N_grams1,1
# 12  0.032114
# 13  0.018418
# 14  0.033441  Balanced Weights/Ngrams 1,1,BoW
# 15  0.015882       Grid Search Random Forrest
# 16  0.013715
# 20  0.023309
# 17  0.022040
# 18  0.011487
# 19  0.012629

# %% [markdown]
# The best model appears to be logistic regression with the grid search parameters, that may be the best model for trying on the test data. I will also try to make a model with a neural network.

# %%
cross_val_df.history.to_csv('cross_val_scores')
validation_scores.history.to_csv('val_scores')

# %%
filename = 'final_logistic.sav'
pickle.dump(LG_GS_Neg, open(filename, 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 2>()
#       1 filename = 'final_logistic.sav'
# ----> 2 pickle.dump(LG_GS_Neg, open(filename, 'wb'))
#
# NameError: name 'LG_GS_Neg' is not defined

# %%
LG_GS_Neg = pickle.load(open('final_logistic.sav', 'rb'))

# %%
fn.reporting(LG_GS_Neg.best_estimator_,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       837
#            1       0.77      0.86      0.81       179
#
#     accuracy                           0.93      1016
#    macro avg       0.87      0.90      0.88      1016
# weighted avg       0.93      0.93      0.93      1016
